# %% [markdown]
# | Description
#
# Authors of notebook: Mateus Balda and Alessandro Bof
#
# Reference paper and dataset: https://www.frontiersin.org/journals/psychiatry/articles/10.3389/fpsyt.2021.707581/full
#
# | Notebook structure
# 0. Setup and Imports
# 1. Utility Functions
# 2. Data Loading and Preprocessing
# 3. Data Preparation for Training
# 4. Model Definition
# 5. Training and Evaluation
# 6. Results
# 7. Conclusions, Problems, and Limitations
#
# | Training
# 1. Multiclass classification for `y` specific.disorder
# 2. Synthetic data (CTGAN)
# 3. Training all features

# %% [markdown]
# ## | 0. Setup and Imports

# %%
# !pip install -q pytorch_tabnet;

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from IPython.display import display, HTML
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.impute import KNNImputer

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.decomposition import PCA
from sklearn.model_selection import StratifiedKFold

from warnings import filterwarnings
filterwarnings('ignore')

torch.__version__
# Out:
# '1.13.1+cu117'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
np.random.seed(123)
torch.manual_seed(123)

# %% [markdown]
# ## | 1. Utility Functions

# %% [markdown]
# ### 1. OUTLIERS

# %%
def detect_outliers_summary(df):
    outliers_summary = {}

    for col in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_limit = Q1 - 1.5 * IQR
        upper_limit = Q3 + 1.5 * IQR

        outliers = df[(df[col] < lower_limit) | (df[col] > upper_limit)][col]
        
        outliers_summary[col] = {
            'num_outliers': len(outliers),
            'percent_outliers': len(outliers) / len(df) * 100,
            'outliers': outliers.tolist(),
            'lower_limit': lower_limit,
            'upper_limit': upper_limit
        }

    return pd.DataFrame(outliers_summary).T


def treat_all_outliers_iqr(df, factor=1.5):
    df_treated = df.copy()
    
    for column in df_treated.select_dtypes(include=[np.number]).columns:
        Q1 = np.percentile(df_treated[column], 25)
        Q3 = np.percentile(df_treated[column], 75)
        IQR = Q3 - Q1

        lower_bound = Q1 - factor * IQR
        upper_bound = Q3 + factor * IQR

        df_treated[column] = np.clip(df_treated[column], lower_bound, upper_bound)

    return df_treated

# %% [markdown]
# ### 2. NANS

# %%
def remove_missing_columns(df, threshold=0.5):
    limit = int(threshold * len(df))
    df = df.dropna(thresh=limit, axis=1)
    return df
    
def find_most_null_column(df, threshold=0.5):
    null_ratios = df.isnull().mean()
    for col, ration in null_ratios.items():
        if ration > threshold:
            return col
    return None

def analyze_missing_values(df):
    missing_values = df.isnull().sum()
    missing_values = missing_values[missing_values > 0]
    total_number_nans = df.isnull().sum().sum()
    
    return missing_values, total_number_nans

def handle_nans(df):
    columns_with_nans = df.columns[df.isnull().any()].tolist()
    
    knn_imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
    
    df_imputed = pd.DataFrame(knn_imputer.fit_transform(df[columns_with_nans]),
                                columns=columns_with_nans)
    
    df[columns_with_nans] = df_imputed[columns_with_nans]
    
    return df

# %% [markdown]
# ## | 2. Data Loading and Preprocessing

# %%
df = pd.read_csv('../input/eeg-psychiatric-disorders-dataset/EEG.machinelearing_data_BRMH.csv')
df_synthetic = pd.read_csv('../input/synthetic-samples-specific-disorder-ctgan/synthetic_samples_specific_disorder_ctgan.csv', index_col=0)

df.shape, df_synthetic.shape
# Out:
# ((945, 1149), (1443, 1144))

# %%
df_synthetic.head()
# Out:
#          age  education          IQ  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0  12.486723  12.720248  111.652880          2.725357         21.452343
# 1  18.546245  14.794858   91.973729          4.684256         35.090543
# 2  13.599379  11.907947  107.347258          9.349618         19.421081
# 3  27.346908  12.815714   82.375051         34.597320         50.193828
# 4  15.558836  19.125513  108.652151         -1.817344         29.857772
#
#    AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  \
# 0        27.299812        19.019614        25.373663        22.539893
# 1        25.702844        21.747822        20.096341         6.902994
# 2        31.597079        24.319588        11.128257         1.524109
# 3         8.127347        23.540958        30.025157        17.017312
# 4        20.471747        24.993812        15.728950        18.494554
#
#    AB.A.delta.g.F8  ...  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0        14.994883  ...              26.880195              57.820169
# 1         9.496179  ...              45.567550              25.359201
# 2        10.764051  ...              11.019094              31.597541
# 3         0.138230  ...              33.195094               1.373304
# 4         2.248556  ...              40.036583              31.316394
#
#    COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0              72.340303             113.228991              56.707236
# 1              81.145683              97.401796               1.298894
# 2              48.291539             111.414746              56.116052
# 3              56.348701              98.378207              -3.453199
# 4              65.225965              62.629056              14.402702
#
#    COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0              54.023712               5.539792              38.782711
# 1              83.881808              24.405675              13.098263
# 2              39.928965              19.604073              24.049729
# 3              69.421351              -9.791777               9.909273
# 4               5.156964               1.741342              41.310525
#
#    COH.F.gamma.r.O1.s.O2  specific.disorder
# 0              -5.282597      Schizophrenia
# 1              40.959226      Schizophrenia
# 2              79.182487      Schizophrenia
# 3              83.766819      Schizophrenia
# 4              53.742409      Schizophrenia
#
# [5 rows x 1144 columns]

# %%
# Checking / imputing Nan

output1 = analyze_missing_values(df)
output2 = find_most_null_column(df)
df = remove_missing_columns(df)
output3 = analyze_missing_values(df)
df = handle_nans(df)

display(output1)
display(HTML('<hr>'))
display(output2)
display(HTML('<hr>'))
display(output3)
display(df.shape)
display(HTML('<hr>'))
display(df.isna().sum().sum())
display(df)
# Out:
# (education        15
#  IQ               13
#  Unnamed: 122    945
#  dtype: int64,
#  973)
# <hr>
# 'Unnamed: 122'
# <hr>
# (education    15
#  IQ           13
#  dtype: int64,
#  28)
# (945, 1148)
# <hr>
# 0
#      no. sex   age    eeg.date  education          IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30   13.43871  101.580472  Addictive disorder
# 1      2   M  37.0    2012.9.6    6.00000  120.000000  Addictive disorder
# 2      3   M  32.0   2012.9.10   16.00000  113.000000  Addictive disorder
# 3      4   M  35.0   2012.10.8   18.00000  126.000000  Addictive disorder
# 4      5   M  36.0  2012.10.18   16.00000  112.000000  Addictive disorder
# ..   ...  ..   ...         ...        ...         ...                 ...
# 940  941   M  22.0   2014.8.28   13.00000  116.000000     Healthy control
# 941  942   M  26.0   2014.9.19   13.00000  118.000000     Healthy control
# 942  943   M  26.0   2014.9.27   16.00000  113.000000     Healthy control
# 943  944   M  24.0   2014.9.20   13.00000  107.000000     Healthy control
# 944  945   M  21.0  2015.10.23   13.00000  105.000000     Healthy control
#
#         specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0    Alcohol use disorder         35.998557         21.717375  ...
# 1    Alcohol use disorder         13.425118         11.002916  ...
# 2    Alcohol use disorder         29.941780         27.544684  ...
# 3    Alcohol use disorder         21.496226         21.846832  ...
# 4    Alcohol use disorder         37.775667         33.607679  ...
# ..                    ...               ...               ...  ...
# 940       Healthy control         41.851823         36.771496  ...
# 941       Healthy control         18.986856         19.401387  ...
# 942       Healthy control         28.781317         32.369230  ...
# 943       Healthy control         19.929100         25.196375  ...
# 944       Healthy control         65.195346         69.241972  ...
#
#      COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0                55.989192              16.739679              23.452271
# 1                45.595619              17.510824              26.777368
# 2                99.475453              70.654171              39.131547
# 3                59.986561              63.822201              36.478254
# 4                61.462720              59.166097              51.465531
# ..                     ...                    ...                    ...
# 940              82.905657              34.850706              63.970519
# 941              65.917918              66.700117              44.756285
# 942              61.040959              27.632209              45.552852
# 943              99.113664              48.328934              41.248470
# 944              78.600293              68.255430              70.687410
#
#      COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                45.678820              30.167520              16.918761
# 1                28.201062              57.108861              32.375401
# 2                69.920996              71.063644              38.534505
# 3                47.117006              84.658376              24.724096
# 4                58.635415              80.685608              62.138436
# ..                     ...                    ...                    ...
# 940              63.982003              51.244725              62.203684
# 941              49.787513              98.905995              54.021304
# 942              33.638817              46.690983              19.382928
# 943              28.192238              48.665743              42.007147
# 944              74.433908              74.294750              53.254681
#
#      COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                48.850427               9.422630              34.507082
# 1                60.351749              13.900981              57.831848
# 2                69.908764              27.180532              64.803155
# 3                50.299349              35.319695              79.822944
# 4                75.888749              61.003944              87.455509
# ..                     ...                    ...                    ...
# 940              62.062237              31.013031              31.183413
# 941              93.902401              52.740396              92.807331
# 942              41.050717               7.045821              41.962451
# 943              28.735945              27.176500              27.529522
# 944              72.755265              47.810386              80.166825
#
#      COH.F.gamma.r.O1.s.O2
# 0                28.613029
# 1                43.463261
# 2                31.485799
# 3                41.141873
# 4                70.531662
# ..                     ...
# 940              98.325230
# 941              56.320868
# 942              19.092111
# 943              20.028446
# 944              64.380273
#
# [945 rows x 1148 columns]

# %%
X = df.iloc[:,8:]
target_name = 'specific.disorder'
target = df[target_name]
quantitative_features = df.loc[:, ['age', 'education', 'IQ']]

assert X.shape[0] == target.shape[0] == quantitative_features.shape[0], "Inconsistent number of samples across datasets"

X.shape, target.shape, quantitative_features.shape
# Out:
# ((945, 1140), (945,), (945, 3))

# %%
df_real = pd.concat([quantitative_features, X, target], axis=1)

df_combined = pd.concat([df_real, df_synthetic], axis=0).reset_index(drop=True)

X = df_combined.iloc[:, 3:-1]
quantitative_features = df_combined.loc[:, ['age', 'education', 'IQ']]
target = df_combined[target_name]
X_concatenated = pd.concat([quantitative_features, X], axis=1)

assert target.index.equals(X.index) and target.index.equals(X_concatenated.index), "Indices of target and features do not match"

X.shape, target.shape, quantitative_features.shape, X_concatenated.shape
# Out:
# ((2388, 1140), (2388,), (2388, 3), (2388, 1143))

# %%
CLASS_NAMES = np.unique(target).tolist()
CLASS_NAMES
# Out:
# ['Acute stress disorder',
#  'Adjustment disorder',
#  'Alcohol use disorder',
#  'Behavioral addiction disorder',
#  'Bipolar disorder',
#  'Depressive disorder',
#  'Healthy control',
#  'Obsessive compulsitve disorder',
#  'Panic disorder',
#  'Posttraumatic stress disorder',
#  'Schizophrenia',
#  'Social anxiety disorder']

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(target)
y_encoded = pd.Series(y_encoded, name=target_name)
(pd.DataFrame(y_encoded)).value_counts()
# Out:
# specific.disorder
# 0                    199
# 1                    199
# 2                    199
# 3                    199
# 4                    199
# 5                    199
# 6                    199
# 7                    199
# 8                    199
# 9                    199
# 10                   199
# 11                   199
# Name: count, dtype: int64

# %%
df_union = pd.concat([X_concatenated, pd.DataFrame(y_encoded)], axis=1)

assert df_union.shape[0] == X_concatenated.shape[0] == y_encoded.shape[0], "Inconsistent number of samples in the union DataFrame"
assert X_concatenated.index.equals(y_encoded.index), "Indices of features and target do not match in the union DataFrame"

display(df_union.shape)
display(df_union)
display(df_union.isna().sum().sum())
# Out:
# (2388, 1144)
#             age  education          IQ  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0     57.000000  13.438710  101.580472         35.998557         21.717375
# 1     37.000000   6.000000  120.000000         13.425118         11.002916
# 2     32.000000  16.000000  113.000000         29.941780         27.544684
# 3     35.000000  18.000000  126.000000         21.496226         21.846832
# 4     36.000000  16.000000  112.000000         37.775667         33.607679
# ...         ...        ...         ...               ...               ...
# 2383  41.024158  21.338190  137.508387          3.897484          6.600202
# 2384  55.499292  12.990695   80.726012          1.785503          8.328488
# 2385  56.778344  18.878593  138.331332         19.287896          0.594376
# 2386  46.136011  15.122581  121.912296          2.706127         25.875806
# 2387  33.183874  12.984464  120.547680         13.655639         16.646781
#
#       AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  \
# 0           21.518280        26.825048        26.611516        25.732649
# 1           11.942516        15.272216        14.151570        12.456034
# 2           17.150159        23.608960        27.087811        13.541237
# 3           17.364316        13.833701        14.100954        13.100939
# 4           21.865556        21.771413        22.854536        21.456377
# ...               ...              ...              ...              ...
# 2383        11.625845        13.960831        37.676382        30.945274
# 2384        30.755002        21.065130        37.601797        26.809310
# 2385        41.444599        41.514412        41.861253        21.975527
# 2386        38.546985        24.760639         8.782951        20.560540
# 2387        31.093434        20.784400        40.626022        63.503731
#
#       AB.A.delta.g.F8  ...  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0           16.563408  ...              16.739679              23.452271
# 1            8.436832  ...              17.510824              26.777368
# 2           16.523963  ...              70.654171              39.131547
# 3           14.613650  ...              63.822201              36.478254
# 4           15.969042  ...              59.166097              51.465531
# ...               ...  ...                    ...                    ...
# 2383        11.202927  ...              47.175044              25.935223
# 2384        29.847553  ...              58.018386              62.111926
# 2385        26.688986  ...              87.730085              66.344053
# 2386        15.400793  ...              72.473839              80.167055
# 2387        18.258908  ...              78.344326             109.938131
#
#       COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                 45.678820              30.167520              16.918761
# 1                 28.201062              57.108861              32.375401
# 2                 69.920996              71.063644              38.534505
# 3                 47.117006              84.658376              24.724096
# 4                 58.635415              80.685608              62.138436
# ...                     ...                    ...                    ...
# 2383              80.153058             110.550349              58.663091
# 2384              86.762645              62.187134              16.427574
# 2385              85.630108              85.603845               1.485398
# 2386              86.254430              59.050772              45.043488
# 2387             108.540203              53.452303              -3.917687
#
#       COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                 48.850427               9.422630              34.507082
# 1                 60.351749              13.900981              57.831848
# 2                 69.908764              27.180532              64.803155
# 3                 50.299349              35.319695              79.822944
# 4                 75.888749              61.003944              87.455509
# ...                     ...                    ...                    ...
# 2383              41.690877              -5.156744              81.195055
# 2384              66.377102              18.068607              46.783253
# 2385              49.566798              24.463577             111.231455
# 2386              80.776484             -13.517152              99.023455
# 2387              54.348445              -9.749098             105.386819
#
#       COH.F.gamma.r.O1.s.O2  specific.disorder
# 0                 28.613029                  2
# 1                 43.463261                  2
# 2                 31.485799                  2
# 3                 41.141873                  2
# 4                 70.531662                  2
# ...                     ...                ...
# 2383               2.983596                  1
# 2384              44.923293                  1
# 2385              93.531027                  1
# 2386               3.971395                  1
# 2387              78.966977                  1
#
# [2388 rows x 1144 columns]
# 0

# %%
# detecting outliers

outliers_summary = detect_outliers_summary(df_union)
outliers_summary.to_csv('outliers_summary.csv', index=True)
outliers_summary['num_outliers'].sum()
# Out:
# 62813

# %% [markdown]
# ## | 3. Data Preparation for Training

# %%
# X_concatenated
# y_encoded

# %%
TRAIN_RATIO = 0.7
VAL_RATIO = 0.15

CRITERION = nn.CrossEntropyLoss()
SCALER = StandardScaler()

NUM_EPOCHS = 500

# %% [markdown]
# ## | 4. Model Definition

# %%
from pytorch_tabnet.tab_model import TabNetClassifier

# %%
clf = TabNetClassifier(
    optimizer_fn=torch.optim.Adam,
    scheduler_params={"step_size":30, 
                        "gamma":0.9},
    scheduler_fn=torch.optim.lr_scheduler.StepLR,
    verbose=5,
)

# %% [markdown]
# ## | 5. Training and Evaluation

# %%
X_concatenated.shape[1]
len(np.unique(y_encoded))
# Out:
# 12

# %%
def print_accuracy_report(accuracy, y_true, y_pred, class_names, verbose=True):
    report = classification_report(y_true, y_pred, target_names=class_names, digits=4, output_dict=True)
    cm = confusion_matrix(y_true, y_pred)
    
    sensitivities = {}
    specificities = {}

    for i, class_name in enumerate(class_names):
        TP = cm[i, i]
        FN = np.sum(cm[i, :]) - TP
        FP = np.sum(cm[:, i]) - TP
        TN = np.sum(cm) - (TP + FP + FN)

        sensitivity = TP / (TP + FN) if (TP + FN) != 0 else 0.0
        specificity = TN / (TN + FP) if (TN + FP) != 0 else 0.0

        sensitivities[class_name] = sensitivity
        specificities[class_name] = specificity

    if verbose:
        print(f"\n-- Test Accuracy: {accuracy:.2f}%")
        print("\n-- Classification Report:\n", classification_report(y_true, y_pred, target_names=class_names, digits=4))

        print("-- Sensitivity (Recall) por classe:")
        for cls, sens in sensitivities.items():
            print(f"  - {cls}: {sens:.4f}")

        print("\n-- Specificity por classe:")
        for cls, spec in specificities.items():
            print(f"  - {cls}: {spec:.4f}")

    return report, sensitivities, specificities

# %%
from sklearn.metrics import accuracy_score

num_folds = 5
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

def cross_validate_model(
    X, y, 
    class_names, num_classes
):
    accuracies = []
    aucs = []
    sensitivities = []
    specificities = []

    for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
        print(f"\n- Fold {fold + 1}/{num_folds}")
        
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        X_train_scaled = SCALER.fit_transform(X_train)
        X_test_scaled = SCALER.transform(X_test)
        
        y_train_array = y_train.to_numpy()
        y_test_array = y_test.to_numpy()
        
        clf.fit(
            X_train_scaled, y_train_array,
            eval_set=[(X_train_scaled, y_train_array), (X_test_scaled, y_test_array)],
            eval_name=['train', 'test'],
            eval_metric=['accuracy'],
            max_epochs=200, patience=60,
            batch_size=48, virtual_batch_size=24,
            num_workers=0,
            weights=1,
            drop_last=True
        )
        
        y_pred = clf.predict(X_test_scaled)
        y_proba = clf.predict_proba(X_test_scaled)

        acc = accuracy_score(y_test_array, y_pred)

        report, fold_sensitivities, fold_specificities = print_accuracy_report(
            acc, y_test_array, y_pred, class_names
        )

        auc = roc_auc_score(y_test_array, y_proba, multi_class='ovr', average='macro', labels=np.arange(num_classes))
        
        accuracies.append(acc)
        aucs.append(auc)
        sensitivities.append(fold_sensitivities)
        specificities.append(fold_specificities)

    # Calculate mean and std for all metrics across folds
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    
    mean_sens = {cls: np.mean([s[cls] for s in sensitivities]) for cls in class_names}
    std_sens = {cls: np.std([s[cls] for s in sensitivities]) for cls in class_names}
    
    mean_spec = {cls: np.mean([s[cls] for s in specificities]) for cls in class_names}
    std_spec = {cls: np.std([s[cls] for s in specificities]) for cls in class_names}
    
    return {
        'mean_accuracy': mean_accuracy,
        'std_accuracy': std_accuracy,
        'mean_auc': mean_auc,
        'std_auc': std_auc,
        'mean_sens': mean_sens,
        'std_sens': std_sens,
        'mean_spec': mean_spec,
        'std_spec': std_spec
    }

# %%
cv_results = cross_validate_model(
    X=X_concatenated, 
    y=y_encoded,
    class_names=CLASS_NAMES,
    num_classes=len(np.unique(y_encoded)),
)
# Out:
# - Fold 1/5
# epoch 0  | loss: 2.672   | train_accuracy: 0.12513 | test_accuracy: 0.11715 |  0:00:01s
# epoch 5  | loss: 1.3888  | train_accuracy: 0.58115 | test_accuracy: 0.59414 |  0:00:08s
# epoch 10 | loss: 1.12448 | train_accuracy: 0.63298 | test_accuracy: 0.63389 |  0:00:15s
# epoch 15 | loss: 1.03147 | train_accuracy: 0.66911 | test_accuracy: 0.659   |  0:00:22s
# epoch 20 | loss: 1.00732 | train_accuracy: 0.68377 | test_accuracy: 0.66946 |  0:00:29s
# epoch 25 | loss: 1.01153 | train_accuracy: 0.69372 | test_accuracy: 0.67573 |  0:00:36s
# epoch 30 | loss: 0.9532  | train_accuracy: 0.69372 | test_accuracy: 0.67992 |  0:00:43s
# epoch 35 | loss: 0.86632 | train_accuracy: 0.72408 | test_accuracy: 0.7113  |  0:00:50s
# epoch 40 | loss: 0.88779 | train_accuracy: 0.72618 | test_accuracy: 0.70921 |  0:00:57s
# epoch 45 | loss: 0.91197 | train_accuracy: 0.73403 | test_accuracy: 0.70921 |  0:01:04s
# epoch 50 | loss: 0.8737  | train_accuracy: 0.73351 | test_accuracy: 0.70921 |  0:01:11s
# epoch 55 | loss: 0.87237 | train_accuracy: 0.72984 | test_accuracy: 0.7113  |  0:01:17s
# epoch 60 | loss: 0.81127 | train_accuracy: 0.73298 | test_accuracy: 0.67782 |  0:01:24s
# epoch 65 | loss: 0.81535 | train_accuracy: 0.7356  | test_accuracy: 0.70293 |  0:01:31s
# epoch 70 | loss: 0.77652 | train_accuracy: 0.74084 | test_accuracy: 0.7113  |  0:01:39s
# epoch 75 | loss: 0.75939 | train_accuracy: 0.74398 | test_accuracy: 0.70293 |  0:01:45s
# epoch 80 | loss: 0.78966 | train_accuracy: 0.74712 | test_accuracy: 0.7113  |  0:01:52s
# epoch 85 | loss: 0.78228 | train_accuracy: 0.74607 | test_accuracy: 0.7113  |  0:01:59s
# epoch 90 | loss: 0.77558 | train_accuracy: 0.75079 | test_accuracy: 0.70502 |  0:02:06s
# epoch 95 | loss: 0.71721 | train_accuracy: 0.74555 | test_accuracy: 0.70084 |  0:02:13s
# epoch 100| loss: 0.80312 | train_accuracy: 0.74817 | test_accuracy: 0.7113  |  0:02:20s
# epoch 105| loss: 0.76667 | train_accuracy: 0.76021 | test_accuracy: 0.67782 |  0:02:27s
# epoch 110| loss: 0.75957 | train_accuracy: 0.75916 | test_accuracy: 0.7113  |  0:02:34s
#
# Early stopping occurred at epoch 111 with best_epoch = 51 and best_test_accuracy = 0.71548
#
# -- Test Accuracy: 0.72%
#
# -- Classification Report:
#                                  precision    recall  f1-score   support
#
#          Acute stress disorder     1.0000    0.8000    0.8889        40
#            Adjustment disorder     1.0000    0.8000    0.8889        40
#           Alcohol use disorder     0.8462    0.5500    0.6667        40
#  Behavioral addiction disorder     0.5833    0.7179    0.6437        39
#               Bipolar disorder     1.0000    0.6250    0.7692        40
#            Depressive disorder     0.2556    0.8500    0.3931        40
#                Healthy control     0.7045    0.7750    0.7381        40
# Obsessive compulsitve disorder     1.0000    0.7750    0.8732        40
#                 Panic disorder     1.0000    0.6500    0.7879        40
#  Posttraumatic stress disorder     1.0000    0.7692    0.8696        39
#                  Schizophrenia     1.0000    0.4750    0.6441        40
#        Social anxiety disorder     1.0000    0.8000    0.8889        40
#
#                       accuracy                         0.7155       478
#                      macro avg     0.8658    0.7156    0.7543       478
#                   weighted avg     0.8661    0.7155    0.7543       478
#
# -- Sensitivity (Recall) por classe:
#   - Acute stress disorder: 0.8000
#   - Adjustment disorder: 0.8000
#   - Alcohol use disorder: 0.5500
#   - Behavioral addiction disorder: 0.7179
#   - Bipolar disorder: 0.6250
#   - Depressive disorder: 0.8500
#   - Healthy control: 0.7750
#   - Obsessive compulsitve disorder: 0.7750
#   - Panic disorder: 0.6500
#   - Posttraumatic stress disorder: 0.7692
#   - Schizophrenia: 0.4750
#   - Social anxiety disorder: 0.8000
#
# -- Specificity por classe:
#   - Acute stress disorder: 1.0000
#   - Adjustment disorder: 1.0000
#   - Alcohol use disorder: 0.9909
#   - Behavioral addiction disorder: 0.9544
#   - Bipolar disorder: 1.0000
#   - Depressive disorder: 0.7740
#   - Healthy control: 0.9703
#   - Obsessive compulsitve disorder: 1.0000
#   - Panic disorder: 1.0000
#   - Posttraumatic stress disorder: 1.0000
#   - Schizophrenia: 1.0000
#   - Social anxiety disorder: 1.0000
#
# - Fold 2/5
# epoch 0  | loss: 2.67028 | train_accuracy: 0.10576 | test_accuracy: 0.12134 |  0:00:01s
# epoch 5  | loss: 1.53793 | train_accuracy: 0.55812 | test_accuracy: 0.51883 |  0:00:08s
# epoch 10 | loss: 1.0432  | train_accuracy: 0.68115 | test_accuracy: 0.62552 |  0:00:15s
# epoch 15 | loss: 0.97265 | train_accuracy: 0.69738 | test_accuracy: 0.65063 |  0:00:21s
# epoch 20 | loss: 0.95189 | train_accuracy: 0.69843 | test_accuracy: 0.65272 |  0:00:28s
# epoch 25 | loss: 0.91738 | train_accuracy: 0.70209 | test_accuracy: 0.66109 |  0:00:36s
# epoch 30 | loss: 0.93585 | train_accuracy: 0.70733 | test_accuracy: 0.66109 |  0:00:42s
# epoch 35 | loss: 0.88347 | train_accuracy: 0.71152 | test_accuracy: 0.66318 |  0:00:49s
# epoch 40 | loss: 0.959   | train_accuracy: 0.71257 | test_accuracy: 0.65481 |  0:00:56s
# epoch 45 | loss: 0.94832 | train_accuracy: 0.7199  | test_accuracy: 0.64435 |  0:01:03s
# epoch 50 | loss: 0.92704 | train_accuracy: 0.72513 | test_accuracy: 0.66318 |  0:01:10s
# epoch 55 | loss: 0.86667 | train_accuracy: 0.72408 | test_accuracy: 0.65063 |  0:01:17s
# epoch 60 | loss: 0.8712  | train_accuracy: 0.7267  | test_accuracy: 0.6569  |  0:01:23s
# epoch 65 | loss: 0.84866 | train_accuracy: 0.73455 | test_accuracy: 0.66318 |  0:01:30s
# epoch 70 | loss: 0.78002 | train_accuracy: 0.73927 | test_accuracy: 0.67155 |  0:01:37s
# epoch 75 | loss: 0.80116 | train_accuracy: 0.73927 | test_accuracy: 0.66109 |  0:01:44s
# epoch 80 | loss: 0.81342 | train_accuracy: 0.74188 | test_accuracy: 0.66527 |  0:01:51s
# epoch 85 | loss: 0.7998  | train_accuracy: 0.74712 | test_accuracy: 0.64435 |  0:01:58s
# epoch 90 | loss: 0.77458 | train_accuracy: 0.75654 | test_accuracy: 0.66527 |  0:02:05s
# epoch 95 | loss: 0.73213 | train_accuracy: 0.76178 | test_accuracy: 0.659   |  0:02:12s
# epoch 100| loss: 0.77789 | train_accuracy: 0.70052 | test_accuracy: 0.60251 |  0:02:19s
# epoch 105| loss: 0.74722 | train_accuracy: 0.76335 | test_accuracy: 0.65272 |  0:02:26s
# epoch 110| loss: 0.76216 | train_accuracy: 0.77068 | test_accuracy: 0.66736 |  0:02:33s
# epoch 115| loss: 0.73821 | train_accuracy: 0.76597 | test_accuracy: 0.66527 |  0:02:40s
# epoch 120| loss: 0.74452 | train_accuracy: 0.78063 | test_accuracy: 0.659   |  0:02:47s
# epoch 125| loss: 0.70724 | train_accuracy: 0.78848 | test_accuracy: 0.66109 |  0:02:53s
# epoch 130| loss: 0.66562 | train_accuracy: 0.79424 | test_accuracy: 0.65272 |  0:03:00s
# epoch 135| loss: 0.665   | train_accuracy: 0.79634 | test_accuracy: 0.64854 |  0:03:07s
# epoch 140| loss: 0.62887 | train_accuracy: 0.79791 | test_accuracy: 0.64854 |  0:03:14s
#
# Early stopping occurred at epoch 141 with best_epoch = 81 and best_test_accuracy = 0.67573
#
# -- Test Accuracy: 0.68%
#
# -- Classification Report:
#                                  precision    recall  f1-score   support
#
#          Acute stress disorder     0.8500    0.8500    0.8500        40
#            Adjustment disorder     1.0000    0.8500    0.9189        40
#           Alcohol use disorder     0.8800    0.5500    0.6769        40
#  Behavioral addiction disorder     0.7500    0.6000    0.6667        40
#               Bipolar disorder     1.0000    0.5750    0.7302        40
#            Depressive disorder     0.2258    0.8750    0.3590        40
#                Healthy control     0.6111    0.5641    0.5867        39
# Obsessive compulsitve disorder     1.0000    0.6500    0.7879        40
#                 Panic disorder     1.0000    0.7500    0.8571        40
#  Posttraumatic stress disorder     1.0000    0.7500    0.8571        40
#                  Schizophrenia     0.7895    0.3750    0.5085        40
#        Social anxiety disorder     1.0000    0.7179    0.8358        39
#
#                       accuracy                         0.6757       478
#                      macro avg     0.8422    0.6756    0.7196       478
#                   weighted avg     0.8424    0.6757    0.7196       478
#
# -- Sensitivity (Recall) por classe:
#   - Acute stress disorder: 0.8500
#   - Adjustment disorder: 0.8500
#   - Alcohol use disorder: 0.5500
#   - Behavioral addiction disorder: 0.6000
#   - Bipolar disorder: 0.5750
#   - Depressive disorder: 0.8750
#   - Healthy control: 0.5641
#   - Obsessive compulsitve disorder: 0.6500
#   - Panic disorder: 0.7500
#   - Posttraumatic stress disorder: 0.7500
#   - Schizophrenia: 0.3750
#   - Social anxiety disorder: 0.7179
#
# -- Specificity por classe:
#   - Acute stress disorder: 0.9863
#   - Adjustment disorder: 1.0000
#   - Alcohol use disorder: 0.9932
#   - Behavioral addiction disorder: 0.9817
#   - Bipolar disorder: 1.0000
#   - Depressive disorder: 0.7260
#   - Healthy control: 0.9681
#   - Obsessive compulsitve disorder: 1.0000
#   - Panic disorder: 1.0000
#   - Posttraumatic stress disorder: 1.0000
#   - Schizophrenia: 0.9909
#   - Social anxiety disorder: 1.0000
#
# - Fold 3/5
# epoch 0  | loss: 2.66109 | train_accuracy: 0.11937 | test_accuracy: 0.12134 |  0:00:01s
# epoch 5  | loss: 1.48818 | train_accuracy: 0.56283 | test_accuracy: 0.55439 |  0:00:08s
# epoch 10 | loss: 1.15639 | train_accuracy: 0.61414 | test_accuracy: 0.61925 |  0:00:15s
# epoch 15 | loss: 1.09453 | train_accuracy: 0.64921 | test_accuracy: 0.65272 |  0:00:21s
# epoch 20 | loss: 1.07996 | train_accuracy: 0.65812 | test_accuracy: 0.66109 |  0:00:28s
# epoch 25 | loss: 1.06905 | train_accuracy: 0.65969 | test_accuracy: 0.67155 |  0:00:35s
# epoch 30 | loss: 1.09495 | train_accuracy: 0.66283 | test_accuracy: 0.67782 |  0:00:42s
# epoch 35 | loss: 1.01048 | train_accuracy: 0.65812 | test_accuracy: 0.67155 |  0:00:49s
# epoch 40 | loss: 1.05371 | train_accuracy: 0.66702 | test_accuracy: 0.67364 |  0:00:56s
# epoch 45 | loss: 1.06858 | train_accuracy: 0.66702 | test_accuracy: 0.67364 |  0:01:03s
# epoch 50 | loss: 1.03917 | train_accuracy: 0.66702 | test_accuracy: 0.67364 |  0:01:10s
# epoch 55 | loss: 0.99967 | train_accuracy: 0.67173 | test_accuracy: 0.67992 |  0:01:16s
# epoch 60 | loss: 0.97739 | train_accuracy: 0.66911 | test_accuracy: 0.67782 |  0:01:23s
# epoch 65 | loss: 1.00918 | train_accuracy: 0.66545 | test_accuracy: 0.67992 |  0:01:31s
# epoch 70 | loss: 0.94341 | train_accuracy: 0.67068 | test_accuracy: 0.67155 |  0:01:37s
# epoch 75 | loss: 0.95289 | train_accuracy: 0.67592 | test_accuracy: 0.68201 |  0:01:44s
# epoch 80 | loss: 0.98424 | train_accuracy: 0.67749 | test_accuracy: 0.67782 |  0:01:51s
# epoch 85 | loss: 0.97231 | train_accuracy: 0.67435 | test_accuracy: 0.67573 |  0:01:58s
# epoch 90 | loss: 0.98293 | train_accuracy: 0.67801 | test_accuracy: 0.66946 |  0:02:05s
# epoch 95 | loss: 0.92237 | train_accuracy: 0.68063 | test_accuracy: 0.67573 |  0:02:12s
# epoch 100| loss: 1.01099 | train_accuracy: 0.68115 | test_accuracy: 0.67992 |  0:02:19s
# epoch 105| loss: 0.97384 | train_accuracy: 0.67958 | test_accuracy: 0.67782 |  0:02:26s
# epoch 110| loss: 0.96923 | train_accuracy: 0.68586 | test_accuracy: 0.67573 |  0:02:33s
# epoch 115| loss: 0.96265 | train_accuracy: 0.6911  | test_accuracy: 0.67782 |  0:02:40s
# epoch 120| loss: 0.97452 | train_accuracy: 0.69058 | test_accuracy: 0.67155 |  0:02:46s
# epoch 125| loss: 0.95462 | train_accuracy: 0.69058 | test_accuracy: 0.67364 |  0:02:53s
# epoch 130| loss: 0.91722 | train_accuracy: 0.68901 | test_accuracy: 0.67573 |  0:03:00s
# epoch 135| loss: 0.96953 | train_accuracy: 0.69215 | test_accuracy: 0.6569  |  0:03:08s
#
# Early stopping occurred at epoch 139 with best_epoch = 79 and best_test_accuracy = 0.6841
#
# -- Test Accuracy: 0.68%
#
# -- Classification Report:
#                                  precision    recall  f1-score   support
#
#          Acute stress disorder     1.0000    0.7000    0.8235        40
#            Adjustment disorder     1.0000    0.8500    0.9189        40
#           Alcohol use disorder     1.0000    0.5500    0.7097        40
#  Behavioral addiction disorder     1.0000    0.5250    0.6885        40
#               Bipolar disorder     1.0000    0.6750    0.8060        40
#            Depressive disorder     0.2120    1.0000    0.3498        39
#                Healthy control     0.9565    0.5500    0.6984        40
# Obsessive compulsitve disorder     1.0000    0.6500    0.7879        40
#                 Panic disorder     0.9615    0.6410    0.7692        39
#  Posttraumatic stress disorder     1.0000    0.8250    0.9041        40
#                  Schizophrenia     0.8750    0.5250    0.6563        40
#        Social anxiety disorder     0.9667    0.7250    0.8286        40
#
#                       accuracy                         0.6841       478
#                      macro avg     0.9143    0.6847    0.7451       478
#                   weighted avg     0.9157    0.6841    0.7458       478
#
# -- Sensitivity (Recall) por classe:
#   - Acute stress disorder: 0.7000
#   - Adjustment disorder: 0.8500
#   - Alcohol use disorder: 0.5500
#   - Behavioral addiction disorder: 0.5250
#   - Bipolar disorder: 0.6750
#   - Depressive disorder: 1.0000
#   - Healthy control: 0.5500
#   - Obsessive compulsitve disorder: 0.6500
#   - Panic disorder: 0.6410
#   - Posttraumatic stress disorder: 0.8250
#   - Schizophrenia: 0.5250
#   - Social anxiety disorder: 0.7250
#
# -- Specificity por classe:
#   - Acute stress disorder: 1.0000
#   - Adjustment disorder: 1.0000
#   - Alcohol use disorder: 1.0000
#   - Behavioral addiction disorder: 1.0000
#   - Bipolar disorder: 1.0000
#   - Depressive disorder: 0.6697
#   - Healthy control: 0.9977
#   - Obsessive compulsitve disorder: 1.0000
#   - Panic disorder: 0.9977
#   - Posttraumatic stress disorder: 1.0000
#   - Schizophrenia: 0.9932
#   - Social anxiety disorder: 0.9977
#
# - Fold 4/5
# epoch 0  | loss: 2.68337 | train_accuracy: 0.09942 | test_accuracy: 0.09644 |  0:00:01s
# epoch 5  | loss: 1.54653 | train_accuracy: 0.55364 | test_accuracy: 0.5304  |  0:00:08s
# epoch 10 | loss: 1.20826 | train_accuracy: 0.60701 | test_accuracy: 0.59539 |  0:00:15s
# epoch 15 | loss: 1.11979 | train_accuracy: 0.65934 | test_accuracy: 0.65199 |  0:00:22s
# epoch 20 | loss: 1.08926 | train_accuracy: 0.663   | test_accuracy: 0.6499  |  0:00:29s
# epoch 25 | loss: 1.04316 | train_accuracy: 0.67242 | test_accuracy: 0.66038 |  0:00:36s
# epoch 30 | loss: 1.05163 | train_accuracy: 0.66876 | test_accuracy: 0.66876 |  0:00:43s
# epoch 35 | loss: 0.97282 | train_accuracy: 0.67295 | test_accuracy: 0.67296 |  0:00:49s
# epoch 40 | loss: 0.99694 | train_accuracy: 0.68237 | test_accuracy: 0.67086 |  0:00:56s
# epoch 45 | loss: 1.001   | train_accuracy: 0.68812 | test_accuracy: 0.65618 |  0:01:03s
# epoch 50 | loss: 0.99532 | train_accuracy: 0.6876  | test_accuracy: 0.65409 |  0:01:10s
# epoch 55 | loss: 0.95561 | train_accuracy: 0.69388 | test_accuracy: 0.66876 |  0:01:17s
# epoch 60 | loss: 0.90293 | train_accuracy: 0.70382 | test_accuracy: 0.67505 |  0:01:24s
# epoch 65 | loss: 0.88312 | train_accuracy: 0.70068 | test_accuracy: 0.67296 |  0:01:31s
# epoch 70 | loss: 0.85206 | train_accuracy: 0.70853 | test_accuracy: 0.65618 |  0:01:38s
# epoch 75 | loss: 0.89866 | train_accuracy: 0.70382 | test_accuracy: 0.67296 |  0:01:45s
# epoch 80 | loss: 0.88394 | train_accuracy: 0.70853 | test_accuracy: 0.66667 |  0:01:51s
# epoch 85 | loss: 0.87367 | train_accuracy: 0.71795 | test_accuracy: 0.66457 |  0:01:59s
# epoch 90 | loss: 0.82783 | train_accuracy: 0.70487 | test_accuracy: 0.67505 |  0:02:05s
# epoch 95 | loss: 0.83114 | train_accuracy: 0.71638 | test_accuracy: 0.66667 |  0:02:12s
# epoch 100| loss: 0.82509 | train_accuracy: 0.71533 | test_accuracy: 0.67296 |  0:02:19s
# epoch 105| loss: 0.85349 | train_accuracy: 0.7258  | test_accuracy: 0.66038 |  0:02:26s
# epoch 110| loss: 0.79731 | train_accuracy: 0.73312 | test_accuracy: 0.65199 |  0:02:33s
# epoch 115| loss: 0.82279 | train_accuracy: 0.73626 | test_accuracy: 0.66667 |  0:02:40s
# epoch 120| loss: 0.80261 | train_accuracy: 0.7415  | test_accuracy: 0.66038 |  0:02:47s
# epoch 125| loss: 0.76509 | train_accuracy: 0.73783 | test_accuracy: 0.66247 |  0:02:54s
# epoch 130| loss: 0.75734 | train_accuracy: 0.74202 | test_accuracy: 0.65409 |  0:03:01s
# epoch 135| loss: 0.78868 | train_accuracy: 0.74097 | test_accuracy: 0.66876 |  0:03:08s
# epoch 140| loss: 0.77286 | train_accuracy: 0.75458 | test_accuracy: 0.66038 |  0:03:15s
# epoch 145| loss: 0.73178 | train_accuracy: 0.74097 | test_accuracy: 0.65828 |  0:03:22s
# epoch 150| loss: 0.77747 | train_accuracy: 0.7619  | test_accuracy: 0.66667 |  0:03:29s
# epoch 155| loss: 0.71063 | train_accuracy: 0.76243 | test_accuracy: 0.63941 |  0:03:36s
# epoch 160| loss: 0.74845 | train_accuracy: 0.76452 | test_accuracy: 0.6457  |  0:03:43s
# epoch 165| loss: 0.74722 | train_accuracy: 0.78179 | test_accuracy: 0.65199 |  0:03:50s
# epoch 170| loss: 0.66481 | train_accuracy: 0.77813 | test_accuracy: 0.65618 |  0:03:57s
# epoch 175| loss: 0.71722 | train_accuracy: 0.77603 | test_accuracy: 0.6478  |  0:04:04s
#
# Early stopping occurred at epoch 176 with best_epoch = 116 and best_test_accuracy = 0.68763
#
# -- Test Accuracy: 0.69%
#
# -- Classification Report:
#                                  precision    recall  f1-score   support
#
#          Acute stress disorder     1.0000    0.8718    0.9315        39
#            Adjustment disorder     1.0000    0.7500    0.8571        40
#           Alcohol use disorder     0.9565    0.5500    0.6984        40
#  Behavioral addiction disorder     0.6410    0.6250    0.6329        40
#               Bipolar disorder     0.9310    0.6923    0.7941        39
#            Depressive disorder     0.2759    0.8000    0.4103        40
#                Healthy control     0.7879    0.6500    0.7123        40
# Obsessive compulsitve disorder     0.8372    0.9000    0.8675        40
#                 Panic disorder     0.9600    0.6000    0.7385        40
#  Posttraumatic stress disorder     1.0000    0.7250    0.8406        40
#                  Schizophrenia     0.3696    0.4359    0.4000        39
#        Social anxiety disorder     0.8667    0.6500    0.7429        40
#
#                       accuracy                         0.6876       477
#                      macro avg     0.8021    0.6875    0.7188       477
#                   weighted avg     0.8024    0.6876    0.7189       477
#
# -- Sensitivity (Recall) por classe:
#   - Acute stress disorder: 0.8718
#   - Adjustment disorder: 0.7500
#   - Alcohol use disorder: 0.5500
#   - Behavioral addiction disorder: 0.6250
#   - Bipolar disorder: 0.6923
#   - Depressive disorder: 0.8000
#   - Healthy control: 0.6500
#   - Obsessive compulsitve disorder: 0.9000
#   - Panic disorder: 0.6000
#   - Posttraumatic stress disorder: 0.7250
#   - Schizophrenia: 0.4359
#   - Social anxiety disorder: 0.6500
#
# -- Specificity por classe:
#   - Acute stress disorder: 1.0000
#   - Adjustment disorder: 1.0000
#   - Alcohol use disorder: 0.9977
#   - Behavioral addiction disorder: 0.9680
#   - Bipolar disorder: 0.9954
#   - Depressive disorder: 0.8078
#   - Healthy control: 0.9840
#   - Obsessive compulsitve disorder: 0.9840
#   - Panic disorder: 0.9977
#   - Posttraumatic stress disorder: 1.0000
#   - Schizophrenia: 0.9338
#   - Social anxiety disorder: 0.9908
#
# - Fold 5/5
# epoch 0  | loss: 2.68625 | train_accuracy: 0.15018 | test_accuracy: 0.15514 |  0:00:01s
# epoch 5  | loss: 1.53099 | train_accuracy: 0.53951 | test_accuracy: 0.53669 |  0:00:08s
# epoch 10 | loss: 1.19897 | train_accuracy: 0.62062 | test_accuracy: 0.63941 |  0:00:15s
# epoch 15 | loss: 1.1489  | train_accuracy: 0.63579 | test_accuracy: 0.65618 |  0:00:22s
# epoch 20 | loss: 1.15375 | train_accuracy: 0.64155 | test_accuracy: 0.66247 |  0:00:29s
# epoch 25 | loss: 1.10878 | train_accuracy: 0.64155 | test_accuracy: 0.65828 |  0:00:36s
# epoch 30 | loss: 1.08924 | train_accuracy: 0.65777 | test_accuracy: 0.65828 |  0:00:43s
# epoch 35 | loss: 1.07219 | train_accuracy: 0.66196 | test_accuracy: 0.66667 |  0:00:50s
# epoch 40 | loss: 1.06254 | train_accuracy: 0.65986 | test_accuracy: 0.67925 |  0:00:57s
# epoch 45 | loss: 1.08322 | train_accuracy: 0.6719  | test_accuracy: 0.66876 |  0:01:04s
# epoch 50 | loss: 1.06955 | train_accuracy: 0.67085 | test_accuracy: 0.67086 |  0:01:11s
# epoch 55 | loss: 0.98284 | train_accuracy: 0.68184 | test_accuracy: 0.67505 |  0:01:18s
# epoch 60 | loss: 0.982   | train_accuracy: 0.68132 | test_accuracy: 0.67296 |  0:01:25s
# epoch 65 | loss: 0.96096 | train_accuracy: 0.68446 | test_accuracy: 0.67715 |  0:01:33s
# epoch 70 | loss: 0.94627 | train_accuracy: 0.68184 | test_accuracy: 0.67296 |  0:01:40s
# epoch 75 | loss: 0.95667 | train_accuracy: 0.69335 | test_accuracy: 0.67925 |  0:01:46s
# epoch 80 | loss: 1.00201 | train_accuracy: 0.70016 | test_accuracy: 0.67505 |  0:01:53s
# epoch 85 | loss: 0.98387 | train_accuracy: 0.69702 | test_accuracy: 0.68344 |  0:02:00s
# epoch 90 | loss: 0.88072 | train_accuracy: 0.70853 | test_accuracy: 0.68973 |  0:02:07s
# epoch 95 | loss: 0.85504 | train_accuracy: 0.71952 | test_accuracy: 0.68763 |  0:02:14s
# epoch 100| loss: 0.91618 | train_accuracy: 0.72057 | test_accuracy: 0.68344 |  0:02:21s
# epoch 105| loss: 0.87557 | train_accuracy: 0.72527 | test_accuracy: 0.68973 |  0:02:28s
# epoch 110| loss: 0.83498 | train_accuracy: 0.73469 | test_accuracy: 0.68973 |  0:02:35s
# epoch 115| loss: 0.84175 | train_accuracy: 0.72475 | test_accuracy: 0.68763 |  0:02:42s
# epoch 120| loss: 0.85244 | train_accuracy: 0.73783 | test_accuracy: 0.68553 |  0:02:49s
# epoch 125| loss: 0.81069 | train_accuracy: 0.73993 | test_accuracy: 0.68973 |  0:02:56s
# epoch 130| loss: 0.77512 | train_accuracy: 0.74673 | test_accuracy: 0.69182 |  0:03:03s
# epoch 135| loss: 0.78243 | train_accuracy: 0.75458 | test_accuracy: 0.69602 |  0:03:10s
# epoch 140| loss: 0.78655 | train_accuracy: 0.75406 | test_accuracy: 0.69602 |  0:03:17s
# epoch 145| loss: 0.75053 | train_accuracy: 0.74097 | test_accuracy: 0.68763 |  0:03:24s
# epoch 150| loss: 0.78529 | train_accuracy: 0.75144 | test_accuracy: 0.69602 |  0:03:31s
# epoch 155| loss: 0.69562 | train_accuracy: 0.75929 | test_accuracy: 0.7065  |  0:03:38s
# epoch 160| loss: 0.72088 | train_accuracy: 0.75563 | test_accuracy: 0.70231 |  0:03:45s
# epoch 165| loss: 0.69976 | train_accuracy: 0.76295 | test_accuracy: 0.70021 |  0:03:52s
# epoch 170| loss: 0.62066 | train_accuracy: 0.7776  | test_accuracy: 0.69602 |  0:03:59s
# epoch 175| loss: 0.72036 | train_accuracy: 0.77551 | test_accuracy: 0.68553 |  0:04:06s
# epoch 180| loss: 0.6676  | train_accuracy: 0.77603 | test_accuracy: 0.69182 |  0:04:13s
# epoch 185| loss: 0.68765 | train_accuracy: 0.79383 | test_accuracy: 0.68553 |  0:04:20s
# epoch 190| loss: 0.64278 | train_accuracy: 0.80063 | test_accuracy: 0.69602 |  0:04:27s
# epoch 195| loss: 0.68519 | train_accuracy: 0.78859 | test_accuracy: 0.69602 |  0:04:34s
# Stop training because you reached max_epochs = 200 with best_epoch = 152 and best_test_accuracy = 0.7065
#
# -- Test Accuracy: 0.71%
#
# -- Classification Report:
#                                  precision    recall  f1-score   support
#
#          Acute stress disorder     1.0000    0.8250    0.9041        40
#            Adjustment disorder     1.0000    0.7949    0.8857        39
#           Alcohol use disorder     0.8400    0.5385    0.6562        39
#  Behavioral addiction disorder     0.4630    0.6250    0.5319        40
#               Bipolar disorder     1.0000    0.7750    0.8732        40
#            Depressive disorder     0.2625    0.5250    0.3500        40
#                Healthy control     0.8387    0.6500    0.7324        40
# Obsessive compulsitve disorder     1.0000    0.8462    0.9167        39
#                 Panic disorder     1.0000    0.7250    0.8406        40
#  Posttraumatic stress disorder     1.0000    0.6250    0.7692        40
#                  Schizophrenia     0.4189    0.7750    0.5439        40
#        Social anxiety disorder     1.0000    0.7750    0.8732        40
#
#                       accuracy                         0.7065       477
#                      macro avg     0.8186    0.7066    0.7398       477
#                   weighted avg     0.8178    0.7065    0.7393       477
#
# -- Sensitivity (Recall) por classe:
#   - Acute stress disorder: 0.8250
#   - Adjustment disorder: 0.7949
#   - Alcohol use disorder: 0.5385
#   - Behavioral addiction disorder: 0.6250
#   - Bipolar disorder: 0.7750
#   - Depressive disorder: 0.5250
#   - Healthy control: 0.6500
#   - Obsessive compulsitve disorder: 0.8462
#   - Panic disorder: 0.7250
#   - Posttraumatic stress disorder: 0.6250
#   - Schizophrenia: 0.7750
#   - Social anxiety disorder: 0.7750
#
# -- Specificity por classe:
#   - Acute stress disorder: 1.0000
#   - Adjustment disorder: 1.0000
#   - Alcohol use disorder: 0.9909
#   - Behavioral addiction disorder: 0.9336
#   - Bipolar disorder: 1.0000
#   - Depressive disorder: 0.8650
#   - Healthy control: 0.9886
#   - Obsessive compulsitve disorder: 1.0000
#   - Panic disorder: 1.0000
#   - Posttraumatic stress disorder: 1.0000
#   - Schizophrenia: 0.9016
#   - Social anxiety disorder: 1.0000

# %% [markdown]
# ## | 6. Results

# %%
# dataframe 
cv_df = pd.DataFrame({
    'Metric': ['Mean Accuracy', 'Std Accuracy', 'Mean AUC', 'Std AUC'] + 
              [f'Mean Sensitivity ({cls})' for cls in CLASS_NAMES] + 
              [f'Std Sensitivity ({cls})' for cls in CLASS_NAMES] + 
              [f'Mean Specificity ({cls})' for cls in CLASS_NAMES] + 
              [f'Std Specificity ({cls})' for cls in CLASS_NAMES],
    'Value': [
        cv_results['mean_accuracy'], cv_results['std_accuracy'],
        cv_results['mean_auc'], cv_results['std_auc']
    ] + 
    [cv_results['mean_sens'][cls] for cls in CLASS_NAMES] + 
    [cv_results['std_sens'][cls] for cls in CLASS_NAMES] + 
    [cv_results['mean_spec'][cls] for cls in CLASS_NAMES] + 
    [cv_results['std_spec'][cls] for cls in CLASS_NAMES]
})

cv_df
# Out:
#                                                Metric     Value
# 0                                       Mean Accuracy  0.693889
# 1                                        Std Accuracy  0.014764
# 2                                            Mean AUC  0.932180
# 3                                             Std AUC  0.008228
# 4            Mean Sensitivity (Acute stress disorder)  0.809359
# 5              Mean Sensitivity (Adjustment disorder)  0.808974
# 6             Mean Sensitivity (Alcohol use disorder)  0.547692
# 7    Mean Sensitivity (Behavioral addiction disorder)  0.618590
# 8                 Mean Sensitivity (Bipolar disorder)  0.668462
# 9              Mean Sensitivity (Depressive disorder)  0.810000
# 10                 Mean Sensitivity (Healthy control)  0.637821
# 11  Mean Sensitivity (Obsessive compulsitve disorder)  0.764231
# 12                  Mean Sensitivity (Panic disorder)  0.673205
# 13   Mean Sensitivity (Posttraumatic stress disorder)  0.738846
# 14                   Mean Sensitivity (Schizophrenia)  0.517179
# 15         Mean Sensitivity (Social anxiety disorder)  0.733590
# 16            Std Sensitivity (Acute stress disorder)  0.059735
# 17              Std Sensitivity (Adjustment disorder)  0.037745
# 18             Std Sensitivity (Alcohol use disorder)  0.004615
# 19    Std Sensitivity (Behavioral addiction disorder)  0.061740
# 20                 Std Sensitivity (Bipolar disorder)  0.067210
# 21              Std Sensitivity (Depressive disorder)  0.157003
# 22                  Std Sensitivity (Healthy control)  0.080326
# 23   Std Sensitivity (Obsessive compulsitve disorder)  0.101349
# 24                   Std Sensitivity (Panic disorder)  0.055701
# 25    Std Sensitivity (Posttraumatic stress disorder)  0.065761
# 26                    Std Sensitivity (Schizophrenia)  0.137937
# 27          Std Sensitivity (Social anxiety disorder)  0.051828
# 28           Mean Specificity (Acute stress disorder)  0.997260
# 29             Mean Specificity (Adjustment disorder)  1.000000
# 30            Mean Specificity (Alcohol use disorder)  0.994520
# 31   Mean Specificity (Behavioral addiction disorder)  0.967556
# 32                Mean Specificity (Bipolar disorder)  0.999087
# 33             Mean Specificity (Depressive disorder)  0.768495
# 34                 Mean Specificity (Healthy control)  0.981737
# 35  Mean Specificity (Obsessive compulsitve disorder)  0.996796
# 36                  Mean Specificity (Panic disorder)  0.999087
# 37   Mean Specificity (Posttraumatic stress disorder)  1.000000
# 38                   Mean Specificity (Schizophrenia)  0.963882
# 39         Mean Specificity (Social anxiety disorder)  0.997713
# 40            Std Specificity (Acute stress disorder)  0.005479
# 41              Std Specificity (Adjustment disorder)  0.000000
# 42             Std Specificity (Alcohol use disorder)  0.003709
# 43    Std Specificity (Behavioral addiction disorder)  0.022699
# 44                 Std Specificity (Bipolar disorder)  0.001826
# 45              Std Specificity (Depressive disorder)  0.067004
# 46                  Std Specificity (Healthy control)  0.011162
# 47   Std Specificity (Obsessive compulsitve disorder)  0.006407
# 48                   Std Specificity (Panic disorder)  0.001118
# 49    Std Specificity (Posttraumatic stress disorder)  0.000000
# 50                    Std Specificity (Schizophrenia)  0.039176
# 51          Std Specificity (Social anxiety disorder)  0.003545

# %%
rows = []

rows.append({
    'Class': 'Overall',
    'Metric': 'Accuracy',
    'Mean': cv_results['mean_accuracy'],
    'Std': cv_results['std_accuracy']
})
rows.append({
    'Class': 'Overall',
    'Metric': 'AUC',
    'Mean': cv_results['mean_auc'],
    'Std': cv_results['std_auc']
})

for cls in CLASS_NAMES:
    rows.append({
        'Class': cls,
        'Metric': 'Sensitivity',
        'Mean': cv_results['mean_sens'][cls],
        'Std': cv_results['std_sens'][cls]
    })
    rows.append({
        'Class': cls,
        'Metric': 'Specificity',
        'Mean': cv_results['mean_spec'][cls],
        'Std': cv_results['std_spec'][cls]
    })

cv_df_organized = pd.DataFrame(rows)

cv_df_organized = cv_df_organized.sort_values(by=['Class', 'Metric']).reset_index(drop=True)

cv_df_organized.to_csv('cross_validation_results_multiclass_spec_tabnet.csv', index=False)

cv_df_organized
# Out:
#                              Class       Metric      Mean       Std
# 0            Acute stress disorder  Sensitivity  0.809359  0.059735
# 1            Acute stress disorder  Specificity  0.997260  0.005479
# 2              Adjustment disorder  Sensitivity  0.808974  0.037745
# 3              Adjustment disorder  Specificity  1.000000  0.000000
# 4             Alcohol use disorder  Sensitivity  0.547692  0.004615
# 5             Alcohol use disorder  Specificity  0.994520  0.003709
# 6    Behavioral addiction disorder  Sensitivity  0.618590  0.061740
# 7    Behavioral addiction disorder  Specificity  0.967556  0.022699
# 8                 Bipolar disorder  Sensitivity  0.668462  0.067210
# 9                 Bipolar disorder  Specificity  0.999087  0.001826
# 10             Depressive disorder  Sensitivity  0.810000  0.157003
# 11             Depressive disorder  Specificity  0.768495  0.067004
# 12                 Healthy control  Sensitivity  0.637821  0.080326
# 13                 Healthy control  Specificity  0.981737  0.011162
# 14  Obsessive compulsitve disorder  Sensitivity  0.764231  0.101349
# 15  Obsessive compulsitve disorder  Specificity  0.996796  0.006407
# 16                         Overall          AUC  0.932180  0.008228
# 17                         Overall     Accuracy  0.693889  0.014764
# 18                  Panic disorder  Sensitivity  0.673205  0.055701
# 19                  Panic disorder  Specificity  0.999087  0.001118
# 20   Posttraumatic stress disorder  Sensitivity  0.738846  0.065761
# 21   Posttraumatic stress disorder  Specificity  1.000000  0.000000
# 22                   Schizophrenia  Sensitivity  0.517179  0.137937
# 23                   Schizophrenia  Specificity  0.963882  0.039176
# 24         Social anxiety disorder  Sensitivity  0.733590  0.051828
# 25         Social anxiety disorder  Specificity  0.997713  0.003545

# %% [markdown]
# ## | 7. Conclusions, Problems, and Limitations

# %% [markdown]
# [need to update]
