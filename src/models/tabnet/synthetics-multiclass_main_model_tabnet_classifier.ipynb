# %% [markdown]
# | Description
#
# Authors of notebook: Mateus Balda and Alessandro Bof
#
# Reference paper and dataset: https://www.frontiersin.org/journals/psychiatry/articles/10.3389/fpsyt.2021.707581/full
#
# | Notebook structure
# 0. Setup and Imports
# 1. Utility Functions
# 2. Data Loading and Preprocessing
# 3. Data Preparation for Training
# 4. Model Definition
# 5. Training and Evaluation
# 6. Results
# 7. Conclusions, Problems, and Limitations
#
# | Training
# 1. Multiclass classification for `y` main.disorder
# 2. Synthetic data (CTGAN)
# 3. Training all features

# %% [markdown]
# ## | 0. Setup and Imports

# %%
# !pip install -q pytorch_tabnet;

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from IPython.display import display, HTML
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.impute import KNNImputer

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.decomposition import PCA
from sklearn.model_selection import StratifiedKFold

from warnings import filterwarnings
filterwarnings('ignore')

torch.__version__
# Out:
# '1.13.1+cu117'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
np.random.seed(123)
torch.manual_seed(123)

# %% [markdown]
# ## | 1. Utility Functions

# %% [markdown]
# ### 1. OUTLIERS

# %%
def detect_outliers_summary(df):
    outliers_summary = {}

    for col in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_limit = Q1 - 1.5 * IQR
        upper_limit = Q3 + 1.5 * IQR

        outliers = df[(df[col] < lower_limit) | (df[col] > upper_limit)][col]
        
        outliers_summary[col] = {
            'num_outliers': len(outliers),
            'percent_outliers': len(outliers) / len(df) * 100,
            'outliers': outliers.tolist(),
            'lower_limit': lower_limit,
            'upper_limit': upper_limit
        }

    return pd.DataFrame(outliers_summary).T


def treat_all_outliers_iqr(df, factor=1.5):
    df_treated = df.copy()
    
    for column in df_treated.select_dtypes(include=[np.number]).columns:
        Q1 = np.percentile(df_treated[column], 25)
        Q3 = np.percentile(df_treated[column], 75)
        IQR = Q3 - Q1

        lower_bound = Q1 - factor * IQR
        upper_bound = Q3 + factor * IQR

        df_treated[column] = np.clip(df_treated[column], lower_bound, upper_bound)

    return df_treated

# %% [markdown]
# ### 2. NANS

# %%
def remove_missing_columns(df, threshold=0.5):
    limit = int(threshold * len(df))
    df = df.dropna(thresh=limit, axis=1)
    return df
    
def find_most_null_column(df, threshold=0.5):
    null_ratios = df.isnull().mean()
    for col, ration in null_ratios.items():
        if ration > threshold:
            return col
    return None

def analyze_missing_values(df):
    missing_values = df.isnull().sum()
    missing_values = missing_values[missing_values > 0]
    total_number_nans = df.isnull().sum().sum()
    
    return missing_values, total_number_nans

def handle_nans(df):
    columns_with_nans = df.columns[df.isnull().any()].tolist()
    
    knn_imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
    
    df_imputed = pd.DataFrame(knn_imputer.fit_transform(df[columns_with_nans]),
                                columns=columns_with_nans)
    
    df[columns_with_nans] = df_imputed[columns_with_nans]
    
    return df

# %% [markdown]
# ## | 2. Data Loading and Preprocessing

# %%
df = pd.read_csv('../input/eeg-psychiatric-disorders-dataset/EEG.machinelearing_data_BRMH.csv')
df_synthetic = pd.read_csv('../input/synthetic-samples-main-disorder-ctgan/synthetic_samples_main_disorder_ctgan.csv', index_col=0)

df.shape, df_synthetic.shape
# Out:
# ((945, 1149), (917, 1144))

# %%
df_synthetic.head()
# Out:
#          age  education          IQ  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0  23.376377  12.043075  112.643365         27.144192         16.187808
# 1  20.786404  17.043296  113.232441         10.172036         13.424233
# 2  62.353295  13.435671   65.597080         14.793148         17.651986
# 3  19.308306  12.404831  117.544206          9.177333          6.731468
# 4  23.073199  15.074009   60.646940         27.206730          3.856561
#
#    AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  \
# 0        12.907181        23.669069        29.272920        30.599443
# 1        21.840080        23.491504        32.526876        34.392703
# 2        15.991087        25.001954        14.233273        12.183853
# 3         4.443113        21.096932         7.735151        36.469104
# 4        18.725702        22.135223        16.158441         8.871639
#
#    AB.A.delta.g.F8  ...  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0        19.087608  ...              85.181915              36.457220
# 1        13.730551  ...              73.484918              47.733036
# 2        22.903653  ...              45.342838              30.433142
# 3        25.138482  ...              88.210760              56.262836
# 4        18.606874  ...              57.424337              52.391691
#
#    COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0              78.339581              71.082923              71.358454
# 1              88.327693              76.842599             103.759471
# 2              80.407288              93.064088              92.449444
# 3              40.570765              51.369780              80.274405
# 4              84.822487              79.001387              57.053102
#
#    COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0               1.510461              21.019587              69.051350
# 1              72.031505               4.999746              85.836417
# 2              27.130648              -6.309497              97.717736
# 3              23.631445               7.374698              67.858076
# 4              32.296730              22.092730             103.311152
#
#    COH.F.gamma.r.O1.s.O2       main.disorder
# 0              97.160001  Addictive disorder
# 1             116.402084  Addictive disorder
# 2              93.094953  Addictive disorder
# 3              95.123691  Addictive disorder
# 4              64.631042  Addictive disorder
#
# [5 rows x 1144 columns]

# %%
# Checking / imputing Nan

output1 = analyze_missing_values(df)
output2 = find_most_null_column(df)
df = remove_missing_columns(df)
output3 = analyze_missing_values(df)
df = handle_nans(df)

display(output1)
display(HTML('<hr>'))
display(output2)
display(HTML('<hr>'))
display(output3)
display(df.shape)
display(HTML('<hr>'))
display(df.isna().sum().sum())
display(df)
# Out:
# (education        15
#  IQ               13
#  Unnamed: 122    945
#  dtype: int64,
#  973)
# <hr>
# 'Unnamed: 122'
# <hr>
# (education    15
#  IQ           13
#  dtype: int64,
#  28)
# (945, 1148)
# <hr>
# 0
#      no. sex   age    eeg.date  education          IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30   13.43871  101.580472  Addictive disorder
# 1      2   M  37.0    2012.9.6    6.00000  120.000000  Addictive disorder
# 2      3   M  32.0   2012.9.10   16.00000  113.000000  Addictive disorder
# 3      4   M  35.0   2012.10.8   18.00000  126.000000  Addictive disorder
# 4      5   M  36.0  2012.10.18   16.00000  112.000000  Addictive disorder
# ..   ...  ..   ...         ...        ...         ...                 ...
# 940  941   M  22.0   2014.8.28   13.00000  116.000000     Healthy control
# 941  942   M  26.0   2014.9.19   13.00000  118.000000     Healthy control
# 942  943   M  26.0   2014.9.27   16.00000  113.000000     Healthy control
# 943  944   M  24.0   2014.9.20   13.00000  107.000000     Healthy control
# 944  945   M  21.0  2015.10.23   13.00000  105.000000     Healthy control
#
#         specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0    Alcohol use disorder         35.998557         21.717375  ...
# 1    Alcohol use disorder         13.425118         11.002916  ...
# 2    Alcohol use disorder         29.941780         27.544684  ...
# 3    Alcohol use disorder         21.496226         21.846832  ...
# 4    Alcohol use disorder         37.775667         33.607679  ...
# ..                    ...               ...               ...  ...
# 940       Healthy control         41.851823         36.771496  ...
# 941       Healthy control         18.986856         19.401387  ...
# 942       Healthy control         28.781317         32.369230  ...
# 943       Healthy control         19.929100         25.196375  ...
# 944       Healthy control         65.195346         69.241972  ...
#
#      COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0                55.989192              16.739679              23.452271
# 1                45.595619              17.510824              26.777368
# 2                99.475453              70.654171              39.131547
# 3                59.986561              63.822201              36.478254
# 4                61.462720              59.166097              51.465531
# ..                     ...                    ...                    ...
# 940              82.905657              34.850706              63.970519
# 941              65.917918              66.700117              44.756285
# 942              61.040959              27.632209              45.552852
# 943              99.113664              48.328934              41.248470
# 944              78.600293              68.255430              70.687410
#
#      COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                45.678820              30.167520              16.918761
# 1                28.201062              57.108861              32.375401
# 2                69.920996              71.063644              38.534505
# 3                47.117006              84.658376              24.724096
# 4                58.635415              80.685608              62.138436
# ..                     ...                    ...                    ...
# 940              63.982003              51.244725              62.203684
# 941              49.787513              98.905995              54.021304
# 942              33.638817              46.690983              19.382928
# 943              28.192238              48.665743              42.007147
# 944              74.433908              74.294750              53.254681
#
#      COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                48.850427               9.422630              34.507082
# 1                60.351749              13.900981              57.831848
# 2                69.908764              27.180532              64.803155
# 3                50.299349              35.319695              79.822944
# 4                75.888749              61.003944              87.455509
# ..                     ...                    ...                    ...
# 940              62.062237              31.013031              31.183413
# 941              93.902401              52.740396              92.807331
# 942              41.050717               7.045821              41.962451
# 943              28.735945              27.176500              27.529522
# 944              72.755265              47.810386              80.166825
#
#      COH.F.gamma.r.O1.s.O2
# 0                28.613029
# 1                43.463261
# 2                31.485799
# 3                41.141873
# 4                70.531662
# ..                     ...
# 940              98.325230
# 941              56.320868
# 942              19.092111
# 943              20.028446
# 944              64.380273
#
# [945 rows x 1148 columns]

# %%
X = df.iloc[:,8:]
target_name = 'main.disorder'
target = df[target_name]
quantitative_features = df.loc[:, ['age', 'education', 'IQ']]

assert X.shape[0] == target.shape[0] == quantitative_features.shape[0], "Inconsistent number of samples across datasets"

X.shape, target.shape, quantitative_features.shape
# Out:
# ((945, 1140), (945,), (945, 3))

# %%
df_real = pd.concat([quantitative_features, X, target], axis=1)

df_combined = pd.concat([df_real, df_synthetic], axis=0).reset_index(drop=True)

X = df_combined.iloc[:, 3:-1]
quantitative_features = df_combined.loc[:, ['age', 'education', 'IQ']]
target = df_combined[target_name]
X_concatenated = pd.concat([quantitative_features, X], axis=1)

assert target.index.equals(X.index) and target.index.equals(X_concatenated.index), "Indices of target and features do not match"

X.shape, target.shape, quantitative_features.shape, X_concatenated.shape
# Out:
# ((1862, 1140), (1862,), (1862, 3), (1862, 1143))

# %%
CLASS_NAMES = np.unique(target).tolist()
CLASS_NAMES
# Out:
# ['Addictive disorder',
#  'Anxiety disorder',
#  'Healthy control',
#  'Mood disorder',
#  'Obsessive compulsive disorder',
#  'Schizophrenia',
#  'Trauma and stress related disorder']

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(target)
y_encoded = pd.Series(y_encoded, name=target_name)
(pd.DataFrame(y_encoded)).value_counts()
# Out:
# main.disorder
# 0                266
# 1                266
# 2                266
# 3                266
# 4                266
# 5                266
# 6                266
# Name: count, dtype: int64

# %%
df_union = pd.concat([X_concatenated, pd.DataFrame(y_encoded)], axis=1)

assert df_union.shape[0] == X_concatenated.shape[0] == y_encoded.shape[0], "Inconsistent number of samples in the union DataFrame"
assert X_concatenated.index.equals(y_encoded.index), "Indices of features and target do not match in the union DataFrame"

display(df_union.shape)
display(df_union)
display(df_union.isna().sum().sum())
# Out:
# (1862, 1144)
#             age  education          IQ  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0     57.000000  13.438710  101.580472         35.998557         21.717375
# 1     37.000000   6.000000  120.000000         13.425118         11.002916
# 2     32.000000  16.000000  113.000000         29.941780         27.544684
# 3     35.000000  18.000000  126.000000         21.496226         21.846832
# 4     36.000000  16.000000  112.000000         37.775667         33.607679
# ...         ...        ...         ...               ...               ...
# 1857  56.586838  15.910817   92.598793         58.344625         16.250204
# 1858  34.766892  16.829058   69.452233         26.380735         38.919817
# 1859  25.948962  13.414100   64.088265          6.856573         21.632333
# 1860  35.215274  18.050538   67.202613          4.865726         21.731444
# 1861  44.332310  17.187037   92.784441          9.495949         -0.639325
#
#       AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  \
# 0           21.518280        26.825048        26.611516        25.732649
# 1           11.942516        15.272216        14.151570        12.456034
# 2           17.150159        23.608960        27.087811        13.541237
# 3           17.364316        13.833701        14.100954        13.100939
# 4           21.865556        21.771413        22.854536        21.456377
# ...               ...              ...              ...              ...
# 1857        22.165892         3.017798         1.382935        23.911295
# 1858        19.233551        22.543899        17.145224         2.036416
# 1859        21.378422         9.903213        51.725818        26.871169
# 1860        21.325605        31.383891        39.464086        16.740952
# 1861        29.198259        25.873878        10.851746        26.600429
#
#       AB.A.delta.g.F8  ...  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0           16.563408  ...              16.739679              23.452271
# 1            8.436832  ...              17.510824              26.777368
# 2           16.523963  ...              70.654171              39.131547
# 3           14.613650  ...              63.822201              36.478254
# 4           15.969042  ...              59.166097              51.465531
# ...               ...  ...                    ...                    ...
# 1857         6.217182  ...               9.107626              20.435264
# 1858        -2.938821  ...              40.756644              84.770737
# 1859         6.390204  ...              84.125462              85.274250
# 1860        13.293345  ...              45.337457              14.478245
# 1861         8.099031  ...              13.560613              61.698102
#
#       COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                 45.678820              30.167520              16.918761
# 1                 28.201062              57.108861              32.375401
# 2                 69.920996              71.063644              38.534505
# 3                 47.117006              84.658376              24.724096
# 4                 58.635415              80.685608              62.138436
# ...                     ...                    ...                    ...
# 1857              63.706446              66.611018              25.983391
# 1858              93.419613              71.142697              89.953221
# 1859              51.210326              10.838181              13.540271
# 1860              81.563188              76.144551              61.625960
# 1861              30.094704              45.895766               0.359232
#
#       COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                 48.850427               9.422630              34.507082
# 1                 60.351749              13.900981              57.831848
# 2                 69.908764              27.180532              64.803155
# 3                 50.299349              35.319695              79.822944
# 4                 75.888749              61.003944              87.455509
# ...                     ...                    ...                    ...
# 1857              57.757929              56.713252              67.893062
# 1858              70.565893              48.294927              39.524151
# 1859              69.141473              63.682173              68.032213
# 1860              52.572968              93.442888              54.596480
# 1861              82.230916              57.970064              97.281033
#
#       COH.F.gamma.r.O1.s.O2  main.disorder
# 0                 28.613029              0
# 1                 43.463261              0
# 2                 31.485799              0
# 3                 41.141873              0
# 4                 70.531662              0
# ...                     ...            ...
# 1857              96.850570              4
# 1858              86.316144              4
# 1859              61.115077              4
# 1860              27.025361              4
# 1861              51.134638              4
#
# [1862 rows x 1144 columns]
# 0

# %%
# detecting outliers

outliers_summary = detect_outliers_summary(df_union)
outliers_summary.to_csv('outliers_summary.csv', index=True)
outliers_summary['num_outliers'].sum()
# Out:
# 56613

# %% [markdown]
# ## | 3. Data Preparation for Training

# %%
# X_concatenated
# y_encoded

# %%
TRAIN_RATIO = 0.7
VAL_RATIO = 0.15

CRITERION = nn.CrossEntropyLoss()
SCALER = StandardScaler()

NUM_EPOCHS = 500

# %% [markdown]
# ## | 4. Model Definition

# %%
from pytorch_tabnet.tab_model import TabNetClassifier

# %%
clf = TabNetClassifier(
    optimizer_fn=torch.optim.Adam,
    scheduler_params={"step_size":30, 
                        "gamma":0.9},
    scheduler_fn=torch.optim.lr_scheduler.StepLR,
    verbose=5,
)

# %% [markdown]
# ## | 5. Training and Evaluation

# %%
X_concatenated.shape[1]
len(np.unique(y_encoded))
# Out:
# 7

# %%
def print_accuracy_report(accuracy, y_true, y_pred, class_names, verbose=True):
    report = classification_report(y_true, y_pred, target_names=class_names, digits=4, output_dict=True)
    cm = confusion_matrix(y_true, y_pred)
    
    sensitivities = {}
    specificities = {}

    for i, class_name in enumerate(class_names):
        TP = cm[i, i]
        FN = np.sum(cm[i, :]) - TP
        FP = np.sum(cm[:, i]) - TP
        TN = np.sum(cm) - (TP + FP + FN)

        sensitivity = TP / (TP + FN) if (TP + FN) != 0 else 0.0
        specificity = TN / (TN + FP) if (TN + FP) != 0 else 0.0

        sensitivities[class_name] = sensitivity
        specificities[class_name] = specificity

    if verbose:
        print(f"\n-- Test Accuracy: {accuracy:.2f}%")
        print("\n-- Classification Report:\n", classification_report(y_true, y_pred, target_names=class_names, digits=4))

        print("-- Sensitivity (Recall) por classe:")
        for cls, sens in sensitivities.items():
            print(f"  - {cls}: {sens:.4f}")

        print("\n-- Specificity por classe:")
        for cls, spec in specificities.items():
            print(f"  - {cls}: {spec:.4f}")

    return report, sensitivities, specificities

# %%
from sklearn.metrics import accuracy_score

num_folds = 5
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

def cross_validate_model(
    X, y, 
    class_names, num_classes
):
    accuracies = []
    aucs = []
    sensitivities = []
    specificities = []

    for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
        print(f"\n- Fold {fold + 1}/{num_folds}")
        
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        X_train_scaled = SCALER.fit_transform(X_train)
        X_test_scaled = SCALER.transform(X_test)
        
        y_train_array = y_train.to_numpy()
        y_test_array = y_test.to_numpy()
        
        clf.fit(
            X_train_scaled, y_train_array,
            eval_set=[(X_train_scaled, y_train_array), (X_test_scaled, y_test_array)],
            eval_name=['train', 'test'],
            eval_metric=['accuracy'],
            max_epochs=200, patience=60,
            batch_size=48, virtual_batch_size=24,
            num_workers=0,
            weights=1,
            drop_last=True
        )
        
        y_pred = clf.predict(X_test_scaled)
        y_proba = clf.predict_proba(X_test_scaled)

        acc = accuracy_score(y_test_array, y_pred)

        report, fold_sensitivities, fold_specificities = print_accuracy_report(
            acc, y_test_array, y_pred, class_names
        )

        auc = roc_auc_score(y_test_array, y_proba, multi_class='ovr', average='macro', labels=np.arange(num_classes))
        
        accuracies.append(acc)
        aucs.append(auc)
        sensitivities.append(fold_sensitivities)
        specificities.append(fold_specificities)

    # Calculate mean and std for all metrics across folds
    mean_accuracy = np.mean(accuracies)
    std_accuracy = np.std(accuracies)
    mean_auc = np.mean(aucs)
    std_auc = np.std(aucs)
    
    mean_sens = {cls: np.mean([s[cls] for s in sensitivities]) for cls in class_names}
    std_sens = {cls: np.std([s[cls] for s in sensitivities]) for cls in class_names}
    
    mean_spec = {cls: np.mean([s[cls] for s in specificities]) for cls in class_names}
    std_spec = {cls: np.std([s[cls] for s in specificities]) for cls in class_names}
    
    return {
        'mean_accuracy': mean_accuracy,
        'std_accuracy': std_accuracy,
        'mean_auc': mean_auc,
        'std_auc': std_auc,
        'mean_sens': mean_sens,
        'std_sens': std_sens,
        'mean_spec': mean_spec,
        'std_spec': std_spec
    }

# %%
cv_results = cross_validate_model(
    X=X_concatenated, 
    y=y_encoded,
    class_names=CLASS_NAMES,
    num_classes=len(np.unique(y_encoded)),
)
# Out:
# - Fold 1/5
# epoch 0  | loss: 2.13269 | train_accuracy: 0.1679  | test_accuracy: 0.14477 |  0:00:01s
# epoch 5  | loss: 1.22997 | train_accuracy: 0.57152 | test_accuracy: 0.59517 |  0:00:07s
# epoch 10 | loss: 1.07837 | train_accuracy: 0.6266  | test_accuracy: 0.64879 |  0:00:13s
# epoch 15 | loss: 1.03914 | train_accuracy: 0.61988 | test_accuracy: 0.64075 |  0:00:18s
# epoch 20 | loss: 0.97793 | train_accuracy: 0.62794 | test_accuracy: 0.65684 |  0:00:24s
# epoch 25 | loss: 0.99164 | train_accuracy: 0.63197 | test_accuracy: 0.65416 |  0:00:29s
# epoch 30 | loss: 0.94008 | train_accuracy: 0.63465 | test_accuracy: 0.65952 |  0:00:35s
# epoch 35 | loss: 0.9261  | train_accuracy: 0.64943 | test_accuracy: 0.64879 |  0:00:41s
# epoch 40 | loss: 0.92697 | train_accuracy: 0.65346 | test_accuracy: 0.64075 |  0:00:46s
# epoch 45 | loss: 0.88996 | train_accuracy: 0.66286 | test_accuracy: 0.66488 |  0:00:52s
# epoch 50 | loss: 0.92035 | train_accuracy: 0.67226 | test_accuracy: 0.67292 |  0:00:57s
# epoch 55 | loss: 0.8733  | train_accuracy: 0.68099 | test_accuracy: 0.62735 |  0:01:03s
# epoch 60 | loss: 0.84854 | train_accuracy: 0.68234 | test_accuracy: 0.62735 |  0:01:08s
# epoch 65 | loss: 0.80694 | train_accuracy: 0.68301 | test_accuracy: 0.67024 |  0:01:14s
# epoch 70 | loss: 0.79915 | train_accuracy: 0.70584 | test_accuracy: 0.6622  |  0:01:19s
# epoch 75 | loss: 0.79023 | train_accuracy: 0.69711 | test_accuracy: 0.65684 |  0:01:25s
# epoch 80 | loss: 0.76111 | train_accuracy: 0.71122 | test_accuracy: 0.63271 |  0:01:30s
# epoch 85 | loss: 0.7935  | train_accuracy: 0.72263 | test_accuracy: 0.65952 |  0:01:36s
# epoch 90 | loss: 0.70938 | train_accuracy: 0.72868 | test_accuracy: 0.65684 |  0:01:41s
# epoch 95 | loss: 0.73622 | train_accuracy: 0.73875 | test_accuracy: 0.65416 |  0:01:47s
# epoch 100| loss: 0.69686 | train_accuracy: 0.73741 | test_accuracy: 0.65416 |  0:01:53s
# epoch 105| loss: 0.67514 | train_accuracy: 0.7542  | test_accuracy: 0.65147 |  0:01:58s
# epoch 110| loss: 0.71748 | train_accuracy: 0.74278 | test_accuracy: 0.6622  |  0:02:04s
# epoch 115| loss: 0.71066 | train_accuracy: 0.75017 | test_accuracy: 0.63271 |  0:02:09s
# epoch 120| loss: 0.64434 | train_accuracy: 0.75957 | test_accuracy: 0.64879 |  0:02:15s
# epoch 125| loss: 0.62733 | train_accuracy: 0.75285 | test_accuracy: 0.6756  |  0:02:20s
# epoch 130| loss: 0.65255 | train_accuracy: 0.7636  | test_accuracy: 0.65416 |  0:02:26s
# epoch 135| loss: 0.65881 | train_accuracy: 0.77435 | test_accuracy: 0.64075 |  0:02:31s
# epoch 140| loss: 0.63512 | train_accuracy: 0.78778 | test_accuracy: 0.64879 |  0:02:37s
# epoch 145| loss: 0.6458  | train_accuracy: 0.78576 | test_accuracy: 0.65147 |  0:02:42s
#
# Early stopping occurred at epoch 147 with best_epoch = 87 and best_test_accuracy = 0.68901
#
# -- Test Accuracy: 0.69%
#
# -- Classification Report:
#                                      precision    recall  f1-score   support
#
#                 Addictive disorder     0.5455    0.5556    0.5505        54
#                   Anxiety disorder     1.0000    0.6226    0.7674        53
#                    Healthy control     0.8077    0.7925    0.8000        53
#                      Mood disorder     0.3571    0.8491    0.5028        53
#      Obsessive compulsive disorder     1.0000    0.8302    0.9072        53
#                      Schizophrenia     1.0000    0.6296    0.7727        54
# Trauma and stress related disorder     1.0000    0.5472    0.7073        53
#
#                           accuracy                         0.6890       373
#                          macro avg     0.8158    0.6895    0.7154       373
#                       weighted avg     0.8155    0.6890    0.7151       373
#
# -- Sensitivity (Recall) por classe:
#   - Addictive disorder: 0.5556
#   - Anxiety disorder: 0.6226
#   - Healthy control: 0.7925
#   - Mood disorder: 0.8491
#   - Obsessive compulsive disorder: 0.8302
#   - Schizophrenia: 0.6296
#   - Trauma and stress related disorder: 0.5472
#
# -- Specificity por classe:
#   - Addictive disorder: 0.9216
#   - Anxiety disorder: 1.0000
#   - Healthy control: 0.9688
#   - Mood disorder: 0.7469
#   - Obsessive compulsive disorder: 1.0000
#   - Schizophrenia: 1.0000
#   - Trauma and stress related disorder: 1.0000
#
# - Fold 2/5
# epoch 0  | loss: 2.12416 | train_accuracy: 0.16387 | test_accuracy: 0.16354 |  0:00:01s
# epoch 5  | loss: 1.50188 | train_accuracy: 0.42982 | test_accuracy: 0.3941  |  0:00:06s
# epoch 10 | loss: 1.17392 | train_accuracy: 0.55608 | test_accuracy: 0.48794 |  0:00:12s
# epoch 15 | loss: 1.07867 | train_accuracy: 0.59637 | test_accuracy: 0.56568 |  0:00:17s
# epoch 20 | loss: 1.02418 | train_accuracy: 0.60107 | test_accuracy: 0.57909 |  0:00:23s
# epoch 25 | loss: 1.05577 | train_accuracy: 0.60712 | test_accuracy: 0.56836 |  0:00:29s
# epoch 30 | loss: 1.03193 | train_accuracy: 0.61585 | test_accuracy: 0.58981 |  0:00:34s
# epoch 35 | loss: 1.05176 | train_accuracy: 0.62324 | test_accuracy: 0.59517 |  0:00:40s
# epoch 40 | loss: 0.99759 | train_accuracy: 0.62861 | test_accuracy: 0.57373 |  0:00:46s
# epoch 45 | loss: 0.99751 | train_accuracy: 0.62861 | test_accuracy: 0.57909 |  0:00:51s
# epoch 50 | loss: 0.98757 | train_accuracy: 0.64406 | test_accuracy: 0.59249 |  0:00:57s
# epoch 55 | loss: 0.91888 | train_accuracy: 0.67092 | test_accuracy: 0.61394 |  0:01:02s
# epoch 60 | loss: 0.93615 | train_accuracy: 0.67428 | test_accuracy: 0.61662 |  0:01:08s
# epoch 65 | loss: 0.88758 | train_accuracy: 0.69107 | test_accuracy: 0.62198 |  0:01:14s
# epoch 70 | loss: 0.84573 | train_accuracy: 0.68972 | test_accuracy: 0.62466 |  0:01:19s
# epoch 75 | loss: 0.81879 | train_accuracy: 0.70047 | test_accuracy: 0.64075 |  0:01:25s
# epoch 80 | loss: 0.79888 | train_accuracy: 0.6951  | test_accuracy: 0.62466 |  0:01:30s
# epoch 85 | loss: 0.84436 | train_accuracy: 0.69644 | test_accuracy: 0.63271 |  0:01:36s
# epoch 90 | loss: 0.84085 | train_accuracy: 0.69241 | test_accuracy: 0.60858 |  0:01:42s
# epoch 95 | loss: 0.79411 | train_accuracy: 0.70316 | test_accuracy: 0.62466 |  0:01:47s
# epoch 100| loss: 0.81523 | train_accuracy: 0.70786 | test_accuracy: 0.61662 |  0:01:53s
# epoch 105| loss: 0.7819  | train_accuracy: 0.70651 | test_accuracy: 0.62198 |  0:01:58s
# epoch 110| loss: 0.78412 | train_accuracy: 0.71726 | test_accuracy: 0.62735 |  0:02:04s
# epoch 115| loss: 0.77134 | train_accuracy: 0.72263 | test_accuracy: 0.63003 |  0:02:09s
# epoch 120| loss: 0.70693 | train_accuracy: 0.72129 | test_accuracy: 0.63807 |  0:02:15s
# epoch 125| loss: 0.73954 | train_accuracy: 0.73203 | test_accuracy: 0.65147 |  0:02:21s
# epoch 130| loss: 0.71956 | train_accuracy: 0.73338 | test_accuracy: 0.63539 |  0:02:26s
# epoch 135| loss: 0.66111 | train_accuracy: 0.73539 | test_accuracy: 0.64343 |  0:02:32s
# epoch 140| loss: 0.76129 | train_accuracy: 0.74144 | test_accuracy: 0.62735 |  0:02:37s
# epoch 145| loss: 0.74595 | train_accuracy: 0.75554 | test_accuracy: 0.63271 |  0:02:43s
# epoch 150| loss: 0.68586 | train_accuracy: 0.7542  | test_accuracy: 0.62198 |  0:02:49s
# epoch 155| loss: 0.61073 | train_accuracy: 0.75487 | test_accuracy: 0.62466 |  0:02:54s
# epoch 160| loss: 0.65081 | train_accuracy: 0.75823 | test_accuracy: 0.62735 |  0:03:00s
# epoch 165| loss: 0.67599 | train_accuracy: 0.76763 | test_accuracy: 0.64343 |  0:03:05s
# epoch 170| loss: 0.64033 | train_accuracy: 0.76024 | test_accuracy: 0.62735 |  0:03:11s
# epoch 175| loss: 0.62013 | train_accuracy: 0.77837 | test_accuracy: 0.63271 |  0:03:16s
# epoch 180| loss: 0.59846 | train_accuracy: 0.77972 | test_accuracy: 0.62466 |  0:03:22s
# epoch 185| loss: 0.59608 | train_accuracy: 0.78643 | test_accuracy: 0.6193  |  0:03:27s
#
# Early stopping occurred at epoch 185 with best_epoch = 125 and best_test_accuracy = 0.65147
#
# -- Test Accuracy: 0.65%
#
# -- Classification Report:
#                                      precision    recall  f1-score   support
#
#                 Addictive disorder     0.6512    0.5283    0.5833        53
#                   Anxiety disorder     1.0000    0.6296    0.7727        54
#                    Healthy control     0.7167    0.8113    0.7611        53
#                      Mood disorder     0.3071    0.8113    0.4456        53
#      Obsessive compulsive disorder     0.9778    0.8302    0.8980        53
#                      Schizophrenia     1.0000    0.5660    0.7229        53
# Trauma and stress related disorder     1.0000    0.3889    0.5600        54
#
#                           accuracy                         0.6515       373
#                          macro avg     0.8075    0.6522    0.6777       373
#                       weighted avg     0.8086    0.6515    0.6776       373
#
# -- Sensitivity (Recall) por classe:
#   - Addictive disorder: 0.5283
#   - Anxiety disorder: 0.6296
#   - Healthy control: 0.8113
#   - Mood disorder: 0.8113
#   - Obsessive compulsive disorder: 0.8302
#   - Schizophrenia: 0.5660
#   - Trauma and stress related disorder: 0.3889
#
# -- Specificity por classe:
#   - Addictive disorder: 0.9531
#   - Anxiety disorder: 1.0000
#   - Healthy control: 0.9469
#   - Mood disorder: 0.6969
#   - Obsessive compulsive disorder: 0.9969
#   - Schizophrenia: 1.0000
#   - Trauma and stress related disorder: 1.0000
#
# - Fold 3/5
# epoch 0  | loss: 2.14397 | train_accuracy: 0.14497 | test_accuracy: 0.15591 |  0:00:01s
# epoch 5  | loss: 1.55794 | train_accuracy: 0.43826 | test_accuracy: 0.43817 |  0:00:06s
# epoch 10 | loss: 1.27109 | train_accuracy: 0.56376 | test_accuracy: 0.51882 |  0:00:12s
# epoch 15 | loss: 1.11574 | train_accuracy: 0.6047  | test_accuracy: 0.58871 |  0:00:17s
# epoch 20 | loss: 0.99507 | train_accuracy: 0.61946 | test_accuracy: 0.60215 |  0:00:23s
# epoch 25 | loss: 1.02529 | train_accuracy: 0.61946 | test_accuracy: 0.59409 |  0:00:28s
# epoch 30 | loss: 1.00392 | train_accuracy: 0.62416 | test_accuracy: 0.60215 |  0:00:34s
# epoch 35 | loss: 0.99287 | train_accuracy: 0.63356 | test_accuracy: 0.6129  |  0:00:40s
# epoch 40 | loss: 0.94583 | train_accuracy: 0.62617 | test_accuracy: 0.61559 |  0:00:45s
# epoch 45 | loss: 0.9207  | train_accuracy: 0.63087 | test_accuracy: 0.62097 |  0:00:51s
# epoch 50 | loss: 0.97898 | train_accuracy: 0.63289 | test_accuracy: 0.6129  |  0:00:56s
# epoch 55 | loss: 0.95452 | train_accuracy: 0.63221 | test_accuracy: 0.61559 |  0:01:02s
# epoch 60 | loss: 0.97614 | train_accuracy: 0.62953 | test_accuracy: 0.61022 |  0:01:07s
# epoch 65 | loss: 0.97213 | train_accuracy: 0.61477 | test_accuracy: 0.59677 |  0:01:13s
# epoch 70 | loss: 0.97151 | train_accuracy: 0.56443 | test_accuracy: 0.55645 |  0:01:18s
# epoch 75 | loss: 0.94386 | train_accuracy: 0.63624 | test_accuracy: 0.61828 |  0:01:24s
# epoch 80 | loss: 0.9543  | train_accuracy: 0.63893 | test_accuracy: 0.61559 |  0:01:29s
# epoch 85 | loss: 0.9548  | train_accuracy: 0.64161 | test_accuracy: 0.62366 |  0:01:35s
# epoch 90 | loss: 0.93265 | train_accuracy: 0.6349  | test_accuracy: 0.61828 |  0:01:40s
# epoch 95 | loss: 0.97352 | train_accuracy: 0.6396  | test_accuracy: 0.60753 |  0:01:46s
# epoch 100| loss: 0.97065 | train_accuracy: 0.64765 | test_accuracy: 0.63978 |  0:01:51s
# epoch 105| loss: 0.92529 | train_accuracy: 0.64027 | test_accuracy: 0.6129  |  0:01:57s
# epoch 110| loss: 0.93398 | train_accuracy: 0.65436 | test_accuracy: 0.62366 |  0:02:02s
# epoch 115| loss: 0.94408 | train_accuracy: 0.64966 | test_accuracy: 0.62097 |  0:02:08s
# epoch 120| loss: 0.89064 | train_accuracy: 0.66174 | test_accuracy: 0.6371  |  0:02:14s
# epoch 125| loss: 0.92545 | train_accuracy: 0.6604  | test_accuracy: 0.63978 |  0:02:19s
# epoch 130| loss: 0.86368 | train_accuracy: 0.66242 | test_accuracy: 0.62903 |  0:02:25s
# epoch 135| loss: 0.8673  | train_accuracy: 0.66107 | test_accuracy: 0.62366 |  0:02:30s
# epoch 140| loss: 0.88115 | train_accuracy: 0.67584 | test_accuracy: 0.6371  |  0:02:36s
# epoch 145| loss: 0.88926 | train_accuracy: 0.67248 | test_accuracy: 0.62903 |  0:02:41s
# epoch 150| loss: 0.8495  | train_accuracy: 0.67718 | test_accuracy: 0.64247 |  0:02:47s
# epoch 155| loss: 0.83846 | train_accuracy: 0.68121 | test_accuracy: 0.65323 |  0:02:52s
# epoch 160| loss: 0.83379 | train_accuracy: 0.67047 | test_accuracy: 0.62903 |  0:02:58s
# epoch 165| loss: 0.8406  | train_accuracy: 0.68054 | test_accuracy: 0.62903 |  0:03:04s
# epoch 170| loss: 0.87026 | train_accuracy: 0.68591 | test_accuracy: 0.64785 |  0:03:09s
# epoch 175| loss: 0.80241 | train_accuracy: 0.69396 | test_accuracy: 0.64516 |  0:03:15s
# epoch 180| loss: 0.80547 | train_accuracy: 0.69732 | test_accuracy: 0.64516 |  0:03:20s
#
# Early stopping occurred at epoch 181 with best_epoch = 121 and best_test_accuracy = 0.6586
#
# -- Test Accuracy: 0.66%
#
# -- Classification Report:
#                                      precision    recall  f1-score   support
#
#                 Addictive disorder     0.4151    0.4151    0.4151        53
#                   Anxiety disorder     0.9375    0.5660    0.7059        53
#                    Healthy control     0.8542    0.7736    0.8119        53
#                      Mood disorder     0.3609    0.8889    0.5134        54
#      Obsessive compulsive disorder     1.0000    0.8113    0.8958        53
#                      Schizophrenia     1.0000    0.5283    0.6914        53
# Trauma and stress related disorder     0.9429    0.6226    0.7500        53
#
#                           accuracy                         0.6586       372
#                          macro avg     0.7872    0.6580    0.6833       372
#                       weighted avg     0.7861    0.6586    0.6829       372
#
# -- Sensitivity (Recall) por classe:
#   - Addictive disorder: 0.4151
#   - Anxiety disorder: 0.5660
#   - Healthy control: 0.7736
#   - Mood disorder: 0.8889
#   - Obsessive compulsive disorder: 0.8113
#   - Schizophrenia: 0.5283
#   - Trauma and stress related disorder: 0.6226
#
# -- Specificity por classe:
#   - Addictive disorder: 0.9028
#   - Anxiety disorder: 0.9937
#   - Healthy control: 0.9781
#   - Mood disorder: 0.7327
#   - Obsessive compulsive disorder: 1.0000
#   - Schizophrenia: 1.0000
#   - Trauma and stress related disorder: 0.9937
#
# - Fold 4/5
# epoch 0  | loss: 2.11582 | train_accuracy: 0.18255 | test_accuracy: 0.17742 |  0:00:01s
# epoch 5  | loss: 1.4702  | train_accuracy: 0.48121 | test_accuracy: 0.48925 |  0:00:06s
# epoch 10 | loss: 1.18787 | train_accuracy: 0.60268 | test_accuracy: 0.54032 |  0:00:12s
# epoch 15 | loss: 1.08463 | train_accuracy: 0.62953 | test_accuracy: 0.60753 |  0:00:17s
# epoch 20 | loss: 0.93541 | train_accuracy: 0.6557  | test_accuracy: 0.61022 |  0:00:23s
# epoch 25 | loss: 0.97411 | train_accuracy: 0.6443  | test_accuracy: 0.61828 |  0:00:29s
# epoch 30 | loss: 0.94312 | train_accuracy: 0.66779 | test_accuracy: 0.60484 |  0:00:34s
# epoch 35 | loss: 0.91813 | train_accuracy: 0.67383 | test_accuracy: 0.61828 |  0:00:40s
# epoch 40 | loss: 0.87926 | train_accuracy: 0.67248 | test_accuracy: 0.62097 |  0:00:46s
# epoch 45 | loss: 0.8421  | train_accuracy: 0.69195 | test_accuracy: 0.62097 |  0:00:52s
# epoch 50 | loss: 0.83336 | train_accuracy: 0.70067 | test_accuracy: 0.61828 |  0:00:58s
# epoch 55 | loss: 0.79465 | train_accuracy: 0.72148 | test_accuracy: 0.64516 |  0:01:03s
# epoch 60 | loss: 0.82647 | train_accuracy: 0.7094  | test_accuracy: 0.62097 |  0:01:09s
# epoch 65 | loss: 0.77964 | train_accuracy: 0.72886 | test_accuracy: 0.63172 |  0:01:14s
# epoch 70 | loss: 0.71769 | train_accuracy: 0.74295 | test_accuracy: 0.62097 |  0:01:20s
# epoch 75 | loss: 0.69674 | train_accuracy: 0.74295 | test_accuracy: 0.62903 |  0:01:26s
# epoch 80 | loss: 0.72434 | train_accuracy: 0.74564 | test_accuracy: 0.64247 |  0:01:31s
# epoch 85 | loss: 0.7225  | train_accuracy: 0.75034 | test_accuracy: 0.62634 |  0:01:37s
# epoch 90 | loss: 0.68274 | train_accuracy: 0.75235 | test_accuracy: 0.63441 |  0:01:42s
# epoch 95 | loss: 0.67545 | train_accuracy: 0.7557  | test_accuracy: 0.62903 |  0:01:48s
# epoch 100| loss: 0.64986 | train_accuracy: 0.76309 | test_accuracy: 0.63978 |  0:01:54s
# epoch 105| loss: 0.68657 | train_accuracy: 0.76913 | test_accuracy: 0.64247 |  0:01:59s
# epoch 110| loss: 0.65866 | train_accuracy: 0.76913 | test_accuracy: 0.61828 |  0:02:05s
# epoch 115| loss: 0.66812 | train_accuracy: 0.77383 | test_accuracy: 0.63172 |  0:02:11s
#
# Early stopping occurred at epoch 115 with best_epoch = 55 and best_test_accuracy = 0.64516
#
# -- Test Accuracy: 0.65%
#
# -- Classification Report:
#                                      precision    recall  f1-score   support
#
#                 Addictive disorder     0.5000    0.5472    0.5225        53
#                   Anxiety disorder     1.0000    0.5849    0.7381        53
#                    Healthy control     0.8000    0.8148    0.8073        54
#                      Mood disorder     0.3016    0.7170    0.4246        53
#      Obsessive compulsive disorder     1.0000    0.7925    0.8842        53
#                      Schizophrenia     1.0000    0.5094    0.6750        53
# Trauma and stress related disorder     0.8788    0.5472    0.6744        53
#
#                           accuracy                         0.6452       372
#                          macro avg     0.7829    0.6447    0.6752       372
#                       weighted avg     0.7830    0.6452    0.6755       372
#
# -- Sensitivity (Recall) por classe:
#   - Addictive disorder: 0.5472
#   - Anxiety disorder: 0.5849
#   - Healthy control: 0.8148
#   - Mood disorder: 0.7170
#   - Obsessive compulsive disorder: 0.7925
#   - Schizophrenia: 0.5094
#   - Trauma and stress related disorder: 0.5472
#
# -- Specificity por classe:
#   - Addictive disorder: 0.9091
#   - Anxiety disorder: 1.0000
#   - Healthy control: 0.9654
#   - Mood disorder: 0.7241
#   - Obsessive compulsive disorder: 1.0000
#   - Schizophrenia: 1.0000
#   - Trauma and stress related disorder: 0.9875
#
# - Fold 5/5
# epoch 0  | loss: 2.11249 | train_accuracy: 0.19128 | test_accuracy: 0.16935 |  0:00:01s
# epoch 5  | loss: 1.32653 | train_accuracy: 0.55168 | test_accuracy: 0.54839 |  0:00:06s
# epoch 10 | loss: 1.1171  | train_accuracy: 0.62282 | test_accuracy: 0.62903 |  0:00:12s
# epoch 15 | loss: 1.09188 | train_accuracy: 0.63154 | test_accuracy: 0.6371  |  0:00:17s
# epoch 20 | loss: 0.9814  | train_accuracy: 0.65235 | test_accuracy: 0.62097 |  0:00:23s
# epoch 25 | loss: 0.99133 | train_accuracy: 0.64966 | test_accuracy: 0.66667 |  0:00:29s
# epoch 30 | loss: 0.94424 | train_accuracy: 0.64631 | test_accuracy: 0.65591 |  0:00:35s
# epoch 35 | loss: 0.93544 | train_accuracy: 0.65436 | test_accuracy: 0.65054 |  0:00:40s
# epoch 40 | loss: 0.92674 | train_accuracy: 0.65034 | test_accuracy: 0.64516 |  0:00:46s
# epoch 45 | loss: 0.89544 | train_accuracy: 0.66107 | test_accuracy: 0.6586  |  0:00:51s
# epoch 50 | loss: 0.89995 | train_accuracy: 0.67517 | test_accuracy: 0.64247 |  0:00:57s
# epoch 55 | loss: 0.88832 | train_accuracy: 0.68322 | test_accuracy: 0.66129 |  0:01:03s
# epoch 60 | loss: 0.87071 | train_accuracy: 0.69732 | test_accuracy: 0.6586  |  0:01:09s
# epoch 65 | loss: 0.82559 | train_accuracy: 0.70067 | test_accuracy: 0.63172 |  0:01:14s
# epoch 70 | loss: 0.76311 | train_accuracy: 0.71141 | test_accuracy: 0.6586  |  0:01:20s
# epoch 75 | loss: 0.76638 | train_accuracy: 0.73087 | test_accuracy: 0.6371  |  0:01:25s
# epoch 80 | loss: 0.74185 | train_accuracy: 0.74497 | test_accuracy: 0.64516 |  0:01:31s
# epoch 85 | loss: 0.72394 | train_accuracy: 0.75705 | test_accuracy: 0.65054 |  0:01:37s
# epoch 90 | loss: 0.69883 | train_accuracy: 0.76846 | test_accuracy: 0.66129 |  0:01:42s
# epoch 95 | loss: 0.65811 | train_accuracy: 0.78725 | test_accuracy: 0.63978 |  0:01:48s
# epoch 100| loss: 0.66591 | train_accuracy: 0.79463 | test_accuracy: 0.66129 |  0:01:54s
# epoch 105| loss: 0.63911 | train_accuracy: 0.80201 | test_accuracy: 0.64785 |  0:01:59s
# epoch 110| loss: 0.63791 | train_accuracy: 0.81611 | test_accuracy: 0.66129 |  0:02:05s
# epoch 115| loss: 0.5987  | train_accuracy: 0.83087 | test_accuracy: 0.6586  |  0:02:11s
#
# Early stopping occurred at epoch 118 with best_epoch = 58 and best_test_accuracy = 0.67742
#
# -- Test Accuracy: 0.68%
#
# -- Classification Report:
#                                      precision    recall  f1-score   support
#
#                 Addictive disorder     0.4625    0.6981    0.5564        53
#                   Anxiety disorder     1.0000    0.5849    0.7381        53
#                    Healthy control     1.0000    0.6604    0.7955        53
#                      Mood disorder     0.3585    0.7170    0.4780        53
#      Obsessive compulsive disorder     0.9592    0.8704    0.9126        54
#                      Schizophrenia     1.0000    0.5660    0.7229        53
# Trauma and stress related disorder     0.8293    0.6415    0.7234        53
#
#                           accuracy                         0.6774       372
#                          macro avg     0.8013    0.6769    0.7038       372
#                       weighted avg     0.8018    0.6774    0.7044       372
#
# -- Sensitivity (Recall) por classe:
#   - Addictive disorder: 0.6981
#   - Anxiety disorder: 0.5849
#   - Healthy control: 0.6604
#   - Mood disorder: 0.7170
#   - Obsessive compulsive disorder: 0.8704
#   - Schizophrenia: 0.5660
#   - Trauma and stress related disorder: 0.6415
#
# -- Specificity por classe:
#   - Addictive disorder: 0.8652
#   - Anxiety disorder: 1.0000
#   - Healthy control: 1.0000
#   - Mood disorder: 0.7868
#   - Obsessive compulsive disorder: 0.9937
#   - Schizophrenia: 1.0000
#   - Trauma and stress related disorder: 0.9781

# %% [markdown]
# ## | 6. Results

# %%
# dataframe 
cv_df = pd.DataFrame({
    'Metric': ['Mean Accuracy', 'Std Accuracy', 'Mean AUC', 'Std AUC'] + 
              [f'Mean Sensitivity ({cls})' for cls in CLASS_NAMES] + 
              [f'Std Sensitivity ({cls})' for cls in CLASS_NAMES] + 
              [f'Mean Specificity ({cls})' for cls in CLASS_NAMES] + 
              [f'Std Specificity ({cls})' for cls in CLASS_NAMES],
    'Value': [
        cv_results['mean_accuracy'], cv_results['std_accuracy'],
        cv_results['mean_auc'], cv_results['std_auc']
    ] + 
    [cv_results['mean_sens'][cls] for cls in CLASS_NAMES] + 
    [cv_results['std_sens'][cls] for cls in CLASS_NAMES] + 
    [cv_results['mean_spec'][cls] for cls in CLASS_NAMES] + 
    [cv_results['std_spec'][cls] for cls in CLASS_NAMES]
})

cv_df
# Out:
#                                                Metric     Value
# 0                                       Mean Accuracy  0.664333
# 1                                        Std Accuracy  0.016406
# 2                                            Mean AUC  0.893943
# 3                                             Std AUC  0.009720
# 4               Mean Sensitivity (Addictive disorder)  0.548847
# 5                 Mean Sensitivity (Anxiety disorder)  0.597624
# 6                  Mean Sensitivity (Healthy control)  0.770510
# 7                    Mean Sensitivity (Mood disorder)  0.796646
# 8    Mean Sensitivity (Obsessive compulsive disorder)  0.826904
# 9                    Mean Sensitivity (Schizophrenia)  0.559888
# 10  Mean Sensitivity (Trauma and stress related di...  0.549476
# 11               Std Sensitivity (Addictive disorder)  0.090156
# 12                 Std Sensitivity (Anxiety disorder)  0.024378
# 13                  Std Sensitivity (Healthy control)  0.057006
# 14                    Std Sensitivity (Mood disorder)  0.069518
# 15    Std Sensitivity (Obsessive compulsive disorder)  0.025848
# 16                    Std Sensitivity (Schizophrenia)  0.041189
# 17  Std Sensitivity (Trauma and stress related dis...  0.089019
# 18              Mean Specificity (Addictive disorder)  0.910374
# 19                Mean Specificity (Anxiety disorder)  0.998746
# 20                 Mean Specificity (Healthy control)  0.971818
# 21                   Mean Specificity (Mood disorder)  0.737485
# 22   Mean Specificity (Obsessive compulsive disorder)  0.998117
# 23                   Mean Specificity (Schizophrenia)  1.000000
# 24  Mean Specificity (Trauma and stress related di...  0.991850
# 25               Std Specificity (Addictive disorder)  0.028472
# 26                 Std Specificity (Anxiety disorder)  0.002508
# 27                  Std Specificity (Healthy control)  0.017354
# 28                    Std Specificity (Mood disorder)  0.029576
# 29    Std Specificity (Obsessive compulsive disorder)  0.002514
# 30                    Std Specificity (Schizophrenia)  0.000000
# 31  Std Specificity (Trauma and stress related dis...  0.008318

# %%
rows = []

rows.append({
    'Class': 'Overall',
    'Metric': 'Accuracy',
    'Mean': cv_results['mean_accuracy'],
    'Std': cv_results['std_accuracy']
})
rows.append({
    'Class': 'Overall',
    'Metric': 'AUC',
    'Mean': cv_results['mean_auc'],
    'Std': cv_results['std_auc']
})

for cls in CLASS_NAMES:
    rows.append({
        'Class': cls,
        'Metric': 'Sensitivity',
        'Mean': cv_results['mean_sens'][cls],
        'Std': cv_results['std_sens'][cls]
    })
    rows.append({
        'Class': cls,
        'Metric': 'Specificity',
        'Mean': cv_results['mean_spec'][cls],
        'Std': cv_results['std_spec'][cls]
    })

cv_df_organized = pd.DataFrame(rows)

cv_df_organized = cv_df_organized.sort_values(by=['Class', 'Metric']).reset_index(drop=True)

cv_df_organized.to_csv('cross_validation_results_multiclass_main_tabnet.csv', index=False)

cv_df_organized
# Out:
#                                  Class       Metric      Mean       Std
# 0                   Addictive disorder  Sensitivity  0.548847  0.090156
# 1                   Addictive disorder  Specificity  0.910374  0.028472
# 2                     Anxiety disorder  Sensitivity  0.597624  0.024378
# 3                     Anxiety disorder  Specificity  0.998746  0.002508
# 4                      Healthy control  Sensitivity  0.770510  0.057006
# 5                      Healthy control  Specificity  0.971818  0.017354
# 6                        Mood disorder  Sensitivity  0.796646  0.069518
# 7                        Mood disorder  Specificity  0.737485  0.029576
# 8        Obsessive compulsive disorder  Sensitivity  0.826904  0.025848
# 9        Obsessive compulsive disorder  Specificity  0.998117  0.002514
# 10                             Overall          AUC  0.893943  0.009720
# 11                             Overall     Accuracy  0.664333  0.016406
# 12                       Schizophrenia  Sensitivity  0.559888  0.041189
# 13                       Schizophrenia  Specificity  1.000000  0.000000
# 14  Trauma and stress related disorder  Sensitivity  0.549476  0.089019
# 15  Trauma and stress related disorder  Specificity  0.991850  0.008318

# %% [markdown]
# ## | 7. Conclusions, Problems, and Limitations

# %% [markdown]
# [need to update]
