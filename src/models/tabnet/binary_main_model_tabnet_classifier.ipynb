# %% [markdown]
# | Description
#
# Authors of notebook: Mateus Balda and Alessandro Bof
#
# Reference paper and dataset: https://www.frontiersin.org/journals/psychiatry/articles/10.3389/fpsyt.2021.707581/full
#
# | Notebook structure
# 0. Setup and Imports
# 1. Utility Functions
# 2. Data Loading and Preprocessing
# 3. Data Preparation for Training
# 4. Model Definition
# 5. Training and Evaluation
# 6. Results
# 7. Conclusions, Problems, and Limitations
#
# | Training
# 1. Binary classification for `y` main.disorder (Disorder vs. Health control)
# 2. Balancing using BorderlineSMOTE for minority classes
# 3. Training across the 21 subsets

# %% [markdown]
# ## | 0. Setup and Imports

# %%
# !pip install -q imbalanced-learn==0.12.4;
# !pip install -q pytorch_tabnet;
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 5.8 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 29.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.0 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylibcugraph-cu12 24.12.0 requires pylibraft-cu12==24.12.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires rmm-cu12==24.12.*, but you have rmm-cu12 25.2.0 which is incompatible.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from IPython.display import FileLink, display, HTML
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.impute import KNNImputer

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau

from imblearn.over_sampling import BorderlineSMOTE

from warnings import filterwarnings
filterwarnings('ignore')

torch.__version__
# Out:
# '2.5.1+cu124'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
experiment_name = "binary_classification_main_disorder_tabnet"
device
# Out:
# device(type='cuda')

# %%
np.random.seed(123)
torch.manual_seed(123)

# %% [markdown]
# ## | 1. Utility Functions

# %% [markdown]
# ### 1. OUTLIERS

# %%
def detect_outliers_summary(df):
    outliers_summary = {}

    for col in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_limit = Q1 - 1.5 * IQR
        upper_limit = Q3 + 1.5 * IQR

        outliers = df[(df[col] < lower_limit) | (df[col] > upper_limit)][col]
        
        outliers_summary[col] = {
            'num_outliers': len(outliers),
            'percent_outliers': len(outliers) / len(df) * 100,
            'outliers': outliers.tolist(),
            'lower_limit': lower_limit,
            'upper_limit': upper_limit
        }

    return pd.DataFrame(outliers_summary).T


def treat_all_outliers_iqr(df, factor=1.5):
    df_treated = df.copy()
    
    for column in df_treated.select_dtypes(include=[np.number]).columns:
        Q1 = np.percentile(df_treated[column], 25)
        Q3 = np.percentile(df_treated[column], 75)
        IQR = Q3 - Q1

        lower_bound = Q1 - factor * IQR
        upper_bound = Q3 + factor * IQR

        df_treated[column] = np.clip(df_treated[column], lower_bound, upper_bound)

    return df_treated

# %% [markdown]
# ### 2. NANS

# %%
def remove_missing_columns(df, threshold=0.5):
    limit = int(threshold * len(df))
    df = df.dropna(thresh=limit, axis=1)
    return df
    
def find_most_null_column(df, threshold=0.5):
    null_ratios = df.isnull().mean()
    for col, ration in null_ratios.items():
        if ration > threshold:
            return col
    return None

def analyze_missing_values(df):
    missing_values = df.isnull().sum()
    missing_values = missing_values[missing_values > 0]
    total_number_nans = df.isnull().sum().sum()
    
    return missing_values, total_number_nans

def handle_nans(df):
    columns_with_nans = df.columns[df.isnull().any()].tolist()
    
    knn_imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
    
    df_imputed = pd.DataFrame(knn_imputer.fit_transform(df[columns_with_nans]),
                                columns=columns_with_nans)
    
    df[columns_with_nans] = df_imputed[columns_with_nans]
    
    return df

# %% [markdown]
# ### 3. SETS & SUBSETS

# %%
class Sets:
    # AB = PSD (Power Spectral Density) 19 * 6
    # COH = FC (Functional Connectivity) 171 * 6
    
    def __init__(self, dataframe: pd.DataFrame):
        
        if not isinstance(dataframe, pd.DataFrame):
            raise ValueError("The parameter must be a pandas DataFrame")
        
        self.df = dataframe.copy()
        self.df_ab_psd = None
        self.df_coh_fc = None
        self.df_ab_psd_coh_fc = None
        
        self.__create_df_psd()
        self.__create_df_fc()
        self.__create_union_psd_fc()

    # 19 (6 bands)
    def __create_df_psd(self):
        columns_AB = [col for col in self.df.columns if col.startswith('AB')]
        self.df_ab_psd = self.df[columns_AB]
    
    # 171 (6 bands)
    def __create_df_fc(self):
        columns_COH = [col for col in self.df.columns if col.startswith('COH')]
        self.df_coh_fc = self.df[columns_COH]
        
    def __create_union_psd_fc(self):
        if self.df_ab_psd is not None and self.df_coh_fc is not None:
            self.df_ab_psd_coh_fc = pd.concat([self.df_ab_psd, self.df_coh_fc], axis=1)
        else:
            raise ValueError("Subsets AB and COH were not created correctly")

    def create_dfs_bands(self, bands: list[str] = None, df: pd.DataFrame = None):
        dfs_bands = {}
        
        if bands is None:
            bands = ['delta', 'theta', 'alpha', 'beta', 'highbeta','gamma']
        
        for band in bands:
            columns_band = [col for col in df.columns if f'.{band}.' in col]
            if columns_band:
                dfs_bands[band] = df[columns_band]
        
        return dfs_bands

# %% [markdown]
# ## | 2. Data Loading and Preprocessing

# %%
df = pd.read_csv('../input/eeg-psychiatric-disorders-dataset/EEG.machinelearing_data_BRMH.csv')
df.shape
# Out:
# (945, 1149)

# %%
# Checking / imputing Nan

output1 = analyze_missing_values(df)
output2 = find_most_null_column(df)
df = remove_missing_columns(df)
output3 = analyze_missing_values(df)
df = handle_nans(df)

display(output1)
display(HTML('<hr>'))
display(output2)
display(HTML('<hr>'))
display(output3)
display(df.shape)
display(HTML('<hr>'))
display(df.isna().sum().sum())
display(df)
# Out:
# (education        15
#  IQ               13
#  Unnamed: 122    945
#  dtype: int64,
#  973)
# <hr>
# 'Unnamed: 122'
# <hr>
# (education    15
#  IQ           13
#  dtype: int64,
#  28)
# (945, 1148)
# <hr>
# 0
#      no. sex   age    eeg.date  education          IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30   13.43871  101.580472  Addictive disorder
# 1      2   M  37.0    2012.9.6    6.00000  120.000000  Addictive disorder
# 2      3   M  32.0   2012.9.10   16.00000  113.000000  Addictive disorder
# 3      4   M  35.0   2012.10.8   18.00000  126.000000  Addictive disorder
# 4      5   M  36.0  2012.10.18   16.00000  112.000000  Addictive disorder
# ..   ...  ..   ...         ...        ...         ...                 ...
# 940  941   M  22.0   2014.8.28   13.00000  116.000000     Healthy control
# 941  942   M  26.0   2014.9.19   13.00000  118.000000     Healthy control
# 942  943   M  26.0   2014.9.27   16.00000  113.000000     Healthy control
# 943  944   M  24.0   2014.9.20   13.00000  107.000000     Healthy control
# 944  945   M  21.0  2015.10.23   13.00000  105.000000     Healthy control
#
#         specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0    Alcohol use disorder         35.998557         21.717375  ...
# 1    Alcohol use disorder         13.425118         11.002916  ...
# 2    Alcohol use disorder         29.941780         27.544684  ...
# 3    Alcohol use disorder         21.496226         21.846832  ...
# 4    Alcohol use disorder         37.775667         33.607679  ...
# ..                    ...               ...               ...  ...
# 940       Healthy control         41.851823         36.771496  ...
# 941       Healthy control         18.986856         19.401387  ...
# 942       Healthy control         28.781317         32.369230  ...
# 943       Healthy control         19.929100         25.196375  ...
# 944       Healthy control         65.195346         69.241972  ...
#
#      COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0                55.989192              16.739679              23.452271
# 1                45.595619              17.510824              26.777368
# 2                99.475453              70.654171              39.131547
# 3                59.986561              63.822201              36.478254
# 4                61.462720              59.166097              51.465531
# ..                     ...                    ...                    ...
# 940              82.905657              34.850706              63.970519
# 941              65.917918              66.700117              44.756285
# 942              61.040959              27.632209              45.552852
# 943              99.113664              48.328934              41.248470
# 944              78.600293              68.255430              70.687410
#
#      COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                45.678820              30.167520              16.918761
# 1                28.201062              57.108861              32.375401
# 2                69.920996              71.063644              38.534505
# 3                47.117006              84.658376              24.724096
# 4                58.635415              80.685608              62.138436
# ..                     ...                    ...                    ...
# 940              63.982003              51.244725              62.203684
# 941              49.787513              98.905995              54.021304
# 942              33.638817              46.690983              19.382928
# 943              28.192238              48.665743              42.007147
# 944              74.433908              74.294750              53.254681
#
#      COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                48.850427               9.422630              34.507082
# 1                60.351749              13.900981              57.831848
# 2                69.908764              27.180532              64.803155
# 3                50.299349              35.319695              79.822944
# 4                75.888749              61.003944              87.455509
# ..                     ...                    ...                    ...
# 940              62.062237              31.013031              31.183413
# 941              93.902401              52.740396              92.807331
# 942              41.050717               7.045821              41.962451
# 943              28.735945              27.176500              27.529522
# 944              72.755265              47.810386              80.166825
#
#      COH.F.gamma.r.O1.s.O2
# 0                28.613029
# 1                43.463261
# 2                31.485799
# 3                41.141873
# 4                70.531662
# ..                     ...
# 940              98.325230
# 941              56.320868
# 942              19.092111
# 943              20.028446
# 944              64.380273
#
# [945 rows x 1148 columns]

# %%
# detecting outliers

outliers_summary = detect_outliers_summary(df)
outliers_summary.to_csv('outliers_summary.csv', index=True)
outliers_summary['num_outliers'].sum()
# Out:
# 26452

# %%
label_encoder = LabelEncoder()
target_name = 'main.disorder'

X = df.iloc[:,8:]
target = df[target_name]

quantitative_features = df.loc[:, ['age', 'education', 'IQ']]

sex = df['sex']
sex_encoded = label_encoder.fit_transform(sex)
sex_encoded = pd.Series(sex_encoded, name='sex')

X = pd.concat([quantitative_features, sex_encoded, X], axis=1)

X.shape, target.shape, quantitative_features.shape, sex.shape
# Out:
# ((945, 1144), (945,), (945, 3), (945,))

# %%
disorders = np.unique(target).tolist()
disorders.remove('Healthy control')
disorders
# Out:
# ['Addictive disorder',
#  'Anxiety disorder',
#  'Mood disorder',
#  'Obsessive compulsive disorder',
#  'Schizophrenia',
#  'Trauma and stress related disorder']

# %%
X_concated = pd.concat([X, target], axis=1)

display(X.head())
display(X_concated.head())
display(X.isna().sum().sum())
display(X_concated.isna().sum().sum())
# Out:
#     age  education          IQ  sex  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0  57.0   13.43871  101.580472    1         35.998557         21.717375
# 1  37.0    6.00000  120.000000    1         13.425118         11.002916
# 2  32.0   16.00000  113.000000    1         29.941780         27.544684
# 3  35.0   18.00000  126.000000    1         21.496226         21.846832
# 4  36.0   16.00000  112.000000    1         37.775667         33.607679
#
#    AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  ...  \
# 0        21.518280        26.825048        26.611516        25.732649  ...
# 1        11.942516        15.272216        14.151570        12.456034  ...
# 2        17.150159        23.608960        27.087811        13.541237  ...
# 3        17.364316        13.833701        14.100954        13.100939  ...
# 4        21.865556        21.771413        22.854536        21.456377  ...
#
#    COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0              55.989192              16.739679              23.452271
# 1              45.595619              17.510824              26.777368
# 2              99.475453              70.654171              39.131547
# 3              59.986561              63.822201              36.478254
# 4              61.462720              59.166097              51.465531
#
#    COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0              45.678820              30.167520              16.918761
# 1              28.201062              57.108861              32.375401
# 2              69.920996              71.063644              38.534505
# 3              47.117006              84.658376              24.724096
# 4              58.635415              80.685608              62.138436
#
#    COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0              48.850427               9.422630              34.507082
# 1              60.351749              13.900981              57.831848
# 2              69.908764              27.180532              64.803155
# 3              50.299349              35.319695              79.822944
# 4              75.888749              61.003944              87.455509
#
#    COH.F.gamma.r.O1.s.O2
# 0              28.613029
# 1              43.463261
# 2              31.485799
# 3              41.141873
# 4              70.531662
#
# [5 rows x 1144 columns]
#     age  education          IQ  sex  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0  57.0   13.43871  101.580472    1         35.998557         21.717375
# 1  37.0    6.00000  120.000000    1         13.425118         11.002916
# 2  32.0   16.00000  113.000000    1         29.941780         27.544684
# 3  35.0   18.00000  126.000000    1         21.496226         21.846832
# 4  36.0   16.00000  112.000000    1         37.775667         33.607679
#
#    AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  ...  \
# 0        21.518280        26.825048        26.611516        25.732649  ...
# 1        11.942516        15.272216        14.151570        12.456034  ...
# 2        17.150159        23.608960        27.087811        13.541237  ...
# 3        17.364316        13.833701        14.100954        13.100939  ...
# 4        21.865556        21.771413        22.854536        21.456377  ...
#
#    COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  COH.F.gamma.o.Pz.s.O2  \
# 0              16.739679              23.452271              45.678820
# 1              17.510824              26.777368              28.201062
# 2              70.654171              39.131547              69.920996
# 3              63.822201              36.478254              47.117006
# 4              59.166097              51.465531              58.635415
#
#    COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  COH.F.gamma.p.P4.s.O2  \
# 0              30.167520              16.918761              48.850427
# 1              57.108861              32.375401              60.351749
# 2              71.063644              38.534505              69.908764
# 3              84.658376              24.724096              50.299349
# 4              80.685608              62.138436              75.888749
#
#    COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  COH.F.gamma.r.O1.s.O2  \
# 0               9.422630              34.507082              28.613029
# 1              13.900981              57.831848              43.463261
# 2              27.180532              64.803155              31.485799
# 3              35.319695              79.822944              41.141873
# 4              61.003944              87.455509              70.531662
#
#         main.disorder
# 0  Addictive disorder
# 1  Addictive disorder
# 2  Addictive disorder
# 3  Addictive disorder
# 4  Addictive disorder
#
# [5 rows x 1145 columns]
# 0
# 0

# %%
# treat outliers X_concated

X = treat_all_outliers_iqr(X, factor=1.5)
outliers_summary = detect_outliers_summary(X)
outliers_summary['num_outliers'].sum()
# Out:
# 0

# %%
binary_datasets = {}

for disorder in disorders:
    
    mask = X_concated[target_name].isin(['Healthy control', disorder])
    
    df_filtered = X_concated[mask]
    df_filtered_X = X.loc[mask]
    
    y_binary = df_filtered[target_name].apply(lambda x: 0 if x == 'Healthy control' else 1)
    
    borderline_smote = BorderlineSMOTE(kind='borderline-2', random_state=42, k_neighbors=10, m_neighbors=15)
    X_resampled, y_resampled = borderline_smote.fit_resample(df_filtered_X, y_binary)
    
    dataset = pd.concat([X_resampled, y_resampled], axis=1)
    
    binary_datasets[disorder] = {
        'data': dataset,
        'labels': ['Healthy control', disorder]
    }

# %%
binary_datasets[disorders[0]]['data']
# Out:
#            age  education          IQ  sex  AB.A.delta.a.FP1  \
# 0    56.030000  13.438710  101.580472    1         35.998557
# 1    37.000000   6.000000  120.000000    1         13.425118
# 2    32.000000  16.000000  113.000000    1         29.941780
# 3    35.000000  18.000000  126.000000    1         21.496226
# 4    36.000000  16.000000  112.000000    1         37.775667
# ..         ...        ...         ...  ...               ...
# 367  23.936684  12.914847  106.786020    0         14.437635
# 368  23.931990  15.948992  102.282243    1         13.138764
# 369  22.000000  13.000000  133.026971    1         15.690757
# 370  25.983926  16.190356  121.454457    1         17.235063
# 371  24.055489  13.005044  105.065578    1          6.718726
#
#      AB.A.delta.b.FP2  AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  \
# 0           21.717375        21.518280        26.825048        26.611516
# 1           11.002916        11.942516        15.272216        14.151570
# 2           27.544684        17.150159        23.608960        27.087811
# 3           21.846832        17.364316        13.833701        14.100954
# 4           33.607679        21.865556        21.771413        22.854536
# ..                ...              ...              ...              ...
# 367         12.248253        12.008394        15.753527        16.710368
# 368         21.004126        12.924976        13.116845        17.862602
# 369         14.745960        11.360117        15.665005        20.809406
# 370         18.973345        13.134278        18.516893        21.669362
# 371          7.675588         5.420095         7.472920         9.500486
#
#      AB.A.delta.f.F4  ...  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0          25.732649  ...              16.739679              23.452271
# 1          12.456034  ...              17.510824              26.777368
# 2          13.541237  ...              70.654171              39.131547
# 3          13.100939  ...              63.822201              36.478254
# 4          21.456377  ...              59.166097              51.465531
# ..               ...  ...                    ...                    ...
# 367        12.349961  ...              62.841966              75.293952
# 368        17.925295  ...              16.902791              39.786575
# 369        17.723404  ...              39.895060              36.969294
# 370        22.479819  ...              64.383890              72.705952
# 371         8.847232  ...              87.913740              91.282016
#
#      COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                45.678820              30.167520              16.918761
# 1                28.201062              57.108861              32.375401
# 2                69.920996              71.063644              38.534505
# 3                47.117006              84.658376              24.724096
# 4                58.635415              80.685608              62.138436
# ..                     ...                    ...                    ...
# 367              64.040256              95.871374              46.718100
# 368              38.205377              32.522101              29.408334
# 369              35.186558              50.849725              31.069971
# 370              77.612578              74.304228              61.461376
# 371              83.834698              99.276480              83.165388
#
#      COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                48.850427               9.422630              34.507082
# 1                60.351749              13.900981              57.831848
# 2                69.908764              27.180532              64.803155
# 3                50.299349              35.319695              79.822944
# 4                75.888749              61.003944              87.455509
# ..                     ...                    ...                    ...
# 367              79.288627              44.872529              78.717620
# 368              52.904032              10.820888              34.237195
# 369              42.293424              21.050751              35.997421
# 370              81.776479              46.188054              78.515296
# 371              93.075384              82.400589              93.151561
#
#      COH.F.gamma.r.O1.s.O2  main.disorder
# 0                28.613029              1
# 1                43.463261              1
# 2                31.485799              1
# 3                41.141873              1
# 4                70.531662              1
# ..                     ...            ...
# 367              54.905455              0
# 368              32.547049              0
# 369              47.988328              0
# 370              67.269585              0
# 371              84.357897              0
#
# [372 rows x 1145 columns]

# %%
sets_binaries = {}

for disorder, bin_data in binary_datasets.items():
    df_bin = bin_data['data'].copy()
    
    X_bin = df_bin.drop(columns=[target_name,'age', 'education', 'IQ', 'sex'], errors='ignore') 
    X_quantitative = df_bin.loc[:, ['age', 'education', 'IQ', 'sex']]
    y_bin = df_bin[target_name] if target_name in df_bin.columns else df_bin.iloc[:, -1]

    sets = Sets(dataframe=X_bin)

    sets_binaries[disorder] = {
        'sets': sets,
        'labels': bin_data['labels'],
        'X_quantitative': X_quantitative,
        'y': y_bin
    }

# %%
for disorder in sets_binaries:
    sets = sets_binaries[disorder]['sets']

    dfs_bands_psd = sets.create_dfs_bands(df=sets.df_ab_psd)
    dfs_bands_fc = sets.create_dfs_bands(df=sets.df_coh_fc)
    dfs_bands_psd_fc = sets.create_dfs_bands(df=sets.df_ab_psd_coh_fc)

    sets_binaries[disorder].update({
        'dfs_bands_psd': dfs_bands_psd,
        'dfs_bands_fc': dfs_bands_fc,
        'dfs_bands_psd_fc': dfs_bands_psd_fc,
    })

# %%
for disorder, data in sets_binaries.items():
    print(f"Disorder: {disorder}")
    print(f"Labels: {data['labels']}")
    print(f"Number of samples: {len(data['y'])}")
    print(f"Quantitative features shape: {data['X_quantitative'].shape}")
    print(f"PSD bands shape: {data['sets'].df_ab_psd.shape}")
    print(f"FC bands shape: {data['sets'].df_coh_fc.shape}")
    print(f"PSD + FC bands shape: {data['sets'].df_ab_psd_coh_fc.shape}\n")
# Out:
# Disorder: Addictive disorder
# Labels: ['Healthy control', 'Addictive disorder']
# Number of samples: 372
# Quantitative features shape: (372, 4)
# PSD bands shape: (372, 114)
# FC bands shape: (372, 1026)
# PSD + FC bands shape: (372, 1140)
#
# Disorder: Anxiety disorder
# Labels: ['Healthy control', 'Anxiety disorder']
# Number of samples: 214
# Quantitative features shape: (214, 4)
# PSD bands shape: (214, 114)
# FC bands shape: (214, 1026)
# PSD + FC bands shape: (214, 1140)
#
# Disorder: Mood disorder
# Labels: ['Healthy control', 'Mood disorder']
# Number of samples: 532
# Quantitative features shape: (532, 4)
# PSD bands shape: (532, 114)
# FC bands shape: (532, 1026)
# PSD + FC bands shape: (532, 1140)
#
# Disorder: Obsessive compulsive disorder
# Labels: ['Healthy control', 'Obsessive compulsive disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Schizophrenia
# Labels: ['Healthy control', 'Schizophrenia']
# Number of samples: 234
# Quantitative features shape: (234, 4)
# PSD bands shape: (234, 114)
# FC bands shape: (234, 1026)
# PSD + FC bands shape: (234, 1140)
#
# Disorder: Trauma and stress related disorder
# Labels: ['Healthy control', 'Trauma and stress related disorder']
# Number of samples: 256
# Quantitative features shape: (256, 4)
# PSD bands shape: (256, 114)
# FC bands shape: (256, 1026)
# PSD + FC bands shape: (256, 1140)

# %%
dfs_dicts_binaries = {}

for disorder, data in sets_binaries.items():
    dfs_psd = data['dfs_bands_psd']
    dfs_fc = data['dfs_bands_fc']
    dfs_psd_fc = data['dfs_bands_psd_fc']
    sets = data['sets']

    df_dict_psd_all_bands = {
        'psd_all_bands': sets.df_ab_psd,
    }

    df_dict_fc_all_bands = {
        'fc_all_bands': sets.df_coh_fc,
    }

    df_dict_psd_fc_all_bands = {
        'psd_fc_all_bands': sets.df_ab_psd_coh_fc,
    }

    df_dict_psd_band = {
        f'psd_{band}': dfs_psd[band] for band in dfs_psd
    }

    df_dict_fc_band = {
        f'fc_{band}': dfs_fc[band] for band in dfs_fc
    }

    df_dict_psd_fc_band = {
        f'psd_fc_{band}': dfs_psd_fc[band] for band in dfs_psd_fc
    }

    dfs_dicts_binaries[disorder] = {
        'df_dict_psd_all_bands': df_dict_psd_all_bands,
        'df_dict_fc_all_bands': df_dict_fc_all_bands,
        'df_dict_psd_fc_all_bands': df_dict_psd_fc_all_bands,
        'df_dict_psd_band': df_dict_psd_band,
        'df_dict_fc_band': df_dict_fc_band,
        'df_dict_psd_fc_band': df_dict_psd_fc_band,
    }

# %%
from pytorch_tabnet.tab_model import TabNetClassifier

# %%
clf = TabNetClassifier(
    optimizer_fn=torch.optim.Adam,
    scheduler_params={"step_size":30, 
                        "gamma":0.9},
    scheduler_fn=torch.optim.lr_scheduler.StepLR,
    verbose=10,
)

# %%
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score
from collections import defaultdict

all_results = {}

for disorder, dicts in dfs_dicts_binaries.items():
    print(f"\n=== Disorder: {disorder} ===")
    
    y_binary = sets_binaries[disorder]['y']
    X_quantitative = sets_binaries[disorder]['X_quantitative']
    labels = sets_binaries[disorder]['labels']
    
    all_results[disorder] = {}
    
    for dict_name, df_dict in dicts.items():
        if not dict_name.startswith('df_dict_'):
            continue
        
        for df_name, df in df_dict.items():
            print(f"\n--- Processing: {df_name} ---")
            print("Shape:", df.shape)
            print("Missing values:", df.isna().sum().sum())
            
            df_full = pd.concat([X_quantitative, df], axis=1)
            assert all(df_full.index == y_binary.index), 'Misaligned indexes'
            
            X_train, X_test, y_train, y_test = train_test_split(
                df_full,
                y_binary,
                train_size=0.80,
                stratify=y_binary,
                random_state=42
            )
            
            X_cols = X_train.drop(columns=['sex']).columns
            
            scaler = RobustScaler()
            X_train_scaled = scaler.fit_transform(X_train[X_cols])
            X_test_scaled = scaler.transform(X_test[X_cols])
            
            X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_cols, index=X_train.index)
            X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_cols, index=X_test.index)

            X_train_final = pd.concat([X_train_scaled_df, X_train['sex']], axis=1)
            X_test_final = pd.concat([X_test_scaled_df, X_test['sex']], axis=1)

            X_train_array = X_train_final.to_numpy()
            X_test_array = X_test_final.to_numpy()
            y_train_array = y_train.to_numpy()
            y_test_array = y_test.to_numpy()
            
            clf.fit(
                X_train_array, y_train_array,
                eval_set=[(X_train_array, y_train_array), (X_test_array, y_test_array)],
                eval_name=['train', 'test'],
                eval_metric=['auc','accuracy'],
                max_epochs=200, patience=60,
                batch_size=48, virtual_batch_size=24,
                num_workers=0,
                weights=1,
                drop_last=True
            )
            
            y_pred = clf.predict(X_test_array)
            y_proba = clf.predict_proba(X_test_array)[:, 1]

            acc = accuracy_score(y_test_array, y_pred)
            auc = roc_auc_score(y_test_array, y_proba)
            report = classification_report(y_test_array, y_pred)
            
            all_results.setdefault(disorder, {}).setdefault(dict_name, {})[df_name] = {
                'accuracy': acc,
                'auc': auc,
                'classification_report': report,
                'features': list(X_test_final.columns),
                'X_train_shape': X_train_array.shape,
                'X_val_shape': X_test_array.shape,
                'clf': clf
            }
# Out:
# === Disorder: Addictive disorder ===
#
# --- Processing: psd_all_bands ---
# Shape: (372, 114)
# Missing values: 0
# epoch 0  | loss: 0.75306 | train_auc: 0.52206 | train_accuracy: 0.51852 | test_auc: 0.44523 | test_accuracy: 0.46667 |  0:00:01s
# epoch 10 | loss: 0.69248 | train_auc: 0.58271 | train_accuracy: 0.56566 | test_auc: 0.5825  | test_accuracy: 0.56    |  0:00:03s
# epoch 20 | loss: 0.67129 | train_auc: 0.60017 | train_accuracy: 0.57576 | test_auc: 0.51636 | test_accuracy: 0.57333 |  0:00:05s
# epoch 30 | loss: 0.68976 | train_auc: 0.59931 | train_accuracy: 0.54209 | test_auc: 0.633   | test_accuracy: 0.54667 |  0:00:08s
# epoch 40 | loss: 0.6478  | train_auc: 0.69883 | train_accuracy: 0.62626 | test_auc: 0.64083 | test_accuracy: 0.6     |  0:00:10s
# epoch 50 | loss: 0.62572 | train_auc: 0.74134 | train_accuracy: 0.63973 | test_auc: 0.55974 | test_accuracy: 0.58667 |  0:00:12s
# epoch 60 | loss: 0.6033  | train_auc: 0.7481  | train_accuracy: 0.6633  | test_auc: 0.64509 | test_accuracy: 0.6     |  0:00:15s
# epoch 70 | loss: 0.58721 | train_auc: 0.79698 | train_accuracy: 0.71717 | test_auc: 0.73613 | test_accuracy: 0.66667 |  0:00:17s
# epoch 80 | loss: 0.55561 | train_auc: 0.79802 | train_accuracy: 0.74411 | test_auc: 0.78805 | test_accuracy: 0.72    |  0:00:19s
# epoch 90 | loss: 0.57651 | train_auc: 0.85684 | train_accuracy: 0.78451 | test_auc: 0.84708 | test_accuracy: 0.78667 |  0:00:22s
# epoch 100| loss: 0.49758 | train_auc: 0.88237 | train_accuracy: 0.81818 | test_auc: 0.79303 | test_accuracy: 0.68    |  0:00:24s
# epoch 110| loss: 0.50199 | train_auc: 0.89307 | train_accuracy: 0.80471 | test_auc: 0.90541 | test_accuracy: 0.8     |  0:00:26s
# epoch 120| loss: 0.40387 | train_auc: 0.94817 | train_accuracy: 0.87205 | test_auc: 0.85562 | test_accuracy: 0.77333 |  0:00:28s
# epoch 130| loss: 0.35061 | train_auc: 0.92196 | train_accuracy: 0.84512 | test_auc: 0.86344 | test_accuracy: 0.81333 |  0:00:31s
# epoch 140| loss: 0.33318 | train_auc: 0.96213 | train_accuracy: 0.87542 | test_auc: 0.92461 | test_accuracy: 0.88    |  0:00:33s
# epoch 150| loss: 0.35624 | train_auc: 0.96109 | train_accuracy: 0.89562 | test_auc: 0.89047 | test_accuracy: 0.84    |  0:00:35s
# epoch 160| loss: 0.27657 | train_auc: 0.97583 | train_accuracy: 0.91582 | test_auc: 0.93385 | test_accuracy: 0.88    |  0:00:38s
# epoch 170| loss: 0.38372 | train_auc: 0.97012 | train_accuracy: 0.91246 | test_auc: 0.92319 | test_accuracy: 0.86667 |  0:00:40s
# epoch 180| loss: 0.29365 | train_auc: 0.97107 | train_accuracy: 0.89899 | test_auc: 0.94452 | test_accuracy: 0.85333 |  0:00:42s
# epoch 190| loss: 0.42258 | train_auc: 0.98218 | train_accuracy: 0.92929 | test_auc: 0.93385 | test_accuracy: 0.88    |  0:00:45s
# Stop training because you reached max_epochs = 200 with best_epoch = 186 and best_test_accuracy = 0.92
#
# --- Processing: fc_all_bands ---
# Shape: (372, 1026)
# Missing values: 0
# epoch 0  | loss: 0.7815  | train_auc: 0.54857 | train_accuracy: 0.52862 | test_auc: 0.59104 | test_accuracy: 0.53333 |  0:00:00s
# epoch 10 | loss: 0.68953 | train_auc: 0.66538 | train_accuracy: 0.60269 | test_auc: 0.66358 | test_accuracy: 0.64    |  0:00:02s
# epoch 20 | loss: 0.58709 | train_auc: 0.74837 | train_accuracy: 0.69024 | test_auc: 0.69275 | test_accuracy: 0.61333 |  0:00:05s
# epoch 30 | loss: 0.53918 | train_auc: 0.79911 | train_accuracy: 0.70034 | test_auc: 0.67496 | test_accuracy: 0.61333 |  0:00:07s
# epoch 40 | loss: 0.53733 | train_auc: 0.87108 | train_accuracy: 0.78114 | test_auc: 0.83001 | test_accuracy: 0.73333 |  0:00:10s
# epoch 50 | loss: 0.40118 | train_auc: 0.92023 | train_accuracy: 0.82828 | test_auc: 0.76671 | test_accuracy: 0.66667 |  0:00:12s
# epoch 60 | loss: 0.59165 | train_auc: 0.88595 | train_accuracy: 0.82155 | test_auc: 0.79232 | test_accuracy: 0.74667 |  0:00:14s
# epoch 70 | loss: 0.26341 | train_auc: 0.98726 | train_accuracy: 0.94276 | test_auc: 0.86131 | test_accuracy: 0.8     |  0:00:17s
# epoch 80 | loss: 0.25711 | train_auc: 0.99288 | train_accuracy: 0.9697  | test_auc: 0.86842 | test_accuracy: 0.82667 |  0:00:19s
# epoch 90 | loss: 0.21727 | train_auc: 0.99102 | train_accuracy: 0.96296 | test_auc: 0.86558 | test_accuracy: 0.82667 |  0:00:22s
# epoch 100| loss: 0.24723 | train_auc: 0.99075 | train_accuracy: 0.94276 | test_auc: 0.83499 | test_accuracy: 0.76    |  0:00:24s
# epoch 110| loss: 0.16531 | train_auc: 0.99918 | train_accuracy: 0.97643 | test_auc: 0.9303  | test_accuracy: 0.84    |  0:00:27s
# epoch 120| loss: 0.09788 | train_auc: 0.99959 | train_accuracy: 0.98316 | test_auc: 0.87838 | test_accuracy: 0.82667 |  0:00:29s
# epoch 130| loss: 0.05243 | train_auc: 1.0     | train_accuracy: 0.99663 | test_auc: 0.88051 | test_accuracy: 0.84    |  0:00:31s
# epoch 140| loss: 0.12926 | train_auc: 0.99977 | train_accuracy: 0.99327 | test_auc: 0.85135 | test_accuracy: 0.8     |  0:00:34s
# epoch 150| loss: 0.12987 | train_auc: 1.0     | train_accuracy: 0.99663 | test_auc: 0.86984 | test_accuracy: 0.84    |  0:00:36s
#
# Early stopping occurred at epoch 155 with best_epoch = 95 and best_test_accuracy = 0.89333
#
# --- Processing: psd_fc_all_bands ---
# Shape: (372, 1140)
# Missing values: 0
# epoch 0  | loss: 0.79654 | train_auc: 0.49946 | train_accuracy: 0.53199 | test_auc: 0.47582 | test_accuracy: 0.45333 |  0:00:00s
# epoch 10 | loss: 0.6863  | train_auc: 0.69041 | train_accuracy: 0.60606 | test_auc: 0.56046 | test_accuracy: 0.57333 |  0:00:02s
# epoch 20 | loss: 0.689   | train_auc: 0.62851 | train_accuracy: 0.60269 | test_auc: 0.52347 | test_accuracy: 0.56    |  0:00:05s
# epoch 30 | loss: 0.61459 | train_auc: 0.7115  | train_accuracy: 0.63636 | test_auc: 0.57397 | test_accuracy: 0.54667 |  0:00:07s
# epoch 40 | loss: 0.61415 | train_auc: 0.7086  | train_accuracy: 0.65993 | test_auc: 0.57468 | test_accuracy: 0.58667 |  0:00:10s
# epoch 50 | loss: 0.63111 | train_auc: 0.75172 | train_accuracy: 0.70707 | test_auc: 0.72333 | test_accuracy: 0.68    |  0:00:12s
# epoch 60 | loss: 0.61049 | train_auc: 0.76868 | train_accuracy: 0.68687 | test_auc: 0.61166 | test_accuracy: 0.57333 |  0:00:14s
# epoch 70 | loss: 0.60866 | train_auc: 0.71204 | train_accuracy: 0.64646 | test_auc: 0.69275 | test_accuracy: 0.65333 |  0:00:17s
# epoch 80 | loss: 0.63106 | train_auc: 0.75467 | train_accuracy: 0.66667 | test_auc: 0.75533 | test_accuracy: 0.72    |  0:00:19s
# epoch 90 | loss: 0.5705  | train_auc: 0.81934 | train_accuracy: 0.72727 | test_auc: 0.72617 | test_accuracy: 0.68    |  0:00:22s
# epoch 100| loss: 0.54387 | train_auc: 0.82387 | train_accuracy: 0.75421 | test_auc: 0.81721 | test_accuracy: 0.73333 |  0:00:24s
# epoch 110| loss: 0.57855 | train_auc: 0.74719 | train_accuracy: 0.6734  | test_auc: 0.74395 | test_accuracy: 0.66667 |  0:00:27s
# epoch 120| loss: 0.58523 | train_auc: 0.80328 | train_accuracy: 0.7037  | test_auc: 0.80583 | test_accuracy: 0.72    |  0:00:29s
# epoch 130| loss: 0.57268 | train_auc: 0.77299 | train_accuracy: 0.6835  | test_auc: 0.76671 | test_accuracy: 0.66667 |  0:00:31s
# epoch 140| loss: 0.59619 | train_auc: 0.75399 | train_accuracy: 0.67003 | test_auc: 0.73115 | test_accuracy: 0.64    |  0:00:34s
# epoch 150| loss: 0.57604 | train_auc: 0.81675 | train_accuracy: 0.73737 | test_auc: 0.79232 | test_accuracy: 0.73333 |  0:00:36s
# epoch 160| loss: 0.53218 | train_auc: 0.82655 | train_accuracy: 0.74411 | test_auc: 0.80085 | test_accuracy: 0.72    |  0:00:39s
#
# Early stopping occurred at epoch 162 with best_epoch = 102 and best_test_accuracy = 0.78667
#
# --- Processing: psd_delta ---
# Shape: (372, 19)
# Missing values: 0
# epoch 0  | loss: 0.93607 | train_auc: 0.5599  | train_accuracy: 0.52189 | test_auc: 0.47866 | test_accuracy: 0.54667 |  0:00:00s
# epoch 10 | loss: 0.60357 | train_auc: 0.77344 | train_accuracy: 0.74074 | test_auc: 0.78236 | test_accuracy: 0.77333 |  0:00:02s
# epoch 20 | loss: 0.52118 | train_auc: 0.8421  | train_accuracy: 0.76768 | test_auc: 0.82361 | test_accuracy: 0.77333 |  0:00:04s
# epoch 30 | loss: 0.47445 | train_auc: 0.84505 | train_accuracy: 0.78788 | test_auc: 0.83713 | test_accuracy: 0.78667 |  0:00:07s
# epoch 40 | loss: 0.45069 | train_auc: 0.91457 | train_accuracy: 0.83502 | test_auc: 0.86842 | test_accuracy: 0.86667 |  0:00:09s
# epoch 50 | loss: 0.43655 | train_auc: 0.93406 | train_accuracy: 0.83838 | test_auc: 0.87055 | test_accuracy: 0.85333 |  0:00:11s
# epoch 60 | loss: 0.36084 | train_auc: 0.93393 | train_accuracy: 0.83165 | test_auc: 0.90185 | test_accuracy: 0.84    |  0:00:14s
# epoch 70 | loss: 0.36174 | train_auc: 0.95243 | train_accuracy: 0.87542 | test_auc: 0.91181 | test_accuracy: 0.85333 |  0:00:16s
# epoch 80 | loss: 0.33943 | train_auc: 0.95225 | train_accuracy: 0.87205 | test_auc: 0.91394 | test_accuracy: 0.85333 |  0:00:18s
# epoch 90 | loss: 0.41056 | train_auc: 0.94422 | train_accuracy: 0.85522 | test_auc: 0.91821 | test_accuracy: 0.84    |  0:00:20s
# epoch 100| loss: 0.3371  | train_auc: 0.93969 | train_accuracy: 0.85185 | test_auc: 0.90398 | test_accuracy: 0.82667 |  0:00:23s
# epoch 110| loss: 0.31147 | train_auc: 0.96377 | train_accuracy: 0.84175 | test_auc: 0.91394 | test_accuracy: 0.81333 |  0:00:25s
#
# Early stopping occurred at epoch 115 with best_epoch = 55 and best_test_accuracy = 0.89333
#
# --- Processing: psd_theta ---
# Shape: (372, 19)
# Missing values: 0
# epoch 0  | loss: 0.89923 | train_auc: 0.5078  | train_accuracy: 0.51852 | test_auc: 0.60811 | test_accuracy: 0.56    |  0:00:00s
# epoch 10 | loss: 0.58409 | train_auc: 0.80478 | train_accuracy: 0.73064 | test_auc: 0.84211 | test_accuracy: 0.74667 |  0:00:02s
# epoch 20 | loss: 0.55911 | train_auc: 0.79027 | train_accuracy: 0.71044 | test_auc: 0.88691 | test_accuracy: 0.85333 |  0:00:04s
# epoch 30 | loss: 0.45466 | train_auc: 0.87108 | train_accuracy: 0.75758 | test_auc: 0.93883 | test_accuracy: 0.88    |  0:00:07s
# epoch 40 | loss: 0.45416 | train_auc: 0.89602 | train_accuracy: 0.79461 | test_auc: 0.94595 | test_accuracy: 0.88    |  0:00:09s
# epoch 50 | loss: 0.46303 | train_auc: 0.92214 | train_accuracy: 0.81481 | test_auc: 0.91607 | test_accuracy: 0.84    |  0:00:11s
# epoch 60 | loss: 0.38984 | train_auc: 0.89572 | train_accuracy: 0.79461 | test_auc: 0.94666 | test_accuracy: 0.88    |  0:00:14s
# epoch 70 | loss: 0.391   | train_auc: 0.93261 | train_accuracy: 0.82828 | test_auc: 0.94523 | test_accuracy: 0.92    |  0:00:16s
# epoch 80 | loss: 0.36139 | train_auc: 0.94005 | train_accuracy: 0.84512 | test_auc: 0.93599 | test_accuracy: 0.88    |  0:00:18s
# epoch 90 | loss: 0.42334 | train_auc: 0.94078 | train_accuracy: 0.86195 | test_auc: 0.93599 | test_accuracy: 0.86667 |  0:00:20s
# epoch 100| loss: 0.31686 | train_auc: 0.94304 | train_accuracy: 0.85522 | test_auc: 0.94737 | test_accuracy: 0.89333 |  0:00:23s
# epoch 110| loss: 0.31535 | train_auc: 0.95275 | train_accuracy: 0.84175 | test_auc: 0.95164 | test_accuracy: 0.90667 |  0:00:25s
# epoch 120| loss: 0.32347 | train_auc: 0.95325 | train_accuracy: 0.85185 | test_auc: 0.93457 | test_accuracy: 0.86667 |  0:00:27s
# epoch 130| loss: 0.34312 | train_auc: 0.96313 | train_accuracy: 0.88552 | test_auc: 0.94026 | test_accuracy: 0.88    |  0:00:30s
# epoch 140| loss: 0.33725 | train_auc: 0.96304 | train_accuracy: 0.88552 | test_auc: 0.95804 | test_accuracy: 0.90667 |  0:00:32s
# epoch 150| loss: 0.35178 | train_auc: 0.96989 | train_accuracy: 0.89899 | test_auc: 0.95377 | test_accuracy: 0.92    |  0:00:34s
# epoch 160| loss: 0.3069  | train_auc: 0.9547  | train_accuracy: 0.86869 | test_auc: 0.92461 | test_accuracy: 0.84    |  0:00:36s
#
# Early stopping occurred at epoch 162 with best_epoch = 102 and best_test_accuracy = 0.94667
#
# --- Processing: psd_alpha ---
# Shape: (372, 19)
# Missing values: 0
# epoch 0  | loss: 0.90599 | train_auc: 0.5614  | train_accuracy: 0.52189 | test_auc: 0.60455 | test_accuracy: 0.52    |  0:00:00s
# epoch 10 | loss: 0.59837 | train_auc: 0.7149  | train_accuracy: 0.6835  | test_auc: 0.65789 | test_accuracy: 0.65333 |  0:00:02s
# epoch 20 | loss: 0.50476 | train_auc: 0.87003 | train_accuracy: 0.77778 | test_auc: 0.87767 | test_accuracy: 0.8     |  0:00:04s
# epoch 30 | loss: 0.47091 | train_auc: 0.87448 | train_accuracy: 0.78788 | test_auc: 0.86486 | test_accuracy: 0.84    |  0:00:07s
# epoch 40 | loss: 0.4604  | train_auc: 0.90155 | train_accuracy: 0.83165 | test_auc: 0.87767 | test_accuracy: 0.88    |  0:00:09s
# epoch 50 | loss: 0.4471  | train_auc: 0.88078 | train_accuracy: 0.79125 | test_auc: 0.89118 | test_accuracy: 0.81333 |  0:00:11s
# epoch 60 | loss: 0.3887  | train_auc: 0.92064 | train_accuracy: 0.85185 | test_auc: 0.899   | test_accuracy: 0.85333 |  0:00:13s
# epoch 70 | loss: 0.43949 | train_auc: 0.9313  | train_accuracy: 0.86195 | test_auc: 0.90683 | test_accuracy: 0.85333 |  0:00:16s
# epoch 80 | loss: 0.35005 | train_auc: 0.9318  | train_accuracy: 0.85859 | test_auc: 0.91252 | test_accuracy: 0.88    |  0:00:18s
# epoch 90 | loss: 0.38311 | train_auc: 0.95624 | train_accuracy: 0.85859 | test_auc: 0.92105 | test_accuracy: 0.89333 |  0:00:20s
# epoch 100| loss: 0.39242 | train_auc: 0.92277 | train_accuracy: 0.83838 | test_auc: 0.91679 | test_accuracy: 0.82667 |  0:00:22s
# epoch 110| loss: 0.32949 | train_auc: 0.95629 | train_accuracy: 0.84512 | test_auc: 0.90043 | test_accuracy: 0.85333 |  0:00:25s
# epoch 120| loss: 0.36403 | train_auc: 0.94236 | train_accuracy: 0.86195 | test_auc: 0.91038 | test_accuracy: 0.85333 |  0:00:27s
# epoch 130| loss: 0.33148 | train_auc: 0.95882 | train_accuracy: 0.86195 | test_auc: 0.91892 | test_accuracy: 0.89333 |  0:00:29s
# epoch 140| loss: 0.32039 | train_auc: 0.95275 | train_accuracy: 0.86532 | test_auc: 0.91963 | test_accuracy: 0.88    |  0:00:32s
# epoch 150| loss: 0.30598 | train_auc: 0.9591  | train_accuracy: 0.87879 | test_auc: 0.92034 | test_accuracy: 0.86667 |  0:00:34s
#
# Early stopping occurred at epoch 152 with best_epoch = 92 and best_test_accuracy = 0.90667
#
# --- Processing: psd_beta ---
# Shape: (372, 19)
# Missing values: 0
# epoch 0  | loss: 0.86295 | train_auc: 0.60557 | train_accuracy: 0.57576 | test_auc: 0.72333 | test_accuracy: 0.66667 |  0:00:00s
# epoch 10 | loss: 0.55869 | train_auc: 0.73721 | train_accuracy: 0.6734  | test_auc: 0.79587 | test_accuracy: 0.69333 |  0:00:02s
# epoch 20 | loss: 0.54512 | train_auc: 0.84405 | train_accuracy: 0.73401 | test_auc: 0.87553 | test_accuracy: 0.8     |  0:00:04s
# epoch 30 | loss: 0.47741 | train_auc: 0.86654 | train_accuracy: 0.80471 | test_auc: 0.84708 | test_accuracy: 0.78667 |  0:00:07s
# epoch 40 | loss: 0.45235 | train_auc: 0.89625 | train_accuracy: 0.81145 | test_auc: 0.7909  | test_accuracy: 0.74667 |  0:00:09s
# epoch 50 | loss: 0.43444 | train_auc: 0.92409 | train_accuracy: 0.83838 | test_auc: 0.87269 | test_accuracy: 0.8     |  0:00:11s
# epoch 60 | loss: 0.38886 | train_auc: 0.94477 | train_accuracy: 0.87542 | test_auc: 0.88122 | test_accuracy: 0.81333 |  0:00:14s
# epoch 70 | loss: 0.36    | train_auc: 0.9576  | train_accuracy: 0.87542 | test_auc: 0.85917 | test_accuracy: 0.78667 |  0:00:16s
# epoch 80 | loss: 0.35717 | train_auc: 0.93933 | train_accuracy: 0.87205 | test_auc: 0.8293  | test_accuracy: 0.78667 |  0:00:18s
#
# Early stopping occurred at epoch 85 with best_epoch = 25 and best_test_accuracy = 0.86667
#
# --- Processing: psd_highbeta ---
# Shape: (372, 19)
# Missing values: 0
# epoch 0  | loss: 0.86278 | train_auc: 0.52068 | train_accuracy: 0.51178 | test_auc: 0.48933 | test_accuracy: 0.53333 |  0:00:00s
# epoch 10 | loss: 0.59175 | train_auc: 0.80161 | train_accuracy: 0.68687 | test_auc: 0.77525 | test_accuracy: 0.72    |  0:00:02s
# epoch 20 | loss: 0.49083 | train_auc: 0.8338  | train_accuracy: 0.74411 | test_auc: 0.88905 | test_accuracy: 0.74667 |  0:00:04s
# epoch 30 | loss: 0.49354 | train_auc: 0.86559 | train_accuracy: 0.76094 | test_auc: 0.85562 | test_accuracy: 0.78667 |  0:00:07s
# epoch 40 | loss: 0.44417 | train_auc: 0.85183 | train_accuracy: 0.75758 | test_auc: 0.79374 | test_accuracy: 0.70667 |  0:00:09s
# epoch 50 | loss: 0.49007 | train_auc: 0.9133  | train_accuracy: 0.83165 | test_auc: 0.87838 | test_accuracy: 0.78667 |  0:00:11s
# epoch 60 | loss: 0.41347 | train_auc: 0.91529 | train_accuracy: 0.82492 | test_auc: 0.88336 | test_accuracy: 0.78667 |  0:00:13s
# epoch 70 | loss: 0.426   | train_auc: 0.90813 | train_accuracy: 0.82828 | test_auc: 0.8165  | test_accuracy: 0.8     |  0:00:16s
# epoch 80 | loss: 0.39487 | train_auc: 0.91656 | train_accuracy: 0.83502 | test_auc: 0.91679 | test_accuracy: 0.85333 |  0:00:18s
#
# Early stopping occurred at epoch 86 with best_epoch = 26 and best_test_accuracy = 0.86667
#
# --- Processing: psd_gamma ---
# Shape: (372, 19)
# Missing values: 0
# epoch 0  | loss: 0.88556 | train_auc: 0.5263  | train_accuracy: 0.51515 | test_auc: 0.52205 | test_accuracy: 0.49333 |  0:00:00s
# epoch 10 | loss: 0.54416 | train_auc: 0.83328 | train_accuracy: 0.74411 | test_auc: 0.75889 | test_accuracy: 0.66667 |  0:00:02s
# epoch 20 | loss: 0.53208 | train_auc: 0.85951 | train_accuracy: 0.75758 | test_auc: 0.8478  | test_accuracy: 0.81333 |  0:00:04s
# epoch 30 | loss: 0.52668 | train_auc: 0.8791  | train_accuracy: 0.78788 | test_auc: 0.88762 | test_accuracy: 0.8     |  0:00:07s
# epoch 40 | loss: 0.48851 | train_auc: 0.87321 | train_accuracy: 0.78451 | test_auc: 0.83713 | test_accuracy: 0.78667 |  0:00:09s
# epoch 50 | loss: 0.40307 | train_auc: 0.90473 | train_accuracy: 0.82828 | test_auc: 0.87411 | test_accuracy: 0.81333 |  0:00:11s
# epoch 60 | loss: 0.4239  | train_auc: 0.91987 | train_accuracy: 0.85522 | test_auc: 0.92319 | test_accuracy: 0.86667 |  0:00:13s
# epoch 70 | loss: 0.42427 | train_auc: 0.90309 | train_accuracy: 0.80471 | test_auc: 0.86984 | test_accuracy: 0.8     |  0:00:16s
# epoch 80 | loss: 0.38093 | train_auc: 0.91026 | train_accuracy: 0.82155 | test_auc: 0.92034 | test_accuracy: 0.8     |  0:00:18s
# epoch 90 | loss: 0.45591 | train_auc: 0.9371  | train_accuracy: 0.85522 | test_auc: 0.86771 | test_accuracy: 0.8     |  0:00:20s
# epoch 100| loss: 0.40255 | train_auc: 0.9235  | train_accuracy: 0.83165 | test_auc: 0.87269 | test_accuracy: 0.81333 |  0:00:22s
# epoch 110| loss: 0.39596 | train_auc: 0.94449 | train_accuracy: 0.84512 | test_auc: 0.90754 | test_accuracy: 0.81333 |  0:00:25s
# epoch 120| loss: 0.343   | train_auc: 0.9452  | train_accuracy: 0.84512 | test_auc: 0.90327 | test_accuracy: 0.8     |  0:00:27s
#
# Early stopping occurred at epoch 121 with best_epoch = 61 and best_test_accuracy = 0.88
#
# --- Processing: fc_delta ---
# Shape: (372, 171)
# Missing values: 0
# epoch 0  | loss: 0.80835 | train_auc: 0.4995  | train_accuracy: 0.48148 | test_auc: 0.44737 | test_accuracy: 0.46667 |  0:00:00s
# epoch 10 | loss: 0.65182 | train_auc: 0.69735 | train_accuracy: 0.6229  | test_auc: 0.73257 | test_accuracy: 0.58667 |  0:00:02s
# epoch 20 | loss: 0.55337 | train_auc: 0.84682 | train_accuracy: 0.76094 | test_auc: 0.70341 | test_accuracy: 0.61333 |  0:00:04s
# epoch 30 | loss: 0.5411  | train_auc: 0.87734 | train_accuracy: 0.79798 | test_auc: 0.81294 | test_accuracy: 0.74667 |  0:00:07s
# epoch 40 | loss: 0.45807 | train_auc: 0.86287 | train_accuracy: 0.78451 | test_auc: 0.81437 | test_accuracy: 0.70667 |  0:00:09s
# epoch 50 | loss: 0.44297 | train_auc: 0.91194 | train_accuracy: 0.82492 | test_auc: 0.77809 | test_accuracy: 0.69333 |  0:00:11s
# epoch 60 | loss: 0.35721 | train_auc: 0.95456 | train_accuracy: 0.86869 | test_auc: 0.73826 | test_accuracy: 0.68    |  0:00:13s
# epoch 70 | loss: 0.4533  | train_auc: 0.96386 | train_accuracy: 0.90236 | test_auc: 0.77169 | test_accuracy: 0.69333 |  0:00:16s
# epoch 80 | loss: 0.37655 | train_auc: 0.91477 | train_accuracy: 0.80808 | test_auc: 0.87269 | test_accuracy: 0.76    |  0:00:18s
# epoch 90 | loss: 0.31965 | train_auc: 0.97046 | train_accuracy: 0.93603 | test_auc: 0.81366 | test_accuracy: 0.72    |  0:00:20s
# epoch 100| loss: 0.30923 | train_auc: 0.98655 | train_accuracy: 0.94613 | test_auc: 0.78236 | test_accuracy: 0.72    |  0:00:22s
# epoch 110| loss: 0.21633 | train_auc: 0.99227 | train_accuracy: 0.9596  | test_auc: 0.87198 | test_accuracy: 0.8     |  0:00:25s
# epoch 120| loss: 0.19114 | train_auc: 0.99381 | train_accuracy: 0.97306 | test_auc: 0.85846 | test_accuracy: 0.74667 |  0:00:27s
# epoch 130| loss: 0.20539 | train_auc: 0.99456 | train_accuracy: 0.96633 | test_auc: 0.86558 | test_accuracy: 0.78667 |  0:00:29s
# epoch 140| loss: 0.14745 | train_auc: 0.98903 | train_accuracy: 0.95623 | test_auc: 0.86415 | test_accuracy: 0.73333 |  0:00:32s
# epoch 150| loss: 0.24186 | train_auc: 0.99565 | train_accuracy: 0.94949 | test_auc: 0.88905 | test_accuracy: 0.77333 |  0:00:34s
# epoch 160| loss: 0.20789 | train_auc: 0.99261 | train_accuracy: 0.96296 | test_auc: 0.84851 | test_accuracy: 0.74667 |  0:00:37s
# epoch 170| loss: 0.18721 | train_auc: 0.99878 | train_accuracy: 0.98316 | test_auc: 0.87411 | test_accuracy: 0.8     |  0:00:39s
# epoch 180| loss: 0.20603 | train_auc: 0.99855 | train_accuracy: 0.9798  | test_auc: 0.87127 | test_accuracy: 0.77333 |  0:00:41s
# epoch 190| loss: 0.10895 | train_auc: 0.99923 | train_accuracy: 0.99327 | test_auc: 0.85349 | test_accuracy: 0.72    |  0:00:43s
# Stop training because you reached max_epochs = 200 with best_epoch = 145 and best_test_accuracy = 0.84
#
# --- Processing: fc_theta ---
# Shape: (372, 171)
# Missing values: 0
# epoch 0  | loss: 0.79882 | train_auc: 0.45288 | train_accuracy: 0.45791 | test_auc: 0.45875 | test_accuracy: 0.46667 |  0:00:00s
# epoch 10 | loss: 0.64499 | train_auc: 0.66543 | train_accuracy: 0.60943 | test_auc: 0.50569 | test_accuracy: 0.50667 |  0:00:02s
# epoch 20 | loss: 0.53703 | train_auc: 0.82015 | train_accuracy: 0.70707 | test_auc: 0.67568 | test_accuracy: 0.58667 |  0:00:04s
# epoch 30 | loss: 0.4355  | train_auc: 0.89044 | train_accuracy: 0.80135 | test_auc: 0.75462 | test_accuracy: 0.74667 |  0:00:07s
# epoch 40 | loss: 0.40217 | train_auc: 0.921   | train_accuracy: 0.84848 | test_auc: 0.76316 | test_accuracy: 0.73333 |  0:00:09s
# epoch 50 | loss: 0.37407 | train_auc: 0.94363 | train_accuracy: 0.85522 | test_auc: 0.80085 | test_accuracy: 0.73333 |  0:00:11s
# epoch 60 | loss: 0.20954 | train_auc: 0.98186 | train_accuracy: 0.94949 | test_auc: 0.81721 | test_accuracy: 0.81333 |  0:00:13s
# epoch 70 | loss: 0.27396 | train_auc: 0.99166 | train_accuracy: 0.96296 | test_auc: 0.86486 | test_accuracy: 0.82667 |  0:00:16s
# epoch 80 | loss: 0.22114 | train_auc: 0.99497 | train_accuracy: 0.95623 | test_auc: 0.83855 | test_accuracy: 0.72    |  0:00:18s
# epoch 90 | loss: 0.21915 | train_auc: 0.9878  | train_accuracy: 0.96633 | test_auc: 0.84851 | test_accuracy: 0.81333 |  0:00:20s
# epoch 100| loss: 0.19413 | train_auc: 0.99474 | train_accuracy: 0.96633 | test_auc: 0.89545 | test_accuracy: 0.78667 |  0:00:23s
# epoch 110| loss: 0.13757 | train_auc: 0.99723 | train_accuracy: 0.98653 | test_auc: 0.88478 | test_accuracy: 0.81333 |  0:00:25s
# epoch 120| loss: 0.13456 | train_auc: 0.99873 | train_accuracy: 0.98653 | test_auc: 0.86273 | test_accuracy: 0.84    |  0:00:27s
#
# Early stopping occurred at epoch 123 with best_epoch = 63 and best_test_accuracy = 0.85333
#
# --- Processing: fc_alpha ---
# Shape: (372, 171)
# Missing values: 0
# epoch 0  | loss: 0.82541 | train_auc: 0.4825  | train_accuracy: 0.48148 | test_auc: 0.5128  | test_accuracy: 0.49333 |  0:00:00s
# epoch 10 | loss: 0.69639 | train_auc: 0.65985 | train_accuracy: 0.61616 | test_auc: 0.60313 | test_accuracy: 0.50667 |  0:00:02s
# epoch 20 | loss: 0.62288 | train_auc: 0.7578  | train_accuracy: 0.6835  | test_auc: 0.76529 | test_accuracy: 0.66667 |  0:00:04s
# epoch 30 | loss: 0.60464 | train_auc: 0.80473 | train_accuracy: 0.70707 | test_auc: 0.71195 | test_accuracy: 0.6     |  0:00:07s
# epoch 40 | loss: 0.55069 | train_auc: 0.78619 | train_accuracy: 0.75084 | test_auc: 0.66714 | test_accuracy: 0.69333 |  0:00:09s
# epoch 50 | loss: 0.53328 | train_auc: 0.86106 | train_accuracy: 0.77778 | test_auc: 0.84637 | test_accuracy: 0.8     |  0:00:11s
# epoch 60 | loss: 0.46993 | train_auc: 0.90495 | train_accuracy: 0.82155 | test_auc: 0.74751 | test_accuracy: 0.74667 |  0:00:14s
# epoch 70 | loss: 0.35576 | train_auc: 0.9554  | train_accuracy: 0.89562 | test_auc: 0.7596  | test_accuracy: 0.72    |  0:00:16s
# epoch 80 | loss: 0.39195 | train_auc: 0.96173 | train_accuracy: 0.90909 | test_auc: 0.77596 | test_accuracy: 0.77333 |  0:00:19s
# epoch 90 | loss: 0.26125 | train_auc: 0.9727  | train_accuracy: 0.93603 | test_auc: 0.83428 | test_accuracy: 0.78667 |  0:00:21s
# epoch 100| loss: 0.39088 | train_auc: 0.97533 | train_accuracy: 0.92593 | test_auc: 0.80725 | test_accuracy: 0.8     |  0:00:23s
# epoch 110| loss: 0.25506 | train_auc: 0.97964 | train_accuracy: 0.94949 | test_auc: 0.79161 | test_accuracy: 0.77333 |  0:00:25s
# epoch 120| loss: 0.21579 | train_auc: 0.97819 | train_accuracy: 0.92256 | test_auc: 0.77738 | test_accuracy: 0.76    |  0:00:28s
# epoch 130| loss: 0.24879 | train_auc: 0.99025 | train_accuracy: 0.9697  | test_auc: 0.82646 | test_accuracy: 0.78667 |  0:00:30s
# epoch 140| loss: 0.20091 | train_auc: 0.99152 | train_accuracy: 0.97643 | test_auc: 0.84282 | test_accuracy: 0.82667 |  0:00:32s
# epoch 150| loss: 0.16893 | train_auc: 0.99007 | train_accuracy: 0.97306 | test_auc: 0.8101  | test_accuracy: 0.78667 |  0:00:34s
# epoch 160| loss: 0.16982 | train_auc: 0.99528 | train_accuracy: 0.9798  | test_auc: 0.82504 | test_accuracy: 0.8     |  0:00:37s
# epoch 170| loss: 0.15808 | train_auc: 0.99619 | train_accuracy: 0.97643 | test_auc: 0.82432 | test_accuracy: 0.77333 |  0:00:39s
# epoch 180| loss: 0.12231 | train_auc: 0.99365 | train_accuracy: 0.9798  | test_auc: 0.87767 | test_accuracy: 0.82667 |  0:00:41s
#
# Early stopping occurred at epoch 186 with best_epoch = 126 and best_test_accuracy = 0.84
#
# --- Processing: fc_beta ---
# Shape: (372, 171)
# Missing values: 0
# epoch 0  | loss: 0.83443 | train_auc: 0.45107 | train_accuracy: 0.48822 | test_auc: 0.5128  | test_accuracy: 0.50667 |  0:00:00s
# epoch 10 | loss: 0.63268 | train_auc: 0.68719 | train_accuracy: 0.60269 | test_auc: 0.6138  | test_accuracy: 0.53333 |  0:00:02s
# epoch 20 | loss: 0.65216 | train_auc: 0.6745  | train_accuracy: 0.60606 | test_auc: 0.5377  | test_accuracy: 0.49333 |  0:00:04s
# epoch 30 | loss: 0.65355 | train_auc: 0.76542 | train_accuracy: 0.69697 | test_auc: 0.63727 | test_accuracy: 0.61333 |  0:00:07s
# epoch 40 | loss: 0.5611  | train_auc: 0.80229 | train_accuracy: 0.7037  | test_auc: 0.61024 | test_accuracy: 0.58667 |  0:00:09s
# epoch 50 | loss: 0.54094 | train_auc: 0.78378 | train_accuracy: 0.68687 | test_auc: 0.6394  | test_accuracy: 0.58667 |  0:00:11s
# epoch 60 | loss: 0.5181  | train_auc: 0.87266 | train_accuracy: 0.78788 | test_auc: 0.60953 | test_accuracy: 0.54667 |  0:00:14s
# epoch 70 | loss: 0.4643  | train_auc: 0.8981  | train_accuracy: 0.82155 | test_auc: 0.68777 | test_accuracy: 0.61333 |  0:00:16s
# epoch 80 | loss: 0.4138  | train_auc: 0.90908 | train_accuracy: 0.81481 | test_auc: 0.71195 | test_accuracy: 0.62667 |  0:00:18s
# epoch 90 | loss: 0.31756 | train_auc: 0.97034 | train_accuracy: 0.89899 | test_auc: 0.82148 | test_accuracy: 0.73333 |  0:00:20s
# epoch 100| loss: 0.32996 | train_auc: 0.96145 | train_accuracy: 0.88215 | test_auc: 0.78805 | test_accuracy: 0.73333 |  0:00:23s
# epoch 110| loss: 0.22463 | train_auc: 0.97474 | train_accuracy: 0.92929 | test_auc: 0.86913 | test_accuracy: 0.82667 |  0:00:25s
# epoch 120| loss: 0.2054  | train_auc: 0.99057 | train_accuracy: 0.9596  | test_auc: 0.83215 | test_accuracy: 0.8     |  0:00:27s
# epoch 130| loss: 0.17787 | train_auc: 0.98962 | train_accuracy: 0.96296 | test_auc: 0.85704 | test_accuracy: 0.76    |  0:00:29s
# epoch 140| loss: 0.20857 | train_auc: 0.99429 | train_accuracy: 0.97306 | test_auc: 0.81081 | test_accuracy: 0.76    |  0:00:32s
# epoch 150| loss: 0.20789 | train_auc: 0.99655 | train_accuracy: 0.97643 | test_auc: 0.90754 | test_accuracy: 0.81333 |  0:00:34s
# epoch 160| loss: 0.23454 | train_auc: 0.99619 | train_accuracy: 0.96296 | test_auc: 0.89545 | test_accuracy: 0.8     |  0:00:36s
# epoch 170| loss: 0.12158 | train_auc: 0.99547 | train_accuracy: 0.9899  | test_auc: 0.87838 | test_accuracy: 0.77333 |  0:00:39s
#
# Early stopping occurred at epoch 171 with best_epoch = 111 and best_test_accuracy = 0.86667
#
# --- Processing: fc_highbeta ---
# Shape: (372, 171)
# Missing values: 0
# epoch 0  | loss: 0.86897 | train_auc: 0.51841 | train_accuracy: 0.50842 | test_auc: 0.5     | test_accuracy: 0.50667 |  0:00:00s
# epoch 10 | loss: 0.69103 | train_auc: 0.63699 | train_accuracy: 0.6229  | test_auc: 0.58321 | test_accuracy: 0.57333 |  0:00:02s
# epoch 20 | loss: 0.61241 | train_auc: 0.66556 | train_accuracy: 0.62626 | test_auc: 0.70199 | test_accuracy: 0.66667 |  0:00:04s
# epoch 30 | loss: 0.64696 | train_auc: 0.74093 | train_accuracy: 0.62963 | test_auc: 0.65149 | test_accuracy: 0.64    |  0:00:07s
# epoch 40 | loss: 0.55865 | train_auc: 0.77335 | train_accuracy: 0.7037  | test_auc: 0.64225 | test_accuracy: 0.61333 |  0:00:09s
# epoch 50 | loss: 0.52872 | train_auc: 0.90305 | train_accuracy: 0.81481 | test_auc: 0.84139 | test_accuracy: 0.78667 |  0:00:11s
# epoch 60 | loss: 0.34824 | train_auc: 0.94073 | train_accuracy: 0.86195 | test_auc: 0.88265 | test_accuracy: 0.82667 |  0:00:14s
# epoch 70 | loss: 0.43571 | train_auc: 0.95502 | train_accuracy: 0.88552 | test_auc: 0.91038 | test_accuracy: 0.82667 |  0:00:16s
# epoch 80 | loss: 0.36112 | train_auc: 0.97683 | train_accuracy: 0.92593 | test_auc: 0.92105 | test_accuracy: 0.90667 |  0:00:18s
# epoch 90 | loss: 0.26003 | train_auc: 0.9644  | train_accuracy: 0.88215 | test_auc: 0.80228 | test_accuracy: 0.73333 |  0:00:20s
# epoch 100| loss: 0.31485 | train_auc: 0.98159 | train_accuracy: 0.89226 | test_auc: 0.92034 | test_accuracy: 0.8     |  0:00:23s
# epoch 110| loss: 0.1393  | train_auc: 0.97896 | train_accuracy: 0.92256 | test_auc: 0.86913 | test_accuracy: 0.76    |  0:00:25s
# epoch 120| loss: 0.14128 | train_auc: 0.97837 | train_accuracy: 0.92593 | test_auc: 0.89545 | test_accuracy: 0.85333 |  0:00:27s
# epoch 130| loss: 0.15682 | train_auc: 0.98617 | train_accuracy: 0.94276 | test_auc: 0.89758 | test_accuracy: 0.78667 |  0:00:30s
# epoch 140| loss: 0.12289 | train_auc: 0.99469 | train_accuracy: 0.9697  | test_auc: 0.90683 | test_accuracy: 0.84    |  0:00:32s
#
# Early stopping occurred at epoch 140 with best_epoch = 80 and best_test_accuracy = 0.90667
#
# --- Processing: fc_gamma ---
# Shape: (372, 171)
# Missing values: 0
# epoch 0  | loss: 0.89646 | train_auc: 0.43452 | train_accuracy: 0.46465 | test_auc: 0.51707 | test_accuracy: 0.54667 |  0:00:00s
# epoch 10 | loss: 0.70468 | train_auc: 0.64765 | train_accuracy: 0.59596 | test_auc: 0.63158 | test_accuracy: 0.62667 |  0:00:02s
# epoch 20 | loss: 0.65851 | train_auc: 0.73889 | train_accuracy: 0.68013 | test_auc: 0.70128 | test_accuracy: 0.61333 |  0:00:04s
# epoch 30 | loss: 0.61065 | train_auc: 0.7368  | train_accuracy: 0.6936  | test_auc: 0.73471 | test_accuracy: 0.69333 |  0:00:07s
# epoch 40 | loss: 0.51158 | train_auc: 0.83367 | train_accuracy: 0.76094 | test_auc: 0.85064 | test_accuracy: 0.78667 |  0:00:09s
# epoch 50 | loss: 0.51008 | train_auc: 0.87743 | train_accuracy: 0.81818 | test_auc: 0.86558 | test_accuracy: 0.82667 |  0:00:11s
# epoch 60 | loss: 0.41861 | train_auc: 0.89103 | train_accuracy: 0.78788 | test_auc: 0.88549 | test_accuracy: 0.81333 |  0:00:14s
# epoch 70 | loss: 0.50103 | train_auc: 0.84455 | train_accuracy: 0.78451 | test_auc: 0.84424 | test_accuracy: 0.78667 |  0:00:16s
# epoch 80 | loss: 0.40315 | train_auc: 0.94132 | train_accuracy: 0.86869 | test_auc: 0.91536 | test_accuracy: 0.81333 |  0:00:18s
# epoch 90 | loss: 0.34436 | train_auc: 0.95384 | train_accuracy: 0.89226 | test_auc: 0.90541 | test_accuracy: 0.84    |  0:00:20s
# epoch 100| loss: 0.30149 | train_auc: 0.96993 | train_accuracy: 0.89226 | test_auc: 0.89047 | test_accuracy: 0.81333 |  0:00:23s
# epoch 110| loss: 0.22158 | train_auc: 0.979   | train_accuracy: 0.92256 | test_auc: 0.86415 | test_accuracy: 0.78667 |  0:00:25s
# epoch 120| loss: 0.15722 | train_auc: 0.99678 | train_accuracy: 0.9697  | test_auc: 0.899   | test_accuracy: 0.84    |  0:00:27s
# epoch 130| loss: 0.16959 | train_auc: 0.99687 | train_accuracy: 0.97306 | test_auc: 0.92319 | test_accuracy: 0.89333 |  0:00:30s
# epoch 140| loss: 0.12227 | train_auc: 0.98862 | train_accuracy: 0.94613 | test_auc: 0.87055 | test_accuracy: 0.8     |  0:00:32s
# epoch 150| loss: 0.16238 | train_auc: 0.99406 | train_accuracy: 0.93266 | test_auc: 0.91821 | test_accuracy: 0.86667 |  0:00:34s
# epoch 160| loss: 0.2563  | train_auc: 0.99955 | train_accuracy: 0.99327 | test_auc: 0.90683 | test_accuracy: 0.84    |  0:00:37s
# epoch 170| loss: 0.15666 | train_auc: 0.99488 | train_accuracy: 0.97643 | test_auc: 0.89758 | test_accuracy: 0.81333 |  0:00:39s
# epoch 180| loss: 0.18216 | train_auc: 0.99837 | train_accuracy: 0.96296 | test_auc: 0.90185 | test_accuracy: 0.86667 |  0:00:41s
# epoch 190| loss: 0.09473 | train_auc: 0.99692 | train_accuracy: 0.96296 | test_auc: 0.8798  | test_accuracy: 0.8     |  0:00:44s
#
# Early stopping occurred at epoch 191 with best_epoch = 131 and best_test_accuracy = 0.90667
#
# --- Processing: psd_fc_delta ---
# Shape: (372, 190)
# Missing values: 0
# epoch 0  | loss: 1.35615 | train_auc: 0.44554 | train_accuracy: 0.47811 | test_auc: 0.36913 | test_accuracy: 0.46667 |  0:00:00s
# epoch 10 | loss: 0.68905 | train_auc: 0.62448 | train_accuracy: 0.57576 | test_auc: 0.49716 | test_accuracy: 0.52    |  0:00:02s
# epoch 20 | loss: 0.6594  | train_auc: 0.63582 | train_accuracy: 0.60606 | test_auc: 0.62873 | test_accuracy: 0.65333 |  0:00:04s
# epoch 30 | loss: 0.60677 | train_auc: 0.77866 | train_accuracy: 0.65657 | test_auc: 0.64011 | test_accuracy: 0.57333 |  0:00:07s
# epoch 40 | loss: 0.60697 | train_auc: 0.80895 | train_accuracy: 0.75084 | test_auc: 0.73755 | test_accuracy: 0.66667 |  0:00:09s
# epoch 50 | loss: 0.48258 | train_auc: 0.83475 | train_accuracy: 0.74747 | test_auc: 0.6266  | test_accuracy: 0.62667 |  0:00:11s
# epoch 60 | loss: 0.59698 | train_auc: 0.83503 | train_accuracy: 0.74074 | test_auc: 0.75818 | test_accuracy: 0.68    |  0:00:14s
# epoch 70 | loss: 0.50636 | train_auc: 0.89339 | train_accuracy: 0.77778 | test_auc: 0.78876 | test_accuracy: 0.72    |  0:00:16s
# epoch 80 | loss: 0.41966 | train_auc: 0.89974 | train_accuracy: 0.81818 | test_auc: 0.7724  | test_accuracy: 0.65333 |  0:00:18s
# epoch 90 | loss: 0.33666 | train_auc: 0.97764 | train_accuracy: 0.90236 | test_auc: 0.90754 | test_accuracy: 0.8     |  0:00:21s
# epoch 100| loss: 0.28797 | train_auc: 0.98544 | train_accuracy: 0.92929 | test_auc: 0.86842 | test_accuracy: 0.81333 |  0:00:23s
# epoch 110| loss: 0.28979 | train_auc: 0.97606 | train_accuracy: 0.93939 | test_auc: 0.8734  | test_accuracy: 0.8     |  0:00:25s
# epoch 120| loss: 0.36533 | train_auc: 0.98204 | train_accuracy: 0.93266 | test_auc: 0.8357  | test_accuracy: 0.76    |  0:00:28s
# epoch 130| loss: 0.31939 | train_auc: 0.98299 | train_accuracy: 0.94276 | test_auc: 0.87055 | test_accuracy: 0.77333 |  0:00:30s
# epoch 140| loss: 0.28093 | train_auc: 0.98971 | train_accuracy: 0.94949 | test_auc: 0.88265 | test_accuracy: 0.78667 |  0:00:32s
# epoch 150| loss: 0.25666 | train_auc: 0.99356 | train_accuracy: 0.95623 | test_auc: 0.9431  | test_accuracy: 0.82667 |  0:00:35s
# epoch 160| loss: 0.13388 | train_auc: 0.99587 | train_accuracy: 0.97306 | test_auc: 0.83997 | test_accuracy: 0.77333 |  0:00:37s
# epoch 170| loss: 0.1309  | train_auc: 0.99891 | train_accuracy: 0.98316 | test_auc: 0.84211 | test_accuracy: 0.74667 |  0:00:39s
#
# Early stopping occurred at epoch 174 with best_epoch = 114 and best_test_accuracy = 0.84
#
# --- Processing: psd_fc_theta ---
# Shape: (372, 190)
# Missing values: 0
# epoch 0  | loss: 1.19169 | train_auc: 0.48526 | train_accuracy: 0.49158 | test_auc: 0.46871 | test_accuracy: 0.49333 |  0:00:00s
# epoch 10 | loss: 0.74153 | train_auc: 0.50487 | train_accuracy: 0.50168 | test_auc: 0.56401 | test_accuracy: 0.54667 |  0:00:02s
# epoch 20 | loss: 0.66687 | train_auc: 0.6954  | train_accuracy: 0.63636 | test_auc: 0.60882 | test_accuracy: 0.58667 |  0:00:04s
# epoch 30 | loss: 0.57987 | train_auc: 0.82532 | train_accuracy: 0.73737 | test_auc: 0.80512 | test_accuracy: 0.76    |  0:00:07s
# epoch 40 | loss: 0.47095 | train_auc: 0.88563 | train_accuracy: 0.79798 | test_auc: 0.84495 | test_accuracy: 0.77333 |  0:00:09s
# epoch 50 | loss: 0.37688 | train_auc: 0.93815 | train_accuracy: 0.86532 | test_auc: 0.7845  | test_accuracy: 0.74667 |  0:00:11s
# epoch 60 | loss: 0.28785 | train_auc: 0.95053 | train_accuracy: 0.87879 | test_auc: 0.84282 | test_accuracy: 0.72    |  0:00:14s
# epoch 70 | loss: 0.28358 | train_auc: 0.97293 | train_accuracy: 0.89562 | test_auc: 0.88762 | test_accuracy: 0.78667 |  0:00:16s
# epoch 80 | loss: 0.30323 | train_auc: 0.97819 | train_accuracy: 0.93603 | test_auc: 0.85633 | test_accuracy: 0.84    |  0:00:18s
# epoch 90 | loss: 0.23038 | train_auc: 0.98558 | train_accuracy: 0.93603 | test_auc: 0.84993 | test_accuracy: 0.73333 |  0:00:21s
# epoch 100| loss: 0.27194 | train_auc: 0.98739 | train_accuracy: 0.93939 | test_auc: 0.87909 | test_accuracy: 0.82667 |  0:00:23s
# epoch 110| loss: 0.2065  | train_auc: 0.97948 | train_accuracy: 0.94276 | test_auc: 0.86344 | test_accuracy: 0.77333 |  0:00:25s
# epoch 120| loss: 0.28724 | train_auc: 0.99438 | train_accuracy: 0.9697  | test_auc: 0.899   | test_accuracy: 0.82667 |  0:00:27s
# epoch 130| loss: 0.22924 | train_auc: 0.99859 | train_accuracy: 0.9798  | test_auc: 0.88122 | test_accuracy: 0.8     |  0:00:29s
#
# Early stopping occurred at epoch 137 with best_epoch = 77 and best_test_accuracy = 0.88
#
# --- Processing: psd_fc_alpha ---
# Shape: (372, 190)
# Missing values: 0
# epoch 0  | loss: 1.28445 | train_auc: 0.50245 | train_accuracy: 0.49158 | test_auc: 0.54694 | test_accuracy: 0.49333 |  0:00:00s
# epoch 10 | loss: 0.65397 | train_auc: 0.64348 | train_accuracy: 0.633   | test_auc: 0.69417 | test_accuracy: 0.64    |  0:00:02s
# epoch 20 | loss: 0.59121 | train_auc: 0.76097 | train_accuracy: 0.65993 | test_auc: 0.64367 | test_accuracy: 0.58667 |  0:00:04s
# epoch 30 | loss: 0.59128 | train_auc: 0.75834 | train_accuracy: 0.69697 | test_auc: 0.75533 | test_accuracy: 0.69333 |  0:00:07s
# epoch 40 | loss: 0.51863 | train_auc: 0.81385 | train_accuracy: 0.73737 | test_auc: 0.78023 | test_accuracy: 0.72    |  0:00:09s
# epoch 50 | loss: 0.58923 | train_auc: 0.84995 | train_accuracy: 0.78114 | test_auc: 0.84424 | test_accuracy: 0.76    |  0:00:11s
# epoch 60 | loss: 0.52633 | train_auc: 0.88087 | train_accuracy: 0.78114 | test_auc: 0.8037  | test_accuracy: 0.70667 |  0:00:14s
# epoch 70 | loss: 0.43831 | train_auc: 0.92037 | train_accuracy: 0.81481 | test_auc: 0.77667 | test_accuracy: 0.69333 |  0:00:16s
# epoch 80 | loss: 0.35534 | train_auc: 0.93769 | train_accuracy: 0.85859 | test_auc: 0.8293  | test_accuracy: 0.72    |  0:00:18s
# epoch 90 | loss: 0.30755 | train_auc: 0.95796 | train_accuracy: 0.88215 | test_auc: 0.82788 | test_accuracy: 0.74667 |  0:00:20s
# epoch 100| loss: 0.33688 | train_auc: 0.9576  | train_accuracy: 0.89562 | test_auc: 0.84424 | test_accuracy: 0.77333 |  0:00:23s
# epoch 110| loss: 0.2849  | train_auc: 0.97483 | train_accuracy: 0.90236 | test_auc: 0.85846 | test_accuracy: 0.76    |  0:00:25s
# epoch 120| loss: 0.27779 | train_auc: 0.99397 | train_accuracy: 0.9596  | test_auc: 0.87198 | test_accuracy: 0.77333 |  0:00:27s
# epoch 130| loss: 0.21324 | train_auc: 0.9927  | train_accuracy: 0.93603 | test_auc: 0.83784 | test_accuracy: 0.76    |  0:00:30s
# epoch 140| loss: 0.2571  | train_auc: 0.99664 | train_accuracy: 0.96296 | test_auc: 0.86202 | test_accuracy: 0.77333 |  0:00:32s
# epoch 150| loss: 0.18894 | train_auc: 0.99737 | train_accuracy: 0.9798  | test_auc: 0.88976 | test_accuracy: 0.78667 |  0:00:34s
# epoch 160| loss: 0.15769 | train_auc: 0.99791 | train_accuracy: 0.9596  | test_auc: 0.88051 | test_accuracy: 0.78667 |  0:00:37s
# epoch 170| loss: 0.21118 | train_auc: 0.99732 | train_accuracy: 0.97306 | test_auc: 0.87838 | test_accuracy: 0.76    |  0:00:39s
# epoch 180| loss: 0.14927 | train_auc: 0.99923 | train_accuracy: 0.9798  | test_auc: 0.88976 | test_accuracy: 0.81333 |  0:00:41s
# epoch 190| loss: 0.11552 | train_auc: 0.99905 | train_accuracy: 0.9798  | test_auc: 0.84602 | test_accuracy: 0.78667 |  0:00:43s
# Stop training because you reached max_epochs = 200 with best_epoch = 157 and best_test_accuracy = 0.85333
#
# --- Processing: psd_fc_beta ---
# Shape: (372, 190)
# Missing values: 0
# epoch 0  | loss: 1.17044 | train_auc: 0.55346 | train_accuracy: 0.54882 | test_auc: 0.5825  | test_accuracy: 0.46667 |  0:00:00s
# epoch 10 | loss: 0.62511 | train_auc: 0.74633 | train_accuracy: 0.63973 | test_auc: 0.7027  | test_accuracy: 0.68    |  0:00:02s
# epoch 20 | loss: 0.57368 | train_auc: 0.80369 | train_accuracy: 0.7138  | test_auc: 0.62731 | test_accuracy: 0.61333 |  0:00:04s
# epoch 30 | loss: 0.48528 | train_auc: 0.90259 | train_accuracy: 0.82828 | test_auc: 0.78307 | test_accuracy: 0.73333 |  0:00:07s
# epoch 40 | loss: 0.38805 | train_auc: 0.93697 | train_accuracy: 0.86195 | test_auc: 0.84851 | test_accuracy: 0.78667 |  0:00:09s
# epoch 50 | loss: 0.42902 | train_auc: 0.95207 | train_accuracy: 0.88215 | test_auc: 0.80014 | test_accuracy: 0.72    |  0:00:11s
# epoch 60 | loss: 0.34752 | train_auc: 0.96984 | train_accuracy: 0.91246 | test_auc: 0.91607 | test_accuracy: 0.81333 |  0:00:14s
# epoch 70 | loss: 0.26795 | train_auc: 0.9898  | train_accuracy: 0.95286 | test_auc: 0.93101 | test_accuracy: 0.86667 |  0:00:16s
# epoch 80 | loss: 0.24015 | train_auc: 0.99601 | train_accuracy: 0.96633 | test_auc: 0.93172 | test_accuracy: 0.86667 |  0:00:18s
# epoch 90 | loss: 0.14044 | train_auc: 0.9927  | train_accuracy: 0.96296 | test_auc: 0.90967 | test_accuracy: 0.84    |  0:00:20s
# epoch 100| loss: 0.2018  | train_auc: 0.99864 | train_accuracy: 0.97643 | test_auc: 0.90754 | test_accuracy: 0.88    |  0:00:23s
# epoch 110| loss: 0.16908 | train_auc: 0.99796 | train_accuracy: 0.9798  | test_auc: 0.89829 | test_accuracy: 0.78667 |  0:00:25s
# epoch 120| loss: 0.237   | train_auc: 1.0     | train_accuracy: 0.99663 | test_auc: 0.92817 | test_accuracy: 0.89333 |  0:00:28s
# epoch 130| loss: 0.12734 | train_auc: 0.99964 | train_accuracy: 0.99327 | test_auc: 0.94097 | test_accuracy: 0.93333 |  0:00:30s
# epoch 140| loss: 0.1242  | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.95021 | test_accuracy: 0.93333 |  0:00:32s
# epoch 150| loss: 0.06849 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.95946 | test_accuracy: 0.90667 |  0:00:35s
# epoch 160| loss: 0.17311 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.93172 | test_accuracy: 0.86667 |  0:00:37s
# epoch 170| loss: 0.10962 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.88122 | test_accuracy: 0.85333 |  0:00:39s
# epoch 180| loss: 0.09328 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.93741 | test_accuracy: 0.89333 |  0:00:41s
# epoch 190| loss: 0.03291 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.94666 | test_accuracy: 0.85333 |  0:00:44s
#
# Early stopping occurred at epoch 196 with best_epoch = 136 and best_test_accuracy = 0.96
#
# --- Processing: psd_fc_highbeta ---
# Shape: (372, 190)
# Missing values: 0
# epoch 0  | loss: 1.29181 | train_auc: 0.50948 | train_accuracy: 0.48822 | test_auc: 0.6643  | test_accuracy: 0.6     |  0:00:00s
# epoch 10 | loss: 0.70254 | train_auc: 0.61582 | train_accuracy: 0.57576 | test_auc: 0.64296 | test_accuracy: 0.57333 |  0:00:02s
# epoch 20 | loss: 0.62423 | train_auc: 0.7135  | train_accuracy: 0.6734  | test_auc: 0.78094 | test_accuracy: 0.76    |  0:00:04s
# epoch 30 | loss: 0.60482 | train_auc: 0.79866 | train_accuracy: 0.72391 | test_auc: 0.734   | test_accuracy: 0.68    |  0:00:07s
# epoch 40 | loss: 0.4557  | train_auc: 0.8562  | train_accuracy: 0.78114 | test_auc: 0.75676 | test_accuracy: 0.68    |  0:00:09s
# epoch 50 | loss: 0.51941 | train_auc: 0.9303  | train_accuracy: 0.86195 | test_auc: 0.76529 | test_accuracy: 0.69333 |  0:00:11s
# epoch 60 | loss: 0.44626 | train_auc: 0.94069 | train_accuracy: 0.84175 | test_auc: 0.79801 | test_accuracy: 0.69333 |  0:00:14s
# epoch 70 | loss: 0.34222 | train_auc: 0.97456 | train_accuracy: 0.89562 | test_auc: 0.84068 | test_accuracy: 0.77333 |  0:00:16s
# epoch 80 | loss: 0.352   | train_auc: 0.98036 | train_accuracy: 0.93603 | test_auc: 0.83997 | test_accuracy: 0.77333 |  0:00:18s
# epoch 90 | loss: 0.20293 | train_auc: 0.99637 | train_accuracy: 0.9697  | test_auc: 0.8862  | test_accuracy: 0.81333 |  0:00:20s
# epoch 100| loss: 0.23078 | train_auc: 0.99732 | train_accuracy: 0.9697  | test_auc: 0.86913 | test_accuracy: 0.78667 |  0:00:23s
# epoch 110| loss: 0.1967  | train_auc: 0.99705 | train_accuracy: 0.96633 | test_auc: 0.88336 | test_accuracy: 0.8     |  0:00:25s
# epoch 120| loss: 0.20521 | train_auc: 0.99683 | train_accuracy: 0.96633 | test_auc: 0.88834 | test_accuracy: 0.78667 |  0:00:27s
# epoch 130| loss: 0.20316 | train_auc: 0.99732 | train_accuracy: 0.97306 | test_auc: 0.87838 | test_accuracy: 0.81333 |  0:00:29s
# epoch 140| loss: 0.17718 | train_auc: 1.0     | train_accuracy: 0.99663 | test_auc: 0.87411 | test_accuracy: 0.84    |  0:00:32s
# epoch 150| loss: 0.19033 | train_auc: 0.9976  | train_accuracy: 0.9899  | test_auc: 0.89829 | test_accuracy: 0.86667 |  0:00:34s
# epoch 160| loss: 0.13192 | train_auc: 0.99673 | train_accuracy: 0.96633 | test_auc: 0.82859 | test_accuracy: 0.76    |  0:00:36s
# epoch 170| loss: 0.16998 | train_auc: 0.98835 | train_accuracy: 0.98316 | test_auc: 0.89189 | test_accuracy: 0.85333 |  0:00:39s
# epoch 180| loss: 0.11818 | train_auc: 0.99501 | train_accuracy: 0.94949 | test_auc: 0.87553 | test_accuracy: 0.82667 |  0:00:41s
# epoch 190| loss: 0.12715 | train_auc: 0.99959 | train_accuracy: 0.98653 | test_auc: 0.87767 | test_accuracy: 0.86667 |  0:00:43s
# Stop training because you reached max_epochs = 200 with best_epoch = 172 and best_test_accuracy = 0.89333
#
# --- Processing: psd_fc_gamma ---
# Shape: (372, 190)
# Missing values: 0
# epoch 0  | loss: 1.19182 | train_auc: 0.53954 | train_accuracy: 0.54882 | test_auc: 0.56899 | test_accuracy: 0.57333 |  0:00:00s
# epoch 10 | loss: 0.65242 | train_auc: 0.66216 | train_accuracy: 0.62626 | test_auc: 0.69417 | test_accuracy: 0.68    |  0:00:02s
# epoch 20 | loss: 0.60442 | train_auc: 0.7042  | train_accuracy: 0.60269 | test_auc: 0.6458  | test_accuracy: 0.56    |  0:00:04s
# epoch 30 | loss: 0.64702 | train_auc: 0.79059 | train_accuracy: 0.7138  | test_auc: 0.75747 | test_accuracy: 0.64    |  0:00:07s
# epoch 40 | loss: 0.56076 | train_auc: 0.84645 | train_accuracy: 0.75758 | test_auc: 0.83855 | test_accuracy: 0.76    |  0:00:09s
# epoch 50 | loss: 0.48741 | train_auc: 0.87035 | train_accuracy: 0.80135 | test_auc: 0.79018 | test_accuracy: 0.76    |  0:00:11s
# epoch 60 | loss: 0.4122  | train_auc: 0.92309 | train_accuracy: 0.84175 | test_auc: 0.87127 | test_accuracy: 0.82667 |  0:00:13s
# epoch 70 | loss: 0.3434  | train_auc: 0.9605  | train_accuracy: 0.90236 | test_auc: 0.85917 | test_accuracy: 0.82667 |  0:00:16s
# epoch 80 | loss: 0.44751 | train_auc: 0.923   | train_accuracy: 0.82828 | test_auc: 0.88336 | test_accuracy: 0.82667 |  0:00:18s
# epoch 90 | loss: 0.24344 | train_auc: 0.96386 | train_accuracy: 0.90909 | test_auc: 0.84566 | test_accuracy: 0.8     |  0:00:20s
# epoch 100| loss: 0.25163 | train_auc: 0.96916 | train_accuracy: 0.89226 | test_auc: 0.81935 | test_accuracy: 0.73333 |  0:00:23s
# epoch 110| loss: 0.24899 | train_auc: 0.9722  | train_accuracy: 0.90909 | test_auc: 0.88834 | test_accuracy: 0.81333 |  0:00:25s
# epoch 120| loss: 0.20563 | train_auc: 0.99342 | train_accuracy: 0.95623 | test_auc: 0.89972 | test_accuracy: 0.84    |  0:00:27s
# epoch 130| loss: 0.23555 | train_auc: 0.99469 | train_accuracy: 0.96633 | test_auc: 0.90754 | test_accuracy: 0.82667 |  0:00:30s
# epoch 140| loss: 0.25446 | train_auc: 0.99238 | train_accuracy: 0.93939 | test_auc: 0.92248 | test_accuracy: 0.85333 |  0:00:32s
# epoch 150| loss: 0.11392 | train_auc: 0.99451 | train_accuracy: 0.97306 | test_auc: 0.92888 | test_accuracy: 0.86667 |  0:00:34s
# epoch 160| loss: 0.10274 | train_auc: 0.99905 | train_accuracy: 0.9798  | test_auc: 0.93314 | test_accuracy: 0.86667 |  0:00:37s
# epoch 170| loss: 0.17275 | train_auc: 0.99973 | train_accuracy: 0.98316 | test_auc: 0.93314 | test_accuracy: 0.86667 |  0:00:39s
# epoch 180| loss: 0.07666 | train_auc: 0.99959 | train_accuracy: 0.9899  | test_auc: 0.92888 | test_accuracy: 0.82667 |  0:00:41s
#
# Early stopping occurred at epoch 184 with best_epoch = 124 and best_test_accuracy = 0.89333
#
# === Disorder: Anxiety disorder ===
#
# ...
# epoch 120| loss: 0.23731 | train_auc: 0.98645 | train_accuracy: 0.94118 | test_auc: 0.83284 | test_accuracy: 0.76923 |  0:00:19s
# epoch 130| loss: 0.3563  | train_auc: 0.99058 | train_accuracy: 0.94608 | test_auc: 0.8358  | test_accuracy: 0.75    |  0:00:21s
# epoch 140| loss: 0.15642 | train_auc: 0.9951  | train_accuracy: 0.97549 | test_auc: 0.85503 | test_accuracy: 0.86538 |  0:00:23s
# epoch 150| loss: 0.12227 | train_auc: 0.99654 | train_accuracy: 0.97549 | test_auc: 0.79734 | test_accuracy: 0.69231 |  0:00:24s
# epoch 160| loss: 0.21146 | train_auc: 0.99654 | train_accuracy: 0.98039 | test_auc: 0.81361 | test_accuracy: 0.75    |  0:00:26s
# epoch 170| loss: 0.27312 | train_auc: 0.99817 | train_accuracy: 0.9902  | test_auc: 0.84024 | test_accuracy: 0.73077 |  0:00:28s
# epoch 180| loss: 0.18596 | train_auc: 0.99962 | train_accuracy: 0.98529 | test_auc: 0.83284 | test_accuracy: 0.73077 |  0:00:29s
# epoch 190| loss: 0.10102 | train_auc: 0.99731 | train_accuracy: 0.9902  | test_auc: 0.80917 | test_accuracy: 0.71154 |  0:00:31s
# Stop training because you reached max_epochs = 200 with best_epoch = 140 and best_test_accuracy = 0.86538
#
# --- Processing: fc_gamma ---
# Shape: (256, 171)
# Missing values: 0
# epoch 0  | loss: 0.84324 | train_auc: 0.42801 | train_accuracy: 0.45098 | test_auc: 0.65385 | test_accuracy: 0.55769 |  0:00:00s
# epoch 10 | loss: 0.727   | train_auc: 0.58948 | train_accuracy: 0.55392 | test_auc: 0.49704 | test_accuracy: 0.44231 |  0:00:01s
# epoch 20 | loss: 0.68263 | train_auc: 0.60381 | train_accuracy: 0.57353 | test_auc: 0.6213  | test_accuracy: 0.55769 |  0:00:03s
# epoch 30 | loss: 0.69489 | train_auc: 0.65158 | train_accuracy: 0.60294 | test_auc: 0.58728 | test_accuracy: 0.51923 |  0:00:05s
# epoch 40 | loss: 0.52568 | train_auc: 0.79181 | train_accuracy: 0.67157 | test_auc: 0.53254 | test_accuracy: 0.42308 |  0:00:06s
# epoch 50 | loss: 0.50047 | train_auc: 0.84227 | train_accuracy: 0.7549  | test_auc: 0.68787 | test_accuracy: 0.57692 |  0:00:08s
# epoch 60 | loss: 0.44238 | train_auc: 0.85217 | train_accuracy: 0.79412 | test_auc: 0.58876 | test_accuracy: 0.57692 |  0:00:09s
# epoch 70 | loss: 0.44027 | train_auc: 0.95867 | train_accuracy: 0.87745 | test_auc: 0.68639 | test_accuracy: 0.63462 |  0:00:11s
# epoch 80 | loss: 0.28295 | train_auc: 0.92522 | train_accuracy: 0.87745 | test_auc: 0.66272 | test_accuracy: 0.63462 |  0:00:13s
# epoch 90 | loss: 0.28257 | train_auc: 0.92166 | train_accuracy: 0.88725 | test_auc: 0.59172 | test_accuracy: 0.59615 |  0:00:14s
# epoch 100| loss: 0.16514 | train_auc: 0.96905 | train_accuracy: 0.93627 | test_auc: 0.65089 | test_accuracy: 0.67308 |  0:00:16s
# epoch 110| loss: 0.24278 | train_auc: 0.98837 | train_accuracy: 0.95098 | test_auc: 0.70414 | test_accuracy: 0.63462 |  0:00:18s
# epoch 120| loss: 0.18351 | train_auc: 0.99241 | train_accuracy: 0.97059 | test_auc: 0.80917 | test_accuracy: 0.76923 |  0:00:19s
# epoch 130| loss: 0.15431 | train_auc: 0.99298 | train_accuracy: 0.97549 | test_auc: 0.83136 | test_accuracy: 0.78846 |  0:00:21s
# epoch 140| loss: 0.17053 | train_auc: 0.99385 | train_accuracy: 0.97549 | test_auc: 0.76479 | test_accuracy: 0.67308 |  0:00:22s
# epoch 150| loss: 0.15098 | train_auc: 0.99981 | train_accuracy: 0.9902  | test_auc: 0.78107 | test_accuracy: 0.69231 |  0:00:24s
# epoch 160| loss: 0.10672 | train_auc: 1.0     | train_accuracy: 0.9902  | test_auc: 0.74556 | test_accuracy: 0.67308 |  0:00:26s
# epoch 170| loss: 0.12338 | train_auc: 0.99894 | train_accuracy: 0.9902  | test_auc: 0.78698 | test_accuracy: 0.73077 |  0:00:27s
# epoch 180| loss: 0.12277 | train_auc: 0.99885 | train_accuracy: 0.9902  | test_auc: 0.80178 | test_accuracy: 0.75    |  0:00:29s
#
# Early stopping occurred at epoch 185 with best_epoch = 125 and best_test_accuracy = 0.82692
#
# --- Processing: psd_fc_delta ---
# Shape: (256, 190)
# Missing values: 0
# epoch 0  | loss: 1.50955 | train_auc: 0.49471 | train_accuracy: 0.48039 | test_auc: 0.47041 | test_accuracy: 0.44231 |  0:00:00s
# epoch 10 | loss: 0.63954 | train_auc: 0.72174 | train_accuracy: 0.69608 | test_auc: 0.47189 | test_accuracy: 0.46154 |  0:00:01s
# epoch 20 | loss: 0.59931 | train_auc: 0.74577 | train_accuracy: 0.68627 | test_auc: 0.71893 | test_accuracy: 0.71154 |  0:00:03s
# epoch 30 | loss: 0.50954 | train_auc: 0.86909 | train_accuracy: 0.7549  | test_auc: 0.67604 | test_accuracy: 0.65385 |  0:00:05s
# epoch 40 | loss: 0.45523 | train_auc: 0.906   | train_accuracy: 0.82843 | test_auc: 0.75    | test_accuracy: 0.69231 |  0:00:06s
# epoch 50 | loss: 0.45833 | train_auc: 0.90705 | train_accuracy: 0.81863 | test_auc: 0.7855  | test_accuracy: 0.65385 |  0:00:08s
# epoch 60 | loss: 0.3945  | train_auc: 0.91071 | train_accuracy: 0.83824 | test_auc: 0.77367 | test_accuracy: 0.65385 |  0:00:09s
# epoch 70 | loss: 0.39285 | train_auc: 0.92157 | train_accuracy: 0.87255 | test_auc: 0.75148 | test_accuracy: 0.67308 |  0:00:11s
# epoch 80 | loss: 0.39009 | train_auc: 0.88178 | train_accuracy: 0.78922 | test_auc: 0.7071  | test_accuracy: 0.65385 |  0:00:13s
# epoch 90 | loss: 0.38709 | train_auc: 0.93868 | train_accuracy: 0.85294 | test_auc: 0.73077 | test_accuracy: 0.65385 |  0:00:14s
# epoch 100| loss: 0.36833 | train_auc: 0.92397 | train_accuracy: 0.85294 | test_auc: 0.66272 | test_accuracy: 0.63462 |  0:00:16s
# epoch 110| loss: 0.31651 | train_auc: 0.93329 | train_accuracy: 0.90196 | test_auc: 0.71746 | test_accuracy: 0.67308 |  0:00:18s
# epoch 120| loss: 0.32491 | train_auc: 0.96655 | train_accuracy: 0.90196 | test_auc: 0.72041 | test_accuracy: 0.61538 |  0:00:19s
# epoch 130| loss: 0.30108 | train_auc: 0.96838 | train_accuracy: 0.92157 | test_auc: 0.71006 | test_accuracy: 0.67308 |  0:00:21s
#
# Early stopping occurred at epoch 132 with best_epoch = 72 and best_test_accuracy = 0.73077
#
# --- Processing: psd_fc_theta ---
# Shape: (256, 190)
# Missing values: 0
# epoch 0  | loss: 1.47447 | train_auc: 0.54143 | train_accuracy: 0.52941 | test_auc: 0.58876 | test_accuracy: 0.57692 |  0:00:00s
# epoch 10 | loss: 0.62008 | train_auc: 0.72626 | train_accuracy: 0.65686 | test_auc: 0.7071  | test_accuracy: 0.51923 |  0:00:01s
# epoch 20 | loss: 0.47394 | train_auc: 0.8564  | train_accuracy: 0.7598  | test_auc: 0.63757 | test_accuracy: 0.67308 |  0:00:03s
# epoch 30 | loss: 0.45189 | train_auc: 0.88572 | train_accuracy: 0.79902 | test_auc: 0.75    | test_accuracy: 0.71154 |  0:00:05s
# epoch 40 | loss: 0.36375 | train_auc: 0.92964 | train_accuracy: 0.85294 | test_auc: 0.77959 | test_accuracy: 0.75    |  0:00:06s
# epoch 50 | loss: 0.34177 | train_auc: 0.96828 | train_accuracy: 0.92647 | test_auc: 0.79882 | test_accuracy: 0.76923 |  0:00:08s
# epoch 60 | loss: 0.23098 | train_auc: 0.9802  | train_accuracy: 0.92647 | test_auc: 0.85207 | test_accuracy: 0.82692 |  0:00:09s
# epoch 70 | loss: 0.22314 | train_auc: 0.98222 | train_accuracy: 0.95588 | test_auc: 0.85207 | test_accuracy: 0.82692 |  0:00:11s
# epoch 80 | loss: 0.20842 | train_auc: 0.97982 | train_accuracy: 0.94608 | test_auc: 0.85651 | test_accuracy: 0.80769 |  0:00:13s
# epoch 90 | loss: 0.15217 | train_auc: 0.99135 | train_accuracy: 0.96569 | test_auc: 0.90089 | test_accuracy: 0.88462 |  0:00:14s
# epoch 100| loss: 0.1168  | train_auc: 0.99942 | train_accuracy: 0.98529 | test_auc: 0.90237 | test_accuracy: 0.84615 |  0:00:16s
# epoch 110| loss: 0.15169 | train_auc: 0.99923 | train_accuracy: 0.98529 | test_auc: 0.89053 | test_accuracy: 0.84615 |  0:00:17s
# epoch 120| loss: 0.10268 | train_auc: 0.99942 | train_accuracy: 0.98529 | test_auc: 0.88018 | test_accuracy: 0.86538 |  0:00:19s
# epoch 130| loss: 0.13434 | train_auc: 0.99962 | train_accuracy: 0.9951  | test_auc: 0.8713  | test_accuracy: 0.86538 |  0:00:21s
# epoch 140| loss: 0.18897 | train_auc: 0.99856 | train_accuracy: 0.97549 | test_auc: 0.8787  | test_accuracy: 0.82692 |  0:00:22s
# epoch 150| loss: 0.13255 | train_auc: 0.99664 | train_accuracy: 0.98039 | test_auc: 0.86982 | test_accuracy: 0.80769 |  0:00:24s
#
# Early stopping occurred at epoch 152 with best_epoch = 92 and best_test_accuracy = 0.90385
#
# --- Processing: psd_fc_alpha ---
# Shape: (256, 190)
# Missing values: 0
# epoch 0  | loss: 1.46711 | train_auc: 0.52422 | train_accuracy: 0.52451 | test_auc: 0.5503  | test_accuracy: 0.57692 |  0:00:00s
# epoch 10 | loss: 0.64079 | train_auc: 0.64158 | train_accuracy: 0.57353 | test_auc: 0.60725 | test_accuracy: 0.55769 |  0:00:01s
# epoch 20 | loss: 0.63755 | train_auc: 0.68589 | train_accuracy: 0.60784 | test_auc: 0.58432 | test_accuracy: 0.59615 |  0:00:03s
# epoch 30 | loss: 0.54963 | train_auc: 0.76384 | train_accuracy: 0.69608 | test_auc: 0.5858  | test_accuracy: 0.59615 |  0:00:05s
# epoch 40 | loss: 0.63706 | train_auc: 0.83747 | train_accuracy: 0.7598  | test_auc: 0.65385 | test_accuracy: 0.65385 |  0:00:06s
# epoch 50 | loss: 0.56072 | train_auc: 0.87745 | train_accuracy: 0.80882 | test_auc: 0.53994 | test_accuracy: 0.5     |  0:00:08s
# epoch 60 | loss: 0.4182  | train_auc: 0.93426 | train_accuracy: 0.86275 | test_auc: 0.59024 | test_accuracy: 0.53846 |  0:00:09s
# epoch 70 | loss: 0.31512 | train_auc: 0.95031 | train_accuracy: 0.88725 | test_auc: 0.63757 | test_accuracy: 0.59615 |  0:00:11s
# epoch 80 | loss: 0.30743 | train_auc: 0.95271 | train_accuracy: 0.84804 | test_auc: 0.66716 | test_accuracy: 0.67308 |  0:00:13s
# epoch 90 | loss: 0.36347 | train_auc: 0.96155 | train_accuracy: 0.90196 | test_auc: 0.78254 | test_accuracy: 0.69231 |  0:00:14s
# epoch 100| loss: 0.30287 | train_auc: 0.97539 | train_accuracy: 0.92157 | test_auc: 0.67012 | test_accuracy: 0.65385 |  0:00:16s
# epoch 110| loss: 0.31863 | train_auc: 0.97626 | train_accuracy: 0.94118 | test_auc: 0.6716  | test_accuracy: 0.65385 |  0:00:18s
# epoch 120| loss: 0.27127 | train_auc: 0.99337 | train_accuracy: 0.94118 | test_auc: 0.71893 | test_accuracy: 0.63462 |  0:00:19s
# epoch 130| loss: 0.23848 | train_auc: 0.9875  | train_accuracy: 0.95588 | test_auc: 0.75    | test_accuracy: 0.69231 |  0:00:21s
# epoch 140| loss: 0.25148 | train_auc: 0.995   | train_accuracy: 0.95588 | test_auc: 0.62574 | test_accuracy: 0.57692 |  0:00:22s
#
# Early stopping occurred at epoch 149 with best_epoch = 89 and best_test_accuracy = 0.75
#
# --- Processing: psd_fc_beta ---
# Shape: (256, 190)
# Missing values: 0
# epoch 0  | loss: 1.38963 | train_auc: 0.51817 | train_accuracy: 0.5049  | test_auc: 0.69231 | test_accuracy: 0.51923 |  0:00:00s
# epoch 10 | loss: 0.68566 | train_auc: 0.63389 | train_accuracy: 0.61765 | test_auc: 0.44379 | test_accuracy: 0.53846 |  0:00:01s
# epoch 20 | loss: 0.65312 | train_auc: 0.80632 | train_accuracy: 0.72059 | test_auc: 0.57396 | test_accuracy: 0.5     |  0:00:03s
# epoch 30 | loss: 0.6137  | train_auc: 0.70233 | train_accuracy: 0.66667 | test_auc: 0.57988 | test_accuracy: 0.57692 |  0:00:05s
# epoch 40 | loss: 0.56827 | train_auc: 0.82276 | train_accuracy: 0.69118 | test_auc: 0.66272 | test_accuracy: 0.57692 |  0:00:06s
# epoch 50 | loss: 0.58463 | train_auc: 0.89302 | train_accuracy: 0.82353 | test_auc: 0.71154 | test_accuracy: 0.61538 |  0:00:08s
# epoch 60 | loss: 0.41781 | train_auc: 0.89764 | train_accuracy: 0.80392 | test_auc: 0.66716 | test_accuracy: 0.55769 |  0:00:10s
# epoch 70 | loss: 0.39409 | train_auc: 0.92359 | train_accuracy: 0.86275 | test_auc: 0.7929  | test_accuracy: 0.65385 |  0:00:11s
# epoch 80 | loss: 0.39218 | train_auc: 0.9407  | train_accuracy: 0.83333 | test_auc: 0.69231 | test_accuracy: 0.63462 |  0:00:13s
# epoch 90 | loss: 0.3796  | train_auc: 0.96348 | train_accuracy: 0.90196 | test_auc: 0.78107 | test_accuracy: 0.73077 |  0:00:15s
# epoch 100| loss: 0.36079 | train_auc: 0.97684 | train_accuracy: 0.91176 | test_auc: 0.78846 | test_accuracy: 0.73077 |  0:00:16s
# epoch 110| loss: 0.23127 | train_auc: 0.98453 | train_accuracy: 0.91667 | test_auc: 0.83876 | test_accuracy: 0.78846 |  0:00:18s
# epoch 120| loss: 0.25086 | train_auc: 0.98529 | train_accuracy: 0.93627 | test_auc: 0.76923 | test_accuracy: 0.67308 |  0:00:19s
# epoch 130| loss: 0.25864 | train_auc: 0.99202 | train_accuracy: 0.93627 | test_auc: 0.89793 | test_accuracy: 0.78846 |  0:00:21s
# epoch 140| loss: 0.21193 | train_auc: 0.98731 | train_accuracy: 0.95588 | test_auc: 0.89497 | test_accuracy: 0.80769 |  0:00:23s
# epoch 150| loss: 0.19444 | train_auc: 0.98818 | train_accuracy: 0.93627 | test_auc: 0.87574 | test_accuracy: 0.78846 |  0:00:24s
# epoch 160| loss: 0.17619 | train_auc: 0.99856 | train_accuracy: 0.98529 | test_auc: 0.89941 | test_accuracy: 0.84615 |  0:00:26s
# epoch 170| loss: 0.17522 | train_auc: 0.99231 | train_accuracy: 0.96569 | test_auc: 0.88905 | test_accuracy: 0.80769 |  0:00:27s
# epoch 180| loss: 0.11048 | train_auc: 0.99798 | train_accuracy: 0.98039 | test_auc: 0.90976 | test_accuracy: 0.80769 |  0:00:29s
# epoch 190| loss: 0.19207 | train_auc: 0.99952 | train_accuracy: 0.98529 | test_auc: 0.93491 | test_accuracy: 0.80769 |  0:00:31s
# Stop training because you reached max_epochs = 200 with best_epoch = 184 and best_test_accuracy = 0.90385
#
# --- Processing: psd_fc_highbeta ---
# Shape: (256, 190)
# Missing values: 0
# epoch 0  | loss: 1.36518 | train_auc: 0.47751 | train_accuracy: 0.46569 | test_auc: 0.48225 | test_accuracy: 0.48077 |  0:00:00s
# epoch 10 | loss: 0.65158 | train_auc: 0.53758 | train_accuracy: 0.52451 | test_auc: 0.38905 | test_accuracy: 0.44231 |  0:00:01s
# epoch 20 | loss: 0.66727 | train_auc: 0.5915  | train_accuracy: 0.53431 | test_auc: 0.5784  | test_accuracy: 0.5     |  0:00:03s
# epoch 30 | loss: 0.65033 | train_auc: 0.73577 | train_accuracy: 0.60784 | test_auc: 0.59911 | test_accuracy: 0.44231 |  0:00:05s
# epoch 40 | loss: 0.67851 | train_auc: 0.80085 | train_accuracy: 0.71569 | test_auc: 0.64053 | test_accuracy: 0.61538 |  0:00:06s
# epoch 50 | loss: 0.63022 | train_auc: 0.82747 | train_accuracy: 0.76961 | test_auc: 0.84024 | test_accuracy: 0.75    |  0:00:08s
# epoch 60 | loss: 0.6094  | train_auc: 0.8095  | train_accuracy: 0.72059 | test_auc: 0.8787  | test_accuracy: 0.78846 |  0:00:10s
# epoch 70 | loss: 0.53879 | train_auc: 0.89725 | train_accuracy: 0.81863 | test_auc: 0.86391 | test_accuracy: 0.80769 |  0:00:11s
# epoch 80 | loss: 0.40555 | train_auc: 0.94675 | train_accuracy: 0.88725 | test_auc: 0.72485 | test_accuracy: 0.71154 |  0:00:13s
# epoch 90 | loss: 0.33005 | train_auc: 0.95675 | train_accuracy: 0.89216 | test_auc: 0.73817 | test_accuracy: 0.57692 |  0:00:14s
# epoch 100| loss: 0.33811 | train_auc: 0.97357 | train_accuracy: 0.90196 | test_auc: 0.77071 | test_accuracy: 0.63462 |  0:00:16s
#
# Early stopping occurred at epoch 106 with best_epoch = 46 and best_test_accuracy = 0.82692
#
# --- Processing: psd_fc_gamma ---
# Shape: (256, 190)
# Missing values: 0
# epoch 0  | loss: 1.55808 | train_auc: 0.47136 | train_accuracy: 0.5049  | test_auc: 0.57249 | test_accuracy: 0.57692 |  0:00:00s
# epoch 10 | loss: 0.71501 | train_auc: 0.64639 | train_accuracy: 0.60784 | test_auc: 0.51036 | test_accuracy: 0.53846 |  0:00:01s
# epoch 20 | loss: 0.59813 | train_auc: 0.77095 | train_accuracy: 0.68627 | test_auc: 0.59615 | test_accuracy: 0.55769 |  0:00:03s
# epoch 30 | loss: 0.50782 | train_auc: 0.82709 | train_accuracy: 0.7549  | test_auc: 0.76627 | test_accuracy: 0.71154 |  0:00:05s
# epoch 40 | loss: 0.45492 | train_auc: 0.92724 | train_accuracy: 0.83824 | test_auc: 0.73521 | test_accuracy: 0.69231 |  0:00:06s
# epoch 50 | loss: 0.43078 | train_auc: 0.93214 | train_accuracy: 0.84314 | test_auc: 0.81213 | test_accuracy: 0.73077 |  0:00:08s
# epoch 60 | loss: 0.33938 | train_auc: 0.94118 | train_accuracy: 0.86275 | test_auc: 0.72485 | test_accuracy: 0.67308 |  0:00:09s
# epoch 70 | loss: 0.44235 | train_auc: 0.94358 | train_accuracy: 0.86275 | test_auc: 0.82396 | test_accuracy: 0.73077 |  0:00:11s
# epoch 80 | loss: 0.37069 | train_auc: 0.94935 | train_accuracy: 0.87745 | test_auc: 0.7855  | test_accuracy: 0.65385 |  0:00:13s
# epoch 90 | loss: 0.22068 | train_auc: 0.9926  | train_accuracy: 0.95588 | test_auc: 0.78846 | test_accuracy: 0.71154 |  0:00:14s
# epoch 100| loss: 0.19294 | train_auc: 0.99145 | train_accuracy: 0.97059 | test_auc: 0.77367 | test_accuracy: 0.65385 |  0:00:16s
#
# Early stopping occurred at epoch 109 with best_epoch = 49 and best_test_accuracy = 0.78846

# %% [markdown]
# ## | 6. Results

# %%
rows = []

for disorder, dicts in all_results.items():
    for dict_name, df_results in dicts.items():
        for df_name, metrics in df_results.items():
            row = {
                'Disorder': disorder,
                'Dict': dict_name,
                'DataFrame': df_name,
                'Accuracy': metrics['accuracy'],
                'AUC': metrics['auc'],
                'Classification Report': metrics['classification_report']
            }
            
            rows.append(row)

results_df = pd.DataFrame(rows)
results_df.to_csv(f'{experiment_name}.csv', index=False)
results_df
# Out:
#                                Disorder                      Dict  \
# 0                    Addictive disorder     df_dict_psd_all_bands
# 1                    Addictive disorder      df_dict_fc_all_bands
# 2                    Addictive disorder  df_dict_psd_fc_all_bands
# 3                    Addictive disorder          df_dict_psd_band
# 4                    Addictive disorder          df_dict_psd_band
# ..                                  ...                       ...
# 121  Trauma and stress related disorder       df_dict_psd_fc_band
# 122  Trauma and stress related disorder       df_dict_psd_fc_band
# 123  Trauma and stress related disorder       df_dict_psd_fc_band
# 124  Trauma and stress related disorder       df_dict_psd_fc_band
# 125  Trauma and stress related disorder       df_dict_psd_fc_band
#
#             DataFrame  Accuracy       AUC  \
# 0       psd_all_bands  0.920000  0.937411
# 1        fc_all_bands  0.893333  0.923186
# 2    psd_fc_all_bands  0.786667  0.842105
# 3           psd_delta  0.893333  0.894737
# 4           psd_theta  0.946667  0.951636
# ..                ...       ...       ...
# 121      psd_fc_theta  0.903846  0.889053
# 122      psd_fc_alpha  0.750000  0.781065
# 123       psd_fc_beta  0.903846  0.933432
# 124   psd_fc_highbeta  0.826923  0.868343
# 125      psd_fc_gamma  0.788462  0.795858
#
#                                  Classification Report
# 0                  precision    recall  f1-score   ...
# 1                  precision    recall  f1-score   ...
# 2                  precision    recall  f1-score   ...
# 3                  precision    recall  f1-score   ...
# 4                  precision    recall  f1-score   ...
# ..                                                 ...
# 121                precision    recall  f1-score   ...
# 122                precision    recall  f1-score   ...
# 123                precision    recall  f1-score   ...
# 124                precision    recall  f1-score   ...
# 125                precision    recall  f1-score   ...
#
# [126 rows x 6 columns]

# %% [markdown]
# ## | 7. Conclusions, Problems, and Limitations

# %% [markdown]
# [need to update]
