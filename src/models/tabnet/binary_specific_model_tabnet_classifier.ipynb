# %% [markdown]
# | Description
#
# Authors of notebook: Mateus Balda and Alessandro Bof
#
# Reference paper and dataset: https://www.frontiersin.org/journals/psychiatry/articles/10.3389/fpsyt.2021.707581/full
#
# | Notebook structure
# 0. Setup and Imports
# 1. Utility Functions
# 2. Data Loading and Preprocessing
# 3. Data Preparation for Training
# 4. Model Definition
# 5. Training and Evaluation
# 6. Results
# 7. Conclusions, Problems, and Limitations
#
# | Training
# 1. Binary classification for `y` specific.disorder (Disorder vs. Health control)
# 2. Balancing using BorderlineSMOTE for minority classes
# 3. Training across the 21 subsets

# %% [markdown]
# ## | 0. Setup and Imports

# %%
# !pip install -q imbalanced-learn==0.12.4;
# !pip install -q pytorch_tabnet;

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from IPython.display import FileLink, display, HTML
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.impute import KNNImputer

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau

from imblearn.over_sampling import BorderlineSMOTE

from warnings import filterwarnings
filterwarnings('ignore')

torch.__version__
# Out:
# '2.5.1+cu124'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
experiment_name = "binary_classification_specifc_disorder_tabnet"
device
# Out:
# device(type='cuda')

# %%
np.random.seed(123)
torch.manual_seed(123)

# %% [markdown]
# ## | 1. Utility Functions

# %% [markdown]
# ### 1. OUTLIERS

# %%
def detect_outliers_summary(df):
    outliers_summary = {}

    for col in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_limit = Q1 - 1.5 * IQR
        upper_limit = Q3 + 1.5 * IQR

        outliers = df[(df[col] < lower_limit) | (df[col] > upper_limit)][col]
        
        outliers_summary[col] = {
            'num_outliers': len(outliers),
            'percent_outliers': len(outliers) / len(df) * 100,
            'outliers': outliers.tolist(),
            'lower_limit': lower_limit,
            'upper_limit': upper_limit
        }

    return pd.DataFrame(outliers_summary).T


def treat_all_outliers_iqr(df, factor=1.5):
    df_treated = df.copy()
    
    for column in df_treated.select_dtypes(include=[np.number]).columns:
        Q1 = np.percentile(df_treated[column], 25)
        Q3 = np.percentile(df_treated[column], 75)
        IQR = Q3 - Q1

        lower_bound = Q1 - factor * IQR
        upper_bound = Q3 + factor * IQR

        df_treated[column] = np.clip(df_treated[column], lower_bound, upper_bound)

    return df_treated

# %% [markdown]
# ### 2. NANS

# %%
def remove_missing_columns(df, threshold=0.5):
    limit = int(threshold * len(df))
    df = df.dropna(thresh=limit, axis=1)
    return df
    
def find_most_null_column(df, threshold=0.5):
    null_ratios = df.isnull().mean()
    for col, ration in null_ratios.items():
        if ration > threshold:
            return col
    return None

def analyze_missing_values(df):
    missing_values = df.isnull().sum()
    missing_values = missing_values[missing_values > 0]
    total_number_nans = df.isnull().sum().sum()
    
    return missing_values, total_number_nans

def handle_nans(df):
    columns_with_nans = df.columns[df.isnull().any()].tolist()
    
    knn_imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
    
    df_imputed = pd.DataFrame(knn_imputer.fit_transform(df[columns_with_nans]),
                                columns=columns_with_nans)
    
    df[columns_with_nans] = df_imputed[columns_with_nans]
    
    return df

# %% [markdown]
# ### 3. SETS & SUBSETS

# %%
class Sets:
    # AB = PSD (Power Spectral Density) 19 * 6
    # COH = FC (Functional Connectivity) 171 * 6
    
    def __init__(self, dataframe: pd.DataFrame):
        
        if not isinstance(dataframe, pd.DataFrame):
            raise ValueError("The parameter must be a pandas DataFrame")
        
        self.df = dataframe.copy()
        self.df_ab_psd = None
        self.df_coh_fc = None
        self.df_ab_psd_coh_fc = None
        
        self.__create_df_psd()
        self.__create_df_fc()
        self.__create_union_psd_fc()

    # 19 (6 bands)
    def __create_df_psd(self):
        columns_AB = [col for col in self.df.columns if col.startswith('AB')]
        self.df_ab_psd = self.df[columns_AB]
    
    # 171 (6 bands)
    def __create_df_fc(self):
        columns_COH = [col for col in self.df.columns if col.startswith('COH')]
        self.df_coh_fc = self.df[columns_COH]
        
    def __create_union_psd_fc(self):
        if self.df_ab_psd is not None and self.df_coh_fc is not None:
            self.df_ab_psd_coh_fc = pd.concat([self.df_ab_psd, self.df_coh_fc], axis=1)
        else:
            raise ValueError("Subsets AB and COH were not created correctly")

    def create_dfs_bands(self, bands: list[str] = None, df: pd.DataFrame = None):
        dfs_bands = {}
        
        if bands is None:
            bands = ['delta', 'theta', 'alpha', 'beta', 'highbeta','gamma']
        
        for band in bands:
            columns_band = [col for col in df.columns if f'.{band}.' in col]
            if columns_band:
                dfs_bands[band] = df[columns_band]
        
        return dfs_bands

# %% [markdown]
# ## | 2. Data Loading and Preprocessing

# %%
df = pd.read_csv('../input/eeg-psychiatric-disorders-dataset/EEG.machinelearing_data_BRMH.csv')
df.shape
# Out:
# (945, 1149)

# %%
# Checking / imputing Nan

output1 = analyze_missing_values(df)
output2 = find_most_null_column(df)
df = remove_missing_columns(df)
output3 = analyze_missing_values(df)
df = handle_nans(df)

display(output1)
display(HTML('<hr>'))
display(output2)
display(HTML('<hr>'))
display(output3)
display(df.shape)
display(HTML('<hr>'))
display(df.isna().sum().sum())
display(df)
# Out:
# (education        15
#  IQ               13
#  Unnamed: 122    945
#  dtype: int64,
#  973)
# <hr>
# 'Unnamed: 122'
# <hr>
# (education    15
#  IQ           13
#  dtype: int64,
#  28)
# (945, 1148)
# <hr>
# 0
#      no. sex   age    eeg.date  education          IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30   13.43871  101.580472  Addictive disorder
# 1      2   M  37.0    2012.9.6    6.00000  120.000000  Addictive disorder
# 2      3   M  32.0   2012.9.10   16.00000  113.000000  Addictive disorder
# 3      4   M  35.0   2012.10.8   18.00000  126.000000  Addictive disorder
# 4      5   M  36.0  2012.10.18   16.00000  112.000000  Addictive disorder
# ..   ...  ..   ...         ...        ...         ...                 ...
# 940  941   M  22.0   2014.8.28   13.00000  116.000000     Healthy control
# 941  942   M  26.0   2014.9.19   13.00000  118.000000     Healthy control
# 942  943   M  26.0   2014.9.27   16.00000  113.000000     Healthy control
# 943  944   M  24.0   2014.9.20   13.00000  107.000000     Healthy control
# 944  945   M  21.0  2015.10.23   13.00000  105.000000     Healthy control
#
#         specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0    Alcohol use disorder         35.998557         21.717375  ...
# 1    Alcohol use disorder         13.425118         11.002916  ...
# 2    Alcohol use disorder         29.941780         27.544684  ...
# 3    Alcohol use disorder         21.496226         21.846832  ...
# 4    Alcohol use disorder         37.775667         33.607679  ...
# ..                    ...               ...               ...  ...
# 940       Healthy control         41.851823         36.771496  ...
# 941       Healthy control         18.986856         19.401387  ...
# 942       Healthy control         28.781317         32.369230  ...
# 943       Healthy control         19.929100         25.196375  ...
# 944       Healthy control         65.195346         69.241972  ...
#
#      COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0                55.989192              16.739679              23.452271
# 1                45.595619              17.510824              26.777368
# 2                99.475453              70.654171              39.131547
# 3                59.986561              63.822201              36.478254
# 4                61.462720              59.166097              51.465531
# ..                     ...                    ...                    ...
# 940              82.905657              34.850706              63.970519
# 941              65.917918              66.700117              44.756285
# 942              61.040959              27.632209              45.552852
# 943              99.113664              48.328934              41.248470
# 944              78.600293              68.255430              70.687410
#
#      COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                45.678820              30.167520              16.918761
# 1                28.201062              57.108861              32.375401
# 2                69.920996              71.063644              38.534505
# 3                47.117006              84.658376              24.724096
# 4                58.635415              80.685608              62.138436
# ..                     ...                    ...                    ...
# 940              63.982003              51.244725              62.203684
# 941              49.787513              98.905995              54.021304
# 942              33.638817              46.690983              19.382928
# 943              28.192238              48.665743              42.007147
# 944              74.433908              74.294750              53.254681
#
#      COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                48.850427               9.422630              34.507082
# 1                60.351749              13.900981              57.831848
# 2                69.908764              27.180532              64.803155
# 3                50.299349              35.319695              79.822944
# 4                75.888749              61.003944              87.455509
# ..                     ...                    ...                    ...
# 940              62.062237              31.013031              31.183413
# 941              93.902401              52.740396              92.807331
# 942              41.050717               7.045821              41.962451
# 943              28.735945              27.176500              27.529522
# 944              72.755265              47.810386              80.166825
#
#      COH.F.gamma.r.O1.s.O2
# 0                28.613029
# 1                43.463261
# 2                31.485799
# 3                41.141873
# 4                70.531662
# ..                     ...
# 940              98.325230
# 941              56.320868
# 942              19.092111
# 943              20.028446
# 944              64.380273
#
# [945 rows x 1148 columns]

# %%
# detecting outliers

outliers_summary = detect_outliers_summary(df)
outliers_summary.to_csv('outliers_summary.csv', index=True)
outliers_summary['num_outliers'].sum()
# Out:
# 26452

# %%
label_encoder = LabelEncoder()
target_name = 'specific.disorder'

X = df.iloc[:,8:]
target = df[target_name]

quantitative_features = df.loc[:, ['age', 'education', 'IQ']]

sex = df['sex']
sex_encoded = label_encoder.fit_transform(sex)
sex_encoded = pd.Series(sex_encoded, name='sex')

X = pd.concat([quantitative_features, sex_encoded, X], axis=1)

X.shape, target.shape, quantitative_features.shape, sex.shape
# Out:
# ((945, 1144), (945,), (945, 3), (945,))

# %%
disorders = np.unique(target).tolist()
disorders.remove('Healthy control')
disorders.remove('Obsessive compulsitve disorder')
disorders.remove('Schizophrenia')
disorders
# Out:
# ['Acute stress disorder',
#  'Adjustment disorder',
#  'Alcohol use disorder',
#  'Behavioral addiction disorder',
#  'Bipolar disorder',
#  'Depressive disorder',
#  'Panic disorder',
#  'Posttraumatic stress disorder',
#  'Social anxiety disorder']

# %%
X_concated = pd.concat([X, target], axis=1)

display(X.head())
display(X_concated.head())
display(X.isna().sum().sum())
display(X_concated.isna().sum().sum())
# Out:
#     age  education          IQ  sex  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0  57.0   13.43871  101.580472    1         35.998557         21.717375
# 1  37.0    6.00000  120.000000    1         13.425118         11.002916
# 2  32.0   16.00000  113.000000    1         29.941780         27.544684
# 3  35.0   18.00000  126.000000    1         21.496226         21.846832
# 4  36.0   16.00000  112.000000    1         37.775667         33.607679
#
#    AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  ...  \
# 0        21.518280        26.825048        26.611516        25.732649  ...
# 1        11.942516        15.272216        14.151570        12.456034  ...
# 2        17.150159        23.608960        27.087811        13.541237  ...
# 3        17.364316        13.833701        14.100954        13.100939  ...
# 4        21.865556        21.771413        22.854536        21.456377  ...
#
#    COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0              55.989192              16.739679              23.452271
# 1              45.595619              17.510824              26.777368
# 2              99.475453              70.654171              39.131547
# 3              59.986561              63.822201              36.478254
# 4              61.462720              59.166097              51.465531
#
#    COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0              45.678820              30.167520              16.918761
# 1              28.201062              57.108861              32.375401
# 2              69.920996              71.063644              38.534505
# 3              47.117006              84.658376              24.724096
# 4              58.635415              80.685608              62.138436
#
#    COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0              48.850427               9.422630              34.507082
# 1              60.351749              13.900981              57.831848
# 2              69.908764              27.180532              64.803155
# 3              50.299349              35.319695              79.822944
# 4              75.888749              61.003944              87.455509
#
#    COH.F.gamma.r.O1.s.O2
# 0              28.613029
# 1              43.463261
# 2              31.485799
# 3              41.141873
# 4              70.531662
#
# [5 rows x 1144 columns]
#     age  education          IQ  sex  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0  57.0   13.43871  101.580472    1         35.998557         21.717375
# 1  37.0    6.00000  120.000000    1         13.425118         11.002916
# 2  32.0   16.00000  113.000000    1         29.941780         27.544684
# 3  35.0   18.00000  126.000000    1         21.496226         21.846832
# 4  36.0   16.00000  112.000000    1         37.775667         33.607679
#
#    AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  ...  \
# 0        21.518280        26.825048        26.611516        25.732649  ...
# 1        11.942516        15.272216        14.151570        12.456034  ...
# 2        17.150159        23.608960        27.087811        13.541237  ...
# 3        17.364316        13.833701        14.100954        13.100939  ...
# 4        21.865556        21.771413        22.854536        21.456377  ...
#
#    COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  COH.F.gamma.o.Pz.s.O2  \
# 0              16.739679              23.452271              45.678820
# 1              17.510824              26.777368              28.201062
# 2              70.654171              39.131547              69.920996
# 3              63.822201              36.478254              47.117006
# 4              59.166097              51.465531              58.635415
#
#    COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  COH.F.gamma.p.P4.s.O2  \
# 0              30.167520              16.918761              48.850427
# 1              57.108861              32.375401              60.351749
# 2              71.063644              38.534505              69.908764
# 3              84.658376              24.724096              50.299349
# 4              80.685608              62.138436              75.888749
#
#    COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  COH.F.gamma.r.O1.s.O2  \
# 0               9.422630              34.507082              28.613029
# 1              13.900981              57.831848              43.463261
# 2              27.180532              64.803155              31.485799
# 3              35.319695              79.822944              41.141873
# 4              61.003944              87.455509              70.531662
#
#       specific.disorder
# 0  Alcohol use disorder
# 1  Alcohol use disorder
# 2  Alcohol use disorder
# 3  Alcohol use disorder
# 4  Alcohol use disorder
#
# [5 rows x 1145 columns]
# 0
# 0

# %%
# treat outliers X_concated

X = treat_all_outliers_iqr(X, factor=1.5)
outliers_summary = detect_outliers_summary(X)
outliers_summary['num_outliers'].sum()
# Out:
# 0

# %%
binary_datasets = {}

for disorder in disorders:
    
    mask = X_concated[target_name].isin(['Healthy control', disorder])
    
    df_filtered = X_concated[mask]
    df_filtered_X = X.loc[mask]
    
    y_binary = df_filtered[target_name].apply(lambda x: 0 if x == 'Healthy control' else 1)
    
    borderline_smote = BorderlineSMOTE(kind='borderline-2', random_state=42, k_neighbors=10, m_neighbors=15)
    X_resampled, y_resampled = borderline_smote.fit_resample(df_filtered_X, y_binary)
    
    dataset = pd.concat([X_resampled, y_resampled], axis=1)
    
    binary_datasets[disorder] = {
        'data': dataset,
        'labels': ['Healthy control', disorder]
    }

# %%
binary_datasets[disorders[0]]['data']
# Out:
#            age  education          IQ  sex  AB.A.delta.a.FP1  \
# 0    19.700000  13.000000  103.000000    0         11.906893
# 1    19.940000  13.000000   81.000000    0         19.849686
# 2    19.260000  12.000000   86.600000    0         28.675766
# 3    25.610000  16.000000  108.000000    0         12.187185
# 4    24.580000  16.000000  110.000000    0          7.414042
# ..         ...        ...         ...  ...               ...
# 185  23.636111  12.460159   88.624699    0         24.991060
# 186  39.661676  12.240593  103.624002    0         14.579592
# 187  19.821461  16.000000  133.028511    0         17.654770
# 188  21.288249  12.022254   94.278175    0         16.180424
# 189  24.902333  14.389570  119.863495    0         28.722673
#
#      AB.A.delta.b.FP2  AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  \
# 0            9.707117        12.455193        14.208682        14.626761
# 1           15.705436        17.863425        25.394940        23.916326
# 2           25.368575        25.912400        29.496788        27.661687
# 3           22.798506        14.977824        13.852327        21.125052
# 4            7.173058         9.649153         9.033750         9.068607
# ..                ...              ...              ...              ...
# 185         21.790181        22.814510        27.422891        25.339652
# 186         14.081592        13.329846        10.602656        16.347242
# 187         13.746061         8.336923        10.146754        13.001747
# 188         17.626350        17.813587        12.328262        11.149706
# 189         37.327172        27.818018        23.818943        23.551339
#
#      AB.A.delta.f.F4  ...  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0          19.885365  ...              69.067513              76.479372
# 1          17.032967  ...              71.257029              74.666719
# 2          26.305027  ...              38.850170              26.148667
# 3          12.611427  ...              32.936146              48.492975
# 4          10.328719  ...              21.278355              22.090032
# ..               ...  ...                    ...                    ...
# 185        23.790325  ...              40.679754              43.349875
# 186        17.618628  ...              80.909684              80.956008
# 187        15.361196  ...              62.423946              61.543612
# 188        12.025291  ...              39.672862              46.860606
# 189        22.706705  ...              48.179674              45.615034
#
#      COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                81.723959              82.075368              65.408405
# 1                77.063648              83.056486              68.744644
# 2                47.985078              51.488546              14.825718
# 3                72.469967              45.758411              37.811075
# 4                75.129025              46.765039              12.676249
# ..                     ...                    ...                    ...
# 185              58.108614              60.001815              32.401796
# 186              87.373216              87.263718              78.826967
# 187              69.530314              80.809356              49.325702
# 188              46.651085              73.083370              42.194749
# 189              55.702417              74.844985              40.351338
#
#      COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                84.541111              58.012987              85.867872
# 1                83.468447              76.265372              90.029157
# 2                43.673794              13.046605              58.780474
# 3                70.308929               9.725031              32.678063
# 4                74.705851               9.431155              48.014229
# ..                     ...                    ...                    ...
# 185              56.697487              20.368472              52.072205
# 186              89.175762              71.807474              81.009151
# 187              75.090400              39.760503              75.953645
# 188              74.792077              29.596620              84.976867
# 189              67.946291              28.616925              69.945983
#
#      COH.F.gamma.r.O1.s.O2  specific.disorder
# 0                78.224773                  1
# 1                88.220089                  1
# 2                35.502275                  1
# 3                68.764822                  1
# 4                54.848927                  1
# ..                     ...                ...
# 185              53.363849                  1
# 186              86.173498                  1
# 187              59.867818                  1
# 188              47.631831                  1
# 189              53.747447                  1
#
# [190 rows x 1145 columns]

# %%
sets_binaries = {}

for disorder, bin_data in binary_datasets.items():
    df_bin = bin_data['data'].copy()
    
    X_bin = df_bin.drop(columns=[target_name,'age', 'education', 'IQ', 'sex'], errors='ignore') 
    X_quantitative = df_bin.loc[:, ['age', 'education', 'IQ', 'sex']]
    y_bin = df_bin[target_name] if target_name in df_bin.columns else df_bin.iloc[:, -1]

    sets = Sets(dataframe=X_bin)

    sets_binaries[disorder] = {
        'sets': sets,
        'labels': bin_data['labels'],
        'X_quantitative': X_quantitative,
        'y': y_bin
    }

# %%
for disorder in sets_binaries:
    sets = sets_binaries[disorder]['sets']

    dfs_bands_psd = sets.create_dfs_bands(df=sets.df_ab_psd)
    dfs_bands_fc = sets.create_dfs_bands(df=sets.df_coh_fc)
    dfs_bands_psd_fc = sets.create_dfs_bands(df=sets.df_ab_psd_coh_fc)

    sets_binaries[disorder].update({
        'dfs_bands_psd': dfs_bands_psd,
        'dfs_bands_fc': dfs_bands_fc,
        'dfs_bands_psd_fc': dfs_bands_psd_fc,
    })

# %%
for disorder, data in sets_binaries.items():
    print(f"Disorder: {disorder}")
    print(f"Labels: {data['labels']}")
    print(f"Number of samples: {len(data['y'])}")
    print(f"Quantitative features shape: {data['X_quantitative'].shape}")
    print(f"PSD bands shape: {data['sets'].df_ab_psd.shape}")
    print(f"FC bands shape: {data['sets'].df_coh_fc.shape}")
    print(f"PSD + FC bands shape: {data['sets'].df_ab_psd_coh_fc.shape}\n")
# Out:
# Disorder: Acute stress disorder
# Labels: ['Healthy control', 'Acute stress disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Adjustment disorder
# Labels: ['Healthy control', 'Adjustment disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Alcohol use disorder
# Labels: ['Healthy control', 'Alcohol use disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Behavioral addiction disorder
# Labels: ['Healthy control', 'Behavioral addiction disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Bipolar disorder
# Labels: ['Healthy control', 'Bipolar disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Depressive disorder
# Labels: ['Healthy control', 'Depressive disorder']
# Number of samples: 398
# Quantitative features shape: (398, 4)
# PSD bands shape: (398, 114)
# FC bands shape: (398, 1026)
# PSD + FC bands shape: (398, 1140)
#
# Disorder: Panic disorder
# Labels: ['Healthy control', 'Panic disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Posttraumatic stress disorder
# Labels: ['Healthy control', 'Posttraumatic stress disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Social anxiety disorder
# Labels: ['Healthy control', 'Social anxiety disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)

# %%
dfs_dicts_binaries = {}

for disorder, data in sets_binaries.items():
    dfs_psd = data['dfs_bands_psd']
    dfs_fc = data['dfs_bands_fc']
    dfs_psd_fc = data['dfs_bands_psd_fc']
    sets = data['sets']

    df_dict_psd_all_bands = {
        'psd_all_bands': sets.df_ab_psd,
    }

    df_dict_fc_all_bands = {
        'fc_all_bands': sets.df_coh_fc,
    }

    df_dict_psd_fc_all_bands = {
        'psd_fc_all_bands': sets.df_ab_psd_coh_fc,
    }

    df_dict_psd_band = {
        f'psd_{band}': dfs_psd[band] for band in dfs_psd
    }

    df_dict_fc_band = {
        f'fc_{band}': dfs_fc[band] for band in dfs_fc
    }

    df_dict_psd_fc_band = {
        f'psd_fc_{band}': dfs_psd_fc[band] for band in dfs_psd_fc
    }

    dfs_dicts_binaries[disorder] = {
        'df_dict_psd_all_bands': df_dict_psd_all_bands,
        'df_dict_fc_all_bands': df_dict_fc_all_bands,
        'df_dict_psd_fc_all_bands': df_dict_psd_fc_all_bands,
        'df_dict_psd_band': df_dict_psd_band,
        'df_dict_fc_band': df_dict_fc_band,
        'df_dict_psd_fc_band': df_dict_psd_fc_band,
    }

# %%
from pytorch_tabnet.tab_model import TabNetClassifier

# %%
clf = TabNetClassifier(
    optimizer_fn=torch.optim.Adam,
    scheduler_params={"step_size":8, 
                        "gamma":0.9},
    scheduler_fn=torch.optim.lr_scheduler.StepLR,
    verbose=10,
)

# %%
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score
from collections import defaultdict

all_results = {}

for disorder, dicts in dfs_dicts_binaries.items():
    print(f"\n=== Disorder: {disorder} ===")
    
    y_binary = sets_binaries[disorder]['y']
    X_quantitative = sets_binaries[disorder]['X_quantitative']
    labels = sets_binaries[disorder]['labels']
    
    all_results[disorder] = {}
    
    for dict_name, df_dict in dicts.items():
        if not dict_name.startswith('df_dict_'):
            continue
        
        for df_name, df in df_dict.items():
            print(f"\n--- Processing: {df_name} ---")
            print("Shape:", df.shape)
            print("Missing values:", df.isna().sum().sum())
            
            df_full = pd.concat([X_quantitative, df], axis=1)
            assert all(df_full.index == y_binary.index), 'Misaligned indexes'
            
            X_train, X_test, y_train, y_test = train_test_split(
                df_full,
                y_binary,
                train_size=0.80,
                stratify=y_binary,
                random_state=42
            )
            
            X_cols = X_train.drop(columns=['sex']).columns
            
            scaler = RobustScaler()
            X_train_scaled = scaler.fit_transform(X_train[X_cols])
            X_test_scaled = scaler.transform(X_test[X_cols])
            
            X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_cols, index=X_train.index)
            X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_cols, index=X_test.index)

            X_train_final = pd.concat([X_train_scaled_df, X_train['sex']], axis=1)
            X_test_final = pd.concat([X_test_scaled_df, X_test['sex']], axis=1)

            X_train_array = X_train_final.to_numpy()
            X_test_array = X_test_final.to_numpy()
            y_train_array = y_train.to_numpy()
            y_test_array = y_test.to_numpy()
            
            clf.fit(
                X_train_array, y_train_array,
                eval_set=[(X_train_array, y_train_array), (X_test_array, y_test_array)],
                eval_name=['train', 'test'],
                eval_metric=['auc','accuracy'],
                max_epochs=200, patience=60,
                batch_size=48, virtual_batch_size=24,
                num_workers=0,
                weights=1,
                drop_last=True
            )
            
            y_pred = clf.predict(X_test_array)
            y_proba = clf.predict_proba(X_test_array)[:, 1]

            acc = accuracy_score(y_test_array, y_pred)
            auc = roc_auc_score(y_test_array, y_proba)
            report = classification_report(y_test_array, y_pred)
            
            all_results.setdefault(disorder, {}).setdefault(dict_name, {})[df_name] = {
                'accuracy': acc,
                'auc': auc,
                'classification_report': report,
                'features': list(X_test_final.columns),
                'X_train_shape': X_train_array.shape,
                'X_val_shape': X_test_array.shape,
                'clf': clf
            }
# Out:
# === Disorder: Acute stress disorder ===
#
# --- Processing: psd_all_bands ---
# Shape: (190, 114)
# Missing values: 0
# epoch 0  | loss: 0.76018 | train_auc: 0.54398 | train_accuracy: 0.51316 | test_auc: 0.6482  | test_accuracy: 0.60526 |  0:00:00s
# epoch 10 | loss: 0.58586 | train_auc: 0.7713  | train_accuracy: 0.69737 | test_auc: 0.52355 | test_accuracy: 0.5     |  0:00:01s
# epoch 20 | loss: 0.51838 | train_auc: 0.84401 | train_accuracy: 0.71711 | test_auc: 0.78116 | test_accuracy: 0.68421 |  0:00:03s
# epoch 30 | loss: 0.42057 | train_auc: 0.89595 | train_accuracy: 0.85526 | test_auc: 0.67036 | test_accuracy: 0.68421 |  0:00:04s
# epoch 40 | loss: 0.41089 | train_auc: 0.93404 | train_accuracy: 0.86184 | test_auc: 0.80609 | test_accuracy: 0.71053 |  0:00:05s
# epoch 50 | loss: 0.28066 | train_auc: 0.97161 | train_accuracy: 0.92763 | test_auc: 0.86704 | test_accuracy: 0.78947 |  0:00:06s
# epoch 60 | loss: 0.27465 | train_auc: 0.99082 | train_accuracy: 0.94737 | test_auc: 0.89197 | test_accuracy: 0.76316 |  0:00:07s
# epoch 70 | loss: 0.2163  | train_auc: 0.99186 | train_accuracy: 0.96711 | test_auc: 0.9169  | test_accuracy: 0.86842 |  0:00:09s
# epoch 80 | loss: 0.16947 | train_auc: 0.99498 | train_accuracy: 0.96711 | test_auc: 0.95291 | test_accuracy: 0.92105 |  0:00:10s
# epoch 90 | loss: 0.11401 | train_auc: 0.99723 | train_accuracy: 0.98026 | test_auc: 0.95014 | test_accuracy: 0.84211 |  0:00:11s
# epoch 100| loss: 0.25545 | train_auc: 0.99688 | train_accuracy: 0.97368 | test_auc: 0.96122 | test_accuracy: 0.89474 |  0:00:12s
# epoch 110| loss: 0.10624 | train_auc: 0.99931 | train_accuracy: 0.98026 | test_auc: 0.96953 | test_accuracy: 0.89474 |  0:00:13s
# epoch 120| loss: 0.12034 | train_auc: 0.99948 | train_accuracy: 0.98684 | test_auc: 0.95845 | test_accuracy: 0.92105 |  0:00:15s
# epoch 130| loss: 0.20809 | train_auc: 0.99948 | train_accuracy: 0.98684 | test_auc: 0.98061 | test_accuracy: 0.92105 |  0:00:16s
#
# Early stopping occurred at epoch 137 with best_epoch = 77 and best_test_accuracy = 0.92105
#
# --- Processing: fc_all_bands ---
# Shape: (190, 1026)
# Missing values: 0
# epoch 0  | loss: 0.8279  | train_auc: 0.51922 | train_accuracy: 0.49342 | test_auc: 0.70637 | test_accuracy: 0.65789 |  0:00:00s
# epoch 10 | loss: 0.66665 | train_auc: 0.67555 | train_accuracy: 0.58553 | test_auc: 0.59834 | test_accuracy: 0.60526 |  0:00:01s
# epoch 20 | loss: 0.64276 | train_auc: 0.73442 | train_accuracy: 0.67763 | test_auc: 0.6482  | test_accuracy: 0.52632 |  0:00:02s
# epoch 30 | loss: 0.62777 | train_auc: 0.74152 | train_accuracy: 0.71053 | test_auc: 0.79778 | test_accuracy: 0.73684 |  0:00:03s
# epoch 40 | loss: 0.5628  | train_auc: 0.74325 | train_accuracy: 0.68421 | test_auc: 0.73684 | test_accuracy: 0.63158 |  0:00:05s
# epoch 50 | loss: 0.49677 | train_auc: 0.92486 | train_accuracy: 0.84868 | test_auc: 0.71191 | test_accuracy: 0.65789 |  0:00:06s
# epoch 60 | loss: 0.48718 | train_auc: 0.90738 | train_accuracy: 0.82895 | test_auc: 0.72022 | test_accuracy: 0.73684 |  0:00:07s
# epoch 70 | loss: 0.33455 | train_auc: 0.97368 | train_accuracy: 0.94079 | test_auc: 0.80332 | test_accuracy: 0.76316 |  0:00:08s
# epoch 80 | loss: 0.2328  | train_auc: 0.98805 | train_accuracy: 0.94737 | test_auc: 0.87258 | test_accuracy: 0.73684 |  0:00:10s
# epoch 90 | loss: 0.24896 | train_auc: 0.97091 | train_accuracy: 0.95395 | test_auc: 0.94737 | test_accuracy: 0.86842 |  0:00:11s
# epoch 100| loss: 0.1904  | train_auc: 0.98961 | train_accuracy: 0.96053 | test_auc: 0.80609 | test_accuracy: 0.76316 |  0:00:12s
# epoch 110| loss: 0.21199 | train_auc: 0.99948 | train_accuracy: 0.98026 | test_auc: 0.75069 | test_accuracy: 0.71053 |  0:00:13s
# epoch 120| loss: 0.11712 | train_auc: 0.99948 | train_accuracy: 0.99342 | test_auc: 0.79224 | test_accuracy: 0.73684 |  0:00:15s
# epoch 130| loss: 0.20642 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.82271 | test_accuracy: 0.76316 |  0:00:16s
# epoch 140| loss: 0.11319 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.83934 | test_accuracy: 0.76316 |  0:00:17s
# epoch 150| loss: 0.15211 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.84488 | test_accuracy: 0.76316 |  0:00:18s
#
# Early stopping occurred at epoch 150 with best_epoch = 90 and best_test_accuracy = 0.86842
#
# --- Processing: psd_fc_all_bands ---
# Shape: (190, 1140)
# Missing values: 0
# epoch 0  | loss: 0.93668 | train_auc: 0.50087 | train_accuracy: 0.51316 | test_auc: 0.52355 | test_accuracy: 0.5     |  0:00:00s
# epoch 10 | loss: 0.68992 | train_auc: 0.50121 | train_accuracy: 0.48684 | test_auc: 0.66205 | test_accuracy: 0.52632 |  0:00:01s
# epoch 20 | loss: 0.64216 | train_auc: 0.72749 | train_accuracy: 0.58553 | test_auc: 0.54294 | test_accuracy: 0.57895 |  0:00:02s
# epoch 30 | loss: 0.55833 | train_auc: 0.83535 | train_accuracy: 0.75658 | test_auc: 0.84488 | test_accuracy: 0.84211 |  0:00:03s
# epoch 40 | loss: 0.46848 | train_auc: 0.86046 | train_accuracy: 0.80921 | test_auc: 0.75623 | test_accuracy: 0.60526 |  0:00:05s
# epoch 50 | loss: 0.36824 | train_auc: 0.94598 | train_accuracy: 0.90789 | test_auc: 0.85873 | test_accuracy: 0.78947 |  0:00:06s
# epoch 60 | loss: 0.37811 | train_auc: 0.94668 | train_accuracy: 0.90789 | test_auc: 0.82548 | test_accuracy: 0.78947 |  0:00:07s
# epoch 70 | loss: 0.37535 | train_auc: 0.97299 | train_accuracy: 0.93421 | test_auc: 0.86981 | test_accuracy: 0.76316 |  0:00:08s
# epoch 80 | loss: 0.32918 | train_auc: 0.99048 | train_accuracy: 0.96711 | test_auc: 0.86981 | test_accuracy: 0.73684 |  0:00:10s
# epoch 90 | loss: 0.36165 | train_auc: 0.9839  | train_accuracy: 0.94737 | test_auc: 0.87258 | test_accuracy: 0.78947 |  0:00:11s
#
# Early stopping occurred at epoch 90 with best_epoch = 30 and best_test_accuracy = 0.84211
#
# --- Processing: psd_delta ---
# Shape: (190, 19)
# Missing values: 0
# epoch 0  | loss: 1.27077 | train_auc: 0.45447 | train_accuracy: 0.44079 | test_auc: 0.56787 | test_accuracy: 0.52632 |  0:00:00s
# epoch 10 | loss: 0.60531 | train_auc: 0.75    | train_accuracy: 0.58553 | test_auc: 0.65651 | test_accuracy: 0.60526 |  0:00:01s
# epoch 20 | loss: 0.37134 | train_auc: 0.92936 | train_accuracy: 0.88158 | test_auc: 0.90305 | test_accuracy: 0.84211 |  0:00:02s
# epoch 30 | loss: 0.30207 | train_auc: 0.94477 | train_accuracy: 0.86842 | test_auc: 0.83934 | test_accuracy: 0.76316 |  0:00:03s
# epoch 40 | loss: 0.29226 | train_auc: 0.91854 | train_accuracy: 0.78947 | test_auc: 0.8615  | test_accuracy: 0.73684 |  0:00:04s
# epoch 50 | loss: 0.21747 | train_auc: 0.97836 | train_accuracy: 0.90789 | test_auc: 0.9723  | test_accuracy: 0.86842 |  0:00:06s
# epoch 60 | loss: 0.32575 | train_auc: 0.97438 | train_accuracy: 0.93421 | test_auc: 0.92798 | test_accuracy: 0.81579 |  0:00:07s
# epoch 70 | loss: 0.25227 | train_auc: 0.99325 | train_accuracy: 0.93421 | test_auc: 0.9723  | test_accuracy: 0.89474 |  0:00:08s
#
# Early stopping occurred at epoch 77 with best_epoch = 17 and best_test_accuracy = 0.92105
#
# --- Processing: psd_theta ---
# Shape: (190, 19)
# Missing values: 0
# epoch 0  | loss: 0.96431 | train_auc: 0.47039 | train_accuracy: 0.47368 | test_auc: 0.48753 | test_accuracy: 0.44737 |  0:00:00s
# epoch 10 | loss: 0.61794 | train_auc: 0.80038 | train_accuracy: 0.69737 | test_auc: 0.71745 | test_accuracy: 0.71053 |  0:00:01s
# epoch 20 | loss: 0.5339  | train_auc: 0.84557 | train_accuracy: 0.75658 | test_auc: 0.73407 | test_accuracy: 0.65789 |  0:00:02s
# epoch 30 | loss: 0.46716 | train_auc: 0.9008  | train_accuracy: 0.78947 | test_auc: 0.80609 | test_accuracy: 0.78947 |  0:00:03s
# epoch 40 | loss: 0.40989 | train_auc: 0.90963 | train_accuracy: 0.82237 | test_auc: 0.78393 | test_accuracy: 0.71053 |  0:00:04s
# epoch 50 | loss: 0.3006  | train_auc: 0.98511 | train_accuracy: 0.94737 | test_auc: 0.92521 | test_accuracy: 0.86842 |  0:00:06s
# epoch 60 | loss: 0.30137 | train_auc: 0.96762 | train_accuracy: 0.90789 | test_auc: 0.89474 | test_accuracy: 0.84211 |  0:00:07s
# epoch 70 | loss: 0.2142  | train_auc: 0.98979 | train_accuracy: 0.93421 | test_auc: 0.90305 | test_accuracy: 0.89474 |  0:00:08s
# epoch 80 | loss: 0.18057 | train_auc: 0.97143 | train_accuracy: 0.90132 | test_auc: 0.92798 | test_accuracy: 0.84211 |  0:00:09s
# epoch 90 | loss: 0.27225 | train_auc: 0.99636 | train_accuracy: 0.94737 | test_auc: 0.94737 | test_accuracy: 0.86842 |  0:00:10s
# epoch 100| loss: 0.1938  | train_auc: 0.98702 | train_accuracy: 0.92763 | test_auc: 0.91967 | test_accuracy: 0.84211 |  0:00:12s
# epoch 110| loss: 0.16062 | train_auc: 0.9974  | train_accuracy: 0.96711 | test_auc: 0.93629 | test_accuracy: 0.84211 |  0:00:13s
#
# Early stopping occurred at epoch 116 with best_epoch = 56 and best_test_accuracy = 0.89474
#
# --- Processing: psd_alpha ---
# Shape: (190, 19)
# Missing values: 0
# epoch 0  | loss: 0.99443 | train_auc: 0.48632 | train_accuracy: 0.48684 | test_auc: 0.57618 | test_accuracy: 0.5     |  0:00:00s
# epoch 10 | loss: 0.50505 | train_auc: 0.87344 | train_accuracy: 0.83553 | test_auc: 0.65374 | test_accuracy: 0.65789 |  0:00:01s
# epoch 20 | loss: 0.36581 | train_auc: 0.88521 | train_accuracy: 0.80263 | test_auc: 0.72853 | test_accuracy: 0.76316 |  0:00:02s
# epoch 30 | loss: 0.31771 | train_auc: 0.92105 | train_accuracy: 0.81579 | test_auc: 0.84211 | test_accuracy: 0.71053 |  0:00:03s
# epoch 40 | loss: 0.36613 | train_auc: 0.93992 | train_accuracy: 0.86842 | test_auc: 0.68144 | test_accuracy: 0.71053 |  0:00:04s
# epoch 50 | loss: 0.23579 | train_auc: 0.96918 | train_accuracy: 0.91447 | test_auc: 0.70637 | test_accuracy: 0.63158 |  0:00:06s
# epoch 60 | loss: 0.30123 | train_auc: 0.94737 | train_accuracy: 0.86184 | test_auc: 0.84488 | test_accuracy: 0.78947 |  0:00:07s
# epoch 70 | loss: 0.24723 | train_auc: 0.95412 | train_accuracy: 0.85526 | test_auc: 0.77008 | test_accuracy: 0.68421 |  0:00:08s
# epoch 80 | loss: 0.34485 | train_auc: 0.962   | train_accuracy: 0.89474 | test_auc: 0.7313  | test_accuracy: 0.63158 |  0:00:09s
# epoch 90 | loss: 0.2397  | train_auc: 0.98857 | train_accuracy: 0.95395 | test_auc: 0.80332 | test_accuracy: 0.68421 |  0:00:10s
#
# Early stopping occurred at epoch 92 with best_epoch = 32 and best_test_accuracy = 0.78947
#
# --- Processing: psd_beta ---
# Shape: (190, 19)
# Missing values: 0
# epoch 0  | loss: 1.14901 | train_auc: 0.53757 | train_accuracy: 0.52632 | test_auc: 0.54571 | test_accuracy: 0.63158 |  0:00:00s
# epoch 10 | loss: 0.42752 | train_auc: 0.89785 | train_accuracy: 0.81579 | test_auc: 0.84765 | test_accuracy: 0.71053 |  0:00:01s
# epoch 20 | loss: 0.41599 | train_auc: 0.89733 | train_accuracy: 0.70395 | test_auc: 0.74238 | test_accuracy: 0.63158 |  0:00:02s
# epoch 30 | loss: 0.34683 | train_auc: 0.92019 | train_accuracy: 0.83553 | test_auc: 0.78947 | test_accuracy: 0.73684 |  0:00:03s
# epoch 40 | loss: 0.32328 | train_auc: 0.9678  | train_accuracy: 0.91447 | test_auc: 0.91136 | test_accuracy: 0.81579 |  0:00:04s
# epoch 50 | loss: 0.29009 | train_auc: 0.96503 | train_accuracy: 0.89474 | test_auc: 0.8615  | test_accuracy: 0.76316 |  0:00:06s
# epoch 60 | loss: 0.36262 | train_auc: 0.98286 | train_accuracy: 0.90789 | test_auc: 0.73961 | test_accuracy: 0.76316 |  0:00:07s
# epoch 70 | loss: 0.24064 | train_auc: 0.97957 | train_accuracy: 0.91447 | test_auc: 0.89474 | test_accuracy: 0.78947 |  0:00:08s
# epoch 80 | loss: 0.33071 | train_auc: 0.98546 | train_accuracy: 0.94079 | test_auc: 0.77839 | test_accuracy: 0.65789 |  0:00:09s
# epoch 90 | loss: 0.28192 | train_auc: 0.98736 | train_accuracy: 0.93421 | test_auc: 0.78393 | test_accuracy: 0.76316 |  0:00:10s
# epoch 100| loss: 0.23737 | train_auc: 0.99256 | train_accuracy: 0.96053 | test_auc: 0.78947 | test_accuracy: 0.73684 |  0:00:11s
#
# Early stopping occurred at epoch 101 with best_epoch = 41 and best_test_accuracy = 0.84211
#
# --- Processing: psd_highbeta ---
# Shape: (190, 19)
# Missing values: 0
# epoch 0  | loss: 0.98415 | train_auc: 0.59505 | train_accuracy: 0.55921 | test_auc: 0.50139 | test_accuracy: 0.55263 |  0:00:00s
# epoch 10 | loss: 0.52477 | train_auc: 0.78757 | train_accuracy: 0.73026 | test_auc: 0.69252 | test_accuracy: 0.68421 |  0:00:01s
# epoch 20 | loss: 0.43814 | train_auc: 0.89335 | train_accuracy: 0.81579 | test_auc: 0.83657 | test_accuracy: 0.76316 |  0:00:02s
# epoch 30 | loss: 0.40672 | train_auc: 0.87725 | train_accuracy: 0.84211 | test_auc: 0.76731 | test_accuracy: 0.73684 |  0:00:03s
# epoch 40 | loss: 0.35559 | train_auc: 0.88989 | train_accuracy: 0.84211 | test_auc: 0.81994 | test_accuracy: 0.78947 |  0:00:04s
# epoch 50 | loss: 0.34514 | train_auc: 0.93992 | train_accuracy: 0.88158 | test_auc: 0.79501 | test_accuracy: 0.73684 |  0:00:06s
# epoch 60 | loss: 0.3192  | train_auc: 0.95914 | train_accuracy: 0.88816 | test_auc: 0.78947 | test_accuracy: 0.78947 |  0:00:07s
# epoch 70 | loss: 0.30287 | train_auc: 0.96105 | train_accuracy: 0.90132 | test_auc: 0.75623 | test_accuracy: 0.73684 |  0:00:08s
# epoch 80 | loss: 0.23768 | train_auc: 0.97351 | train_accuracy: 0.92763 | test_auc: 0.80609 | test_accuracy: 0.78947 |  0:00:09s
# epoch 90 | loss: 0.33252 | train_auc: 0.97039 | train_accuracy: 0.91447 | test_auc: 0.77008 | test_accuracy: 0.78947 |  0:00:10s
# epoch 100| loss: 0.24216 | train_auc: 0.98217 | train_accuracy: 0.92763 | test_auc: 0.79778 | test_accuracy: 0.78947 |  0:00:12s
# epoch 110| loss: 0.24131 | train_auc: 0.98373 | train_accuracy: 0.92763 | test_auc: 0.81717 | test_accuracy: 0.81579 |  0:00:13s
# epoch 120| loss: 0.21566 | train_auc: 0.9865  | train_accuracy: 0.93421 | test_auc: 0.79224 | test_accuracy: 0.81579 |  0:00:14s
# epoch 130| loss: 0.16024 | train_auc: 0.99377 | train_accuracy: 0.94079 | test_auc: 0.80609 | test_accuracy: 0.86842 |  0:00:15s
# epoch 140| loss: 0.18843 | train_auc: 0.99688 | train_accuracy: 0.94079 | test_auc: 0.80609 | test_accuracy: 0.84211 |  0:00:16s
#
# Early stopping occurred at epoch 147 with best_epoch = 87 and best_test_accuracy = 0.89474
#
# --- Processing: psd_gamma ---
# Shape: (190, 19)
# Missing values: 0
# epoch 0  | loss: 0.86057 | train_auc: 0.44997 | train_accuracy: 0.44737 | test_auc: 0.48199 | test_accuracy: 0.52632 |  0:00:00s
# epoch 10 | loss: 0.46768 | train_auc: 0.82618 | train_accuracy: 0.73684 | test_auc: 0.70914 | test_accuracy: 0.60526 |  0:00:01s
# epoch 20 | loss: 0.38229 | train_auc: 0.80506 | train_accuracy: 0.71053 | test_auc: 0.85596 | test_accuracy: 0.71053 |  0:00:02s
# epoch 30 | loss: 0.42122 | train_auc: 0.90772 | train_accuracy: 0.78947 | test_auc: 0.8615  | test_accuracy: 0.71053 |  0:00:03s
# epoch 40 | loss: 0.4311  | train_auc: 0.89751 | train_accuracy: 0.78947 | test_auc: 0.82825 | test_accuracy: 0.60526 |  0:00:04s
# epoch 50 | loss: 0.3384  | train_auc: 0.94252 | train_accuracy: 0.82895 | test_auc: 0.91136 | test_accuracy: 0.81579 |  0:00:06s
# epoch 60 | loss: 0.28709 | train_auc: 0.96382 | train_accuracy: 0.89474 | test_auc: 0.93352 | test_accuracy: 0.81579 |  0:00:07s
# epoch 70 | loss: 0.28119 | train_auc: 0.97022 | train_accuracy: 0.88816 | test_auc: 0.91967 | test_accuracy: 0.81579 |  0:00:08s
# epoch 80 | loss: 0.28745 | train_auc: 0.97732 | train_accuracy: 0.90132 | test_auc: 0.91413 | test_accuracy: 0.76316 |  0:00:09s
# epoch 90 | loss: 0.28684 | train_auc: 0.96866 | train_accuracy: 0.91447 | test_auc: 0.84765 | test_accuracy: 0.78947 |  0:00:10s
# epoch 100| loss: 0.21312 | train_auc: 0.98823 | train_accuracy: 0.94737 | test_auc: 0.91967 | test_accuracy: 0.81579 |  0:00:11s
# epoch 110| loss: 0.20702 | train_auc: 0.99636 | train_accuracy: 0.96711 | test_auc: 0.93906 | test_accuracy: 0.81579 |  0:00:13s
# epoch 120| loss: 0.28867 | train_auc: 0.99515 | train_accuracy: 0.97368 | test_auc: 0.9446  | test_accuracy: 0.86842 |  0:00:14s
# epoch 130| loss: 0.12749 | train_auc: 0.99636 | train_accuracy: 0.95395 | test_auc: 0.95014 | test_accuracy: 0.86842 |  0:00:15s
# epoch 140| loss: 0.18394 | train_auc: 0.99931 | train_accuracy: 0.97368 | test_auc: 0.95291 | test_accuracy: 0.84211 |  0:00:16s
# epoch 150| loss: 0.29138 | train_auc: 0.99792 | train_accuracy: 0.96711 | test_auc: 0.95014 | test_accuracy: 0.86842 |  0:00:17s
# epoch 160| loss: 0.15141 | train_auc: 0.99723 | train_accuracy: 0.97368 | test_auc: 0.95845 | test_accuracy: 0.86842 |  0:00:19s
# epoch 170| loss: 0.19717 | train_auc: 0.99896 | train_accuracy: 0.97368 | test_auc: 0.95845 | test_accuracy: 0.86842 |  0:00:20s
#
# Early stopping occurred at epoch 173 with best_epoch = 113 and best_test_accuracy = 0.89474
#
# --- Processing: fc_delta ---
# Shape: (190, 171)
# Missing values: 0
# epoch 0  | loss: 0.81698 | train_auc: 0.51437 | train_accuracy: 0.53947 | test_auc: 0.57618 | test_accuracy: 0.57895 |  0:00:00s
# epoch 10 | loss: 0.61926 | train_auc: 0.7777  | train_accuracy: 0.72368 | test_auc: 0.72853 | test_accuracy: 0.68421 |  0:00:01s
# epoch 20 | loss: 0.49629 | train_auc: 0.84037 | train_accuracy: 0.75    | test_auc: 0.66205 | test_accuracy: 0.52632 |  0:00:02s
# epoch 30 | loss: 0.32085 | train_auc: 0.93057 | train_accuracy: 0.82895 | test_auc: 0.83934 | test_accuracy: 0.73684 |  0:00:03s
# epoch 40 | loss: 0.31591 | train_auc: 0.94131 | train_accuracy: 0.85526 | test_auc: 0.81163 | test_accuracy: 0.68421 |  0:00:04s
# epoch 50 | loss: 0.25584 | train_auc: 0.97974 | train_accuracy: 0.89474 | test_auc: 0.8338  | test_accuracy: 0.73684 |  0:00:06s
# epoch 60 | loss: 0.31053 | train_auc: 0.98511 | train_accuracy: 0.95395 | test_auc: 0.85319 | test_accuracy: 0.73684 |  0:00:07s
# epoch 70 | loss: 0.27126 | train_auc: 0.95724 | train_accuracy: 0.91447 | test_auc: 0.84488 | test_accuracy: 0.78947 |  0:00:08s
# epoch 80 | loss: 0.20595 | train_auc: 0.97888 | train_accuracy: 0.94079 | test_auc: 0.85596 | test_accuracy: 0.84211 |  0:00:09s
# epoch 90 | loss: 0.15647 | train_auc: 0.9974  | train_accuracy: 0.96053 | test_auc: 0.8615  | test_accuracy: 0.78947 |  0:00:10s
# epoch 100| loss: 0.22438 | train_auc: 0.99498 | train_accuracy: 0.96053 | test_auc: 0.86427 | test_accuracy: 0.84211 |  0:00:11s
# epoch 110| loss: 0.1115  | train_auc: 0.99082 | train_accuracy: 0.95395 | test_auc: 0.90859 | test_accuracy: 0.84211 |  0:00:13s
# epoch 120| loss: 0.09934 | train_auc: 0.99844 | train_accuracy: 0.98026 | test_auc: 0.86704 | test_accuracy: 0.81579 |  0:00:14s
# epoch 130| loss: 0.1482  | train_auc: 0.99775 | train_accuracy: 0.97368 | test_auc: 0.85596 | test_accuracy: 0.81579 |  0:00:15s
#
# Early stopping occurred at epoch 139 with best_epoch = 79 and best_test_accuracy = 0.86842
#
# --- Processing: fc_theta ---
# Shape: (190, 171)
# Missing values: 0
# epoch 0  | loss: 0.86267 | train_auc: 0.30852 | train_accuracy: 0.38158 | test_auc: 0.47922 | test_accuracy: 0.42105 |  0:00:00s
# epoch 10 | loss: 0.59645 | train_auc: 0.73009 | train_accuracy: 0.70395 | test_auc: 0.60665 | test_accuracy: 0.52632 |  0:00:01s
# epoch 20 | loss: 0.55004 | train_auc: 0.83016 | train_accuracy: 0.70395 | test_auc: 0.70083 | test_accuracy: 0.55263 |  0:00:02s
# epoch 30 | loss: 0.44327 | train_auc: 0.90357 | train_accuracy: 0.84868 | test_auc: 0.86981 | test_accuracy: 0.81579 |  0:00:03s
# epoch 40 | loss: 0.4514  | train_auc: 0.94564 | train_accuracy: 0.85526 | test_auc: 0.8144  | test_accuracy: 0.73684 |  0:00:04s
# epoch 50 | loss: 0.42285 | train_auc: 0.90478 | train_accuracy: 0.82895 | test_auc: 0.8338  | test_accuracy: 0.78947 |  0:00:06s
# epoch 60 | loss: 0.31686 | train_auc: 0.9388  | train_accuracy: 0.88158 | test_auc: 0.87812 | test_accuracy: 0.76316 |  0:00:07s
# epoch 70 | loss: 0.35904 | train_auc: 0.97542 | train_accuracy: 0.91447 | test_auc: 0.82548 | test_accuracy: 0.78947 |  0:00:08s
# epoch 80 | loss: 0.31727 | train_auc: 0.96762 | train_accuracy: 0.90789 | test_auc: 0.8615  | test_accuracy: 0.81579 |  0:00:09s
# epoch 90 | loss: 0.25037 | train_auc: 0.98148 | train_accuracy: 0.92763 | test_auc: 0.91413 | test_accuracy: 0.84211 |  0:00:10s
# epoch 100| loss: 0.25442 | train_auc: 0.98182 | train_accuracy: 0.94079 | test_auc: 0.88643 | test_accuracy: 0.84211 |  0:00:12s
#
# Early stopping occurred at epoch 104 with best_epoch = 44 and best_test_accuracy = 0.89474
#
# --- Processing: fc_alpha ---
# Shape: (190, 171)
# Missing values: 0
# epoch 0  | loss: 0.77149 | train_auc: 0.56389 | train_accuracy: 0.54605 | test_auc: 0.40166 | test_accuracy: 0.39474 |  0:00:00s
# epoch 10 | loss: 0.68337 | train_auc: 0.62864 | train_accuracy: 0.57237 | test_auc: 0.69252 | test_accuracy: 0.63158 |  0:00:01s
# epoch 20 | loss: 0.60371 | train_auc: 0.7964  | train_accuracy: 0.71053 | test_auc: 0.80332 | test_accuracy: 0.65789 |  0:00:02s
# epoch 30 | loss: 0.48914 | train_auc: 0.90495 | train_accuracy: 0.79605 | test_auc: 0.82825 | test_accuracy: 0.78947 |  0:00:03s
# epoch 40 | loss: 0.47768 | train_auc: 0.9304  | train_accuracy: 0.86184 | test_auc: 0.84488 | test_accuracy: 0.84211 |  0:00:05s
# epoch 50 | loss: 0.33001 | train_auc: 0.90841 | train_accuracy: 0.875   | test_auc: 0.90582 | test_accuracy: 0.84211 |  0:00:06s
# epoch 60 | loss: 0.31684 | train_auc: 0.93317 | train_accuracy: 0.88158 | test_auc: 0.85596 | test_accuracy: 0.76316 |  0:00:07s
# epoch 70 | loss: 0.21849 | train_auc: 0.97836 | train_accuracy: 0.92763 | test_auc: 0.89474 | test_accuracy: 0.78947 |  0:00:08s
# epoch 80 | loss: 0.26231 | train_auc: 0.98719 | train_accuracy: 0.96053 | test_auc: 0.91136 | test_accuracy: 0.84211 |  0:00:09s
# epoch 90 | loss: 0.2138  | train_auc: 0.98944 | train_accuracy: 0.95395 | test_auc: 0.87535 | test_accuracy: 0.84211 |  0:00:11s
# epoch 100| loss: 0.17745 | train_auc: 0.99844 | train_accuracy: 0.97368 | test_auc: 0.94737 | test_accuracy: 0.89474 |  0:00:12s
# epoch 110| loss: 0.13353 | train_auc: 0.99775 | train_accuracy: 0.98026 | test_auc: 0.93629 | test_accuracy: 0.86842 |  0:00:13s
#
# Early stopping occurred at epoch 115 with best_epoch = 55 and best_test_accuracy = 0.89474
#
# --- Processing: fc_beta ---
# Shape: (190, 171)
# Missing values: 0
# epoch 0  | loss: 0.92664 | train_auc: 0.4394  | train_accuracy: 0.49342 | test_auc: 0.49861 | test_accuracy: 0.55263 |  0:00:00s
# epoch 10 | loss: 0.68473 | train_auc: 0.59886 | train_accuracy: 0.54605 | test_auc: 0.73684 | test_accuracy: 0.76316 |  0:00:01s
# epoch 20 | loss: 0.63016 | train_auc: 0.75416 | train_accuracy: 0.66447 | test_auc: 0.66205 | test_accuracy: 0.60526 |  0:00:02s
# epoch 30 | loss: 0.53443 | train_auc: 0.80592 | train_accuracy: 0.73026 | test_auc: 0.74238 | test_accuracy: 0.73684 |  0:00:03s
# epoch 40 | loss: 0.53919 | train_auc: 0.8866  | train_accuracy: 0.79605 | test_auc: 0.71191 | test_accuracy: 0.63158 |  0:00:04s
# epoch 50 | loss: 0.48308 | train_auc: 0.89578 | train_accuracy: 0.78289 | test_auc: 0.76731 | test_accuracy: 0.63158 |  0:00:06s
# epoch 60 | loss: 0.4098  | train_auc: 0.94893 | train_accuracy: 0.88158 | test_auc: 0.82548 | test_accuracy: 0.73684 |  0:00:07s
#
# Early stopping occurred at epoch 66 with best_epoch = 6 and best_test_accuracy = 0.76316
#
# --- Processing: fc_highbeta ---
# Shape: (190, 171)
# Missing values: 0
# epoch 0  | loss: 0.87037 | train_auc: 0.38002 | train_accuracy: 0.41447 | test_auc: 0.34072 | test_accuracy: 0.44737 |  0:00:00s
# epoch 10 | loss: 0.6732  | train_auc: 0.73355 | train_accuracy: 0.72368 | test_auc: 0.72299 | test_accuracy: 0.65789 |  0:00:01s
# epoch 20 | loss: 0.52412 | train_auc: 0.76073 | train_accuracy: 0.69079 | test_auc: 0.59003 | test_accuracy: 0.57895 |  0:00:02s
# epoch 30 | loss: 0.46465 | train_auc: 0.86115 | train_accuracy: 0.78289 | test_auc: 0.55402 | test_accuracy: 0.52632 |  0:00:03s
# epoch 40 | loss: 0.4003  | train_auc: 0.91932 | train_accuracy: 0.85526 | test_auc: 0.85873 | test_accuracy: 0.78947 |  0:00:04s
# epoch 50 | loss: 0.40621 | train_auc: 0.96174 | train_accuracy: 0.88158 | test_auc: 0.8338  | test_accuracy: 0.76316 |  0:00:06s
# epoch 60 | loss: 0.26646 | train_auc: 0.98182 | train_accuracy: 0.92105 | test_auc: 0.93352 | test_accuracy: 0.81579 |  0:00:07s
# epoch 70 | loss: 0.25718 | train_auc: 0.98044 | train_accuracy: 0.92763 | test_auc: 0.77562 | test_accuracy: 0.71053 |  0:00:08s
# epoch 80 | loss: 0.23349 | train_auc: 0.98892 | train_accuracy: 0.96711 | test_auc: 0.81994 | test_accuracy: 0.84211 |  0:00:09s
# epoch 90 | loss: 0.23377 | train_auc: 0.99082 | train_accuracy: 0.94079 | test_auc: 0.79224 | test_accuracy: 0.81579 |  0:00:10s
# epoch 100| loss: 0.18729 | train_auc: 0.99463 | train_accuracy: 0.96053 | test_auc: 0.8615  | test_accuracy: 0.78947 |  0:00:12s
# epoch 110| loss: 0.22187 | train_auc: 0.99827 | train_accuracy: 0.97368 | test_auc: 0.89474 | test_accuracy: 0.78947 |  0:00:13s
#
# Early stopping occurred at epoch 113 with best_epoch = 53 and best_test_accuracy = 0.86842
#
# --- Processing: fc_gamma ---
# Shape: (190, 171)
# Missing values: 0
# epoch 0  | loss: 0.87301 | train_auc: 0.42729 | train_accuracy: 0.43421 | test_auc: 0.6482  | test_accuracy: 0.57895 |  0:00:00s
# epoch 10 | loss: 0.66013 | train_auc: 0.54675 | train_accuracy: 0.50658 | test_auc: 0.47645 | test_accuracy: 0.5     |  0:00:01s
# epoch 20 | loss: 0.69041 | train_auc: 0.58501 | train_accuracy: 0.55921 | test_auc: 0.58726 | test_accuracy: 0.52632 |  0:00:02s
# epoch 30 | loss: 0.6447  | train_auc: 0.72351 | train_accuracy: 0.67105 | test_auc: 0.75623 | test_accuracy: 0.73684 |  0:00:03s
# epoch 40 | loss: 0.58663 | train_auc: 0.81423 | train_accuracy: 0.74342 | test_auc: 0.65928 | test_accuracy: 0.63158 |  0:00:04s
# epoch 50 | loss: 0.55151 | train_auc: 0.87102 | train_accuracy: 0.79605 | test_auc: 0.80055 | test_accuracy: 0.65789 |  0:00:06s
# epoch 60 | loss: 0.49917 | train_auc: 0.88816 | train_accuracy: 0.80263 | test_auc: 0.69529 | test_accuracy: 0.68421 |  0:00:07s
# epoch 70 | loss: 0.40485 | train_auc: 0.92884 | train_accuracy: 0.85526 | test_auc: 0.75623 | test_accuracy: 0.68421 |  0:00:08s
# epoch 80 | loss: 0.38073 | train_auc: 0.93992 | train_accuracy: 0.89474 | test_auc: 0.7867  | test_accuracy: 0.71053 |  0:00:09s
# epoch 90 | loss: 0.36089 | train_auc: 0.96711 | train_accuracy: 0.89474 | test_auc: 0.76731 | test_accuracy: 0.71053 |  0:00:10s
# epoch 100| loss: 0.38955 | train_auc: 0.97265 | train_accuracy: 0.93421 | test_auc: 0.83934 | test_accuracy: 0.73684 |  0:00:11s
# epoch 110| loss: 0.33556 | train_auc: 0.98459 | train_accuracy: 0.94079 | test_auc: 0.85042 | test_accuracy: 0.76316 |  0:00:13s
# epoch 120| loss: 0.37834 | train_auc: 0.9903  | train_accuracy: 0.94737 | test_auc: 0.84765 | test_accuracy: 0.78947 |  0:00:14s
# epoch 130| loss: 0.22928 | train_auc: 0.98459 | train_accuracy: 0.94079 | test_auc: 0.81994 | test_accuracy: 0.76316 |  0:00:15s
# epoch 140| loss: 0.16477 | train_auc: 0.99584 | train_accuracy: 0.95395 | test_auc: 0.84765 | test_accuracy: 0.84211 |  0:00:16s
# epoch 150| loss: 0.17683 | train_auc: 0.99602 | train_accuracy: 0.96711 | test_auc: 0.83657 | test_accuracy: 0.81579 |  0:00:17s
# epoch 160| loss: 0.24533 | train_auc: 0.99671 | train_accuracy: 0.97368 | test_auc: 0.88366 | test_accuracy: 0.81579 |  0:00:19s
# epoch 170| loss: 0.20855 | train_auc: 1.0     | train_accuracy: 0.99342 | test_auc: 0.87535 | test_accuracy: 0.81579 |  0:00:20s
# epoch 180| loss: 0.12897 | train_auc: 0.99965 | train_accuracy: 0.98026 | test_auc: 0.87535 | test_accuracy: 0.84211 |  0:00:21s
# epoch 190| loss: 0.2212  | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.88643 | test_accuracy: 0.86842 |  0:00:22s
# Stop training because you reached max_epochs = 200 with best_epoch = 147 and best_test_accuracy = 0.89474
#
# --- Processing: psd_fc_delta ---
# Shape: (190, 190)
# Missing values: 0
# epoch 0  | loss: 1.40632 | train_auc: 0.49048 | train_accuracy: 0.50658 | test_auc: 0.44321 | test_accuracy: 0.44737 |  0:00:00s
# epoch 10 | loss: 0.7059  | train_auc: 0.71728 | train_accuracy: 0.61184 | test_auc: 0.75069 | test_accuracy: 0.68421 |  0:00:01s
# epoch 20 | loss: 0.47668 | train_auc: 0.82323 | train_accuracy: 0.70395 | test_auc: 0.73684 | test_accuracy: 0.73684 |  0:00:02s
# epoch 30 | loss: 0.31177 | train_auc: 0.93906 | train_accuracy: 0.84211 | test_auc: 0.8144  | test_accuracy: 0.78947 |  0:00:03s
# epoch 40 | loss: 0.37511 | train_auc: 0.90616 | train_accuracy: 0.81579 | test_auc: 0.81717 | test_accuracy: 0.73684 |  0:00:04s
# epoch 50 | loss: 0.33048 | train_auc: 0.95949 | train_accuracy: 0.86842 | test_auc: 0.78116 | test_accuracy: 0.73684 |  0:00:06s
# epoch 60 | loss: 0.24909 | train_auc: 0.96001 | train_accuracy: 0.88816 | test_auc: 0.8338  | test_accuracy: 0.81579 |  0:00:07s
# epoch 70 | loss: 0.25342 | train_auc: 0.98217 | train_accuracy: 0.91447 | test_auc: 0.86981 | test_accuracy: 0.84211 |  0:00:08s
# epoch 80 | loss: 0.30936 | train_auc: 0.99152 | train_accuracy: 0.91447 | test_auc: 0.89197 | test_accuracy: 0.84211 |  0:00:09s
# epoch 90 | loss: 0.25345 | train_auc: 0.99013 | train_accuracy: 0.95395 | test_auc: 0.85319 | test_accuracy: 0.86842 |  0:00:10s
# epoch 100| loss: 0.19251 | train_auc: 0.98684 | train_accuracy: 0.92105 | test_auc: 0.85873 | test_accuracy: 0.76316 |  0:00:12s
# epoch 110| loss: 0.208   | train_auc: 0.9903  | train_accuracy: 0.94737 | test_auc: 0.87258 | test_accuracy: 0.81579 |  0:00:13s
# epoch 120| loss: 0.19162 | train_auc: 0.99377 | train_accuracy: 0.96053 | test_auc: 0.88089 | test_accuracy: 0.84211 |  0:00:14s
# epoch 130| loss: 0.12935 | train_auc: 0.99498 | train_accuracy: 0.94737 | test_auc: 0.90028 | test_accuracy: 0.84211 |  0:00:15s
# epoch 140| loss: 0.21674 | train_auc: 0.99654 | train_accuracy: 0.95395 | test_auc: 0.90305 | test_accuracy: 0.84211 |  0:00:16s
#
# Early stopping occurred at epoch 143 with best_epoch = 83 and best_test_accuracy = 0.86842
#
# --- Processing: psd_fc_theta ---
# Shape: (190, 190)
# Missing values: 0
# epoch 0  | loss: 1.51101 | train_auc: 0.55886 | train_accuracy: 0.54605 | test_auc: 0.55679 | test_accuracy: 0.5     |  0:00:00s
# epoch 10 | loss: 0.69757 | train_auc: 0.71226 | train_accuracy: 0.625   | test_auc: 0.79501 | test_accuracy: 0.65789 |  0:00:01s
# epoch 20 | loss: 0.5608  | train_auc: 0.85751 | train_accuracy: 0.73026 | test_auc: 0.80055 | test_accuracy: 0.71053 |  0:00:02s
# epoch 30 | loss: 0.44732 | train_auc: 0.88054 | train_accuracy: 0.82895 | test_auc: 0.68144 | test_accuracy: 0.57895 |  0:00:03s
# epoch 40 | loss: 0.5256  | train_auc: 0.9356  | train_accuracy: 0.875   | test_auc: 0.77008 | test_accuracy: 0.63158 |  0:00:04s
# epoch 50 | loss: 0.30588 | train_auc: 0.94373 | train_accuracy: 0.875   | test_auc: 0.76454 | test_accuracy: 0.60526 |  0:00:06s
# epoch 60 | loss: 0.41595 | train_auc: 0.96832 | train_accuracy: 0.91447 | test_auc: 0.80055 | test_accuracy: 0.63158 |  0:00:07s
# epoch 70 | loss: 0.31663 | train_auc: 0.97265 | train_accuracy: 0.93421 | test_auc: 0.77008 | test_accuracy: 0.73684 |  0:00:08s
# epoch 80 | loss: 0.22372 | train_auc: 0.97472 | train_accuracy: 0.94079 | test_auc: 0.81717 | test_accuracy: 0.78947 |  0:00:09s
# epoch 90 | loss: 0.21317 | train_auc: 0.99948 | train_accuracy: 0.98684 | test_auc: 0.84488 | test_accuracy: 0.73684 |  0:00:10s
# epoch 100| loss: 0.17307 | train_auc: 0.99931 | train_accuracy: 0.98026 | test_auc: 0.86981 | test_accuracy: 0.76316 |  0:00:12s
# epoch 110| loss: 0.14905 | train_auc: 0.99377 | train_accuracy: 0.96711 | test_auc: 0.85319 | test_accuracy: 0.73684 |  0:00:13s
# epoch 120| loss: 0.12923 | train_auc: 0.99619 | train_accuracy: 0.97368 | test_auc: 0.89197 | test_accuracy: 0.73684 |  0:00:14s
# epoch 130| loss: 0.14478 | train_auc: 0.99654 | train_accuracy: 0.96711 | test_auc: 0.86981 | test_accuracy: 0.73684 |  0:00:15s
# epoch 140| loss: 0.11624 | train_auc: 0.99913 | train_accuracy: 0.98026 | test_auc: 0.87258 | test_accuracy: 0.76316 |  0:00:16s
# epoch 150| loss: 0.09977 | train_auc: 0.99931 | train_accuracy: 0.98684 | test_auc: 0.90305 | test_accuracy: 0.76316 |  0:00:18s
#
# Early stopping occurred at epoch 158 with best_epoch = 98 and best_test_accuracy = 0.81579
#
# --- Processing: psd_fc_alpha ---
# Shape: (190, 190)
# Missing values: 0
# epoch 0  | loss: 1.48501 | train_auc: 0.5412  | train_accuracy: 0.51316 | test_auc: 0.67313 | test_accuracy: 0.65789 |  0:00:00s
# epoch 10 | loss: 0.7253  | train_auc: 0.72091 | train_accuracy: 0.61842 | test_auc: 0.55402 | test_accuracy: 0.5     |  0:00:01s
# epoch 20 | loss: 0.6138  | train_auc: 0.83085 | train_accuracy: 0.74342 | test_auc: 0.75069 | test_accuracy: 0.63158 |  0:00:02s
# epoch 30 | loss: 0.49355 | train_auc: 0.77701 | train_accuracy: 0.71053 | test_auc: 0.57895 | test_accuracy: 0.47368 |  0:00:03s
# epoch 40 | loss: 0.58404 | train_auc: 0.85301 | train_accuracy: 0.76974 | test_auc: 0.69252 | test_accuracy: 0.60526 |  0:00:04s
# epoch 50 | loss: 0.59135 | train_auc: 0.86288 | train_accuracy: 0.75658 | test_auc: 0.70083 | test_accuracy: 0.71053 |  0:00:06s
# epoch 60 | loss: 0.46162 | train_auc: 0.84955 | train_accuracy: 0.72368 | test_auc: 0.58449 | test_accuracy: 0.55263 |  0:00:07s
# epoch 70 | loss: 0.45116 | train_auc: 0.93715 | train_accuracy: 0.85526 | test_auc: 0.74515 | test_accuracy: 0.65789 |  0:00:08s
# epoch 80 | loss: 0.35652 | train_auc: 0.9581  | train_accuracy: 0.84868 | test_auc: 0.83657 | test_accuracy: 0.73684 |  0:00:09s
# epoch 90 | loss: 0.39094 | train_auc: 0.95983 | train_accuracy: 0.90789 | test_auc: 0.86704 | test_accuracy: 0.78947 |  0:00:10s
# epoch 100| loss: 0.40982 | train_auc: 0.942   | train_accuracy: 0.86842 | test_auc: 0.84488 | test_accuracy: 0.71053 |  0:00:12s
# epoch 110| loss: 0.30686 | train_auc: 0.97715 | train_accuracy: 0.93421 | test_auc: 0.84765 | test_accuracy: 0.78947 |  0:00:13s
# epoch 120| loss: 0.26932 | train_auc: 0.97992 | train_accuracy: 0.92763 | test_auc: 0.84765 | test_accuracy: 0.71053 |  0:00:14s
# epoch 130| loss: 0.29438 | train_auc: 0.97905 | train_accuracy: 0.93421 | test_auc: 0.90859 | test_accuracy: 0.84211 |  0:00:15s
# epoch 140| loss: 0.29144 | train_auc: 0.98684 | train_accuracy: 0.95395 | test_auc: 0.88643 | test_accuracy: 0.78947 |  0:00:16s
# epoch 150| loss: 0.21117 | train_auc: 0.9903  | train_accuracy: 0.94079 | test_auc: 0.84488 | test_accuracy: 0.78947 |  0:00:17s
# epoch 160| loss: 0.29715 | train_auc: 0.99204 | train_accuracy: 0.96053 | test_auc: 0.85319 | test_accuracy: 0.78947 |  0:00:19s
# epoch 170| loss: 0.21299 | train_auc: 0.99359 | train_accuracy: 0.95395 | test_auc: 0.8615  | test_accuracy: 0.78947 |  0:00:20s
# epoch 180| loss: 0.21169 | train_auc: 0.99152 | train_accuracy: 0.95395 | test_auc: 0.92798 | test_accuracy: 0.84211 |  0:00:21s
# epoch 190| loss: 0.21292 | train_auc: 0.9955  | train_accuracy: 0.94079 | test_auc: 0.90859 | test_accuracy: 0.81579 |  0:00:22s
#
# Early stopping occurred at epoch 190 with best_epoch = 130 and best_test_accuracy = 0.84211
#
# --- Processing: psd_fc_beta ---
# Shape: (190, 190)
# Missing values: 0
# epoch 0  | loss: 1.50381 | train_auc: 0.49931 | train_accuracy: 0.51974 | test_auc: 0.57341 | test_accuracy: 0.5     |  0:00:00s
# epoch 10 | loss: 0.68054 | train_auc: 0.64301 | train_accuracy: 0.57237 | test_auc: 0.67036 | test_accuracy: 0.52632 |  0:00:01s
# epoch 20 | loss: 0.56453 | train_auc: 0.7687  | train_accuracy: 0.69737 | test_auc: 0.78393 | test_accuracy: 0.65789 |  0:00:02s
# epoch 30 | loss: 0.53186 | train_auc: 0.81406 | train_accuracy: 0.72368 | test_auc: 0.6759  | test_accuracy: 0.63158 |  0:00:03s
# epoch 40 | loss: 0.48778 | train_auc: 0.90686 | train_accuracy: 0.77632 | test_auc: 0.68421 | test_accuracy: 0.65789 |  0:00:05s
# epoch 50 | loss: 0.56633 | train_auc: 0.91136 | train_accuracy: 0.76316 | test_auc: 0.73407 | test_accuracy: 0.76316 |  0:00:06s
# epoch 60 | loss: 0.40411 | train_auc: 0.91049 | train_accuracy: 0.84868 | test_auc: 0.79778 | test_accuracy: 0.71053 |  0:00:07s
# epoch 70 | loss: 0.37468 | train_auc: 0.94668 | train_accuracy: 0.88816 | test_auc: 0.84211 | test_accuracy: 0.78947 |  0:00:08s
# epoch 80 | loss: 0.30076 | train_auc: 0.95291 | train_accuracy: 0.85526 | test_auc: 0.82825 | test_accuracy: 0.76316 |  0:00:09s
# epoch 90 | loss: 0.27857 | train_auc: 0.96953 | train_accuracy: 0.92105 | test_auc: 0.87258 | test_accuracy: 0.78947 |  0:00:11s
# epoch 100| loss: 0.24121 | train_auc: 0.98667 | train_accuracy: 0.92763 | test_auc: 0.83934 | test_accuracy: 0.76316 |  0:00:12s
# epoch 110| loss: 0.24056 | train_auc: 0.98667 | train_accuracy: 0.93421 | test_auc: 0.84765 | test_accuracy: 0.81579 |  0:00:13s
# epoch 120| loss: 0.21354 | train_auc: 0.99602 | train_accuracy: 0.94079 | test_auc: 0.88643 | test_accuracy: 0.84211 |  0:00:14s
# epoch 130| loss: 0.2155  | train_auc: 0.99688 | train_accuracy: 0.96053 | test_auc: 0.86704 | test_accuracy: 0.78947 |  0:00:15s
# epoch 140| loss: 0.16765 | train_auc: 0.99619 | train_accuracy: 0.95395 | test_auc: 0.8615  | test_accuracy: 0.78947 |  0:00:16s
# epoch 150| loss: 0.12156 | train_auc: 0.99827 | train_accuracy: 0.98026 | test_auc: 0.85596 | test_accuracy: 0.78947 |  0:00:18s
# epoch 160| loss: 0.10588 | train_auc: 0.99879 | train_accuracy: 0.97368 | test_auc: 0.86704 | test_accuracy: 0.78947 |  0:00:19s
# epoch 170| loss: 0.1404  | train_auc: 0.99896 | train_accuracy: 0.97368 | test_auc: 0.89197 | test_accuracy: 0.81579 |  0:00:20s
#
# Early stopping occurred at epoch 176 with best_epoch = 116 and best_test_accuracy = 0.86842
#
# --- Processing: psd_fc_highbeta ---
# Shape: (190, 190)
# Missing values: 0
# epoch 0  | loss: 1.37333 | train_auc: 0.5135  | train_accuracy: 0.53947 | test_auc: 0.53186 | test_accuracy: 0.52632 |  0:00:00s
# epoch 10 | loss: 0.69454 | train_auc: 0.67313 | train_accuracy: 0.66447 | test_auc: 0.57618 | test_accuracy: 0.60526 |  0:00:01s
# epoch 20 | loss: 0.65379 | train_auc: 0.71001 | train_accuracy: 0.65132 | test_auc: 0.65097 | test_accuracy: 0.65789 |  0:00:02s
# epoch 30 | loss: 0.57003 | train_auc: 0.83051 | train_accuracy: 0.75    | test_auc: 0.78116 | test_accuracy: 0.73684 |  0:00:03s
# epoch 40 | loss: 0.43346 | train_auc: 0.90616 | train_accuracy: 0.78289 | test_auc: 0.80886 | test_accuracy: 0.78947 |  0:00:04s
# epoch 50 | loss: 0.38962 | train_auc: 0.93923 | train_accuracy: 0.82895 | test_auc: 0.84488 | test_accuracy: 0.78947 |  0:00:06s
# epoch 60 | loss: 0.25081 | train_auc: 0.94148 | train_accuracy: 0.85526 | test_auc: 0.85042 | test_accuracy: 0.81579 |  0:00:07s
# epoch 70 | loss: 0.34082 | train_auc: 0.9356  | train_accuracy: 0.875   | test_auc: 0.83657 | test_accuracy: 0.84211 |  0:00:08s
# epoch 80 | loss: 0.30845 | train_auc: 0.94616 | train_accuracy: 0.84211 | test_auc: 0.89751 | test_accuracy: 0.78947 |  0:00:09s
# epoch 90 | loss: 0.22149 | train_auc: 0.98857 | train_accuracy: 0.95395 | test_auc: 0.8892  | test_accuracy: 0.86842 |  0:00:10s
# epoch 100| loss: 0.23916 | train_auc: 0.99186 | train_accuracy: 0.94737 | test_auc: 0.90582 | test_accuracy: 0.81579 |  0:00:11s
# epoch 110| loss: 0.17976 | train_auc: 0.99706 | train_accuracy: 0.97368 | test_auc: 0.9169  | test_accuracy: 0.81579 |  0:00:13s
#
# Early stopping occurred at epoch 116 with best_epoch = 56 and best_test_accuracy = 0.86842
#
# --- Processing: psd_fc_gamma ---
# Shape: (190, 190)
# Missing values: 0
# epoch 0  | loss: 1.45505 | train_auc: 0.45222 | train_accuracy: 0.42105 | test_auc: 0.4626  | test_accuracy: 0.39474 |  0:00:00s
# epoch 10 | loss: 0.6892  | train_auc: 0.65114 | train_accuracy: 0.53289 | test_auc: 0.61773 | test_accuracy: 0.57895 |  0:00:01s
# epoch 20 | loss: 0.63409 | train_auc: 0.69997 | train_accuracy: 0.65789 | test_auc: 0.52078 | test_accuracy: 0.55263 |  0:00:02s
# epoch 30 | loss: 0.478   | train_auc: 0.82531 | train_accuracy: 0.76316 | test_auc: 0.85596 | test_accuracy: 0.76316 |  0:00:03s
# epoch 40 | loss: 0.50632 | train_auc: 0.82029 | train_accuracy: 0.76316 | test_auc: 0.65097 | test_accuracy: 0.60526 |  0:00:04s
# epoch 50 | loss: 0.38176 | train_auc: 0.93629 | train_accuracy: 0.85526 | test_auc: 0.72576 | test_accuracy: 0.68421 |  0:00:06s
# epoch 60 | loss: 0.28664 | train_auc: 0.94235 | train_accuracy: 0.84868 | test_auc: 0.77839 | test_accuracy: 0.71053 |  0:00:07s
# epoch 70 | loss: 0.28976 | train_auc: 0.95568 | train_accuracy: 0.90132 | test_auc: 0.8144  | test_accuracy: 0.78947 |  0:00:08s
# epoch 80 | loss: 0.29901 | train_auc: 0.95897 | train_accuracy: 0.88158 | test_auc: 0.85873 | test_accuracy: 0.78947 |  0:00:09s
#
# Early stopping occurred at epoch 83 with best_epoch = 23 and best_test_accuracy = 0.86842
#
# === Disorder: Adjustment disorder ===
#
# --- Processing: psd_all_bands ---
# Shape: (190, 114)
# Missing values: 0
# epoch 0  | loss: 0.71054 | train_auc: 0.49221 | train_accuracy: 0.56579 | test_auc: 0.57341 | test_accuracy: 0.52632 |  0:00:00s
# epoch 10 | loss: 0.62696 | train_auc: 0.69356 | train_accuracy: 0.67105 | test_auc: 0.50139 | test_accuracy: 0.5     |  0:00:01s
# epoch 20 | loss: 0.63241 | train_auc: 0.85751 | train_accuracy: 0.80921 | test_auc: 0.73961 | test_accuracy: 0.71053 |  0:00:02s
# epoch 30 | loss: 0.43445 | train_auc: 0.87725 | train_accuracy: 0.78947 | test_auc: 0.82825 | test_accuracy: 0.76316 |  0:00:03s
# epoch 40 | loss: 0.38866 | train_auc: 0.90166 | train_accuracy: 0.82895 | test_auc: 0.79501 | test_accuracy: 0.71053 |  0:00:04s
# epoch 50 | loss: 0.38041 | train_auc: 0.95291 | train_accuracy: 0.89474 | test_auc: 0.8144  | test_accuracy: 0.73684 |  0:00:06s
# epoch 60 | loss: 0.36251 | train_auc: 0.9633  | train_accuracy: 0.91447 | test_auc: 0.81717 | test_accuracy: 0.76316 |  0:00:07s
# epoch 70 | loss: 0.24092 | train_auc: 0.9858  | train_accuracy: 0.93421 | test_auc: 0.81163 | test_accuracy: 0.81579 |  0:00:08s
#
# Early stopping occurred at epoch 78 with best_epoch = 18 and best_test_accuracy = 0.84211
#
# --- Processing: fc_all_bands ---
# Shape: (190, 1026)
# Missing values: 0
# epoch 0  | loss: 0.82382 | train_auc: 0.56856 | train_accuracy: 0.57237 | test_auc: 0.63989 | test_accuracy: 0.63158 |  0:00:00s
# epoch 10 | loss: 0.66095 | train_auc: 0.64474 | train_accuracy: 0.5     | test_auc: 0.63989 | test_accuracy: 0.55263 |  0:00:01s
# epoch 20 | loss: 0.60862 | train_auc: 0.75866 | train_accuracy: 0.69079 | test_auc: 0.48753 | test_accuracy: 0.5     |  0:00:02s
# epoch 30 | loss: 0.56556 | train_auc: 0.8518  | train_accuracy: 0.79605 | test_auc: 0.69806 | test_accuracy: 0.63158 |  0:00:03s
# epoch 40 | loss: 0.58079 | train_auc: 0.81163 | train_accuracy: 0.72368 | test_auc: 0.55402 | test_accuracy: 0.5     |  0:00:05s
# epoch 50 | loss: 0.40609 | train_auc: 0.92036 | train_accuracy: 0.84211 | test_auc: 0.61496 | test_accuracy: 0.65789 |  0:00:06s
# epoch 60 | loss: 0.3026  | train_auc: 0.97091 | train_accuracy: 0.88816 | test_auc: 0.69529 | test_accuracy: 0.71053 |  0:00:07s
# epoch 70 | loss: 0.25695 | train_auc: 0.97905 | train_accuracy: 0.94079 | test_auc: 0.75069 | test_accuracy: 0.71053 |  0:00:08s
# epoch 80 | loss: 0.22716 | train_auc: 0.9981  | train_accuracy: 0.94737 | test_auc: 0.80609 | test_accuracy: 0.73684 |  0:00:10s
# epoch 90 | loss: 0.23524 | train_auc: 0.99636 | train_accuracy: 0.98026 | test_auc: 0.83102 | test_accuracy: 0.73684 |  0:00:11s
# epoch 100| loss: 0.09734 | train_auc: 0.99844 | train_accuracy: 0.98684 | test_auc: 0.80332 | test_accuracy: 0.73684 |  0:00:12s
# epoch 110| loss: 0.22002 | train_auc: 0.99965 | train_accuracy: 0.98684 | test_auc: 0.89197 | test_accuracy: 0.78947 |  0:00:13s
# epoch 120| loss: 0.1111  | train_auc: 0.9981  | train_accuracy: 0.96711 | test_auc: 0.87812 | test_accuracy: 0.71053 |  0:00:15s
# epoch 130| loss: 0.22254 | train_auc: 1.0     | train_accuracy: 0.99342 | test_auc: 0.84765 | test_accuracy: 0.76316 |  0:00:16s
# epoch 140| loss: 0.15699 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.93352 | test_accuracy: 0.76316 |  0:00:17s
# epoch 150| loss: 0.09789 | train_auc: 0.99931 | train_accuracy: 0.99342 | test_auc: 0.88366 | test_accuracy: 0.81579 |  0:00:18s
# epoch 160| loss: 0.0669  | train_auc: 0.99965 | train_accuracy: 0.99342 | test_auc: 0.87258 | test_accuracy: 0.78947 |  0:00:20s
# epoch 170| loss: 0.08834 | train_auc: 1.0     | train_accuracy: 0.99342 | test_auc: 0.85319 | test_accuracy: 0.78947 |  0:00:21s
# epoch 180| loss: 0.10278 | train_auc: 0.99983 | train_accuracy: 0.99342 | test_auc: 0.86981 | test_accuracy: 0.76316 |  0:00:22s
# epoch 190| loss: 0.10062 | train_auc: 1.0     | train_accuracy: 0.99342 | test_auc: 0.88089 | test_accuracy: 0.73684 |  0:00:23s
# Stop training because you reached max_epochs = 200 with best_epoch = 152 and best_test_accuracy = 0.84211
#
# --- Processing: psd_fc_all_bands ---
# Shape: (190, 1140)
# Missing values: 0
# epoch 0  | loss: 0.95276 | train_auc: 0.50173 | train_accuracy: 0.48684 | test_auc: 0.6205  | test_accuracy: 0.65789 |  0:00:00s
# epoch 10 | loss: 0.68182 | train_auc: 0.67902 | train_accuracy: 0.63816 | test_auc: 0.60388 | test_accuracy: 0.63158 |  0:00:01s
# epoch 20 | loss: 0.63443 | train_auc: 0.7365  | train_accuracy: 0.71053 | test_auc: 0.61773 | test_accuracy: 0.55263 |  0:00:02s
# epoch 30 | loss: 0.59965 | train_auc: 0.77026 | train_accuracy: 0.72368 | test_auc: 0.63435 | test_accuracy: 0.52632 |  0:00:03s
# epoch 40 | loss: 0.43911 | train_auc: 0.85336 | train_accuracy: 0.78947 | test_auc: 0.73961 | test_accuracy: 0.63158 |  0:00:05s
# epoch 50 | loss: 0.53335 | train_auc: 0.87067 | train_accuracy: 0.77632 | test_auc: 0.5651  | test_accuracy: 0.52632 |  0:00:06s
# epoch 60 | loss: 0.42834 | train_auc: 0.90703 | train_accuracy: 0.84868 | test_auc: 0.70083 | test_accuracy: 0.68421 |  0:00:07s
# epoch 70 | loss: 0.36551 | train_auc: 0.96278 | train_accuracy: 0.91447 | test_auc: 0.72576 | test_accuracy: 0.73684 |  0:00:08s
# epoch 80 | loss: 0.21937 | train_auc: 0.97403 | train_accuracy: 0.92105 | test_auc: 0.80886 | test_accuracy: 0.71053 |  0:00:10s
# epoch 90 | loss: 0.34116 | train_auc: 0.98598 | train_accuracy: 0.94079 | test_auc: 0.79501 | test_accuracy: 0.76316 |  0:00:11s
# epoch 100| loss: 0.22637 | train_auc: 0.99411 | train_accuracy: 0.95395 | test_auc: 0.7867  | test_accuracy: 0.84211 |  0:00:12s
# epoch 110| loss: 0.13809 | train_auc: 0.99896 | train_accuracy: 0.96711 | test_auc: 0.93629 | test_accuracy: 0.86842 |  0:00:13s
# epoch 120| loss: 0.17333 | train_auc: 0.99827 | train_accuracy: 0.98026 | test_auc: 0.80886 | test_accuracy: 0.78947 |  0:00:15s
# epoch 130| loss: 0.13832 | train_auc: 0.99983 | train_accuracy: 0.99342 | test_auc: 0.93629 | test_accuracy: 0.89474 |  0:00:16s
# epoch 140| loss: 0.12636 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.93075 | test_accuracy: 0.86842 |  0:00:17s
# epoch 150| loss: 0.1464  | train_auc: 0.99983 | train_accuracy: 0.99342 | test_auc: 0.92244 | test_accuracy: 0.81579 |  0:00:19s
# epoch 160| loss: 0.08851 | train_auc: 0.99983 | train_accuracy: 0.99342 | test_auc: 0.90305 | test_accuracy: 0.84211 |  0:00:20s
# epoch 170| loss: 0.08608 | train_auc: 1.0     | train_accuracy: 0.99342 | test_auc: 0.89197 | test_accuracy: 0.84211 |  0:00:21s
# epoch 180| loss: 0.09267 | train_auc: 1.0     | train_accuracy: 0.99342 | test_auc: 0.88089 | test_accuracy: 0.84211 |  0:00:22s
#
# Early stopping occurred at epoch 185 with best_epoch = 125 and best_test_accuracy = 0.92105
#
# --- Processing: psd_delta ---
# Shape: (190, 19)
# Missing values: 0
# epoch 0  | loss: 0.93959 | train_auc: 0.70256 | train_accuracy: 0.65132 | test_auc: 0.61773 | test_accuracy: 0.55263 |  0:00:00s
# epoch 10 | loss: 0.59891 | train_auc: 0.80367 | train_accuracy: 0.71711 | test_auc: 0.85319 | test_accuracy: 0.78947 |  0:00:01s
# epoch 20 | loss: 0.5713  | train_auc: 0.88695 | train_accuracy: 0.79605 | test_auc: 0.75346 | test_accuracy: 0.65789 |  0:00:02s
# epoch 30 | loss: 0.37926 | train_auc: 0.95724 | train_accuracy: 0.85526 | test_auc: 0.85873 | test_accuracy: 0.73684 |  0:00:03s
# epoch 40 | loss: 0.29403 | train_auc: 0.95187 | train_accuracy: 0.875   | test_auc: 0.92798 | test_accuracy: 0.78947 |  0:00:04s
# epoch 50 | loss: 0.20155 | train_auc: 0.98979 | train_accuracy: 0.92763 | test_auc: 0.8615  | test_accuracy: 0.81579 |  0:00:06s
# epoch 60 | loss: 0.23576 | train_auc: 0.98078 | train_accuracy: 0.92763 | test_auc: 0.84488 | test_accuracy: 0.78947 |  0:00:07s
# epoch 70 | loss: 0.16892 | train_auc: 0.98909 | train_accuracy: 0.95395 | test_auc: 0.86427 | test_accuracy: 0.81579 |  0:00:08s
# epoch 80 | loss: 0.12945 | train_auc: 0.99169 | train_accuracy: 0.96053 | test_auc: 0.90582 | test_accuracy: 0.86842 |  0:00:09s
# epoch 90 | loss: 0.15949 | train_auc: 0.99256 | train_accuracy: 0.97368 | test_auc: 0.92244 | test_accuracy: 0.86842 |  0:00:10s
# epoch 100| loss: 0.15024 | train_auc: 0.99983 | train_accuracy: 0.99342 | test_auc: 0.8892  | test_accuracy: 0.89474 |  0:00:11s
# epoch 110| loss: 0.19546 | train_auc: 0.99983 | train_accuracy: 0.99342 | test_auc: 0.87535 | test_accuracy: 0.86842 |  0:00:13s
# epoch 120| loss: 0.06189 | train_auc: 0.99983 | train_accuracy: 0.99342 | test_auc: 0.90582 | test_accuracy: 0.89474 |  0:00:14s
# ...
# epoch 80 | loss: 0.40024 | train_auc: 0.95048 | train_accuracy: 0.90132 | test_auc: 0.75346 | test_accuracy: 0.68421 |  0:00:09s
# epoch 90 | loss: 0.36569 | train_auc: 0.95931 | train_accuracy: 0.89474 | test_auc: 0.85319 | test_accuracy: 0.73684 |  0:00:10s
# epoch 100| loss: 0.28351 | train_auc: 0.9813  | train_accuracy: 0.92763 | test_auc: 0.77285 | test_accuracy: 0.68421 |  0:00:12s
#
# Early stopping occurred at epoch 102 with best_epoch = 42 and best_test_accuracy = 0.84211
#
# --- Processing: fc_beta ---
# Shape: (190, 171)
# Missing values: 0
# epoch 0  | loss: 0.93942 | train_auc: 0.42278 | train_accuracy: 0.44079 | test_auc: 0.34626 | test_accuracy: 0.47368 |  0:00:00s
# epoch 10 | loss: 0.73051 | train_auc: 0.69546 | train_accuracy: 0.58553 | test_auc: 0.55956 | test_accuracy: 0.55263 |  0:00:01s
# epoch 20 | loss: 0.59741 | train_auc: 0.75467 | train_accuracy: 0.66447 | test_auc: 0.6482  | test_accuracy: 0.60526 |  0:00:02s
# epoch 30 | loss: 0.5801  | train_auc: 0.78688 | train_accuracy: 0.71711 | test_auc: 0.55402 | test_accuracy: 0.55263 |  0:00:03s
# epoch 40 | loss: 0.55311 | train_auc: 0.90443 | train_accuracy: 0.79605 | test_auc: 0.759   | test_accuracy: 0.76316 |  0:00:04s
# epoch 50 | loss: 0.5113  | train_auc: 0.91465 | train_accuracy: 0.79605 | test_auc: 0.6205  | test_accuracy: 0.57895 |  0:00:06s
# epoch 60 | loss: 0.39802 | train_auc: 0.92902 | train_accuracy: 0.86184 | test_auc: 0.60665 | test_accuracy: 0.60526 |  0:00:07s
# epoch 70 | loss: 0.44972 | train_auc: 0.95412 | train_accuracy: 0.88816 | test_auc: 0.65651 | test_accuracy: 0.65789 |  0:00:08s
#
# Early stopping occurred at epoch 79 with best_epoch = 19 and best_test_accuracy = 0.76316
#
# --- Processing: fc_highbeta ---
# Shape: (190, 171)
# Missing values: 0
# epoch 0  | loss: 0.88427 | train_auc: 0.59384 | train_accuracy: 0.52632 | test_auc: 0.43213 | test_accuracy: 0.44737 |  0:00:00s
# epoch 10 | loss: 0.71479 | train_auc: 0.53601 | train_accuracy: 0.53289 | test_auc: 0.73961 | test_accuracy: 0.63158 |  0:00:01s
# epoch 20 | loss: 0.58259 | train_auc: 0.82618 | train_accuracy: 0.68421 | test_auc: 0.62604 | test_accuracy: 0.57895 |  0:00:02s
# epoch 30 | loss: 0.52133 | train_auc: 0.85613 | train_accuracy: 0.78289 | test_auc: 0.74792 | test_accuracy: 0.73684 |  0:00:03s
# epoch 40 | loss: 0.45958 | train_auc: 0.91655 | train_accuracy: 0.80921 | test_auc: 0.8144  | test_accuracy: 0.71053 |  0:00:05s
# epoch 50 | loss: 0.50674 | train_auc: 0.86998 | train_accuracy: 0.78947 | test_auc: 0.80609 | test_accuracy: 0.73684 |  0:00:06s
# epoch 60 | loss: 0.47416 | train_auc: 0.92746 | train_accuracy: 0.85526 | test_auc: 0.76177 | test_accuracy: 0.65789 |  0:00:07s
# epoch 70 | loss: 0.4891  | train_auc: 0.95274 | train_accuracy: 0.88158 | test_auc: 0.79501 | test_accuracy: 0.68421 |  0:00:08s
# epoch 80 | loss: 0.36523 | train_auc: 0.9626  | train_accuracy: 0.88816 | test_auc: 0.78116 | test_accuracy: 0.73684 |  0:00:10s
# epoch 90 | loss: 0.3183  | train_auc: 0.98078 | train_accuracy: 0.91447 | test_auc: 0.80332 | test_accuracy: 0.68421 |  0:00:11s
# epoch 100| loss: 0.25843 | train_auc: 0.98234 | train_accuracy: 0.92763 | test_auc: 0.82271 | test_accuracy: 0.68421 |  0:00:12s
# epoch 110| loss: 0.2938  | train_auc: 0.98875 | train_accuracy: 0.94737 | test_auc: 0.80332 | test_accuracy: 0.65789 |  0:00:13s
#
# Early stopping occurred at epoch 119 with best_epoch = 59 and best_test_accuracy = 0.81579
#
# --- Processing: fc_gamma ---
# Shape: (190, 171)
# Missing values: 0
# epoch 0  | loss: 0.91097 | train_auc: 0.40876 | train_accuracy: 0.42763 | test_auc: 0.45152 | test_accuracy: 0.42105 |  0:00:00s
# epoch 10 | loss: 0.71333 | train_auc: 0.60838 | train_accuracy: 0.51974 | test_auc: 0.66482 | test_accuracy: 0.60526 |  0:00:01s
# epoch 20 | loss: 0.56846 | train_auc: 0.75277 | train_accuracy: 0.66447 | test_auc: 0.70637 | test_accuracy: 0.60526 |  0:00:02s
# epoch 30 | loss: 0.49456 | train_auc: 0.73892 | train_accuracy: 0.65789 | test_auc: 0.7313  | test_accuracy: 0.71053 |  0:00:03s
# epoch 40 | loss: 0.41798 | train_auc: 0.8982  | train_accuracy: 0.78947 | test_auc: 0.7867  | test_accuracy: 0.76316 |  0:00:04s
# epoch 50 | loss: 0.34534 | train_auc: 0.97472 | train_accuracy: 0.89474 | test_auc: 0.87258 | test_accuracy: 0.73684 |  0:00:06s
# epoch 60 | loss: 0.23485 | train_auc: 0.98442 | train_accuracy: 0.90789 | test_auc: 0.83657 | test_accuracy: 0.76316 |  0:00:07s
# epoch 70 | loss: 0.23001 | train_auc: 0.99359 | train_accuracy: 0.95395 | test_auc: 0.87258 | test_accuracy: 0.81579 |  0:00:08s
# epoch 80 | loss: 0.15571 | train_auc: 0.99463 | train_accuracy: 0.96711 | test_auc: 0.79224 | test_accuracy: 0.81579 |  0:00:09s
# epoch 90 | loss: 0.15652 | train_auc: 0.99429 | train_accuracy: 0.94079 | test_auc: 0.85042 | test_accuracy: 0.73684 |  0:00:10s
# epoch 100| loss: 0.18568 | train_auc: 0.9929  | train_accuracy: 0.98026 | test_auc: 0.83934 | test_accuracy: 0.81579 |  0:00:12s
# epoch 110| loss: 0.1282  | train_auc: 0.9981  | train_accuracy: 0.98026 | test_auc: 0.81994 | test_accuracy: 0.81579 |  0:00:13s
# epoch 120| loss: 0.06159 | train_auc: 0.99879 | train_accuracy: 0.98684 | test_auc: 0.81163 | test_accuracy: 0.76316 |  0:00:14s
# epoch 130| loss: 0.16104 | train_auc: 0.99913 | train_accuracy: 0.98684 | test_auc: 0.83657 | test_accuracy: 0.78947 |  0:00:15s
# epoch 140| loss: 0.08731 | train_auc: 0.99913 | train_accuracy: 0.99342 | test_auc: 0.81994 | test_accuracy: 0.81579 |  0:00:16s
# epoch 150| loss: 0.09809 | train_auc: 0.99931 | train_accuracy: 0.99342 | test_auc: 0.81163 | test_accuracy: 0.78947 |  0:00:18s
#
# Early stopping occurred at epoch 155 with best_epoch = 95 and best_test_accuracy = 0.84211
#
# --- Processing: psd_fc_delta ---
# Shape: (190, 190)
# Missing values: 0
# epoch 0  | loss: 1.45783 | train_auc: 0.59055 | train_accuracy: 0.52632 | test_auc: 0.45152 | test_accuracy: 0.44737 |  0:00:00s
# epoch 10 | loss: 0.66593 | train_auc: 0.60492 | train_accuracy: 0.55921 | test_auc: 0.40443 | test_accuracy: 0.47368 |  0:00:01s
# epoch 20 | loss: 0.64083 | train_auc: 0.77891 | train_accuracy: 0.69079 | test_auc: 0.63435 | test_accuracy: 0.57895 |  0:00:02s
# epoch 30 | loss: 0.50331 | train_auc: 0.83431 | train_accuracy: 0.78289 | test_auc: 0.67036 | test_accuracy: 0.60526 |  0:00:03s
# epoch 40 | loss: 0.36911 | train_auc: 0.91015 | train_accuracy: 0.81579 | test_auc: 0.73407 | test_accuracy: 0.63158 |  0:00:04s
# epoch 50 | loss: 0.43028 | train_auc: 0.93092 | train_accuracy: 0.84211 | test_auc: 0.74238 | test_accuracy: 0.68421 |  0:00:06s
# epoch 60 | loss: 0.34546 | train_auc: 0.97628 | train_accuracy: 0.92763 | test_auc: 0.73684 | test_accuracy: 0.71053 |  0:00:07s
# epoch 70 | loss: 0.18446 | train_auc: 0.98476 | train_accuracy: 0.94079 | test_auc: 0.72299 | test_accuracy: 0.73684 |  0:00:08s
# epoch 80 | loss: 0.26019 | train_auc: 0.99048 | train_accuracy: 0.94737 | test_auc: 0.76731 | test_accuracy: 0.68421 |  0:00:09s
# epoch 90 | loss: 0.18414 | train_auc: 0.99706 | train_accuracy: 0.95395 | test_auc: 0.73684 | test_accuracy: 0.65789 |  0:00:11s
# epoch 100| loss: 0.14154 | train_auc: 0.99584 | train_accuracy: 0.95395 | test_auc: 0.70914 | test_accuracy: 0.73684 |  0:00:12s
# epoch 110| loss: 0.22362 | train_auc: 0.9981  | train_accuracy: 0.96053 | test_auc: 0.7036  | test_accuracy: 0.60526 |  0:00:13s
#
# Early stopping occurred at epoch 114 with best_epoch = 54 and best_test_accuracy = 0.76316
#
# --- Processing: psd_fc_theta ---
# Shape: (190, 190)
# Missing values: 0
# epoch 0  | loss: 1.56514 | train_auc: 0.59176 | train_accuracy: 0.56579 | test_auc: 0.64266 | test_accuracy: 0.65789 |  0:00:00s
# epoch 10 | loss: 0.63529 | train_auc: 0.63695 | train_accuracy: 0.58553 | test_auc: 0.49584 | test_accuracy: 0.52632 |  0:00:01s
# epoch 20 | loss: 0.6296  | train_auc: 0.70325 | train_accuracy: 0.63816 | test_auc: 0.54848 | test_accuracy: 0.52632 |  0:00:02s
# epoch 30 | loss: 0.47656 | train_auc: 0.85215 | train_accuracy: 0.71711 | test_auc: 0.77562 | test_accuracy: 0.71053 |  0:00:03s
# epoch 40 | loss: 0.50809 | train_auc: 0.86392 | train_accuracy: 0.77632 | test_auc: 0.69806 | test_accuracy: 0.65789 |  0:00:04s
# epoch 50 | loss: 0.41582 | train_auc: 0.91222 | train_accuracy: 0.82237 | test_auc: 0.69252 | test_accuracy: 0.63158 |  0:00:06s
# epoch 60 | loss: 0.36447 | train_auc: 0.924   | train_accuracy: 0.83553 | test_auc: 0.6759  | test_accuracy: 0.60526 |  0:00:07s
# epoch 70 | loss: 0.2629  | train_auc: 0.9794  | train_accuracy: 0.92105 | test_auc: 0.74515 | test_accuracy: 0.68421 |  0:00:08s
# epoch 80 | loss: 0.237   | train_auc: 0.99082 | train_accuracy: 0.92105 | test_auc: 0.76454 | test_accuracy: 0.71053 |  0:00:09s
# epoch 90 | loss: 0.24277 | train_auc: 0.9955  | train_accuracy: 0.97368 | test_auc: 0.8338  | test_accuracy: 0.68421 |  0:00:10s
#
# Early stopping occurred at epoch 97 with best_epoch = 37 and best_test_accuracy = 0.73684
#
# --- Processing: psd_fc_alpha ---
# Shape: (190, 190)
# Missing values: 0
# epoch 0  | loss: 1.61607 | train_auc: 0.53411 | train_accuracy: 0.54605 | test_auc: 0.60388 | test_accuracy: 0.60526 |  0:00:00s
# epoch 10 | loss: 0.67761 | train_auc: 0.66742 | train_accuracy: 0.56579 | test_auc: 0.63989 | test_accuracy: 0.57895 |  0:00:01s
# epoch 20 | loss: 0.73006 | train_auc: 0.64024 | train_accuracy: 0.625   | test_auc: 0.68975 | test_accuracy: 0.65789 |  0:00:02s
# epoch 30 | loss: 0.61016 | train_auc: 0.72195 | train_accuracy: 0.65789 | test_auc: 0.60388 | test_accuracy: 0.60526 |  0:00:03s
# epoch 40 | loss: 0.5556  | train_auc: 0.85959 | train_accuracy: 0.81579 | test_auc: 0.42659 | test_accuracy: 0.44737 |  0:00:05s
# epoch 50 | loss: 0.62885 | train_auc: 0.88764 | train_accuracy: 0.77632 | test_auc: 0.55125 | test_accuracy: 0.55263 |  0:00:06s
# epoch 60 | loss: 0.43463 | train_auc: 0.92729 | train_accuracy: 0.84868 | test_auc: 0.77285 | test_accuracy: 0.65789 |  0:00:07s
# epoch 70 | loss: 0.41673 | train_auc: 0.942   | train_accuracy: 0.88816 | test_auc: 0.65374 | test_accuracy: 0.55263 |  0:00:08s
#
# Early stopping occurred at epoch 76 with best_epoch = 16 and best_test_accuracy = 0.73684
#
# --- Processing: psd_fc_beta ---
# Shape: (190, 190)
# Missing values: 0
# epoch 0  | loss: 1.56521 | train_auc: 0.54605 | train_accuracy: 0.51974 | test_auc: 0.62604 | test_accuracy: 0.63158 |  0:00:00s
# epoch 10 | loss: 0.69865 | train_auc: 0.62812 | train_accuracy: 0.52632 | test_auc: 0.70083 | test_accuracy: 0.63158 |  0:00:01s
# epoch 20 | loss: 0.63578 | train_auc: 0.72888 | train_accuracy: 0.61184 | test_auc: 0.4626  | test_accuracy: 0.39474 |  0:00:02s
# epoch 30 | loss: 0.53767 | train_auc: 0.83137 | train_accuracy: 0.73684 | test_auc: 0.62604 | test_accuracy: 0.57895 |  0:00:03s
# epoch 40 | loss: 0.4683  | train_auc: 0.92175 | train_accuracy: 0.85526 | test_auc: 0.65097 | test_accuracy: 0.65789 |  0:00:05s
# epoch 50 | loss: 0.45395 | train_auc: 0.94183 | train_accuracy: 0.88816 | test_auc: 0.65651 | test_accuracy: 0.52632 |  0:00:06s
# epoch 60 | loss: 0.44893 | train_auc: 0.97039 | train_accuracy: 0.90789 | test_auc: 0.65651 | test_accuracy: 0.63158 |  0:00:07s
# epoch 70 | loss: 0.32589 | train_auc: 0.95793 | train_accuracy: 0.88158 | test_auc: 0.71468 | test_accuracy: 0.65789 |  0:00:08s
# epoch 80 | loss: 0.25838 | train_auc: 0.99065 | train_accuracy: 0.92105 | test_auc: 0.73684 | test_accuracy: 0.71053 |  0:00:10s
# epoch 90 | loss: 0.23197 | train_auc: 0.99654 | train_accuracy: 0.96053 | test_auc: 0.75346 | test_accuracy: 0.71053 |  0:00:11s
# epoch 100| loss: 0.22407 | train_auc: 0.99411 | train_accuracy: 0.94737 | test_auc: 0.84488 | test_accuracy: 0.81579 |  0:00:12s
# epoch 110| loss: 0.18614 | train_auc: 1.0     | train_accuracy: 0.99342 | test_auc: 0.86427 | test_accuracy: 0.81579 |  0:00:13s
# epoch 120| loss: 0.10774 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.79778 | test_accuracy: 0.76316 |  0:00:14s
# epoch 130| loss: 0.12507 | train_auc: 1.0     | train_accuracy: 0.99342 | test_auc: 0.79224 | test_accuracy: 0.76316 |  0:00:16s
# epoch 140| loss: 0.14366 | train_auc: 1.0     | train_accuracy: 0.99342 | test_auc: 0.81717 | test_accuracy: 0.78947 |  0:00:17s
# epoch 150| loss: 0.14305 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.80609 | test_accuracy: 0.76316 |  0:00:18s
# epoch 160| loss: 0.03897 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.79501 | test_accuracy: 0.76316 |  0:00:19s
# epoch 170| loss: 0.08096 | train_auc: 1.0     | train_accuracy: 1.0     | test_auc: 0.84488 | test_accuracy: 0.84211 |  0:00:20s
#
# Early stopping occurred at epoch 176 with best_epoch = 116 and best_test_accuracy = 0.84211
#
# --- Processing: psd_fc_highbeta ---
# Shape: (190, 190)
# Missing values: 0
# epoch 0  | loss: 1.50811 | train_auc: 0.56943 | train_accuracy: 0.56579 | test_auc: 0.58449 | test_accuracy: 0.52632 |  0:00:00s
# epoch 10 | loss: 0.72799 | train_auc: 0.65668 | train_accuracy: 0.58553 | test_auc: 0.45152 | test_accuracy: 0.44737 |  0:00:01s
# epoch 20 | loss: 0.65222 | train_auc: 0.62985 | train_accuracy: 0.54605 | test_auc: 0.56233 | test_accuracy: 0.55263 |  0:00:02s
# epoch 30 | loss: 0.55703 | train_auc: 0.85388 | train_accuracy: 0.68421 | test_auc: 0.53463 | test_accuracy: 0.52632 |  0:00:03s
# epoch 40 | loss: 0.41532 | train_auc: 0.88833 | train_accuracy: 0.80921 | test_auc: 0.59557 | test_accuracy: 0.60526 |  0:00:04s
# epoch 50 | loss: 0.47874 | train_auc: 0.94044 | train_accuracy: 0.84211 | test_auc: 0.57895 | test_accuracy: 0.5     |  0:00:06s
# epoch 60 | loss: 0.42276 | train_auc: 0.96589 | train_accuracy: 0.88158 | test_auc: 0.6205  | test_accuracy: 0.60526 |  0:00:07s
# epoch 70 | loss: 0.38747 | train_auc: 0.95862 | train_accuracy: 0.88816 | test_auc: 0.67036 | test_accuracy: 0.60526 |  0:00:08s
# epoch 80 | loss: 0.35187 | train_auc: 0.96745 | train_accuracy: 0.90789 | test_auc: 0.6205  | test_accuracy: 0.5     |  0:00:09s
# epoch 90 | loss: 0.24421 | train_auc: 0.99152 | train_accuracy: 0.95395 | test_auc: 0.70083 | test_accuracy: 0.52632 |  0:00:10s
# epoch 100| loss: 0.28087 | train_auc: 0.99619 | train_accuracy: 0.96711 | test_auc: 0.62604 | test_accuracy: 0.52632 |  0:00:12s
# epoch 110| loss: 0.29245 | train_auc: 0.99775 | train_accuracy: 0.98684 | test_auc: 0.60942 | test_accuracy: 0.52632 |  0:00:13s
# epoch 120| loss: 0.19169 | train_auc: 0.99948 | train_accuracy: 0.98684 | test_auc: 0.72299 | test_accuracy: 0.60526 |  0:00:14s
#
# Early stopping occurred at epoch 125 with best_epoch = 65 and best_test_accuracy = 0.71053
#
# --- Processing: psd_fc_gamma ---
# Shape: (190, 190)
# Missing values: 0
# epoch 0  | loss: 1.52635 | train_auc: 0.57652 | train_accuracy: 0.49342 | test_auc: 0.67867 | test_accuracy: 0.71053 |  0:00:00s
# epoch 10 | loss: 0.73057 | train_auc: 0.56769 | train_accuracy: 0.51316 | test_auc: 0.62881 | test_accuracy: 0.57895 |  0:00:01s
# epoch 20 | loss: 0.66931 | train_auc: 0.67313 | train_accuracy: 0.60526 | test_auc: 0.77285 | test_accuracy: 0.76316 |  0:00:02s
# epoch 30 | loss: 0.5693  | train_auc: 0.77805 | train_accuracy: 0.73026 | test_auc: 0.73407 | test_accuracy: 0.68421 |  0:00:03s
# epoch 40 | loss: 0.52688 | train_auc: 0.8338  | train_accuracy: 0.72368 | test_auc: 0.8338  | test_accuracy: 0.81579 |  0:00:04s
# epoch 50 | loss: 0.39167 | train_auc: 0.91534 | train_accuracy: 0.84211 | test_auc: 0.75069 | test_accuracy: 0.73684 |  0:00:06s
# epoch 60 | loss: 0.28456 | train_auc: 0.97213 | train_accuracy: 0.90789 | test_auc: 0.72576 | test_accuracy: 0.68421 |  0:00:07s
# epoch 70 | loss: 0.24701 | train_auc: 0.99688 | train_accuracy: 0.96053 | test_auc: 0.77008 | test_accuracy: 0.68421 |  0:00:08s
# epoch 80 | loss: 0.20931 | train_auc: 0.99723 | train_accuracy: 0.97368 | test_auc: 0.77008 | test_accuracy: 0.73684 |  0:00:09s
# epoch 90 | loss: 0.16038 | train_auc: 1.0     | train_accuracy: 0.98684 | test_auc: 0.80886 | test_accuracy: 0.76316 |  0:00:11s
# epoch 100| loss: 0.12837 | train_auc: 1.0     | train_accuracy: 0.99342 | test_auc: 0.83934 | test_accuracy: 0.76316 |  0:00:12s
# epoch 110| loss: 0.19065 | train_auc: 0.99965 | train_accuracy: 0.98684 | test_auc: 0.83934 | test_accuracy: 0.73684 |  0:00:13s
#
# Early stopping occurred at epoch 114 with best_epoch = 54 and best_test_accuracy = 0.86842

# %% [markdown]
# ## | 6. Results

# %%
rows = []

for disorder, dicts in all_results.items():
    for dict_name, df_results in dicts.items():
        for df_name, metrics in df_results.items():
            row = {
                'Disorder': disorder,
                'Dict': dict_name,
                'DataFrame': df_name,
                'Accuracy': metrics['accuracy'],
                'AUC': metrics['auc'],
                'Classification Report': metrics['classification_report']
            }
            
            rows.append(row)

results_df = pd.DataFrame(rows)
results_df.to_csv(f'{experiment_name}.csv', index=False)
results_df
# best_results = df.loc[df.groupby('Disorder')['Accuracy'].idxmax()]
# Out:
#                     Disorder                      Dict         DataFrame  \
# 0      Acute stress disorder     df_dict_psd_all_bands     psd_all_bands
# 1      Acute stress disorder      df_dict_fc_all_bands      fc_all_bands
# 2      Acute stress disorder  df_dict_psd_fc_all_bands  psd_fc_all_bands
# 3      Acute stress disorder          df_dict_psd_band         psd_delta
# 4      Acute stress disorder          df_dict_psd_band         psd_theta
# ..                       ...                       ...               ...
# 184  Social anxiety disorder       df_dict_psd_fc_band      psd_fc_theta
# 185  Social anxiety disorder       df_dict_psd_fc_band      psd_fc_alpha
# 186  Social anxiety disorder       df_dict_psd_fc_band       psd_fc_beta
# 187  Social anxiety disorder       df_dict_psd_fc_band   psd_fc_highbeta
# 188  Social anxiety disorder       df_dict_psd_fc_band      psd_fc_gamma
#
#      Accuracy       AUC                              Classification Report
# 0    0.921053  0.975069                precision    recall  f1-score   ...
# 1    0.868421  0.947368                precision    recall  f1-score   ...
# 2    0.842105  0.844875                precision    recall  f1-score   ...
# 3    0.921053  0.972299                precision    recall  f1-score   ...
# 4    0.894737  0.919668                precision    recall  f1-score   ...
# ..        ...       ...                                                ...
# 184  0.736842  0.695291                precision    recall  f1-score   ...
# 185  0.736842  0.756233                precision    recall  f1-score   ...
# 186  0.842105  0.822715                precision    recall  f1-score   ...
# 187  0.710526  0.750693                precision    recall  f1-score   ...
# 188  0.868421  0.894737                precision    recall  f1-score   ...
#
# [189 rows x 6 columns]

# %% [markdown]
# ## | 7. Conclusions, Problems, and Limitations

# %% [markdown]
# [need to update]
