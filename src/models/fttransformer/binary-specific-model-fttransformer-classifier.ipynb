# %% [markdown]
# | Description
#
# Authors of notebook: Mateus Balda and Alessandro Bof
#
# Reference paper and dataset: https://www.frontiersin.org/journals/psychiatry/articles/10.3389/fpsyt.2021.707581/full
#
# | Notebook structure
# 0. Setup and Imports
# 1. Utility Functions
# 2. Data Loading and Preprocessing
# 3. Data Preparation for Training
# 4. Model Definition
# 5. Training and Evaluation
# 6. Results
# 7. Conclusions, Problems, and Limitations
#
# | Training
# 1. Binary classification for `y` specific.disorder (Disorder vs. Health control)
# 2. Balancing using BorderlineSMOTE for minority classes
# 3. Training across the 21 subsets

# %% [markdown]
# ## | 0. Setup and Imports

# %%
# !pip install -q imbalanced-learn==0.12.4;
# !pip install rtdl;
# !pip install libzero==0.0.4;
# Out:
# Requirement already satisfied: rtdl in /usr/local/lib/python3.11/dist-packages (0.0.13)
# Requirement already satisfied: numpy<2,>=1.18 in /usr/local/lib/python3.11/dist-packages (from rtdl) (1.26.4)
# Requirement already satisfied: torch<2,>=1.7 in /usr/local/lib/python3.11/dist-packages (from rtdl) (1.13.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.18->rtdl) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.18->rtdl) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.18->rtdl) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.18->rtdl) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.18->rtdl) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.18->rtdl) (2.4.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch<2,>=1.7->rtdl) (4.13.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch<2,>=1.7->rtdl) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.11/dist-packages (from torch<2,>=1.7->rtdl) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.11/dist-packages (from torch<2,>=1.7->rtdl) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch<2,>=1.7->rtdl) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2,>=1.7->rtdl) (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2,>=1.7->rtdl) (0.45.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2,>=1.18->rtdl) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2,>=1.18->rtdl) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2,>=1.18->rtdl) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2,>=1.18->rtdl) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2,>=1.18->rtdl) (2024.2.0)
# Requirement already satisfied: libzero==0.0.4 in /usr/local/lib/python3.11/dist-packages (0.0.4)
# Requirement already satisfied: numpy<2,>=1.17 in /usr/local/lib/python3.11/dist-packages (from libzero==0.0.4) (1.26.4)
# Requirement already satisfied: pynvml<9,>=8.0 in /usr/local/lib/python3.11/dist-packages (from libzero==0.0.4) (8.0.4)
# Requirement already satisfied: torch<2,>=1.6 in /usr/local/lib/python3.11/dist-packages (from libzero==0.0.4) (1.13.1)
# Requirement already satisfied: tqdm<5,>=4.0 in /usr/local/lib/python3.11/dist-packages (from libzero==0.0.4) (4.67.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.17->libzero==0.0.4) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.17->libzero==0.0.4) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.17->libzero==0.0.4) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.17->libzero==0.0.4) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.17->libzero==0.0.4) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2,>=1.17->libzero==0.0.4) (2.4.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch<2,>=1.6->libzero==0.0.4) (4.13.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch<2,>=1.6->libzero==0.0.4) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.11/dist-packages (from torch<2,>=1.6->libzero==0.0.4) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.11/dist-packages (from torch<2,>=1.6->libzero==0.0.4) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch<2,>=1.6->libzero==0.0.4) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2,>=1.6->libzero==0.0.4) (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2,>=1.6->libzero==0.0.4) (0.45.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2,>=1.17->libzero==0.0.4) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2,>=1.17->libzero==0.0.4) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2,>=1.17->libzero==0.0.4) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2,>=1.17->libzero==0.0.4) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2,>=1.17->libzero==0.0.4) (2024.2.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from IPython.display import FileLink, display, HTML
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.impute import KNNImputer

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau

from imblearn.over_sampling import BorderlineSMOTE

from warnings import filterwarnings
filterwarnings('ignore')

torch.__version__
# Out:
# '1.13.1+cu117'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
experiment_name = "binary_classification_specific_disorder_fttransformer"
device
# Out:
# device(type='cuda')

# %%
np.random.seed(123)
torch.manual_seed(123)

# %% [markdown]
# ## | 1. Utility Functions

# %% [markdown]
# ### 1. OUTLIERS

# %%
def detect_outliers_summary(df):
    outliers_summary = {}

    for col in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_limit = Q1 - 1.5 * IQR
        upper_limit = Q3 + 1.5 * IQR

        outliers = df[(df[col] < lower_limit) | (df[col] > upper_limit)][col]
        
        outliers_summary[col] = {
            'num_outliers': len(outliers),
            'percent_outliers': len(outliers) / len(df) * 100,
            'outliers': outliers.tolist(),
            'lower_limit': lower_limit,
            'upper_limit': upper_limit
        }

    return pd.DataFrame(outliers_summary).T


def treat_all_outliers_iqr(df, factor=1.5):
    df_treated = df.copy()
    
    for column in df_treated.select_dtypes(include=[np.number]).columns:
        Q1 = np.percentile(df_treated[column], 25)
        Q3 = np.percentile(df_treated[column], 75)
        IQR = Q3 - Q1

        lower_bound = Q1 - factor * IQR
        upper_bound = Q3 + factor * IQR

        df_treated[column] = np.clip(df_treated[column], lower_bound, upper_bound)

    return df_treated

# %% [markdown]
# ### 2. NANS

# %%
def remove_missing_columns(df, threshold=0.5):
    limit = int(threshold * len(df))
    df = df.dropna(thresh=limit, axis=1)
    return df
    
def find_most_null_column(df, threshold=0.5):
    null_ratios = df.isnull().mean()
    for col, ration in null_ratios.items():
        if ration > threshold:
            return col
    return None

def analyze_missing_values(df):
    missing_values = df.isnull().sum()
    missing_values = missing_values[missing_values > 0]
    total_number_nans = df.isnull().sum().sum()
    
    return missing_values, total_number_nans

def handle_nans(df):
    columns_with_nans = df.columns[df.isnull().any()].tolist()
    
    knn_imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
    
    df_imputed = pd.DataFrame(knn_imputer.fit_transform(df[columns_with_nans]),
                                columns=columns_with_nans)
    
    df[columns_with_nans] = df_imputed[columns_with_nans]
    
    return df

# %% [markdown]
# ### 3. SETS & SUBSETS

# %%
class Sets:
    # AB = PSD (Power Spectral Density) 19 * 6
    # COH = FC (Functional Connectivity) 171 * 6
    
    def __init__(self, dataframe: pd.DataFrame):
        
        if not isinstance(dataframe, pd.DataFrame):
            raise ValueError("The parameter must be a pandas DataFrame")
        
        self.df = dataframe.copy()
        self.df_ab_psd = None
        self.df_coh_fc = None
        self.df_ab_psd_coh_fc = None
        
        self.__create_df_psd()
        self.__create_df_fc()
        self.__create_union_psd_fc()

    # 19 (6 bands)
    def __create_df_psd(self):
        columns_AB = [col for col in self.df.columns if col.startswith('AB')]
        self.df_ab_psd = self.df[columns_AB]
    
    # 171 (6 bands)
    def __create_df_fc(self):
        columns_COH = [col for col in self.df.columns if col.startswith('COH')]
        self.df_coh_fc = self.df[columns_COH]
        
    def __create_union_psd_fc(self):
        if self.df_ab_psd is not None and self.df_coh_fc is not None:
            self.df_ab_psd_coh_fc = pd.concat([self.df_ab_psd, self.df_coh_fc], axis=1)
        else:
            raise ValueError("Subsets AB and COH were not created correctly")

    def create_dfs_bands(self, bands: list[str] = None, df: pd.DataFrame = None):
        dfs_bands = {}
        
        if bands is None:
            bands = ['delta', 'theta', 'alpha', 'beta', 'highbeta','gamma']
        
        for band in bands:
            columns_band = [col for col in df.columns if f'.{band}.' in col]
            if columns_band:
                dfs_bands[band] = df[columns_band]
        
        return dfs_bands

# %% [markdown]
# ## | 2. Data Loading and Preprocessing

# %%
df = pd.read_csv('../input/eeg-psychiatric-disorders-dataset/EEG.machinelearing_data_BRMH.csv')
df.shape
# Out:
# (945, 1149)

# %%
# Checking / imputing Nan

output1 = analyze_missing_values(df)
output2 = find_most_null_column(df)
df = remove_missing_columns(df)
output3 = analyze_missing_values(df)
df = handle_nans(df)

display(output1)
display(HTML('<hr>'))
display(output2)
display(HTML('<hr>'))
display(output3)
display(df.shape)
display(HTML('<hr>'))
display(df.isna().sum().sum())
display(df)
# Out:
# (education        15
#  IQ               13
#  Unnamed: 122    945
#  dtype: int64,
#  973)
# <hr>
# 'Unnamed: 122'
# <hr>
# (education    15
#  IQ           13
#  dtype: int64,
#  28)
# (945, 1148)
# <hr>
# 0
#      no. sex   age    eeg.date  education          IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30   13.43871  101.580472  Addictive disorder
# 1      2   M  37.0    2012.9.6    6.00000  120.000000  Addictive disorder
# 2      3   M  32.0   2012.9.10   16.00000  113.000000  Addictive disorder
# 3      4   M  35.0   2012.10.8   18.00000  126.000000  Addictive disorder
# 4      5   M  36.0  2012.10.18   16.00000  112.000000  Addictive disorder
# ..   ...  ..   ...         ...        ...         ...                 ...
# 940  941   M  22.0   2014.8.28   13.00000  116.000000     Healthy control
# 941  942   M  26.0   2014.9.19   13.00000  118.000000     Healthy control
# 942  943   M  26.0   2014.9.27   16.00000  113.000000     Healthy control
# 943  944   M  24.0   2014.9.20   13.00000  107.000000     Healthy control
# 944  945   M  21.0  2015.10.23   13.00000  105.000000     Healthy control
#
#         specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0    Alcohol use disorder         35.998557         21.717375  ...
# 1    Alcohol use disorder         13.425118         11.002916  ...
# 2    Alcohol use disorder         29.941780         27.544684  ...
# 3    Alcohol use disorder         21.496226         21.846832  ...
# 4    Alcohol use disorder         37.775667         33.607679  ...
# ..                    ...               ...               ...  ...
# 940       Healthy control         41.851823         36.771496  ...
# 941       Healthy control         18.986856         19.401387  ...
# 942       Healthy control         28.781317         32.369230  ...
# 943       Healthy control         19.929100         25.196375  ...
# 944       Healthy control         65.195346         69.241972  ...
#
#      COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0                55.989192              16.739679              23.452271
# 1                45.595619              17.510824              26.777368
# 2                99.475453              70.654171              39.131547
# 3                59.986561              63.822201              36.478254
# 4                61.462720              59.166097              51.465531
# ..                     ...                    ...                    ...
# 940              82.905657              34.850706              63.970519
# 941              65.917918              66.700117              44.756285
# 942              61.040959              27.632209              45.552852
# 943              99.113664              48.328934              41.248470
# 944              78.600293              68.255430              70.687410
#
#      COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                45.678820              30.167520              16.918761
# 1                28.201062              57.108861              32.375401
# 2                69.920996              71.063644              38.534505
# 3                47.117006              84.658376              24.724096
# 4                58.635415              80.685608              62.138436
# ..                     ...                    ...                    ...
# 940              63.982003              51.244725              62.203684
# 941              49.787513              98.905995              54.021304
# 942              33.638817              46.690983              19.382928
# 943              28.192238              48.665743              42.007147
# 944              74.433908              74.294750              53.254681
#
#      COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                48.850427               9.422630              34.507082
# 1                60.351749              13.900981              57.831848
# 2                69.908764              27.180532              64.803155
# 3                50.299349              35.319695              79.822944
# 4                75.888749              61.003944              87.455509
# ..                     ...                    ...                    ...
# 940              62.062237              31.013031              31.183413
# 941              93.902401              52.740396              92.807331
# 942              41.050717               7.045821              41.962451
# 943              28.735945              27.176500              27.529522
# 944              72.755265              47.810386              80.166825
#
#      COH.F.gamma.r.O1.s.O2
# 0                28.613029
# 1                43.463261
# 2                31.485799
# 3                41.141873
# 4                70.531662
# ..                     ...
# 940              98.325230
# 941              56.320868
# 942              19.092111
# 943              20.028446
# 944              64.380273
#
# [945 rows x 1148 columns]

# %%
# detecting outliers

outliers_summary = detect_outliers_summary(df)
outliers_summary.to_csv('outliers_summary.csv', index=True)
outliers_summary['num_outliers'].sum()
# Out:
# 26452

# %%
label_encoder = LabelEncoder()
target_name = 'specific.disorder'

X = df.iloc[:,8:]
target = df[target_name]

quantitative_features = df.loc[:, ['age', 'education', 'IQ']]

sex = df['sex']
sex_encoded = label_encoder.fit_transform(sex)
sex_encoded = pd.Series(sex_encoded, name='sex')

X = pd.concat([quantitative_features, sex_encoded, X], axis=1)

X.shape, target.shape, quantitative_features.shape, sex.shape
# Out:
# ((945, 1144), (945,), (945, 3), (945,))

# %%
specific_disorders = np.unique(target).tolist()
specific_disorders.remove('Healthy control')
specific_disorders.remove('Obsessive compulsitve disorder')
specific_disorders.remove('Schizophrenia')
specific_disorders
# Out:
# ['Acute stress disorder',
#  'Adjustment disorder',
#  'Alcohol use disorder',
#  'Behavioral addiction disorder',
#  'Bipolar disorder',
#  'Depressive disorder',
#  'Panic disorder',
#  'Posttraumatic stress disorder',
#  'Social anxiety disorder']

# %%
X_concated = pd.concat([X, target], axis=1)

display(X.head())
display(X_concated.head())
display(X.isna().sum().sum())
display(X_concated.isna().sum().sum())
# Out:
#     age  education          IQ  sex  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0  57.0   13.43871  101.580472    1         35.998557         21.717375
# 1  37.0    6.00000  120.000000    1         13.425118         11.002916
# 2  32.0   16.00000  113.000000    1         29.941780         27.544684
# 3  35.0   18.00000  126.000000    1         21.496226         21.846832
# 4  36.0   16.00000  112.000000    1         37.775667         33.607679
#
#    AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  ...  \
# 0        21.518280        26.825048        26.611516        25.732649  ...
# 1        11.942516        15.272216        14.151570        12.456034  ...
# 2        17.150159        23.608960        27.087811        13.541237  ...
# 3        17.364316        13.833701        14.100954        13.100939  ...
# 4        21.865556        21.771413        22.854536        21.456377  ...
#
#    COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0              55.989192              16.739679              23.452271
# 1              45.595619              17.510824              26.777368
# 2              99.475453              70.654171              39.131547
# 3              59.986561              63.822201              36.478254
# 4              61.462720              59.166097              51.465531
#
#    COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0              45.678820              30.167520              16.918761
# 1              28.201062              57.108861              32.375401
# 2              69.920996              71.063644              38.534505
# 3              47.117006              84.658376              24.724096
# 4              58.635415              80.685608              62.138436
#
#    COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0              48.850427               9.422630              34.507082
# 1              60.351749              13.900981              57.831848
# 2              69.908764              27.180532              64.803155
# 3              50.299349              35.319695              79.822944
# 4              75.888749              61.003944              87.455509
#
#    COH.F.gamma.r.O1.s.O2
# 0              28.613029
# 1              43.463261
# 2              31.485799
# 3              41.141873
# 4              70.531662
#
# [5 rows x 1144 columns]
#     age  education          IQ  sex  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0  57.0   13.43871  101.580472    1         35.998557         21.717375
# 1  37.0    6.00000  120.000000    1         13.425118         11.002916
# 2  32.0   16.00000  113.000000    1         29.941780         27.544684
# 3  35.0   18.00000  126.000000    1         21.496226         21.846832
# 4  36.0   16.00000  112.000000    1         37.775667         33.607679
#
#    AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  ...  \
# 0        21.518280        26.825048        26.611516        25.732649  ...
# 1        11.942516        15.272216        14.151570        12.456034  ...
# 2        17.150159        23.608960        27.087811        13.541237  ...
# 3        17.364316        13.833701        14.100954        13.100939  ...
# 4        21.865556        21.771413        22.854536        21.456377  ...
#
#    COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  COH.F.gamma.o.Pz.s.O2  \
# 0              16.739679              23.452271              45.678820
# 1              17.510824              26.777368              28.201062
# 2              70.654171              39.131547              69.920996
# 3              63.822201              36.478254              47.117006
# 4              59.166097              51.465531              58.635415
#
#    COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  COH.F.gamma.p.P4.s.O2  \
# 0              30.167520              16.918761              48.850427
# 1              57.108861              32.375401              60.351749
# 2              71.063644              38.534505              69.908764
# 3              84.658376              24.724096              50.299349
# 4              80.685608              62.138436              75.888749
#
#    COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  COH.F.gamma.r.O1.s.O2  \
# 0               9.422630              34.507082              28.613029
# 1              13.900981              57.831848              43.463261
# 2              27.180532              64.803155              31.485799
# 3              35.319695              79.822944              41.141873
# 4              61.003944              87.455509              70.531662
#
#       specific.disorder
# 0  Alcohol use disorder
# 1  Alcohol use disorder
# 2  Alcohol use disorder
# 3  Alcohol use disorder
# 4  Alcohol use disorder
#
# [5 rows x 1145 columns]
# 0
# 0

# %%
# treat outliers X_concated

X = treat_all_outliers_iqr(X, factor=1.5)
outliers_summary = detect_outliers_summary(X)
outliers_summary['num_outliers'].sum()
# Out:
# 0

# %%
binary_datasets = {}

for disorder in specific_disorders:
    
    mask = X_concated[target_name].isin(['Healthy control', disorder])
    
    df_filtered = X_concated[mask]
    df_filtered_X = X.loc[mask]
    
    y_binary = df_filtered[target_name].apply(lambda x: 0 if x == 'Healthy control' else 1)
    
    borderline_smote = BorderlineSMOTE(kind='borderline-2', random_state=42, k_neighbors=10, m_neighbors=15)
    X_resampled, y_resampled = borderline_smote.fit_resample(df_filtered_X, y_binary)
    
    dataset = pd.concat([X_resampled, y_resampled], axis=1)
    
    binary_datasets[disorder] = {
        'data': dataset,
        'labels': ['Healthy control', disorder]
    }

# %%
binary_datasets['Acute stress disorder']['data']
# Out:
#            age  education          IQ  sex  AB.A.delta.a.FP1  \
# 0    19.700000  13.000000  103.000000    0         11.906893
# 1    19.940000  13.000000   81.000000    0         19.849686
# 2    19.260000  12.000000   86.600000    0         28.675766
# 3    25.610000  16.000000  108.000000    0         12.187185
# 4    24.580000  16.000000  110.000000    0          7.414042
# ..         ...        ...         ...  ...               ...
# 185  23.636111  12.460159   88.624699    0         24.991060
# 186  39.661676  12.240593  103.624002    0         14.579592
# 187  19.821461  16.000000  133.028511    0         17.654770
# 188  21.288249  12.022254   94.278175    0         16.180424
# 189  24.902333  14.389570  119.863495    0         28.722673
#
#      AB.A.delta.b.FP2  AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  \
# 0            9.707117        12.455193        14.208682        14.626761
# 1           15.705436        17.863425        25.394940        23.916326
# 2           25.368575        25.912400        29.496788        27.661687
# 3           22.798506        14.977824        13.852327        21.125052
# 4            7.173058         9.649153         9.033750         9.068607
# ..                ...              ...              ...              ...
# 185         21.790181        22.814510        27.422891        25.339652
# 186         14.081592        13.329846        10.602656        16.347242
# 187         13.746061         8.336923        10.146754        13.001747
# 188         17.626350        17.813587        12.328262        11.149706
# 189         37.327172        27.818018        23.818943        23.551339
#
#      AB.A.delta.f.F4  ...  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0          19.885365  ...              69.067513              76.479372
# 1          17.032967  ...              71.257029              74.666719
# 2          26.305027  ...              38.850170              26.148667
# 3          12.611427  ...              32.936146              48.492975
# 4          10.328719  ...              21.278355              22.090032
# ..               ...  ...                    ...                    ...
# 185        23.790325  ...              40.679754              43.349875
# 186        17.618628  ...              80.909684              80.956008
# 187        15.361196  ...              62.423946              61.543612
# 188        12.025291  ...              39.672862              46.860606
# 189        22.706705  ...              48.179674              45.615034
#
#      COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                81.723959              82.075368              65.408405
# 1                77.063648              83.056486              68.744644
# 2                47.985078              51.488546              14.825718
# 3                72.469967              45.758411              37.811075
# 4                75.129025              46.765039              12.676249
# ..                     ...                    ...                    ...
# 185              58.108614              60.001815              32.401796
# 186              87.373216              87.263718              78.826967
# 187              69.530314              80.809356              49.325702
# 188              46.651085              73.083370              42.194749
# 189              55.702417              74.844985              40.351338
#
#      COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                84.541111              58.012987              85.867872
# 1                83.468447              76.265372              90.029157
# 2                43.673794              13.046605              58.780474
# 3                70.308929               9.725031              32.678063
# 4                74.705851               9.431155              48.014229
# ..                     ...                    ...                    ...
# 185              56.697487              20.368472              52.072205
# 186              89.175762              71.807474              81.009151
# 187              75.090400              39.760503              75.953645
# 188              74.792077              29.596620              84.976867
# 189              67.946291              28.616925              69.945983
#
#      COH.F.gamma.r.O1.s.O2  specific.disorder
# 0                78.224773                  1
# 1                88.220089                  1
# 2                35.502275                  1
# 3                68.764822                  1
# 4                54.848927                  1
# ..                     ...                ...
# 185              53.363849                  1
# 186              86.173498                  1
# 187              59.867818                  1
# 188              47.631831                  1
# 189              53.747447                  1
#
# [190 rows x 1145 columns]

# %%
sets_binaries = {}

for disorder, bin_data in binary_datasets.items():
    df_bin = bin_data['data'].copy()
    
    X_bin = df_bin.drop(columns=[target_name,'age', 'education', 'IQ', 'sex'], errors='ignore') 
    X_quantitative = df_bin.loc[:, ['age', 'education', 'IQ', 'sex']]
    y_bin = df_bin[target_name] if target_name in df_bin.columns else df_bin.iloc[:, -1]

    sets = Sets(dataframe=X_bin)

    sets_binaries[disorder] = {
        'sets': sets,
        'labels': bin_data['labels'],
        'X_quantitative': X_quantitative,
        'y': y_bin
    }

# %%
for disorder in sets_binaries:
    sets = sets_binaries[disorder]['sets']

    dfs_bands_psd = sets.create_dfs_bands(df=sets.df_ab_psd)
    dfs_bands_fc = sets.create_dfs_bands(df=sets.df_coh_fc)
    dfs_bands_psd_fc = sets.create_dfs_bands(df=sets.df_ab_psd_coh_fc)

    sets_binaries[disorder].update({
        'dfs_bands_psd': dfs_bands_psd,
        'dfs_bands_fc': dfs_bands_fc,
        'dfs_bands_psd_fc': dfs_bands_psd_fc,
    })

# %%
for disorder, data in sets_binaries.items():
    print(f"Disorder: {disorder}")
    print(f"Labels: {data['labels']}")
    print(f"Number of samples: {len(data['y'])}")
    print(f"Quantitative features shape: {data['X_quantitative'].shape}")
    print(f"PSD bands shape: {data['sets'].df_ab_psd.shape}")
    print(f"FC bands shape: {data['sets'].df_coh_fc.shape}")
    print(f"PSD + FC bands shape: {data['sets'].df_ab_psd_coh_fc.shape}\n")
# Out:
# Disorder: Acute stress disorder
# Labels: ['Healthy control', 'Acute stress disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Adjustment disorder
# Labels: ['Healthy control', 'Adjustment disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Alcohol use disorder
# Labels: ['Healthy control', 'Alcohol use disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Behavioral addiction disorder
# Labels: ['Healthy control', 'Behavioral addiction disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Bipolar disorder
# Labels: ['Healthy control', 'Bipolar disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Depressive disorder
# Labels: ['Healthy control', 'Depressive disorder']
# Number of samples: 398
# Quantitative features shape: (398, 4)
# PSD bands shape: (398, 114)
# FC bands shape: (398, 1026)
# PSD + FC bands shape: (398, 1140)
#
# Disorder: Panic disorder
# Labels: ['Healthy control', 'Panic disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Posttraumatic stress disorder
# Labels: ['Healthy control', 'Posttraumatic stress disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Social anxiety disorder
# Labels: ['Healthy control', 'Social anxiety disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)

# %%
dfs_dicts_binaries = {}

for disorder, data in sets_binaries.items():
    dfs_psd = data['dfs_bands_psd']
    dfs_fc = data['dfs_bands_fc']
    dfs_psd_fc = data['dfs_bands_psd_fc']
    sets = data['sets']

    df_dict_psd_all_bands = {
        'psd_all_bands': sets.df_ab_psd,
    }

    df_dict_fc_all_bands = {
        'fc_all_bands': sets.df_coh_fc,
    }

    df_dict_psd_fc_all_bands = {
        'psd_fc_all_bands': sets.df_ab_psd_coh_fc,
    }

    df_dict_psd_band = {
        f'psd_{band}': dfs_psd[band] for band in dfs_psd
    }

    df_dict_fc_band = {
        f'fc_{band}': dfs_fc[band] for band in dfs_fc
    }

    df_dict_psd_fc_band = {
        f'psd_fc_{band}': dfs_psd_fc[band] for band in dfs_psd_fc
    }

    dfs_dicts_binaries[disorder] = {
        'df_dict_psd_all_bands': df_dict_psd_all_bands,
        'df_dict_fc_all_bands': df_dict_fc_all_bands,
        'df_dict_psd_fc_all_bands': df_dict_psd_fc_all_bands,
        'df_dict_psd_band': df_dict_psd_band,
        'df_dict_fc_band': df_dict_fc_band,
        'df_dict_psd_fc_band': df_dict_psd_fc_band,
    }

# %%
import torch.nn as nn
import torch
import rtdl
from rtdl import FTTransformer
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score

# %%
def fit(model, train_loader, epochs=200, lr=1e-3, weight_decay=1e-4, device='cpu', patience=20):
        model.to(device)
        criterion = nn.BCEWithLogitsLoss()
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True)

        best_loss = float('inf')
        best_acc = 0
        patience_counter = 0
        history = {'train_loss': [], 'train_acc': []}
        
        for epoch in range(epochs):
            model.train()
            running_loss = 0.0
            correct, total = 0, 0
            
            for inputs, targets in train_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                
                assert set(targets.cpu().tolist()).issubset({0.0, 1.0}), "Targets must be binary (0 or 1)"
                
                optimizer.zero_grad()
                outputs = model(inputs, None)
                
                # shape
                outputs = outputs.view(-1).float()
                targets = targets.view(-1).float() 
                
                assert outputs.shape == targets.shape, "Outputs and targets must have the same shape"
                assert outputs.dtype == torch.float32 and targets.dtype == torch.float32, "Outputs and targets must be float32"
                assert outputs.dim() == 1 and targets.dim() == 1, "Outputs and targets must be 1-dimensional"
                
                loss = criterion(outputs, targets)
                loss.backward()
                optimizer.step()
                
                preds = (torch.sigmoid(outputs) > 0.5).long()
                correct += (preds == targets.long()).sum().item()
                total += targets.size(0)
                running_loss += loss.item() * inputs.size(0)
                
            train_acc = correct / total
            epoch_loss = running_loss / len(train_loader.dataset)
            history['train_acc'].append(train_acc)
            history['train_loss'].append(epoch_loss)
            
            if epoch_loss < best_loss:
                best_loss = epoch_loss
                patience_counter = 0
            else:
                patience_counter += 1

            if patience_counter >= patience:
                print("Early stopping triggered.")
                break
            
            scheduler.step(epoch_loss)
            
            print(
                f"Epoch [{epoch+1}/{epochs}] | "
                f"Train Loss: {epoch_loss:.4f}, Train Acc: {train_acc:.4f} | "
            )
        
        return history


def test(model, test_loader, device='cpu'):
    model.to(device)
    model.eval()
    
    all_preds, all_probas, all_targets = [], [], []
    correct, total = 0, 0
    test_loss = 0.0
    criterion = nn.BCEWithLogitsLoss()
    history = {'test_loss': [], 'test_acc': [], 'test_auc': []}

    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs, None)
            
            outputs = outputs.view(-1).float()
            targets = targets.view(-1).float() 
            
            loss = criterion(outputs, targets)
            
            proba = torch.sigmoid(outputs)
            pred = (proba > 0.5).long()

            all_preds.append(pred.cpu())
            all_probas.append(proba.cpu())
            all_targets.append(targets.cpu())
            
            correct += (pred == targets.long()).sum().item()
            total += targets.size(0)
            test_loss += loss.item() * inputs.size(0)
    
    test_acc = correct / total
    test_loss /= len(test_loader.dataset)
    history['test_loss'].append(test_loss)
    history['test_acc'].append(test_acc)
    
    y_true = torch.cat(all_targets).numpy().astype(int)
    y_pred = torch.cat(all_preds).numpy().astype(int)
    y_proba = torch.cat(all_probas).numpy().astype(float)

    try:
        auc = roc_auc_score(y_true, y_proba)
    except ValueError:
        auc = float('nan')

    report = classification_report(y_true, y_pred)
    history['test_auc'].append(auc)

    print(
        f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}, Test AUC: {auc:.4f}"
        )
    
    return test_acc, auc, report, history

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
import gc

# %%
all_results = {}

for disorder, dicts in dfs_dicts_binaries.items():
    print(f"\n=== Disorder: {disorder} ===")
    
    y_binary = sets_binaries[disorder]['y']
    X_quantitative = sets_binaries[disorder]['X_quantitative']
    labels = sets_binaries[disorder]['labels']
    
    all_results[disorder] = {}
    
    for dict_name, df_dict in dicts.items():
        if not dict_name.startswith('df_dict_'):
            continue
        
        for df_name, df in df_dict.items():
            print(f"\n--- Processing: {df_name} ---")
            print("Shape:", df.shape)
            print("Missing values:", df.isna().sum().sum())
            
            df_full = pd.concat([X_quantitative, df], axis=1)
            assert all(df_full.index == y_binary.index), 'Misaligned indexes'
            
            X_train, X_test, y_train, y_test = train_test_split(
                df_full,
                y_binary,
                train_size=0.80,
                stratify=y_binary,
                random_state=42
            )
            
            X_cols = X_train.drop(columns=['sex']).columns
            
            scaler = RobustScaler()
            X_train_scaled = scaler.fit_transform(X_train[X_cols])
            X_test_scaled = scaler.transform(X_test[X_cols])
            
            X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_cols, index=X_train.index)
            X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_cols, index=X_test.index)

            X_train_final = pd.concat([X_train_scaled_df, X_train['sex']], axis=1)
            X_test_final = pd.concat([X_test_scaled_df, X_test['sex']], axis=1)

            X_train_array = X_train_final.to_numpy()
            X_test_array = X_test_final.to_numpy()
            y_train_array = y_train.to_numpy()
            y_test_array = y_test.to_numpy()
            
            # tensors
            X_train_tensor = torch.tensor(X_train_array, dtype=torch.float32).to(device)
            y_train_tensor = torch.tensor(y_train_array, dtype=torch.long).to(device)
            X_test_tensor = torch.tensor(X_test_array, dtype=torch.float32).to(device)
            y_test_tensor = torch.tensor(y_test_array, dtype=torch.long).to(device)
            
            train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
            test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

            train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
            test_loader = DataLoader(test_dataset, batch_size=32)
            
            model = FTTransformer.make_default(
                n_num_features=X_train_array.shape[1],
                cat_cardinalities=None,
                last_layer_query_idx=[-1],
                d_out=1,  # binary
            )
            
            fit_history = fit(
                model=model,
                train_loader=train_loader,
                epochs=200,
                lr=1e-3,
                weight_decay=1e-4,
                device=device,
                patience=20
            )
            
            acc, auc, report, test_history = test(
                model=model,
                test_loader=test_loader,
                device=device
            )
            
            all_results.setdefault(disorder, {}).setdefault(dict_name, {})[df_name] = {
                'accuracy': acc,
                'auc': auc,
                'classification_report': report,
                'features': list(X_train_final.columns),
                'X_train_shape': X_train_tensor.shape,
                'X_test_shape': X_test_tensor.shape,
                'history': {
                    'fit': fit_history,
                    'test': test_history
                }
            }
            
            # memory cleaning
            del model
            del X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
# Out:
# === Disorder: Acute stress disorder ===
#
# --- Processing: psd_all_bands ---
# Shape: (190, 114)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.8312, Train Acc: 0.4737 |
# Epoch [2/200] | Train Loss: 0.6762, Train Acc: 0.5658 |
# Epoch [3/200] | Train Loss: 0.7070, Train Acc: 0.5000 |
# Epoch [4/200] | Train Loss: 0.6906, Train Acc: 0.5461 |
# Epoch [5/200] | Train Loss: 0.6781, Train Acc: 0.5789 |
# Epoch [6/200] | Train Loss: 0.6339, Train Acc: 0.6776 |
# Epoch [7/200] | Train Loss: 0.5597, Train Acc: 0.7697 |
# Epoch [8/200] | Train Loss: 0.4554, Train Acc: 0.8092 |
# Epoch [9/200] | Train Loss: 0.4425, Train Acc: 0.8355 |
# Epoch [10/200] | Train Loss: 0.3638, Train Acc: 0.8684 |
# Epoch [11/200] | Train Loss: 0.3752, Train Acc: 0.8355 |
# Epoch [12/200] | Train Loss: 0.2945, Train Acc: 0.8750 |
# Epoch [13/200] | Train Loss: 0.5087, Train Acc: 0.7697 |
# Epoch [14/200] | Train Loss: 0.4349, Train Acc: 0.8158 |
# Epoch [15/200] | Train Loss: 0.3481, Train Acc: 0.8816 |
# Epoch [16/200] | Train Loss: 0.2949, Train Acc: 0.8750 |
# Epoch [17/200] | Train Loss: 0.2532, Train Acc: 0.9145 |
# Epoch [18/200] | Train Loss: 0.1804, Train Acc: 0.9408 |
# Epoch [19/200] | Train Loss: 0.2503, Train Acc: 0.9079 |
# Epoch [20/200] | Train Loss: 0.2026, Train Acc: 0.9276 |
# Epoch [21/200] | Train Loss: 0.1391, Train Acc: 0.9671 |
# Epoch [22/200] | Train Loss: 0.1833, Train Acc: 0.9408 |
# Epoch [23/200] | Train Loss: 0.1516, Train Acc: 0.9671 |
# Epoch [24/200] | Train Loss: 0.1183, Train Acc: 0.9605 |
# Epoch [25/200] | Train Loss: 0.2070, Train Acc: 0.9145 |
# Epoch [26/200] | Train Loss: 0.1472, Train Acc: 0.9605 |
# Epoch [27/200] | Train Loss: 0.2058, Train Acc: 0.9211 |
# Epoch [28/200] | Train Loss: 0.1486, Train Acc: 0.9408 |
# Epoch [29/200] | Train Loss: 0.1672, Train Acc: 0.9539 |
# Epoch [30/200] | Train Loss: 0.1203, Train Acc: 0.9737 |
# Epoch [31/200] | Train Loss: 0.0976, Train Acc: 0.9605 |
# Epoch [32/200] | Train Loss: 0.1475, Train Acc: 0.9539 |
# Epoch [33/200] | Train Loss: 0.1117, Train Acc: 0.9605 |
# Epoch [34/200] | Train Loss: 0.0423, Train Acc: 1.0000 |
# Epoch [35/200] | Train Loss: 0.0615, Train Acc: 0.9737 |
# Epoch [36/200] | Train Loss: 0.0774, Train Acc: 0.9803 |
# Epoch [37/200] | Train Loss: 0.1147, Train Acc: 0.9539 |
# Epoch [38/200] | Train Loss: 0.0702, Train Acc: 0.9737 |
# Epoch [39/200] | Train Loss: 0.0640, Train Acc: 0.9737 |
# Epoch [40/200] | Train Loss: 0.0485, Train Acc: 0.9803 |
# Epoch [41/200] | Train Loss: 0.0406, Train Acc: 0.9803 |
# Epoch [42/200] | Train Loss: 0.0288, Train Acc: 1.0000 |
# Epoch [43/200] | Train Loss: 0.1157, Train Acc: 0.9671 |
# Epoch [44/200] | Train Loss: 0.0766, Train Acc: 0.9868 |
# Epoch [45/200] | Train Loss: 0.1805, Train Acc: 0.9474 |
# Epoch [46/200] | Train Loss: 0.1566, Train Acc: 0.9408 |
# Epoch [47/200] | Train Loss: 0.1144, Train Acc: 0.9671 |
# Epoch [48/200] | Train Loss: 0.1218, Train Acc: 0.9539 |
# Epoch [49/200] | Train Loss: 0.0763, Train Acc: 0.9868 |
# Epoch [50/200] | Train Loss: 0.0758, Train Acc: 0.9605 |
# Epoch [51/200] | Train Loss: 0.0492, Train Acc: 0.9803 |
# Epoch [52/200] | Train Loss: 0.1252, Train Acc: 0.9671 |
# Epoch 00053: reducing learning rate of group 0 to 1.0000e-04.
# Epoch [53/200] | Train Loss: 0.0897, Train Acc: 0.9605 |
# Epoch [54/200] | Train Loss: 0.0722, Train Acc: 0.9803 |
# Epoch [55/200] | Train Loss: 0.0419, Train Acc: 0.9803 |
# Epoch [56/200] | Train Loss: 0.0597, Train Acc: 0.9803 |
# Epoch [57/200] | Train Loss: 0.0342, Train Acc: 0.9868 |
# Epoch [58/200] | Train Loss: 0.0275, Train Acc: 0.9934 |
# Epoch [59/200] | Train Loss: 0.0248, Train Acc: 1.0000 |
# Epoch [60/200] | Train Loss: 0.0374, Train Acc: 0.9803 |
# Epoch [61/200] | Train Loss: 0.0239, Train Acc: 0.9934 |
# Epoch [62/200] | Train Loss: 0.0275, Train Acc: 0.9868 |
# Epoch [63/200] | Train Loss: 0.0173, Train Acc: 1.0000 |
# Epoch [64/200] | Train Loss: 0.0156, Train Acc: 1.0000 |
# Epoch [65/200] | Train Loss: 0.0374, Train Acc: 0.9934 |
# Epoch [66/200] | Train Loss: 0.0437, Train Acc: 0.9934 |
# Epoch [67/200] | Train Loss: 0.0158, Train Acc: 1.0000 |
# Epoch [68/200] | Train Loss: 0.0257, Train Acc: 0.9868 |
# Epoch [69/200] | Train Loss: 0.0131, Train Acc: 1.0000 |
# Epoch [70/200] | Train Loss: 0.0096, Train Acc: 1.0000 |
# Epoch [71/200] | Train Loss: 0.0118, Train Acc: 1.0000 |
# Epoch [72/200] | Train Loss: 0.0114, Train Acc: 1.0000 |
# Epoch [73/200] | Train Loss: 0.0113, Train Acc: 1.0000 |
# Epoch [74/200] | Train Loss: 0.0103, Train Acc: 1.0000 |
# Epoch [75/200] | Train Loss: 0.0202, Train Acc: 0.9934 |
# Epoch [76/200] | Train Loss: 0.0125, Train Acc: 1.0000 |
# Epoch [77/200] | Train Loss: 0.0081, Train Acc: 1.0000 |
# Epoch [78/200] | Train Loss: 0.0096, Train Acc: 1.0000 |
# Epoch [79/200] | Train Loss: 0.0163, Train Acc: 1.0000 |
# Epoch [80/200] | Train Loss: 0.0072, Train Acc: 1.0000 |
# Epoch [81/200] | Train Loss: 0.0072, Train Acc: 1.0000 |
# Epoch [82/200] | Train Loss: 0.0072, Train Acc: 1.0000 |
# Epoch [83/200] | Train Loss: 0.0065, Train Acc: 1.0000 |
# Epoch [84/200] | Train Loss: 0.0065, Train Acc: 1.0000 |
# Epoch [85/200] | Train Loss: 0.0073, Train Acc: 1.0000 |
# Epoch [86/200] | Train Loss: 0.0069, Train Acc: 1.0000 |
# Epoch [87/200] | Train Loss: 0.0060, Train Acc: 1.0000 |
# Epoch [88/200] | Train Loss: 0.0097, Train Acc: 1.0000 |
# Epoch [89/200] | Train Loss: 0.0064, Train Acc: 1.0000 |
# Epoch [90/200] | Train Loss: 0.0057, Train Acc: 1.0000 |
# Epoch [91/200] | Train Loss: 0.0167, Train Acc: 0.9934 |
# Epoch [92/200] | Train Loss: 0.0059, Train Acc: 1.0000 |
# Epoch [93/200] | Train Loss: 0.0069, Train Acc: 1.0000 |
# Epoch [94/200] | Train Loss: 0.0061, Train Acc: 1.0000 |
# Epoch [95/200] | Train Loss: 0.0058, Train Acc: 1.0000 |
# Epoch [96/200] | Train Loss: 0.0080, Train Acc: 1.0000 |
# Epoch [97/200] | Train Loss: 0.0077, Train Acc: 1.0000 |
# Epoch [98/200] | Train Loss: 0.0117, Train Acc: 0.9934 |
# Epoch [99/200] | Train Loss: 0.0060, Train Acc: 1.0000 |
# Epoch [100/200] | Train Loss: 0.0049, Train Acc: 1.0000 |
# Epoch [101/200] | Train Loss: 0.0053, Train Acc: 1.0000 |
# Epoch [102/200] | Train Loss: 0.0046, Train Acc: 1.0000 |
# Epoch [103/200] | Train Loss: 0.0050, Train Acc: 1.0000 |
# Epoch [104/200] | Train Loss: 0.0047, Train Acc: 1.0000 |
# Epoch [105/200] | Train Loss: 0.0047, Train Acc: 1.0000 |
# Epoch [106/200] | Train Loss: 0.0049, Train Acc: 1.0000 |
# Epoch [107/200] | Train Loss: 0.0046, Train Acc: 1.0000 |
# Epoch [108/200] | Train Loss: 0.0045, Train Acc: 1.0000 |
# Epoch [109/200] | Train Loss: 0.0055, Train Acc: 1.0000 |
# Epoch [110/200] | Train Loss: 0.0048, Train Acc: 1.0000 |
# Epoch [111/200] | Train Loss: 0.0054, Train Acc: 1.0000 |
# Epoch [112/200] | Train Loss: 0.0040, Train Acc: 1.0000 |
# Epoch [113/200] | Train Loss: 0.0045, Train Acc: 1.0000 |
# Epoch [114/200] | Train Loss: 0.0042, Train Acc: 1.0000 |
# Epoch [115/200] | Train Loss: 0.0044, Train Acc: 1.0000 |
# Epoch [116/200] | Train Loss: 0.0049, Train Acc: 1.0000 |
# Epoch [117/200] | Train Loss: 0.0080, Train Acc: 1.0000 |
# Epoch [118/200] | Train Loss: 0.0072, Train Acc: 1.0000 |
# Epoch [119/200] | Train Loss: 0.0038, Train Acc: 1.0000 |
# Epoch [120/200] | Train Loss: 0.0036, Train Acc: 1.0000 |
# Epoch [121/200] | Train Loss: 0.0256, Train Acc: 0.9934 |
# Epoch [122/200] | Train Loss: 0.0469, Train Acc: 0.9671 |
# Epoch [123/200] | Train Loss: 0.0161, Train Acc: 0.9934 |
# Epoch [124/200] | Train Loss: 0.0046, Train Acc: 1.0000 |
# Epoch [125/200] | Train Loss: 0.0134, Train Acc: 0.9934 |
# Epoch [126/200] | Train Loss: 0.0053, Train Acc: 1.0000 |
# Epoch [127/200] | Train Loss: 0.0050, Train Acc: 1.0000 |
# Epoch [128/200] | Train Loss: 0.0131, Train Acc: 0.9934 |
# Epoch [129/200] | Train Loss: 0.0166, Train Acc: 0.9934 |
# Epoch [130/200] | Train Loss: 0.0041, Train Acc: 1.0000 |
# Epoch 00131: reducing learning rate of group 0 to 1.0000e-05.
# Epoch [131/200] | Train Loss: 0.0264, Train Acc: 0.9934 |
# Epoch [132/200] | Train Loss: 0.0039, Train Acc: 1.0000 |
# Epoch [133/200] | Train Loss: 0.0040, Train Acc: 1.0000 |
# Epoch [134/200] | Train Loss: 0.0045, Train Acc: 1.0000 |
# Epoch [135/200] | Train Loss: 0.0044, Train Acc: 1.0000 |
# Epoch [136/200] | Train Loss: 0.0057, Train Acc: 1.0000 |
# Epoch [137/200] | Train Loss: 0.0038, Train Acc: 1.0000 |
# Epoch [138/200] | Train Loss: 0.0042, Train Acc: 1.0000 |
# Epoch [139/200] | Train Loss: 0.0050, Train Acc: 1.0000 |
# Early stopping triggered.
# Test Loss: 0.4950, Test Accuracy: 0.9211, Test AUC: 0.9280
#
# --- Processing: fc_all_bands ---
# Shape: (190, 1026)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.8146, Train Acc: 0.5066 |
# Epoch [2/200] | Train Loss: 0.7296, Train Acc: 0.4868 |
# Epoch [3/200] | Train Loss: 0.6887, Train Acc: 0.5592 |
# Epoch [4/200] | Train Loss: 0.7087, Train Acc: 0.5000 |
# Epoch [5/200] | Train Loss: 0.6973, Train Acc: 0.4342 |
# Epoch [6/200] | Train Loss: 0.6947, Train Acc: 0.5000 |
# Epoch [7/200] | Train Loss: 0.6930, Train Acc: 0.5461 |
# Epoch [8/200] | Train Loss: 0.6947, Train Acc: 0.5000 |
# Epoch [9/200] | Train Loss: 0.6967, Train Acc: 0.4671 |
# Epoch [10/200] | Train Loss: 0.6951, Train Acc: 0.5066 |
# Epoch [11/200] | Train Loss: 0.6869, Train Acc: 0.6250 |
# Epoch [12/200] | Train Loss: 0.6674, Train Acc: 0.8026 |
# Epoch [13/200] | Train Loss: 0.5719, Train Acc: 0.7895 |
# Epoch [14/200] | Train Loss: 0.3870, Train Acc: 0.8684 |
# Epoch [15/200] | Train Loss: 0.3435, Train Acc: 0.8750 |
# Epoch [16/200] | Train Loss: 0.3238, Train Acc: 0.8882 |
# Epoch [17/200] | Train Loss: 0.2976, Train Acc: 0.9079 |
# Epoch [18/200] | Train Loss: 0.2541, Train Acc: 0.9276 |
# Epoch [19/200] | Train Loss: 0.2911, Train Acc: 0.9079 |
# Epoch [20/200] | Train Loss: 0.3095, Train Acc: 0.9145 |
# Epoch [21/200] | Train Loss: 0.2752, Train Acc: 0.9079 |
# Epoch [22/200] | Train Loss: 0.2053, Train Acc: 0.9408 |
# Epoch [23/200] | Train Loss: 0.1744, Train Acc: 0.9342 |
# Epoch [24/200] | Train Loss: 0.1711, Train Acc: 0.9474 |
# Epoch [25/200] | Train Loss: 0.1447, Train Acc: 0.9539 |
# Epoch [26/200] | Train Loss: 0.1882, Train Acc: 0.9211 |
# Epoch [27/200] | Train Loss: 0.1906, Train Acc: 0.9211 |
# Epoch [28/200] | Train Loss: 0.1663, Train Acc: 0.9408 |
# Epoch [29/200] | Train Loss: 0.1237, Train Acc: 0.9474 |
# Epoch [30/200] | Train Loss: 0.1640, Train Acc: 0.9211 |
# Epoch [31/200] | Train Loss: 0.2182, Train Acc: 0.9342 |
# Epoch [32/200] | Train Loss: 0.4065, Train Acc: 0.8487 |
# Epoch [33/200] | Train Loss: 0.3498, Train Acc: 0.8947 |
# Epoch [34/200] | Train Loss: 0.2159, Train Acc: 0.9408 |
# Epoch [35/200] | Train Loss: 0.1804, Train Acc: 0.9342 |
# Epoch [36/200] | Train Loss: 0.1391, Train Acc: 0.9605 |
# Epoch [37/200] | Train Loss: 0.0960, Train Acc: 0.9803 |
# Epoch [38/200] | Train Loss: 0.0823, Train Acc: 0.9803 |
# Epoch [39/200] | Train Loss: 0.1379, Train Acc: 0.9605 |
# Epoch [40/200] | Train Loss: 0.1114, Train Acc: 0.9671 |
# Epoch [41/200] | Train Loss: 0.0798, Train Acc: 0.9803 |
# Epoch [42/200] | Train Loss: 0.1175, Train Acc: 0.9671 |
# Epoch [43/200] | Train Loss: 0.1451, Train Acc: 0.9474 |
# Epoch [44/200] | Train Loss: 0.0781, Train Acc: 0.9737 |
# Epoch [45/200] | Train Loss: 0.0510, Train Acc: 0.9868 |
# Epoch [46/200] | Train Loss: 0.0844, Train Acc: 0.9868 |
# Epoch [47/200] | Train Loss: 0.0855, Train Acc: 0.9803 |
# Epoch [48/200] | Train Loss: 0.0727, Train Acc: 0.9803 |
# Epoch [49/200] | Train Loss: 0.0458, Train Acc: 0.9934 |
# Epoch [50/200] | Train Loss: 0.1247, Train Acc: 0.9671 |
# Epoch [51/200] | Train Loss: 0.1911, Train Acc: 0.9408 |
# Epoch [52/200] | Train Loss: 0.0926, Train Acc: 0.9474 |
# Epoch [53/200] | Train Loss: 0.1905, Train Acc: 0.9408 |
# Epoch [54/200] | Train Loss: 0.1239, Train Acc: 0.9605 |
# Epoch [55/200] | Train Loss: 0.1208, Train Acc: 0.9408 |
# Epoch [56/200] | Train Loss: 0.0711, Train Acc: 0.9803 |
# Epoch [57/200] | Train Loss: 0.0682, Train Acc: 0.9868 |
# Epoch [58/200] | Train Loss: 0.0795, Train Acc: 0.9737 |
# Epoch [59/200] | Train Loss: 0.0357, Train Acc: 0.9934 |
# Epoch [60/200] | Train Loss: 0.0513, Train Acc: 0.9803 |
# Epoch [61/200] | Train Loss: 0.0328, Train Acc: 0.9868 |
# Epoch [62/200] | Train Loss: 0.0496, Train Acc: 0.9737 |
# Epoch [63/200] | Train Loss: 0.0412, Train Acc: 0.9868 |
# Epoch [64/200] | Train Loss: 0.0206, Train Acc: 1.0000 |
# Epoch [65/200] | Train Loss: 0.0095, Train Acc: 1.0000 |
# Epoch [66/200] | Train Loss: 0.0153, Train Acc: 0.9934 |
# Epoch [67/200] | Train Loss: 0.0232, Train Acc: 0.9934 |
# Epoch [68/200] | Train Loss: 0.0065, Train Acc: 1.0000 |
# Epoch [69/200] | Train Loss: 0.0074, Train Acc: 1.0000 |
# Epoch [70/200] | Train Loss: 0.0055, Train Acc: 1.0000 |
# Epoch [71/200] | Train Loss: 0.0051, Train Acc: 1.0000 |
# Epoch [72/200] | Train Loss: 0.0044, Train Acc: 1.0000 |
# Epoch [73/200] | Train Loss: 0.0042, Train Acc: 1.0000 |
# Epoch [74/200] | Train Loss: 0.0038, Train Acc: 1.0000 |
# Epoch [75/200] | Train Loss: 0.0037, Train Acc: 1.0000 |
# Epoch [76/200] | Train Loss: 0.0036, Train Acc: 1.0000 |
# Epoch [77/200] | Train Loss: 0.0034, Train Acc: 1.0000 |
# Epoch [78/200] | Train Loss: 0.0034, Train Acc: 1.0000 |
# Epoch [79/200] | Train Loss: 0.0031, Train Acc: 1.0000 |
# Epoch [80/200] | Train Loss: 0.0030, Train Acc: 1.0000 |
# Epoch [81/200] | Train Loss: 0.0028, Train Acc: 1.0000 |
# Epoch [82/200] | Train Loss: 0.0027, Train Acc: 1.0000 |
# Epoch [83/200] | Train Loss: 0.0026, Train Acc: 1.0000 |
# Epoch [84/200] | Train Loss: 0.0026, Train Acc: 1.0000 |
# Epoch [85/200] | Train Loss: 0.0025, Train Acc: 1.0000 |
# Epoch [86/200] | Train Loss: 0.0023, Train Acc: 1.0000 |
# Epoch [87/200] | Train Loss: 0.0023, Train Acc: 1.0000 |
# Epoch [88/200] | Train Loss: 0.0022, Train Acc: 1.0000 |
# Epoch [89/200] | Train Loss: 0.0022, Train Acc: 1.0000 |
# Epoch [90/200] | Train Loss: 0.0021, Train Acc: 1.0000 |
# Epoch [91/200] | Train Loss: 0.0021, Train Acc: 1.0000 |
# Epoch [92/200] | Train Loss: 0.0020, Train Acc: 1.0000 |
# Epoch [93/200] | Train Loss: 0.0020, Train Acc: 1.0000 |
# Epoch [94/200] | Train Loss: 0.0019, Train Acc: 1.0000 |
# Epoch [95/200] | Train Loss: 0.0019, Train Acc: 1.0000 |
# Epoch [96/200] | Train Loss: 0.0018, Train Acc: 1.0000 |
# Epoch [97/200] | Train Loss: 0.0018, Train Acc: 1.0000 |
# Epoch [98/200] | Train Loss: 0.0017, Train Acc: 1.0000 |
# Epoch [99/200] | Train Loss: 0.0017, Train Acc: 1.0000 |
# Epoch [100/200] | Train Loss: 0.0016, Train Acc: 1.0000 |
# Epoch [101/200] | Train Loss: 0.0016, Train Acc: 1.0000 |
# Epoch [102/200] | Train Loss: 0.0015, Train Acc: 1.0000 |
# Epoch [103/200] | Train Loss: 0.0015, Train Acc: 1.0000 |
# Epoch [104/200] | Train Loss: 0.0015, Train Acc: 1.0000 |
# Epoch [105/200] | Train Loss: 0.0014, Train Acc: 1.0000 |
# Epoch [106/200] | Train Loss: 0.0014, Train Acc: 1.0000 |
# Epoch [107/200] | Train Loss: 0.0014, Train Acc: 1.0000 |
# Epoch [108/200] | Train Loss: 0.0013, Train Acc: 1.0000 |
# Epoch [109/200] | Train Loss: 0.0013, Train Acc: 1.0000 |
# Epoch [110/200] | Train Loss: 0.0013, Train Acc: 1.0000 |
# Epoch [111/200] | Train Loss: 0.0013, Train Acc: 1.0000 |
# Epoch [112/200] | Train Loss: 0.0012, Train Acc: 1.0000 |
# Epoch [113/200] | Train Loss: 0.0012, Train Acc: 1.0000 |
# Epoch [114/200] | Train Loss: 0.0012, Train Acc: 1.0000 |
# Epoch [115/200] | Train Loss: 0.0012, Train Acc: 1.0000 |
# Epoch [116/200] | Train Loss: 0.0012, Train Acc: 1.0000 |
# Epoch [117/200] | Train Loss: 0.0011, Train Acc: 1.0000 |
# Epoch [118/200] | Train Loss: 0.0011, Train Acc: 1.0000 |
# Epoch [119/200] | Train Loss: 0.0011, Train Acc: 1.0000 |
# Epoch [120/200] | Train Loss: 0.0011, Train Acc: 1.0000 |
# Epoch [121/200] | Train Loss: 0.0010, Train Acc: 1.0000 |
# Epoch [122/200] | Train Loss: 0.0010, Train Acc: 1.0000 |
# Epoch [123/200] | Train Loss: 0.0010, Train Acc: 1.0000 |
# Epoch [124/200] | Train Loss: 0.0010, Train Acc: 1.0000 |
# Epoch [125/200] | Train Loss: 0.0010, Train Acc: 1.0000 |
# Epoch [126/200] | Train Loss: 0.0010, Train Acc: 1.0000 |
# Epoch [127/200] | Train Loss: 0.0011, Train Acc: 1.0000 |
# Epoch [128/200] | Train Loss: 0.0009, Train Acc: 1.0000 |
# Epoch [129/200] | Train Loss: 0.0009, Train Acc: 1.0000 |
# Epoch [130/200] | Train Loss: 0.0009, Train Acc: 1.0000 |
# Epoch [131/200] | Train Loss: 0.0009, Train Acc: 1.0000 |
# Epoch [132/200] | Train Loss: 0.0009, Train Acc: 1.0000 |
# Epoch [133/200] | Train Loss: 0.0009, Train Acc: 1.0000 |
# Epoch [134/200] | Train Loss: 0.0009, Train Acc: 1.0000 |
# Epoch [135/200] | Train Loss: 0.0008, Train Acc: 1.0000 |
# Epoch [136/200] | Train Loss: 0.0008, Train Acc: 1.0000 |
# Epoch [137/200] | Train Loss: 0.0008, Train Acc: 1.0000 |
# Epoch [138/200] | Train Loss: 0.0008, Train Acc: 1.0000 |
# Epoch [139/200] | Train Loss: 0.0008, Train Acc: 1.0000 |
# Epoch [140/200] | Train Loss: 0.0008, Train Acc: 1.0000 |
# Epoch [141/200] | Train Loss: 0.0009, Train Acc: 1.0000 |
# Epoch [142/200] | Train Loss: 0.0008, Train Acc: 1.0000 |
# Epoch [143/200] | Train Loss: 0.0007, Train Acc: 1.0000 |
# Epoch [144/200] | Train Loss: 0.0007, Train Acc: 1.0000 |
# Epoch [145/200] | Train Loss: 0.0007, Train Acc: 1.0000 |
# Epoch [146/200] | Train Loss: 0.0007, Train Acc: 1.0000 |
# Epoch [147/200] | Train Loss: 0.0007, Train Acc: 1.0000 |
# Epoch [148/200] | Train Loss: 0.0007, Train Acc: 1.0000 |
# Epoch [149/200] | Train Loss: 0.0007, Train Acc: 1.0000 |
# Epoch [150/200] | Train Loss: 0.0007, Train Acc: 1.0000 |
# Epoch [151/200] | Train Loss: 0.0007, Train Acc: 1.0000 |
# Epoch [152/200] | Train Loss: 0.0007, Train Acc: 1.0000 |
# Epoch [153/200] | Train Loss: 0.0007, Train Acc: 1.0000 |
# Epoch [154/200] | Train Loss: 0.0007, Train Acc: 1.0000 |
# Epoch [155/200] | Train Loss: 0.0007, Train Acc: 1.0000 |
# Epoch [156/200] | Train Loss: 0.0008, Train Acc: 1.0000 |
# Epoch [157/200] | Train Loss: 0.0298, Train Acc: 0.9868 |
# Epoch [158/200] | Train Loss: 0.1383, Train Acc: 0.9605 |
# Epoch [159/200] | Train Loss: 0.1129, Train Acc: 0.9605 |
# Epoch [160/200] | Train Loss: 0.1064, Train Acc: 0.9539 |
# Epoch [161/200] | Train Loss: 0.0716, Train Acc: 0.9737 |
# Epoch [162/200] | Train Loss: 0.0736, Train Acc: 0.9803 |
# Epoch [163/200] | Train Loss: 0.0563, Train Acc: 0.9737 |
# Epoch [164/200] | Train Loss: 0.0317, Train Acc: 0.9868 |
# Epoch 00165: reducing learning rate of group 0 to 1.0000e-04.
# Epoch [165/200] | Train Loss: 0.0385, Train Acc: 0.9934 |
# Epoch [166/200] | Train Loss: 0.0454, Train Acc: 0.9803 |
# Epoch [167/200] | Train Loss: 0.0078, Train Acc: 1.0000 |
# Epoch [168/200] | Train Loss: 0.0105, Train Acc: 0.9934 |
# Epoch [169/200] | Train Loss: 0.0098, Train Acc: 1.0000 |
# Epoch [170/200] | Train Loss: 0.0048, Train Acc: 1.0000 |
# Epoch [171/200] | Train Loss: 0.0052, Train Acc: 1.0000 |
# Epoch [172/200] | Train Loss: 0.0073, Train Acc: 1.0000 |
# Epoch [173/200] | Train Loss: 0.0044, Train Acc: 1.0000 |
# Early stopping triggered.
# Test Loss: 1.1566, Test Accuracy: 0.7895, Test AUC: 0.8892
#
# --- Processing: psd_fc_all_bands ---
# Shape: (190, 1140)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.7808, Train Acc: 0.4934 |
# Epoch [2/200] | Train Loss: 0.7118, Train Acc: 0.5000 |
# Epoch [3/200] | Train Loss: 0.6948, Train Acc: 0.5000 |
# Epoch [4/200] | Train Loss: 0.6971, Train Acc: 0.4671 |
# Epoch [5/200] | Train Loss: 0.6934, Train Acc: 0.5000 |
# Epoch [6/200] | Train Loss: 0.6903, Train Acc: 0.4934 |
# Epoch [7/200] | Train Loss: 0.6953, Train Acc: 0.4868 |
# Epoch [8/200] | Train Loss: 0.6939, Train Acc: 0.5000 |
# Epoch [9/200] | Train Loss: 0.6873, Train Acc: 0.5461 |
# Epoch [10/200] | Train Loss: 0.6690, Train Acc: 0.5658 |
# Epoch [11/200] | Train Loss: 0.6066, Train Acc: 0.7237 |
# Epoch [12/200] | Train Loss: 0.4512, Train Acc: 0.8289 |
# Epoch [13/200] | Train Loss: 0.3218, Train Acc: 0.8750 |
# Epoch [14/200] | Train Loss: 0.3089, Train Acc: 0.8882 |
# Epoch [15/200] | Train Loss: 0.3790, Train Acc: 0.8421 |
# Epoch [16/200] | Train Loss: 0.3061, Train Acc: 0.8684 |
# Epoch [17/200] | Train Loss: 0.2175, Train Acc: 0.9079 |
# Epoch [18/200] | Train Loss: 0.2001, Train Acc: 0.9342 |
# Epoch [19/200] | Train Loss: 0.1894, Train Acc: 0.9342 |
# Epoch [20/200] | Train Loss: 0.2690, Train Acc: 0.9276 |
# Epoch [21/200] | Train Loss: 0.1897, Train Acc: 0.9474 |
# Epoch [22/200] | Train Loss: 0.1907, Train Acc: 0.9474 |
# Epoch [23/200] | Train Loss: 0.1738, Train Acc: 0.9408 |
# Epoch [24/200] | Train Loss: 0.1625, Train Acc: 0.9342 |
# Epoch [25/200] | Train Loss: 0.1529, Train Acc: 0.9474 |
# Epoch [26/200] | Train Loss: 0.0979, Train Acc: 0.9803 |
# Epoch [27/200] | Train Loss: 0.0862, Train Acc: 0.9868 |
# Epoch [28/200] | Train Loss: 0.0774, Train Acc: 0.9737 |
# Epoch [29/200] | Train Loss: 0.1334, Train Acc: 0.9605 |
# Epoch [30/200] | Train Loss: 0.1229, Train Acc: 0.9671 |
# Epoch [31/200] | Train Loss: 0.0885, Train Acc: 0.9868 |
# Epoch [32/200] | Train Loss: 0.0925, Train Acc: 0.9737 |
# Epoch [33/200] | Train Loss: 0.0785, Train Acc: 0.9737 |
# Epoch [34/200] | Train Loss: 0.0603, Train Acc: 0.9803 |
# Epoch [35/200] | Train Loss: 0.0472, Train Acc: 0.9737 |
# Epoch [36/200] | Train Loss: 0.0648, Train Acc: 0.9803 |
# Epoch [37/200] | Train Loss: 0.0296, Train Acc: 0.9934 |
# Epoch [38/200] | Train Loss: 0.0350, Train Acc: 0.9934 |
# Epoch [39/200] | Train Loss: 0.0725, Train Acc: 0.9737 |
# Epoch [40/200] | Train Loss: 0.0545, Train Acc: 0.9803 |
# Epoch [41/200] | Train Loss: 0.0181, Train Acc: 1.0000 |
# Epoch [42/200] | Train Loss: 0.0103, Train Acc: 1.0000 |
# Epoch [43/200] | Train Loss: 0.0225, Train Acc: 0.9934 |
# Epoch [44/200] | Train Loss: 0.0925, Train Acc: 0.9803 |
# Epoch [45/200] | Train Loss: 0.0234, Train Acc: 0.9934 |
# Epoch [46/200] | Train Loss: 0.0367, Train Acc: 0.9868 |
# Epoch [47/200] | Train Loss: 0.0472, Train Acc: 0.9868 |
# Epoch [48/200] | Train Loss: 0.0358, Train Acc: 0.9868 |
# Epoch [49/200] | Train Loss: 0.0147, Train Acc: 0.9934 |
# Epoch [50/200] | Train Loss: 0.0125, Train Acc: 0.9934 |
# Epoch [51/200] | Train Loss: 0.0195, Train Acc: 0.9934 |
# Epoch [52/200] | Train Loss: 0.0306, Train Acc: 0.9934 |
# Epoch [53/200] | Train Loss: 0.0057, Train Acc: 1.0000 |
# Epoch [54/200] | Train Loss: 0.0047, Train Acc: 1.0000 |
# Epoch [55/200] | Train Loss: 0.0041, Train Acc: 1.0000 |
# Epoch [56/200] | Train Loss: 0.0077, Train Acc: 1.0000 |
# Epoch [57/200] | Train Loss: 0.0139, Train Acc: 0.9934 |
# Epoch [58/200] | Train Loss: 0.0038, Train Acc: 1.0000 |
# Epoch [59/200] | Train Loss: 0.0206, Train Acc: 0.9934 |
# Epoch [60/200] | Train Loss: 0.1249, Train Acc: 0.9671 |
# Epoch [61/200] | Train Loss: 0.2379, Train Acc: 0.9342 |
# Epoch [62/200] | Train Loss: 0.2690, Train Acc: 0.9276 |
# Epoch [63/200] | Train Loss: 0.1113, Train Acc: 0.9803 |
# Epoch [64/200] | Train Loss: 0.0770, Train Acc: 0.9868 |
# Epoch [65/200] | Train Loss: 0.0467, Train Acc: 0.9934 |
# Epoch [66/200] | Train Loss: 0.0301, Train Acc: 1.0000 |
# Epoch [67/200] | Train Loss: 0.0225, Train Acc: 0.9934 |
# Epoch [68/200] | Train Loss: 0.0469, Train Acc: 0.9868 |
# Epoch 00069: reducing learning rate of group 0 to 1.0000e-04.
# Epoch [69/200] | Train Loss: 0.1163, Train Acc: 0.9671 |
# Epoch [70/200] | Train Loss: 0.3280, Train Acc: 0.9145 |
# Epoch [71/200] | Train Loss: 0.1110, Train Acc: 0.9737 |
# Epoch [72/200] | Train Loss: 0.0280, Train Acc: 0.9868 |
# Epoch [73/200] | Train Loss: 0.0236, Train Acc: 0.9934 |
# Epoch [74/200] | Train Loss: 0.0242, Train Acc: 0.9934 |
# Epoch [75/200] | Train Loss: 0.0206, Train Acc: 0.9934 |
# Epoch [76/200] | Train Loss: 0.0092, Train Acc: 1.0000 |
# Epoch [77/200] | Train Loss: 0.0120, Train Acc: 1.0000 |
# Early stopping triggered.
# Test Loss: 0.6308, Test Accuracy: 0.8684, Test AUC: 0.9086
#
# --- Processing: psd_delta ---
# Shape: (190, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.8252, Train Acc: 0.4671 |
# Epoch [2/200] | Train Loss: 0.6997, Train Acc: 0.5526 |
# Epoch [3/200] | Train Loss: 0.6444, Train Acc: 0.5987 |
# Epoch [4/200] | Train Loss: 0.5488, Train Acc: 0.7500 |
# Epoch [5/200] | Train Loss: 0.4663, Train Acc: 0.7632 |
# Epoch [6/200] | Train Loss: 0.4161, Train Acc: 0.8158 |
# Epoch [7/200] | Train Loss: 0.3926, Train Acc: 0.8289 |
# Epoch [8/200] | Train Loss: 0.3767, Train Acc: 0.8355 |
# Epoch [9/200] | Train Loss: 0.3326, Train Acc: 0.8553 |
# Epoch [10/200] | Train Loss: 0.3266, Train Acc: 0.8816 |
# Epoch [11/200] | Train Loss: 0.3386, Train Acc: 0.8618 |
# Epoch [12/200] | Train Loss: 0.2878, Train Acc: 0.8684 |
# Epoch [13/200] | Train Loss: 0.2534, Train Acc: 0.8750 |
# Epoch [14/200] | Train Loss: 0.2382, Train Acc: 0.9013 |
# Epoch [15/200] | Train Loss: 0.2071, Train Acc: 0.9145 |
# Epoch [16/200] | Train Loss: 0.1975, Train Acc: 0.9211 |
# Epoch [17/200] | Train Loss: 0.2095, Train Acc: 0.9276 |
# Epoch [18/200] | Train Loss: 0.2300, Train Acc: 0.9079 |
# Epoch [19/200] | Train Loss: 0.2414, Train Acc: 0.8882 |
# Epoch [20/200] | Train Loss: 0.2506, Train Acc: 0.9013 |
# Epoch [21/200] | Train Loss: 0.2257, Train Acc: 0.9211 |
# Epoch [22/200] | Train Loss: 0.2358, Train Acc: 0.8750 |
# Epoch [23/200] | Train Loss: 0.2265, Train Acc: 0.9079 |
# Epoch [24/200] | Train Loss: 0.2050, Train Acc: 0.9211 |
# Epoch [25/200] | Train Loss: 0.2135, Train Acc: 0.9211 |
# Epoch [26/200] | Train Loss: 0.1960, Train Acc: 0.9342 |
# Epoch [27/200] | Train Loss: 0.1829, Train Acc: 0.9276 |
# Epoch [28/200] | Train Loss: 0.1585, Train Acc: 0.9211 |
# Epoch [29/200] | Train Loss: 0.1438, Train Acc: 0.9408 |
# Epoch [30/200] | Train Loss: 0.1333, Train Acc: 0.9605 |
# Epoch [31/200] | Train Loss: 0.1085, Train Acc: 0.9474 |
# Epoch [32/200] | Train Loss: 0.1512, Train Acc: 0.9408 |
# Epoch [33/200] | Train Loss: 0.2035, Train Acc: 0.9079 |
# Epoch [34/200] | Train Loss: 0.1425, Train Acc: 0.9342 |
# Epoch [35/200] | Train Loss: 0.1375, Train Acc: 0.9408 |
# Epoch [36/200] | Train Loss: 0.1195, Train Acc: 0.9474 |
# Epoch [37/200] | Train Loss: 0.1184, Train Acc: 0.9408 |
# Epoch [38/200] | Train Loss: 0.1379, Train Acc: 0.9605 |
# Epoch [39/200] | Train Loss: 0.1838, Train Acc: 0.9342 |
# Epoch [40/200] | Train Loss: 0.1506, Train Acc: 0.9539 |
# Epoch [41/200] | Train Loss: 0.1555, Train Acc: 0.9605 |
# Epoch [42/200] | Train Loss: 0.1067, Train Acc: 0.9539 |
# Epoch [43/200] | Train Loss: 0.1188, Train Acc: 0.9605 |
# Epoch [44/200] | Train Loss: 0.0973, Train Acc: 0.9605 |
# Epoch [45/200] | Train Loss: 0.0977, Train Acc: 0.9605 |
# Epoch [46/200] | Train Loss: 0.0782, Train Acc: 0.9737 |
# Epoch [47/200] | Train Loss: 0.1294, Train Acc: 0.9671 |
# Epoch [48/200] | Train Loss: 0.0861, Train Acc: 0.9671 |
# Epoch [49/200] | Train Loss: 0.0911, Train Acc: 0.9605 |
# Epoch [50/200] | Train Loss: 0.0835, Train Acc: 0.9605 |
# Epoch [51/200] | Train Loss: 0.0543, Train Acc: 0.9671 |
# Epoch [52/200] | Train Loss: 0.1188, Train Acc: 0.9671 |
# Epoch [53/200] | Train Loss: 0.2438, Train Acc: 0.9211 |
# Epoch [54/200] | Train Loss: 0.2226, Train Acc: 0.9013 |
# Epoch [55/200] | Train Loss: 0.1808, Train Acc: 0.9013 |
# Epoch [56/200] | Train Loss: 0.1343, Train Acc: 0.9474 |
# Epoch [57/200] | Train Loss: 0.1453, Train Acc: 0.9474 |
# Epoch [58/200] | Train Loss: 0.1155, Train Acc: 0.9671 |
# Epoch [59/200] | Train Loss: 0.1009, Train Acc: 0.9737 |
# Epoch [60/200] | Train Loss: 0.0961, Train Acc: 0.9671 |
# Epoch [61/200] | Train Loss: 0.0790, Train Acc: 0.9671 |
# Epoch 00062: reducing learning rate of group 0 to 1.0000e-04.
# Epoch [62/200] | Train Loss: 0.0705, Train Acc: 0.9737 |
# Epoch [63/200] | Train Loss: 0.0654, Train Acc: 0.9803 |
# Epoch [64/200] | Train Loss: 0.0621, Train Acc: 0.9803 |
# Epoch [65/200] | Train Loss: 0.0554, Train Acc: 0.9803 |
# Epoch [66/200] | Train Loss: 0.0769, Train Acc: 0.9803 |
# Epoch [67/200] | Train Loss: 0.0549, Train Acc: 0.9803 |
# Epoch [68/200] | Train Loss: 0.0585, Train Acc: 0.9803 |
# Epoch [69/200] | Train Loss: 0.0682, Train Acc: 0.9737 |
# Epoch [70/200] | Train Loss: 0.0540, Train Acc: 0.9803 |
# Epoch [71/200] | Train Loss: 0.0478, Train Acc: 0.9868 |
# Epoch [72/200] | Train Loss: 0.0473, Train Acc: 0.9868 |
# Epoch [73/200] | Train Loss: 0.0423, Train Acc: 0.9868 |
# Epoch [74/200] | Train Loss: 0.0516, Train Acc: 0.9868 |
# Epoch [75/200] | Train Loss: 0.0487, Train Acc: 0.9868 |
# Epoch [76/200] | Train Loss: 0.0437, Train Acc: 0.9868 |
# Epoch [77/200] | Train Loss: 0.0403, Train Acc: 0.9868 |
# Epoch [78/200] | Train Loss: 0.0405, Train Acc: 0.9868 |
# Epoch [79/200] | Train Loss: 0.0454, Train Acc: 0.9868 |
# Epoch [80/200] | Train Loss: 0.0375, Train Acc: 0.9868 |
# Epoch [81/200] | Train Loss: 0.0435, Train Acc: 0.9868 |
# Epoch [82/200] | Train Loss: 0.0551, Train Acc: 0.9803 |
# Epoch [83/200] | Train Loss: 0.0422, Train Acc: 0.9868 |
# Epoch [84/200] | Train Loss: 0.0424, Train Acc: 0.9868 |
# Epoch [85/200] | Train Loss: 0.0371, Train Acc: 0.9868 |
# Epoch [86/200] | Train Loss: 0.0483, Train Acc: 0.9868 |
# Epoch [87/200] | Train Loss: 0.0378, Train Acc: 0.9868 |
# Epoch [88/200] | Train Loss: 0.0509, Train Acc: 0.9868 |
# Epoch [89/200] | Train Loss: 0.0338, Train Acc: 0.9868 |
# Epoch [90/200] | Train Loss: 0.0493, Train Acc: 0.9803 |
# Epoch [91/200] | Train Loss: 0.0364, Train Acc: 0.9868 |
# Epoch [92/200] | Train Loss: 0.0313, Train Acc: 0.9868 |
# Epoch [93/200] | Train Loss: 0.0322, Train Acc: 0.9868 |
# Epoch [94/200] | Train Loss: 0.0303, Train Acc: 0.9868 |
# Epoch [95/200] | Train Loss: 0.0343, Train Acc: 0.9868 |
# Epoch [96/200] | Train Loss: 0.0329, Train Acc: 0.9868 |
# Epoch [97/200] | Train Loss: 0.0317, Train Acc: 0.9803 |
# Epoch [98/200] | Train Loss: 0.0252, Train Acc: 0.9868 |
# Epoch [99/200] | Train Loss: 0.0230, Train Acc: 0.9868 |
# Epoch [100/200] | Train Loss: 0.0518, Train Acc: 0.9803 |
# Epoch [101/200] | Train Loss: 0.0275, Train Acc: 0.9868 |
# Epoch [102/200] | Train Loss: 0.0326, Train Acc: 0.9868 |
# Epoch [103/200] | Train Loss: 0.0301, Train Acc: 0.9868 |
# Epoch [104/200] | Train Loss: 0.0229, Train Acc: 0.9868 |
# Epoch [105/200] | Train Loss: 0.0235, Train Acc: 0.9934 |
# Epoch [106/200] | Train Loss: 0.0251, Train Acc: 0.9934 |
# Epoch [107/200] | Train Loss: 0.0223, Train Acc: 0.9934 |
# Epoch [108/200] | Train Loss: 0.0186, Train Acc: 0.9934 |
# Epoch [109/200] | Train Loss: 0.0126, Train Acc: 0.9934 |
# Epoch [110/200] | Train Loss: 0.0216, Train Acc: 0.9934 |
# Epoch [111/200] | Train Loss: 0.0164, Train Acc: 0.9934 |
# Epoch [112/200] | Train Loss: 0.0292, Train Acc: 0.9803 |
# Epoch [113/200] | Train Loss: 0.0200, Train Acc: 1.0000 |
# Epoch [114/200] | Train Loss: 0.0128, Train Acc: 1.0000 |
# Epoch [115/200] | Train Loss: 0.0121, Train Acc: 1.0000 |
# Epoch [116/200] | Train Loss: 0.0155, Train Acc: 1.0000 |
# Epoch [117/200] | Train Loss: 0.0186, Train Acc: 0.9868 |
# Epoch [118/200] | Train Loss: 0.0162, Train Acc: 0.9934 |
# Epoch [119/200] | Train Loss: 0.0151, Train Acc: 1.0000 |
# Epoch [120/200] | Train Loss: 0.0102, Train Acc: 1.0000 |
# Epoch [121/200] | Train Loss: 0.0076, Train Acc: 1.0000 |
# Epoch [122/200] | Train Loss: 0.0060, Train Acc: 1.0000 |
# Epoch [123/200] | Train Loss: 0.0081, Train Acc: 1.0000 |
# Epoch [124/200] | Train Loss: 0.0083, Train Acc: 1.0000 |
# Epoch [125/200] | Train Loss: 0.0078, Train Acc: 1.0000 |
# Epoch [126/200] | Train Loss: 0.0074, Train Acc: 1.0000 |
# Epoch [127/200] | Train Loss: 0.0046, Train Acc: 1.0000 |
# Epoch [128/200] | Train Loss: 0.0039, Train Acc: 1.0000 |
# Epoch [129/200] | Train Loss: 0.0036, Train Acc: 1.0000 |
# Epoch [130/200] | Train Loss: 0.0030, Train Acc: 1.0000 |
# Epoch [131/200] | Train Loss: 0.0039, Train Acc: 1.0000 |
# Epoch [132/200] | Train Loss: 0.0028, Train Acc: 1.0000 |
# Epoch [133/200] | Train Loss: 0.0030, Train Acc: 1.0000 |
# Epoch [134/200] | Train Loss: 0.0036, Train Acc: 1.0000 |
# Epoch [135/200] | Train Loss: 0.0046, Train Acc: 1.0000 |
# Epoch [136/200] | Train Loss: 0.0091, Train Acc: 1.0000 |
# Epoch [137/200] | Train Loss: 0.0139, Train Acc: 0.9934 |
# Epoch [138/200] | Train Loss: 0.0066, Train Acc: 1.0000 |
# Epoch [139/200] | Train Loss: 0.0029, Train Acc: 1.0000 |
# Epoch [140/200] | Train Loss: 0.0031, Train Acc: 1.0000 |
# Epoch [141/200] | Train Loss: 0.0063, Train Acc: 1.0000 |
# Epoch [142/200] | Train Loss: 0.0027, Train Acc: 1.0000 |
# Epoch [143/200] | Train Loss: 0.0026, Train Acc: 1.0000 |
# Epoch [144/200] | Train Loss: 0.0052, Train Acc: 1.0000 |
# Epoch [145/200] | Train Loss: 0.0184, Train Acc: 0.9934 |
# Epoch [146/200] | Train Loss: 0.0041, Train Acc: 1.0000 |
# Epoch [147/200] | Train Loss: 0.0024, Train Acc: 1.0000 |
# Epoch [148/200] | Train Loss: 0.0025, Train Acc: 1.0000 |
# Epoch [149/200] | Train Loss: 0.0047, Train Acc: 1.0000 |
# Epoch [150/200] | Train Loss: 0.0108, Train Acc: 0.9934 |
# Epoch [151/200] | Train Loss: 0.0030, Train Acc: 1.0000 |
# Epoch [152/200] | Train Loss: 0.0049, Train Acc: 1.0000 |
# Epoch [153/200] | Train Loss: 0.0029, Train Acc: 1.0000 |
# Epoch [154/200] | Train Loss: 0.0370, Train Acc: 0.9868 |
# Epoch [155/200] | Train Loss: 0.0231, Train Acc: 0.9934 |
# Epoch [156/200] | Train Loss: 0.0030, Train Acc: 1.0000 |
# Epoch [157/200] | Train Loss: 0.0041, Train Acc: 1.0000 |
# Epoch 00158: reducing learning rate of group 0 to 1.0000e-05.
# Epoch [158/200] | Train Loss: 0.0308, Train Acc: 0.9934 |
# Epoch [159/200] | Train Loss: 0.0142, Train Acc: 0.9934 |
# Epoch [160/200] | Train Loss: 0.0060, Train Acc: 1.0000 |
# Epoch [161/200] | Train Loss: 0.0073, Train Acc: 1.0000 |
# Epoch [162/200] | Train Loss: 0.0052, Train Acc: 1.0000 |
# Epoch [163/200] | Train Loss: 0.0034, Train Acc: 1.0000 |
# Epoch [164/200] | Train Loss: 0.0030, Train Acc: 1.0000 |
# Epoch [165/200] | Train Loss: 0.0076, Train Acc: 1.0000 |
# Epoch [166/200] | Train Loss: 0.0226, Train Acc: 0.9934 |
# Early stopping triggered.
# Test Loss: 0.5902, Test Accuracy: 0.8684, Test AUC: 0.9224
#
# --- Processing: psd_theta ---
# Shape: (190, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.7515, Train Acc: 0.5395 |
# Epoch [2/200] | Train Loss: 0.6505, Train Acc: 0.6118 |
# Epoch [3/200] | Train Loss: 0.6620, Train Acc: 0.5921 |
# Epoch [4/200] | Train Loss: 0.5341, Train Acc: 0.7434 |
# Epoch [5/200] | Train Loss: 0.4267, Train Acc: 0.7961 |
# Epoch [6/200] | Train Loss: 0.3786, Train Acc: 0.8355 |
# Epoch [7/200] | Train Loss: 0.3979, Train Acc: 0.8224 |
# Epoch [8/200] | Train Loss: 0.3909, Train Acc: 0.8092 |
# Epoch [9/200] | Train Loss: 0.3314, Train Acc: 0.8618 |
# Epoch [10/200] | Train Loss: 0.2791, Train Acc: 0.9013 |
# Epoch [11/200] | Train Loss: 0.2946, Train Acc: 0.8816 |
# Epoch [12/200] | Train Loss: 0.3900, Train Acc: 0.7763 |
# Epoch [13/200] | Train Loss: 0.3004, Train Acc: 0.8750 |
# Epoch [14/200] | Train Loss: 0.3258, Train Acc: 0.8553 |
# Epoch [15/200] | Train Loss: 0.2612, Train Acc: 0.9079 |
# Epoch [16/200] | Train Loss: 0.2654, Train Acc: 0.9079 |
# Epoch [17/200] | Train Loss: 0.2715, Train Acc: 0.8882 |
# Epoch [18/200] | Train Loss: 0.3199, Train Acc: 0.8684 |
# Epoch [19/200] | Train Loss: 0.3033, Train Acc: 0.8816 |
# Epoch [20/200] | Train Loss: 0.2795, Train Acc: 0.9013 |
# Epoch [21/200] | Train Loss: 0.2344, Train Acc: 0.9211 |
# Epoch [22/200] | Train Loss: 0.2518, Train Acc: 0.9211 |
# Epoch [23/200] | Train Loss: 0.2365, Train Acc: 0.9145 |
# Epoch [24/200] | Train Loss: 0.2197, Train Acc: 0.9145 |
# Epoch [25/200] | Train Loss: 0.1955, Train Acc: 0.9145 |
# Epoch [26/200] | Train Loss: 0.2145, Train Acc: 0.8947 |
# Epoch [27/200] | Train Loss: 0.2210, Train Acc: 0.9079 |
# Epoch [28/200] | Train Loss: 0.2300, Train Acc: 0.9145 |
# Epoch [29/200] | Train Loss: 0.1785, Train Acc: 0.9474 |
# Epoch [30/200] | Train Loss: 0.1675, Train Acc: 0.9474 |
# Epoch [31/200] | Train Loss: 0.2392, Train Acc: 0.9211 |
# Epoch [32/200] | Train Loss: 0.2525, Train Acc: 0.9013 |
# Epoch [33/200] | Train Loss: 0.2390, Train Acc: 0.9145 |
# Epoch [34/200] | Train Loss: 0.2351, Train Acc: 0.9145 |
# Epoch [35/200] | Train Loss: 0.1815, Train Acc: 0.9276 |
# Epoch [36/200] | Train Loss: 0.1787, Train Acc: 0.9211 |
# Epoch [37/200] | Train Loss: 0.1826, Train Acc: 0.9145 |
# Epoch [38/200] | Train Loss: 0.1721, Train Acc: 0.9276 |
# Epoch [39/200] | Train Loss: 0.1863, Train Acc: 0.9211 |
# Epoch [40/200] | Train Loss: 0.1320, Train Acc: 0.9605 |
# Epoch [41/200] | Train Loss: 0.2168, Train Acc: 0.9079 |
# Epoch [42/200] | Train Loss: 0.2028, Train Acc: 0.9145 |
# Epoch [43/200] | Train Loss: 0.2027, Train Acc: 0.9145 |
# Epoch [44/200] | Train Loss: 0.1839, Train Acc: 0.9145 |
# Epoch [45/200] | Train Loss: 0.1999, Train Acc: 0.9145 |
# Epoch [46/200] | Train Loss: 0.1419, Train Acc: 0.9276 |
# Epoch [47/200] | Train Loss: 0.1449, Train Acc: 0.9408 |
# Epoch [48/200] | Train Loss: 0.1203, Train Acc: 0.9539 |
# Epoch [49/200] | Train Loss: 0.1312, Train Acc: 0.9474 |
# Epoch [50/200] | Train Loss: 0.1301, Train Acc: 0.9408 |
# Epoch [51/200] | Train Loss: 0.1712, Train Acc: 0.9408 |
# Epoch [52/200] | Train Loss: 0.1737, Train Acc: 0.9211 |
# Epoch [53/200] | Train Loss: 0.1277, Train Acc: 0.9474 |
# Epoch [54/200] | Train Loss: 0.1523, Train Acc: 0.9474 |
# Epoch [55/200] | Train Loss: 0.1364, Train Acc: 0.9408 |
# Epoch [56/200] | Train Loss: 0.1655, Train Acc: 0.9342 |
# Epoch [57/200] | Train Loss: 0.1676, Train Acc: 0.9145 |
# Epoch [58/200] | Train Loss: 0.1518, Train Acc: 0.9408 |
# Epoch 00059: reducing learning rate of group 0 to 1.0000e-04.
# Epoch [59/200] | Train Loss: 0.2137, Train Acc: 0.9211 |
# Epoch [60/200] | Train Loss: 0.1474, Train Acc: 0.9342 |
# Epoch [61/200] | Train Loss: 0.1528, Train Acc: 0.9342 |
# Epoch [62/200] | Train Loss: 0.1587, Train Acc: 0.9408 |
# Epoch [63/200] | Train Loss: 0.1093, Train Acc: 0.9539 |
# Epoch [64/200] | Train Loss: 0.1130, Train Acc: 0.9671 |
# Epoch [65/200] | Train Loss: 0.1128, Train Acc: 0.9539 |
# Epoch [66/200] | Train Loss: 0.1067, Train Acc: 0.9671 |
# Epoch [67/200] | Train Loss: 0.1072, Train Acc: 0.9539 |
# Epoch [68/200] | Train Loss: 0.0799, Train Acc: 0.9737 |
# Epoch [69/200] | Train Loss: 0.0951, Train Acc: 0.9605 |
# Epoch [70/200] | Train Loss: 0.1137, Train Acc: 0.9671 |
# Epoch [71/200] | Train Loss: 0.0933, Train Acc: 0.9671 |
# Epoch [72/200] | Train Loss: 0.0769, Train Acc: 0.9671 |
# Epoch [73/200] | Train Loss: 0.0812, Train Acc: 0.9737 |
# Epoch [74/200] | Train Loss: 0.0860, Train Acc: 0.9671 |
# Epoch [75/200] | Train Loss: 0.0809, Train Acc: 0.9737 |
# Epoch [76/200] | Train Loss: 0.0611, Train Acc: 0.9737 |
# Epoch [77/200] | Train Loss: 0.0683, Train Acc: 0.9803 |
# Epoch [78/200] | Train Loss: 0.0685, Train Acc: 0.9737 |
# Epoch [79/200] | Train Loss: 0.0862, Train Acc: 0.9474 |
# Epoch [80/200] | Train Loss: 0.0506, Train Acc: 0.9934 |
# Epoch [81/200] | Train Loss: 0.0487, Train Acc: 0.9868 |
# Epoch [82/200] | Train Loss: 0.0422, Train Acc: 0.9934 |
# Epoch [83/200] | Train Loss: 0.0535, Train Acc: 0.9803 |
# Epoch [84/200] | Train Loss: 0.0919, Train Acc: 0.9605 |
# Epoch [85/200] | Train Loss: 0.0563, Train Acc: 0.9868 |
# Epoch [86/200] | Train Loss: 0.0671, Train Acc: 0.9737 |
# Epoch [87/200] | Train Loss: 0.0411, Train Acc: 0.9803 |
# Epoch [88/200] | Train Loss: 0.0847, Train Acc: 0.9671 |
# Epoch [89/200] | Train Loss: 0.0454, Train Acc: 0.9868 |
# Epoch [90/200] | Train Loss: 0.0591, Train Acc: 0.9868 |
# Epoch [91/200] | Train Loss: 0.0601, Train Acc: 0.9671 |
# Epoch [92/200] | Train Loss: 0.0383, Train Acc: 0.9868 |
# Epoch [93/200] | Train Loss: 0.0438, Train Acc: 0.9803 |
# Epoch [94/200] | Train Loss: 0.0546, Train Acc: 0.9934 |
# Epoch [95/200] | Train Loss: 0.0408, Train Acc: 0.9934 |
# Epoch [96/200] | Train Loss: 0.0440, Train Acc: 0.9737 |
# Epoch [97/200] | Train Loss: 0.0492, Train Acc: 0.9737 |
# Epoch [98/200] | Train Loss: 0.0373, Train Acc: 0.9868 |
# Epoch [99/200] | Train Loss: 0.0447, Train Acc: 0.9803 |
# Epoch [100/200] | Train Loss: 0.0335, Train Acc: 0.9803 |
# Epoch [101/200] | Train Loss: 0.0505, Train Acc: 0.9737 |
# Epoch [102/200] | Train Loss: 0.0498, Train Acc: 0.9868 |
# Epoch [103/200] | Train Loss: 0.0399, Train Acc: 0.9868 |
# Epoch [104/200] | Train Loss: 0.0586, Train Acc: 0.9737 |
# Epoch [105/200] | Train Loss: 0.0451, Train Acc: 0.9803 |
# Epoch [106/200] | Train Loss: 0.0420, Train Acc: 0.9934 |
# Epoch [107/200] | Train Loss: 0.0214, Train Acc: 1.0000 |
# Epoch [108/200] | Train Loss: 0.0420, Train Acc: 0.9934 |
# Epoch [109/200] | Train Loss: 0.0245, Train Acc: 0.9934 |
# Epoch [110/200] | Train Loss: 0.0247, Train Acc: 0.9934 |
# Epoch [111/200] | Train Loss: 0.0251, Train Acc: 0.9934 |
# Epoch [112/200] | Train Loss: 0.0529, Train Acc: 0.9868 |
# Epoch [113/200] | Train Loss: 0.0173, Train Acc: 1.0000 |
# Epoch [114/200] | Train Loss: 0.0222, Train Acc: 0.9934 |
# Epoch [115/200] | Train Loss: 0.0244, Train Acc: 0.9934 |
# Epoch [116/200] | Train Loss: 0.0241, Train Acc: 0.9868 |
# Epoch [117/200] | Train Loss: 0.0256, Train Acc: 0.9934 |
# Epoch [118/200] | Train Loss: 0.0187, Train Acc: 0.9934 |
# Epoch [119/200] | Train Loss: 0.0256, Train Acc: 0.9868 |
# Epoch [120/200] | Train Loss: 0.0331, Train Acc: 0.9934 |
# Epoch [121/200] | Train Loss: 0.0100, Train Acc: 1.0000 |
# Epoch [122/200] | Train Loss: 0.0270, Train Acc: 0.9868 |
# Epoch [123/200] | Train Loss: 0.0185, Train Acc: 0.9934 |
# Epoch [124/200] | Train Loss: 0.0306, Train Acc: 0.9868 |
# Epoch [125/200] | Train Loss: 0.0487, Train Acc: 0.9868 |
# Epoch [126/200] | Train Loss: 0.0432, Train Acc: 0.9868 |
# Epoch [127/200] | Train Loss: 0.0293, Train Acc: 0.9934 |
# Epoch [128/200] | Train Loss: 0.0376, Train Acc: 0.9803 |
# Epoch [129/200] | Train Loss: 0.0209, Train Acc: 0.9868 |
# Epoch [130/200] | Train Loss: 0.0272, Train Acc: 0.9934 |
# Epoch [131/200] | Train Loss: 0.0146, Train Acc: 0.9934 |
# Epoch 00132: reducing learning rate of group 0 to 1.0000e-05.
# Epoch [132/200] | Train Loss: 0.0494, Train Acc: 0.9868 |
# Epoch [133/200] | Train Loss: 0.0181, Train Acc: 0.9934 |
# Epoch [134/200] | Train Loss: 0.0100, Train Acc: 1.0000 |
# Epoch [135/200] | Train Loss: 0.0143, Train Acc: 0.9934 |
# Epoch [136/200] | Train Loss: 0.0107, Train Acc: 1.0000 |
# Epoch [137/200] | Train Loss: 0.0159, Train Acc: 0.9934 |
# Epoch [138/200] | Train Loss: 0.0122, Train Acc: 1.0000 |
# Epoch [139/200] | Train Loss: 0.0075, Train Acc: 1.0000 |
# Epoch [140/200] | Train Loss: 0.0067, Train Acc: 1.0000 |
# Epoch [141/200] | Train Loss: 0.0421, Train Acc: 0.9934 |
# Epoch [142/200] | Train Loss: 0.0089, Train Acc: 1.0000 |
# Epoch [143/200] | Train Loss: 0.0120, Train Acc: 1.0000 |
# Epoch [144/200] | Train Loss: 0.0177, Train Acc: 0.9934 |
# Epoch [145/200] | Train Loss: 0.0580, Train Acc: 0.9803 |
# Epoch [146/200] | Train Loss: 0.0141, Train Acc: 0.9934 |
# Epoch [147/200] | Train Loss: 0.0088, Train Acc: 1.0000 |
# Epoch [148/200] | Train Loss: 0.0060, Train Acc: 1.0000 |
# Epoch [149/200] | Train Loss: 0.0383, Train Acc: 0.9934 |
# Epoch [150/200] | Train Loss: 0.0088, Train Acc: 1.0000 |
# Epoch [151/200] | Train Loss: 0.0066, Train Acc: 1.0000 |
# Epoch [152/200] | Train Loss: 0.0076, Train Acc: 1.0000 |
# Epoch [153/200] | Train Loss: 0.0120, Train Acc: 1.0000 |
# Epoch [154/200] | Train Loss: 0.0112, Train Acc: 1.0000 |
# Epoch [155/200] | Train Loss: 0.0478, Train Acc: 0.9868 |
# Epoch [156/200] | Train Loss: 0.0084, Train Acc: 1.0000 |
# Epoch [157/200] | Train Loss: 0.0176, Train Acc: 0.9934 |
# Epoch [158/200] | Train Loss: 0.0065, Train Acc: 1.0000 |
# Epoch 00159: reducing learning rate of group 0 to 1.0000e-06.
# Epoch [159/200] | Train Loss: 0.0158, Train Acc: 0.9934 |
# Epoch [160/200] | Train Loss: 0.0101, Train Acc: 1.0000 |
# Epoch [161/200] | Train Loss: 0.0139, Train Acc: 1.0000 |
# Epoch [162/200] | Train Loss: 0.0116, Train Acc: 1.0000 |
# Epoch [163/200] | Train Loss: 0.0130, Train Acc: 0.9934 |
# Epoch [164/200] | Train Loss: 0.0097, Train Acc: 1.0000 |
# Epoch [165/200] | Train Loss: 0.0136, Train Acc: 1.0000 |
# Epoch [166/200] | Train Loss: 0.0072, Train Acc: 1.0000 |
# Epoch [167/200] | Train Loss: 0.0135, Train Acc: 1.0000 |
# Early stopping triggered.
# Test Loss: 1.1959, Test Accuracy: 0.7632, Test AUC: 0.8116
#
# --- Processing: psd_alpha ---
# Shape: (190, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.7700, Train Acc: 0.5066 |
# Epoch [2/200] | Train Loss: 0.6494, Train Acc: 0.6250 |
# Epoch [3/200] | Train Loss: 0.6278, Train Acc: 0.6447 |
# Epoch [4/200] | Train Loss: 0.4477, Train Acc: 0.8026 |
# Epoch [5/200] | Train Loss: 0.3858, Train Acc: 0.8421 |
# Epoch [6/200] | Train Loss: 0.3432, Train Acc: 0.8421 |
# Epoch [7/200] | Train Loss: 0.3596, Train Acc: 0.8684 |
# Epoch [8/200] | Train Loss: 0.3881, Train Acc: 0.8421 |
# Epoch [9/200] | Train Loss: 0.4069, Train Acc: 0.8224 |
# Epoch [10/200] | Train Loss: 0.3697, Train Acc: 0.8618 |
# Epoch [11/200] | Train Loss: 0.3026, Train Acc: 0.8816 |
# Epoch [12/200] | Train Loss: 0.2998, Train Acc: 0.8882 |
# Epoch [13/200] | Train Loss: 0.2569, Train Acc: 0.8947 |
# Epoch [14/200] | Train Loss: 0.2548, Train Acc: 0.8947 |
# Epoch [15/200] | Train Loss: 0.3152, Train Acc: 0.8816 |
# Epoch [16/200] | Train Loss: 0.2891, Train Acc: 0.9013 |
# Epoch [17/200] | Train Loss: 0.2639, Train Acc: 0.9145 |
# Epoch [18/200] | Train Loss: 0.2768, Train Acc: 0.9079 |
# Epoch [19/200] | Train Loss: 0.2810, Train Acc: 0.8684 |
# Epoch [20/200] | Train Loss: 0.2581, Train Acc: 0.8750 |
# Epoch [21/200] | Train Loss: 0.2123, Train Acc: 0.9211 |
# Epoch [22/200] | Train Loss: 0.1834, Train Acc: 0.9408 |
# Epoch [23/200] | Train Loss: 0.2091, Train Acc: 0.9276 |
# Epoch [24/200] | Train Loss: 0.2356, Train Acc: 0.9145 |
# Epoch [25/200] | Train Loss: 0.1840, Train Acc: 0.9342 |
# Epoch [26/200] | Train Loss: 0.2058, Train Acc: 0.9474 |
# Epoch [27/200] | Train Loss: 0.2167, Train Acc: 0.9211 |
# Epoch [28/200] | Train Loss: 0.3474, Train Acc: 0.8684 |
# Epoch [29/200] | Train Loss: 0.3036, Train Acc: 0.8750 |
# Epoch [30/200] | Train Loss: 0.2429, Train Acc: 0.8882 |
# Epoch [31/200] | Train Loss: 0.2851, Train Acc: 0.9013 |
# Epoch [32/200] | Train Loss: 0.3143, Train Acc: 0.8816 |
# Epoch 00033: reducing learning rate of group 0 to 1.0000e-04.
# Epoch [33/200] | Train Loss: 0.2610, Train Acc: 0.9013 |
# Epoch [34/200] | Train Loss: 0.2223, Train Acc: 0.9211 |
# Epoch [35/200] | Train Loss: 0.2245, Train Acc: 0.9211 |
# Epoch [36/200] | Train Loss: 0.2165, Train Acc: 0.9211 |
# Epoch [37/200] | Train Loss: 0.2222, Train Acc: 0.9013 |
# Epoch [38/200] | Train Loss: 0.2103, Train Acc: 0.9211 |
# Epoch [39/200] | Train Loss: 0.1865, Train Acc: 0.9342 |
# Epoch [40/200] | Train Loss: 0.1707, Train Acc: 0.9408 |
# Epoch [41/200] | Train Loss: 0.1756, Train Acc: 0.9276 |
# Epoch [42/200] | Train Loss: 0.1661, Train Acc: 0.9408 |
# Epoch [43/200] | Train Loss: 0.1682, Train Acc: 0.9408 |
# Epoch [44/200] | Train Loss: 0.1656, Train Acc: 0.9211 |
# Epoch [45/200] | Train Loss: 0.1315, Train Acc: 0.9539 |
# Epoch [46/200] | Train Loss: 0.1342, Train Acc: 0.9474 |
# Epoch [47/200] | Train Loss: 0.1467, Train Acc: 0.9474 |
# Epoch [48/200] | Train Loss: 0.1515, Train Acc: 0.9408 |
# Epoch [49/200] | Train Loss: 0.1334, Train Acc: 0.9605 |
# Epoch [50/200] | Train Loss: 0.1250, Train Acc: 0.9539 |
# Epoch [51/200] | Train Loss: 0.1286, Train Acc: 0.9605 |
# Epoch [52/200] | Train Loss: 0.1433, Train Acc: 0.9474 |
# Epoch [53/200] | Train Loss: 0.1266, Train Acc: 0.9671 |
# Epoch [54/200] | Train Loss: 0.1267, Train Acc: 0.9539 |
# Epoch [55/200] | Train Loss: 0.1186, Train Acc: 0.9671 |
# Epoch [56/200] | Train Loss: 0.1249, Train Acc: 0.9474 |
# Epoch [57/200] | Train Loss: 0.1226, Train Acc: 0.9605 |
# Epoch [58/200] | Train Loss: 0.1172, Train Acc: 0.9671 |
# Epoch [59/200] | Train Loss: 0.1058, Train Acc: 0.9671 |
# Epoch [60/200] | Train Loss: 0.0915, Train Acc: 0.9737 |
# Epoch [61/200] | Train Loss: 0.1106, Train Acc: 0.9671 |
# Epoch [62/200] | Train Loss: 0.0840, Train Acc: 0.9868 |
# Epoch [63/200] | Train Loss: 0.0862, Train Acc: 0.9803 |
# Epoch [64/200] | Train Loss: 0.0753, Train Acc: 0.9803 |
# Epoch [65/200] | Train Loss: 0.0873, Train Acc: 0.9671 |
# Epoch [66/200] | Train Loss: 0.0683, Train Acc: 0.9803 |
# Epoch [67/200] | Train Loss: 0.0787, Train Acc: 0.9605 |
# Epoch [68/200] | Train Loss: 0.0732, Train Acc: 0.9671 |
# Epoch [69/200] | Train Loss: 0.0791, Train Acc: 0.9737 |
# Epoch [70/200] | Train Loss: 0.1076, Train Acc: 0.9671 |
# Epoch [71/200] | Train Loss: 0.0844, Train Acc: 0.9737 |
# Epoch [72/200] | Train Loss: 0.0793, Train Acc: 0.9868 |
# Epoch [73/200] | Train Loss: 0.0759, Train Acc: 0.9737 |
# Epoch [74/200] | Train Loss: 0.0677, Train Acc: 0.9737 |
# Epoch [75/200] | Train Loss: 0.0678, Train Acc: 0.9803 |
# Epoch [76/200] | Train Loss: 0.0741, Train Acc: 0.9737 |
# ...
# Epoch [136/200] | Train Loss: 0.0081, Train Acc: 1.0000 |
# Epoch [137/200] | Train Loss: 0.0087, Train Acc: 1.0000 |
# Epoch [138/200] | Train Loss: 0.0103, Train Acc: 1.0000 |
# Epoch [139/200] | Train Loss: 0.0074, Train Acc: 1.0000 |
# Epoch [140/200] | Train Loss: 0.0070, Train Acc: 1.0000 |
# Epoch [141/200] | Train Loss: 0.0071, Train Acc: 1.0000 |
# Epoch [142/200] | Train Loss: 0.0066, Train Acc: 1.0000 |
# Epoch [143/200] | Train Loss: 0.0073, Train Acc: 1.0000 |
# Epoch [144/200] | Train Loss: 0.0067, Train Acc: 1.0000 |
# Epoch [145/200] | Train Loss: 0.0222, Train Acc: 0.9934 |
# Epoch [146/200] | Train Loss: 0.0082, Train Acc: 1.0000 |
# Epoch [147/200] | Train Loss: 0.0091, Train Acc: 1.0000 |
# Epoch [148/200] | Train Loss: 0.0084, Train Acc: 1.0000 |
# Epoch [149/200] | Train Loss: 0.0269, Train Acc: 0.9934 |
# Epoch [150/200] | Train Loss: 0.0103, Train Acc: 1.0000 |
# Epoch [151/200] | Train Loss: 0.0241, Train Acc: 0.9934 |
# Epoch [152/200] | Train Loss: 0.0101, Train Acc: 1.0000 |
# Epoch 00153: reducing learning rate of group 0 to 1.0000e-05.
# Epoch [153/200] | Train Loss: 0.0138, Train Acc: 0.9934 |
# Epoch [154/200] | Train Loss: 0.0470, Train Acc: 0.9803 |
# Epoch [155/200] | Train Loss: 0.0239, Train Acc: 0.9934 |
# Epoch [156/200] | Train Loss: 0.0259, Train Acc: 0.9934 |
# Epoch [157/200] | Train Loss: 0.0157, Train Acc: 0.9934 |
# Epoch [158/200] | Train Loss: 0.0130, Train Acc: 0.9934 |
# Epoch [159/200] | Train Loss: 0.0073, Train Acc: 1.0000 |
# Epoch [160/200] | Train Loss: 0.0128, Train Acc: 0.9934 |
# Epoch [161/200] | Train Loss: 0.0112, Train Acc: 0.9934 |
# Epoch [162/200] | Train Loss: 0.0063, Train Acc: 1.0000 |
# Epoch [163/200] | Train Loss: 0.0058, Train Acc: 1.0000 |
# Epoch [164/200] | Train Loss: 0.0076, Train Acc: 1.0000 |
# Epoch [165/200] | Train Loss: 0.0071, Train Acc: 1.0000 |
# Epoch [166/200] | Train Loss: 0.0063, Train Acc: 1.0000 |
# Epoch [167/200] | Train Loss: 0.0061, Train Acc: 1.0000 |
# Epoch [168/200] | Train Loss: 0.0081, Train Acc: 1.0000 |
# Epoch [169/200] | Train Loss: 0.0155, Train Acc: 0.9934 |
# Epoch [170/200] | Train Loss: 0.0059, Train Acc: 1.0000 |
# Epoch [171/200] | Train Loss: 0.0061, Train Acc: 1.0000 |
# Epoch [172/200] | Train Loss: 0.0062, Train Acc: 1.0000 |
# Epoch [173/200] | Train Loss: 0.0062, Train Acc: 1.0000 |
# Epoch 00174: reducing learning rate of group 0 to 1.0000e-06.
# Epoch [174/200] | Train Loss: 0.0099, Train Acc: 1.0000 |
# Epoch [175/200] | Train Loss: 0.0061, Train Acc: 1.0000 |
# Epoch [176/200] | Train Loss: 0.0062, Train Acc: 1.0000 |
# Epoch [177/200] | Train Loss: 0.0063, Train Acc: 1.0000 |
# Epoch [178/200] | Train Loss: 0.0065, Train Acc: 1.0000 |
# Epoch [179/200] | Train Loss: 0.0075, Train Acc: 1.0000 |
# Epoch [180/200] | Train Loss: 0.0058, Train Acc: 1.0000 |
# Epoch [181/200] | Train Loss: 0.0119, Train Acc: 0.9934 |
# Epoch [182/200] | Train Loss: 0.0056, Train Acc: 1.0000 |
# Epoch [183/200] | Train Loss: 0.0152, Train Acc: 0.9934 |
# Epoch [184/200] | Train Loss: 0.0061, Train Acc: 1.0000 |
# Epoch [185/200] | Train Loss: 0.0082, Train Acc: 1.0000 |
# Epoch [186/200] | Train Loss: 0.0056, Train Acc: 1.0000 |
# Epoch [187/200] | Train Loss: 0.0068, Train Acc: 1.0000 |
# Epoch [188/200] | Train Loss: 0.0059, Train Acc: 1.0000 |
# Epoch [189/200] | Train Loss: 0.0057, Train Acc: 1.0000 |
# Epoch [190/200] | Train Loss: 0.0057, Train Acc: 1.0000 |
# Epoch [191/200] | Train Loss: 0.0091, Train Acc: 1.0000 |
# Epoch [192/200] | Train Loss: 0.0063, Train Acc: 1.0000 |
# Epoch [193/200] | Train Loss: 0.0068, Train Acc: 1.0000 |
# Epoch [194/200] | Train Loss: 0.0099, Train Acc: 1.0000 |
# Epoch [195/200] | Train Loss: 0.0060, Train Acc: 1.0000 |
# Epoch [196/200] | Train Loss: 0.0057, Train Acc: 1.0000 |
# Epoch 00197: reducing learning rate of group 0 to 1.0000e-07.
# Epoch [197/200] | Train Loss: 0.0060, Train Acc: 1.0000 |
# Epoch [198/200] | Train Loss: 0.0057, Train Acc: 1.0000 |
# Epoch [199/200] | Train Loss: 0.0075, Train Acc: 1.0000 |
# Epoch [200/200] | Train Loss: 0.0059, Train Acc: 1.0000 |
# Test Loss: 1.1985, Test Accuracy: 0.7368, Test AUC: 0.7784
#
# --- Processing: psd_fc_gamma ---
# Shape: (190, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.8343, Train Acc: 0.5132 |
# Epoch [2/200] | Train Loss: 0.7043, Train Acc: 0.4934 |
# Epoch [3/200] | Train Loss: 0.7095, Train Acc: 0.5000 |
# Epoch [4/200] | Train Loss: 0.7385, Train Acc: 0.4803 |
# Epoch [5/200] | Train Loss: 0.7039, Train Acc: 0.5000 |
# Epoch [6/200] | Train Loss: 0.7000, Train Acc: 0.5000 |
# Epoch [7/200] | Train Loss: 0.6802, Train Acc: 0.6513 |
# Epoch [8/200] | Train Loss: 0.6729, Train Acc: 0.5592 |
# Epoch [9/200] | Train Loss: 0.6295, Train Acc: 0.7566 |
# Epoch [10/200] | Train Loss: 0.5403, Train Acc: 0.7763 |
# Epoch [11/200] | Train Loss: 0.4668, Train Acc: 0.8092 |
# Epoch [12/200] | Train Loss: 0.4254, Train Acc: 0.8289 |
# Epoch [13/200] | Train Loss: 0.4553, Train Acc: 0.7961 |
# Epoch [14/200] | Train Loss: 0.4604, Train Acc: 0.8092 |
# Epoch [15/200] | Train Loss: 0.3917, Train Acc: 0.8158 |
# Epoch [16/200] | Train Loss: 0.2878, Train Acc: 0.8750 |
# Epoch [17/200] | Train Loss: 0.2769, Train Acc: 0.8947 |
# Epoch [18/200] | Train Loss: 0.2427, Train Acc: 0.9145 |
# Epoch [19/200] | Train Loss: 0.2796, Train Acc: 0.8618 |
# Epoch [20/200] | Train Loss: 0.2643, Train Acc: 0.8750 |
# Epoch [21/200] | Train Loss: 0.2914, Train Acc: 0.8750 |
# Epoch [22/200] | Train Loss: 0.1930, Train Acc: 0.9276 |
# Epoch [23/200] | Train Loss: 0.1479, Train Acc: 0.9605 |
# Epoch [24/200] | Train Loss: 0.1834, Train Acc: 0.9474 |
# Epoch [25/200] | Train Loss: 0.1015, Train Acc: 0.9671 |
# Epoch [26/200] | Train Loss: 0.1168, Train Acc: 0.9474 |
# Epoch [27/200] | Train Loss: 0.0987, Train Acc: 0.9605 |
# Epoch [28/200] | Train Loss: 0.0888, Train Acc: 0.9737 |
# Epoch [29/200] | Train Loss: 0.0499, Train Acc: 0.9868 |
# Epoch [30/200] | Train Loss: 0.0701, Train Acc: 0.9868 |
# Epoch [31/200] | Train Loss: 0.0163, Train Acc: 1.0000 |
# Epoch [32/200] | Train Loss: 0.0783, Train Acc: 0.9671 |
# Epoch [33/200] | Train Loss: 0.2823, Train Acc: 0.9079 |
# Epoch [34/200] | Train Loss: 0.3626, Train Acc: 0.8421 |
# Epoch [35/200] | Train Loss: 0.2259, Train Acc: 0.9013 |
# Epoch [36/200] | Train Loss: 0.2183, Train Acc: 0.9079 |
# Epoch [37/200] | Train Loss: 0.1642, Train Acc: 0.9276 |
# Epoch [38/200] | Train Loss: 0.0853, Train Acc: 0.9671 |
# Epoch [39/200] | Train Loss: 0.0910, Train Acc: 0.9737 |
# Epoch [40/200] | Train Loss: 0.0366, Train Acc: 0.9934 |
# Epoch [41/200] | Train Loss: 0.0182, Train Acc: 1.0000 |
# Epoch 00042: reducing learning rate of group 0 to 1.0000e-04.
# Epoch [42/200] | Train Loss: 0.0262, Train Acc: 0.9868 |
# Epoch [43/200] | Train Loss: 0.0107, Train Acc: 1.0000 |
# Epoch [44/200] | Train Loss: 0.0140, Train Acc: 1.0000 |
# Epoch [45/200] | Train Loss: 0.0110, Train Acc: 1.0000 |
# Epoch [46/200] | Train Loss: 0.0100, Train Acc: 1.0000 |
# Epoch [47/200] | Train Loss: 0.0099, Train Acc: 1.0000 |
# Epoch [48/200] | Train Loss: 0.0090, Train Acc: 1.0000 |
# Epoch [49/200] | Train Loss: 0.0110, Train Acc: 1.0000 |
# Epoch [50/200] | Train Loss: 0.0116, Train Acc: 1.0000 |
# Epoch [51/200] | Train Loss: 0.0092, Train Acc: 1.0000 |
# Epoch [52/200] | Train Loss: 0.0087, Train Acc: 1.0000 |
# Epoch [53/200] | Train Loss: 0.0084, Train Acc: 1.0000 |
# Epoch [54/200] | Train Loss: 0.0089, Train Acc: 1.0000 |
# Epoch [55/200] | Train Loss: 0.0083, Train Acc: 1.0000 |
# Epoch [56/200] | Train Loss: 0.0138, Train Acc: 0.9934 |
# Epoch [57/200] | Train Loss: 0.0087, Train Acc: 1.0000 |
# Epoch [58/200] | Train Loss: 0.0082, Train Acc: 1.0000 |
# Epoch [59/200] | Train Loss: 0.0081, Train Acc: 1.0000 |
# Epoch [60/200] | Train Loss: 0.0169, Train Acc: 0.9934 |
# Epoch [61/200] | Train Loss: 0.0093, Train Acc: 1.0000 |
# Epoch [62/200] | Train Loss: 0.0123, Train Acc: 0.9934 |
# Epoch [63/200] | Train Loss: 0.0079, Train Acc: 1.0000 |
# Epoch [64/200] | Train Loss: 0.0075, Train Acc: 1.0000 |
# Epoch [65/200] | Train Loss: 0.0081, Train Acc: 1.0000 |
# Epoch [66/200] | Train Loss: 0.0074, Train Acc: 1.0000 |
# Epoch [67/200] | Train Loss: 0.0066, Train Acc: 1.0000 |
# Epoch [68/200] | Train Loss: 0.0067, Train Acc: 1.0000 |
# Epoch [69/200] | Train Loss: 0.0136, Train Acc: 0.9934 |
# Epoch [70/200] | Train Loss: 0.0065, Train Acc: 1.0000 |
# Epoch [71/200] | Train Loss: 0.0066, Train Acc: 1.0000 |
# Epoch [72/200] | Train Loss: 0.0066, Train Acc: 1.0000 |
# Epoch [73/200] | Train Loss: 0.0060, Train Acc: 1.0000 |
# Epoch [74/200] | Train Loss: 0.0063, Train Acc: 1.0000 |
# Epoch [75/200] | Train Loss: 0.0057, Train Acc: 1.0000 |
# Epoch [76/200] | Train Loss: 0.0060, Train Acc: 1.0000 |
# Epoch [77/200] | Train Loss: 0.0056, Train Acc: 1.0000 |
# Epoch [78/200] | Train Loss: 0.0064, Train Acc: 1.0000 |
# Epoch [79/200] | Train Loss: 0.0057, Train Acc: 1.0000 |
# Epoch [80/200] | Train Loss: 0.0053, Train Acc: 1.0000 |
# Epoch [81/200] | Train Loss: 0.0065, Train Acc: 1.0000 |
# Epoch [82/200] | Train Loss: 0.0055, Train Acc: 1.0000 |
# Epoch [83/200] | Train Loss: 0.0054, Train Acc: 1.0000 |
# Epoch [84/200] | Train Loss: 0.0052, Train Acc: 1.0000 |
# Epoch [85/200] | Train Loss: 0.0051, Train Acc: 1.0000 |
# Epoch [86/200] | Train Loss: 0.0050, Train Acc: 1.0000 |
# Epoch [87/200] | Train Loss: 0.0051, Train Acc: 1.0000 |
# Epoch [88/200] | Train Loss: 0.0049, Train Acc: 1.0000 |
# Epoch [89/200] | Train Loss: 0.0049, Train Acc: 1.0000 |
# Epoch [90/200] | Train Loss: 0.0048, Train Acc: 1.0000 |
# Epoch [91/200] | Train Loss: 0.0052, Train Acc: 1.0000 |
# Epoch [92/200] | Train Loss: 0.0049, Train Acc: 1.0000 |
# Epoch [93/200] | Train Loss: 0.0047, Train Acc: 1.0000 |
# Epoch [94/200] | Train Loss: 0.0046, Train Acc: 1.0000 |
# Epoch [95/200] | Train Loss: 0.0046, Train Acc: 1.0000 |
# Epoch [96/200] | Train Loss: 0.0046, Train Acc: 1.0000 |
# Epoch [97/200] | Train Loss: 0.0045, Train Acc: 1.0000 |
# Epoch [98/200] | Train Loss: 0.0045, Train Acc: 1.0000 |
# Epoch [99/200] | Train Loss: 0.0047, Train Acc: 1.0000 |
# Epoch [100/200] | Train Loss: 0.0043, Train Acc: 1.0000 |
# Epoch [101/200] | Train Loss: 0.0043, Train Acc: 1.0000 |
# Epoch [102/200] | Train Loss: 0.0045, Train Acc: 1.0000 |
# Epoch [103/200] | Train Loss: 0.0041, Train Acc: 1.0000 |
# Epoch [104/200] | Train Loss: 0.0042, Train Acc: 1.0000 |
# Epoch [105/200] | Train Loss: 0.0041, Train Acc: 1.0000 |
# Epoch [106/200] | Train Loss: 0.0043, Train Acc: 1.0000 |
# Epoch [107/200] | Train Loss: 0.0041, Train Acc: 1.0000 |
# Epoch [108/200] | Train Loss: 0.0039, Train Acc: 1.0000 |
# Epoch [109/200] | Train Loss: 0.0040, Train Acc: 1.0000 |
# Epoch [110/200] | Train Loss: 0.0041, Train Acc: 1.0000 |
# Epoch [111/200] | Train Loss: 0.0040, Train Acc: 1.0000 |
# Epoch [112/200] | Train Loss: 0.0039, Train Acc: 1.0000 |
# Epoch [113/200] | Train Loss: 0.0038, Train Acc: 1.0000 |
# Epoch [114/200] | Train Loss: 0.0038, Train Acc: 1.0000 |
# Epoch [115/200] | Train Loss: 0.0041, Train Acc: 1.0000 |
# Epoch [116/200] | Train Loss: 0.0037, Train Acc: 1.0000 |
# Epoch [117/200] | Train Loss: 0.0037, Train Acc: 1.0000 |
# Epoch [118/200] | Train Loss: 0.0036, Train Acc: 1.0000 |
# Epoch [119/200] | Train Loss: 0.0038, Train Acc: 1.0000 |
# Epoch [120/200] | Train Loss: 0.0036, Train Acc: 1.0000 |
# Epoch [121/200] | Train Loss: 0.0037, Train Acc: 1.0000 |
# Epoch [122/200] | Train Loss: 0.0037, Train Acc: 1.0000 |
# Epoch [123/200] | Train Loss: 0.0034, Train Acc: 1.0000 |
# Epoch [124/200] | Train Loss: 0.0034, Train Acc: 1.0000 |
# Epoch [125/200] | Train Loss: 0.0035, Train Acc: 1.0000 |
# Epoch [126/200] | Train Loss: 0.0033, Train Acc: 1.0000 |
# Epoch [127/200] | Train Loss: 0.0035, Train Acc: 1.0000 |
# Epoch [128/200] | Train Loss: 0.0035, Train Acc: 1.0000 |
# Epoch [129/200] | Train Loss: 0.0032, Train Acc: 1.0000 |
# Epoch [130/200] | Train Loss: 0.0033, Train Acc: 1.0000 |
# Epoch [131/200] | Train Loss: 0.0032, Train Acc: 1.0000 |
# Epoch [132/200] | Train Loss: 0.0032, Train Acc: 1.0000 |
# Epoch [133/200] | Train Loss: 0.0032, Train Acc: 1.0000 |
# Epoch [134/200] | Train Loss: 0.0030, Train Acc: 1.0000 |
# Epoch [135/200] | Train Loss: 0.0031, Train Acc: 1.0000 |
# Epoch [136/200] | Train Loss: 0.0031, Train Acc: 1.0000 |
# Epoch [137/200] | Train Loss: 0.0030, Train Acc: 1.0000 |
# Epoch [138/200] | Train Loss: 0.0030, Train Acc: 1.0000 |
# Epoch [139/200] | Train Loss: 0.0031, Train Acc: 1.0000 |
# Epoch [140/200] | Train Loss: 0.0030, Train Acc: 1.0000 |
# Epoch [141/200] | Train Loss: 0.0029, Train Acc: 1.0000 |
# Epoch [142/200] | Train Loss: 0.0029, Train Acc: 1.0000 |
# Epoch [143/200] | Train Loss: 0.0028, Train Acc: 1.0000 |
# Epoch [144/200] | Train Loss: 0.0028, Train Acc: 1.0000 |
# Epoch [145/200] | Train Loss: 0.0029, Train Acc: 1.0000 |
# Epoch [146/200] | Train Loss: 0.0031, Train Acc: 1.0000 |
# Epoch [147/200] | Train Loss: 0.0027, Train Acc: 1.0000 |
# Epoch [148/200] | Train Loss: 0.0027, Train Acc: 1.0000 |
# Epoch [149/200] | Train Loss: 0.0028, Train Acc: 1.0000 |
# Epoch [150/200] | Train Loss: 0.0027, Train Acc: 1.0000 |
# Epoch [151/200] | Train Loss: 0.0026, Train Acc: 1.0000 |
# Epoch [152/200] | Train Loss: 0.0027, Train Acc: 1.0000 |
# Epoch [153/200] | Train Loss: 0.0027, Train Acc: 1.0000 |
# Epoch [154/200] | Train Loss: 0.0026, Train Acc: 1.0000 |
# Epoch [155/200] | Train Loss: 0.0026, Train Acc: 1.0000 |
# Epoch [156/200] | Train Loss: 0.0028, Train Acc: 1.0000 |
# Epoch [157/200] | Train Loss: 0.0025, Train Acc: 1.0000 |
# Epoch [158/200] | Train Loss: 0.0026, Train Acc: 1.0000 |
# Epoch [159/200] | Train Loss: 0.0028, Train Acc: 1.0000 |
# Epoch [160/200] | Train Loss: 0.0074, Train Acc: 0.9934 |
# Epoch [161/200] | Train Loss: 0.0025, Train Acc: 1.0000 |
# Epoch [162/200] | Train Loss: 0.0026, Train Acc: 1.0000 |
# Epoch [163/200] | Train Loss: 0.0029, Train Acc: 1.0000 |
# Epoch [164/200] | Train Loss: 0.0027, Train Acc: 1.0000 |
# Epoch [165/200] | Train Loss: 0.0219, Train Acc: 0.9934 |
# Epoch [166/200] | Train Loss: 0.0024, Train Acc: 1.0000 |
# Epoch [167/200] | Train Loss: 0.0024, Train Acc: 1.0000 |
# Epoch [168/200] | Train Loss: 0.0045, Train Acc: 1.0000 |
# Epoch [169/200] | Train Loss: 0.0024, Train Acc: 1.0000 |
# Epoch [170/200] | Train Loss: 0.0024, Train Acc: 1.0000 |
# Epoch [171/200] | Train Loss: 0.0024, Train Acc: 1.0000 |
# Epoch [172/200] | Train Loss: 0.0024, Train Acc: 1.0000 |
# Epoch [173/200] | Train Loss: 0.0023, Train Acc: 1.0000 |
# Epoch [174/200] | Train Loss: 0.0023, Train Acc: 1.0000 |
# Epoch [175/200] | Train Loss: 0.0023, Train Acc: 1.0000 |
# Epoch [176/200] | Train Loss: 0.0023, Train Acc: 1.0000 |
# Epoch [177/200] | Train Loss: 0.0025, Train Acc: 1.0000 |
# Epoch [178/200] | Train Loss: 0.0023, Train Acc: 1.0000 |
# Epoch [179/200] | Train Loss: 0.0022, Train Acc: 1.0000 |
# Epoch [180/200] | Train Loss: 0.0024, Train Acc: 1.0000 |
# Epoch [181/200] | Train Loss: 0.0025, Train Acc: 1.0000 |
# Epoch [182/200] | Train Loss: 0.0021, Train Acc: 1.0000 |
# Epoch [183/200] | Train Loss: 0.0021, Train Acc: 1.0000 |
# Epoch [184/200] | Train Loss: 0.0022, Train Acc: 1.0000 |
# Epoch [185/200] | Train Loss: 0.0022, Train Acc: 1.0000 |
# Epoch [186/200] | Train Loss: 0.0021, Train Acc: 1.0000 |
# Epoch [187/200] | Train Loss: 0.0022, Train Acc: 1.0000 |
# Epoch [188/200] | Train Loss: 0.0021, Train Acc: 1.0000 |
# Epoch [189/200] | Train Loss: 0.0021, Train Acc: 1.0000 |
# Epoch [190/200] | Train Loss: 0.0020, Train Acc: 1.0000 |
# Epoch [191/200] | Train Loss: 0.0021, Train Acc: 1.0000 |
# Epoch [192/200] | Train Loss: 0.0020, Train Acc: 1.0000 |
# Epoch [193/200] | Train Loss: 0.0020, Train Acc: 1.0000 |
# Epoch [194/200] | Train Loss: 0.0020, Train Acc: 1.0000 |
# Epoch [195/200] | Train Loss: 0.0020, Train Acc: 1.0000 |
# Epoch [196/200] | Train Loss: 0.0019, Train Acc: 1.0000 |
# Epoch [197/200] | Train Loss: 0.0019, Train Acc: 1.0000 |
# Epoch [198/200] | Train Loss: 0.0020, Train Acc: 1.0000 |
# Epoch [199/200] | Train Loss: 0.0019, Train Acc: 1.0000 |
# Epoch [200/200] | Train Loss: 0.0020, Train Acc: 1.0000 |
# Test Loss: 1.2579, Test Accuracy: 0.7895, Test AUC: 0.8670

# %% [markdown]
# ## | 6. Results

# %%
rows = []

for disorder, dicts in all_results.items():
    for dict_name, df_results in dicts.items():
        for df_name, metrics in df_results.items():
            row = {
                'Disorder': disorder,
                'Dict': dict_name,
                'DataFrame': df_name,
                'Accuracy': metrics['accuracy'],
                'AUC': metrics['auc'],
                'Classification Report': metrics['classification_report']
            }
            
            rows.append(row)

results_df = pd.DataFrame(rows)
results_df.to_csv(f'{experiment_name}.csv', index=False)
results_df
# best_results = df.loc[df.groupby('Disorder')['Accuracy'].idxmax()]
# Out:
#                     Disorder                      Dict         DataFrame  \
# 0      Acute stress disorder     df_dict_psd_all_bands     psd_all_bands
# 1      Acute stress disorder      df_dict_fc_all_bands      fc_all_bands
# 2      Acute stress disorder  df_dict_psd_fc_all_bands  psd_fc_all_bands
# 3      Acute stress disorder          df_dict_psd_band         psd_delta
# 4      Acute stress disorder          df_dict_psd_band         psd_theta
# ..                       ...                       ...               ...
# 184  Social anxiety disorder       df_dict_psd_fc_band      psd_fc_theta
# 185  Social anxiety disorder       df_dict_psd_fc_band      psd_fc_alpha
# 186  Social anxiety disorder       df_dict_psd_fc_band       psd_fc_beta
# 187  Social anxiety disorder       df_dict_psd_fc_band   psd_fc_highbeta
# 188  Social anxiety disorder       df_dict_psd_fc_band      psd_fc_gamma
#
#      Accuracy       AUC                              Classification Report
# 0    0.921053  0.927978                precision    recall  f1-score   ...
# 1    0.789474  0.889197                precision    recall  f1-score   ...
# 2    0.868421  0.908587                precision    recall  f1-score   ...
# 3    0.868421  0.922438                precision    recall  f1-score   ...
# 4    0.763158  0.811634                precision    recall  f1-score   ...
# ..        ...       ...                                                ...
# 184  0.789474  0.844875                precision    recall  f1-score   ...
# 185  0.684211  0.803324                precision    recall  f1-score   ...
# 186  0.789474  0.869806                precision    recall  f1-score   ...
# 187  0.736842  0.778393                precision    recall  f1-score   ...
# 188  0.789474  0.867036                precision    recall  f1-score   ...
#
# [189 rows x 6 columns]

# %% [markdown]
# ## | 7. Conclusions, Problems, and Limitations

# %% [markdown]
# [need to update]
