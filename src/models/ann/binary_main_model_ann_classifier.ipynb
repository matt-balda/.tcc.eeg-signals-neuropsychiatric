# %% [markdown]
# | Description
#
# Authors of notebook: Mateus Balda and Alessandro Bof
#
# Reference paper and dataset: https://www.frontiersin.org/journals/psychiatry/articles/10.3389/fpsyt.2021.707581/full
#
# | Notebook structure
# 0. Setup and Imports
# 1. Utility Functions
# 2. Data Loading and Preprocessing
# 3. Data Preparation for Training
# 4. Model Definition
# 5. Training and Evaluation
# 6. Results
# 7. Conclusions, Problems, and Limitations
#
# | Training
# 1. Binary classification for `y` main.disorder (Disorder vs. Health control)
# 2. Balancing using BorderlineSMOTE for minority classes
# 3. Training across the 21 subsets

# %% [markdown]
# ## | 0. Setup and Imports

# %%
# !pip install -q imbalanced-learn==0.12.4;

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from IPython.display import FileLink, display, HTML
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.impute import KNNImputer

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau

from imblearn.over_sampling import BorderlineSMOTE

from warnings import filterwarnings
filterwarnings('ignore')

torch.__version__
# Out:
# '2.5.1+cu124'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
experiment_name = "binary_classification_main_disorder_ann"
device
# Out:
# device(type='cuda')

# %%
np.random.seed(123)
torch.manual_seed(123)

# %% [markdown]
# ## | 1. Utility Functions

# %% [markdown]
# ### 1. OUTLIERS

# %%
def detect_outliers_summary(df):
    outliers_summary = {}

    for col in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_limit = Q1 - 1.5 * IQR
        upper_limit = Q3 + 1.5 * IQR

        outliers = df[(df[col] < lower_limit) | (df[col] > upper_limit)][col]
        
        outliers_summary[col] = {
            'num_outliers': len(outliers),
            'percent_outliers': len(outliers) / len(df) * 100,
            'outliers': outliers.tolist(),
            'lower_limit': lower_limit,
            'upper_limit': upper_limit
        }

    return pd.DataFrame(outliers_summary).T


def treat_all_outliers_iqr(df, factor=1.5):
    df_treated = df.copy()
    
    for column in df_treated.select_dtypes(include=[np.number]).columns:
        Q1 = np.percentile(df_treated[column], 25)
        Q3 = np.percentile(df_treated[column], 75)
        IQR = Q3 - Q1

        lower_bound = Q1 - factor * IQR
        upper_bound = Q3 + factor * IQR

        df_treated[column] = np.clip(df_treated[column], lower_bound, upper_bound)

    return df_treated

# %% [markdown]
# ### 2. NANS

# %%
def remove_missing_columns(df, threshold=0.5):
    limit = int(threshold * len(df))
    df = df.dropna(thresh=limit, axis=1)
    return df
    
def find_most_null_column(df, threshold=0.5):
    null_ratios = df.isnull().mean()
    for col, ration in null_ratios.items():
        if ration > threshold:
            return col
    return None

def analyze_missing_values(df):
    missing_values = df.isnull().sum()
    missing_values = missing_values[missing_values > 0]
    total_number_nans = df.isnull().sum().sum()
    
    return missing_values, total_number_nans

def handle_nans(df):
    columns_with_nans = df.columns[df.isnull().any()].tolist()
    
    knn_imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
    
    df_imputed = pd.DataFrame(knn_imputer.fit_transform(df[columns_with_nans]),
                                columns=columns_with_nans)
    
    df[columns_with_nans] = df_imputed[columns_with_nans]
    
    return df

# %% [markdown]
# ### 3. SETS & SUBSETS

# %%
class Sets:
    # AB = PSD (Power Spectral Density) 19 * 6
    # COH = FC (Functional Connectivity) 171 * 6
    
    def __init__(self, dataframe: pd.DataFrame):
        
        if not isinstance(dataframe, pd.DataFrame):
            raise ValueError("The parameter must be a pandas DataFrame")
        
        self.df = dataframe.copy()
        self.df_ab_psd = None
        self.df_coh_fc = None
        self.df_ab_psd_coh_fc = None
        
        self.__create_df_psd()
        self.__create_df_fc()
        self.__create_union_psd_fc()

    # 19 (6 bands)
    def __create_df_psd(self):
        columns_AB = [col for col in self.df.columns if col.startswith('AB')]
        self.df_ab_psd = self.df[columns_AB]
    
    # 171 (6 bands)
    def __create_df_fc(self):
        columns_COH = [col for col in self.df.columns if col.startswith('COH')]
        self.df_coh_fc = self.df[columns_COH]
        
    def __create_union_psd_fc(self):
        if self.df_ab_psd is not None and self.df_coh_fc is not None:
            self.df_ab_psd_coh_fc = pd.concat([self.df_ab_psd, self.df_coh_fc], axis=1)
        else:
            raise ValueError("Subsets AB and COH were not created correctly")

    def create_dfs_bands(self, bands: list[str] = None, df: pd.DataFrame = None):
        dfs_bands = {}
        
        if bands is None:
            bands = ['delta', 'theta', 'alpha', 'beta', 'highbeta','gamma']
        
        for band in bands:
            columns_band = [col for col in df.columns if f'.{band}.' in col]
            if columns_band:
                dfs_bands[band] = df[columns_band]
        
        return dfs_bands

# %% [markdown]
# ## | 2. Data Loading and Preprocessing

# %%
df = pd.read_csv('../input/eeg-psychiatric-disorders-dataset/EEG.machinelearing_data_BRMH.csv')
df.shape
# Out:
# (945, 1149)

# %%
# Checking / imputing Nan

output1 = analyze_missing_values(df)
output2 = find_most_null_column(df)
df = remove_missing_columns(df)
output3 = analyze_missing_values(df)
df = handle_nans(df)

display(output1)
display(HTML('<hr>'))
display(output2)
display(HTML('<hr>'))
display(output3)
display(df.shape)
display(HTML('<hr>'))
display(df.isna().sum().sum())
display(df)
# Out:
# (education        15
#  IQ               13
#  Unnamed: 122    945
#  dtype: int64,
#  973)
# <hr>
# 'Unnamed: 122'
# <hr>
# (education    15
#  IQ           13
#  dtype: int64,
#  28)
# (945, 1148)
# <hr>
# 0
#      no. sex   age    eeg.date  education          IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30   13.43871  101.580472  Addictive disorder
# 1      2   M  37.0    2012.9.6    6.00000  120.000000  Addictive disorder
# 2      3   M  32.0   2012.9.10   16.00000  113.000000  Addictive disorder
# 3      4   M  35.0   2012.10.8   18.00000  126.000000  Addictive disorder
# 4      5   M  36.0  2012.10.18   16.00000  112.000000  Addictive disorder
# ..   ...  ..   ...         ...        ...         ...                 ...
# 940  941   M  22.0   2014.8.28   13.00000  116.000000     Healthy control
# 941  942   M  26.0   2014.9.19   13.00000  118.000000     Healthy control
# 942  943   M  26.0   2014.9.27   16.00000  113.000000     Healthy control
# 943  944   M  24.0   2014.9.20   13.00000  107.000000     Healthy control
# 944  945   M  21.0  2015.10.23   13.00000  105.000000     Healthy control
#
#         specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0    Alcohol use disorder         35.998557         21.717375  ...
# 1    Alcohol use disorder         13.425118         11.002916  ...
# 2    Alcohol use disorder         29.941780         27.544684  ...
# 3    Alcohol use disorder         21.496226         21.846832  ...
# 4    Alcohol use disorder         37.775667         33.607679  ...
# ..                    ...               ...               ...  ...
# 940       Healthy control         41.851823         36.771496  ...
# 941       Healthy control         18.986856         19.401387  ...
# 942       Healthy control         28.781317         32.369230  ...
# 943       Healthy control         19.929100         25.196375  ...
# 944       Healthy control         65.195346         69.241972  ...
#
#      COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0                55.989192              16.739679              23.452271
# 1                45.595619              17.510824              26.777368
# 2                99.475453              70.654171              39.131547
# 3                59.986561              63.822201              36.478254
# 4                61.462720              59.166097              51.465531
# ..                     ...                    ...                    ...
# 940              82.905657              34.850706              63.970519
# 941              65.917918              66.700117              44.756285
# 942              61.040959              27.632209              45.552852
# 943              99.113664              48.328934              41.248470
# 944              78.600293              68.255430              70.687410
#
#      COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                45.678820              30.167520              16.918761
# 1                28.201062              57.108861              32.375401
# 2                69.920996              71.063644              38.534505
# 3                47.117006              84.658376              24.724096
# 4                58.635415              80.685608              62.138436
# ..                     ...                    ...                    ...
# 940              63.982003              51.244725              62.203684
# 941              49.787513              98.905995              54.021304
# 942              33.638817              46.690983              19.382928
# 943              28.192238              48.665743              42.007147
# 944              74.433908              74.294750              53.254681
#
#      COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                48.850427               9.422630              34.507082
# 1                60.351749              13.900981              57.831848
# 2                69.908764              27.180532              64.803155
# 3                50.299349              35.319695              79.822944
# 4                75.888749              61.003944              87.455509
# ..                     ...                    ...                    ...
# 940              62.062237              31.013031              31.183413
# 941              93.902401              52.740396              92.807331
# 942              41.050717               7.045821              41.962451
# 943              28.735945              27.176500              27.529522
# 944              72.755265              47.810386              80.166825
#
#      COH.F.gamma.r.O1.s.O2
# 0                28.613029
# 1                43.463261
# 2                31.485799
# 3                41.141873
# 4                70.531662
# ..                     ...
# 940              98.325230
# 941              56.320868
# 942              19.092111
# 943              20.028446
# 944              64.380273
#
# [945 rows x 1148 columns]

# %%
# detecting outliers

outliers_summary = detect_outliers_summary(df)
outliers_summary.to_csv('outliers_summary.csv', index=True)
outliers_summary['num_outliers'].sum()
# Out:
# 26452

# %%
label_encoder = LabelEncoder()
target_name = 'main.disorder'

X = df.iloc[:,8:]
target = df[target_name]

quantitative_features = df.loc[:, ['age', 'education', 'IQ']]

sex = df['sex']
sex_encoded = label_encoder.fit_transform(sex)
sex_encoded = pd.Series(sex_encoded, name='sex')

X = pd.concat([quantitative_features, sex_encoded, X], axis=1)

X.shape, target.shape, quantitative_features.shape, sex.shape
# Out:
# ((945, 1144), (945,), (945, 3), (945,))

# %%
disorders = np.unique(target).tolist()
disorders.remove('Healthy control')
disorders
# Out:
# ['Addictive disorder',
#  'Anxiety disorder',
#  'Mood disorder',
#  'Obsessive compulsive disorder',
#  'Schizophrenia',
#  'Trauma and stress related disorder']

# %%
X_concated = pd.concat([X, target], axis=1)

display(X.head())
display(X_concated.head())
display(X.isna().sum().sum())
display(X_concated.isna().sum().sum())
# Out:
#     age  education          IQ  sex  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0  57.0   13.43871  101.580472    1         35.998557         21.717375
# 1  37.0    6.00000  120.000000    1         13.425118         11.002916
# 2  32.0   16.00000  113.000000    1         29.941780         27.544684
# 3  35.0   18.00000  126.000000    1         21.496226         21.846832
# 4  36.0   16.00000  112.000000    1         37.775667         33.607679
#
#    AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  ...  \
# 0        21.518280        26.825048        26.611516        25.732649  ...
# 1        11.942516        15.272216        14.151570        12.456034  ...
# 2        17.150159        23.608960        27.087811        13.541237  ...
# 3        17.364316        13.833701        14.100954        13.100939  ...
# 4        21.865556        21.771413        22.854536        21.456377  ...
#
#    COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0              55.989192              16.739679              23.452271
# 1              45.595619              17.510824              26.777368
# 2              99.475453              70.654171              39.131547
# 3              59.986561              63.822201              36.478254
# 4              61.462720              59.166097              51.465531
#
#    COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0              45.678820              30.167520              16.918761
# 1              28.201062              57.108861              32.375401
# 2              69.920996              71.063644              38.534505
# 3              47.117006              84.658376              24.724096
# 4              58.635415              80.685608              62.138436
#
#    COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0              48.850427               9.422630              34.507082
# 1              60.351749              13.900981              57.831848
# 2              69.908764              27.180532              64.803155
# 3              50.299349              35.319695              79.822944
# 4              75.888749              61.003944              87.455509
#
#    COH.F.gamma.r.O1.s.O2
# 0              28.613029
# 1              43.463261
# 2              31.485799
# 3              41.141873
# 4              70.531662
#
# [5 rows x 1144 columns]
#     age  education          IQ  sex  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0  57.0   13.43871  101.580472    1         35.998557         21.717375
# 1  37.0    6.00000  120.000000    1         13.425118         11.002916
# 2  32.0   16.00000  113.000000    1         29.941780         27.544684
# 3  35.0   18.00000  126.000000    1         21.496226         21.846832
# 4  36.0   16.00000  112.000000    1         37.775667         33.607679
#
#    AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  ...  \
# 0        21.518280        26.825048        26.611516        25.732649  ...
# 1        11.942516        15.272216        14.151570        12.456034  ...
# 2        17.150159        23.608960        27.087811        13.541237  ...
# 3        17.364316        13.833701        14.100954        13.100939  ...
# 4        21.865556        21.771413        22.854536        21.456377  ...
#
#    COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  COH.F.gamma.o.Pz.s.O2  \
# 0              16.739679              23.452271              45.678820
# 1              17.510824              26.777368              28.201062
# 2              70.654171              39.131547              69.920996
# 3              63.822201              36.478254              47.117006
# 4              59.166097              51.465531              58.635415
#
#    COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  COH.F.gamma.p.P4.s.O2  \
# 0              30.167520              16.918761              48.850427
# 1              57.108861              32.375401              60.351749
# 2              71.063644              38.534505              69.908764
# 3              84.658376              24.724096              50.299349
# 4              80.685608              62.138436              75.888749
#
#    COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  COH.F.gamma.r.O1.s.O2  \
# 0               9.422630              34.507082              28.613029
# 1              13.900981              57.831848              43.463261
# 2              27.180532              64.803155              31.485799
# 3              35.319695              79.822944              41.141873
# 4              61.003944              87.455509              70.531662
#
#         main.disorder
# 0  Addictive disorder
# 1  Addictive disorder
# 2  Addictive disorder
# 3  Addictive disorder
# 4  Addictive disorder
#
# [5 rows x 1145 columns]
# 0
# 0

# %%
# treat outliers X_concated

X = treat_all_outliers_iqr(X, factor=1.5)
outliers_summary = detect_outliers_summary(X)
outliers_summary['num_outliers'].sum()
# Out:
# 0

# %%
binary_datasets = {}

for disorder in disorders:
    
    mask = X_concated[target_name].isin(['Healthy control', disorder])
    
    df_filtered = X_concated[mask]
    df_filtered_X = X.loc[mask]
    
    y_binary = df_filtered[target_name].apply(lambda x: 0 if x == 'Healthy control' else 1)
    
    borderline_smote = BorderlineSMOTE(kind='borderline-2', random_state=42, k_neighbors=10, m_neighbors=15)
    X_resampled, y_resampled = borderline_smote.fit_resample(df_filtered_X, y_binary)
    
    dataset = pd.concat([X_resampled, y_resampled], axis=1)
    
    binary_datasets[disorder] = {
        'data': dataset,
        'labels': ['Healthy control', disorder]
    }

# %%
binary_datasets['Mood disorder']['data']
# Out:
#            age  education          IQ  sex  AB.A.delta.a.FP1  \
# 0    32.870000  16.000000  108.000000    0         12.159137
# 1    20.240000  12.000000  127.000000    0         12.404484
# 2    19.890000  13.000000  113.000000    0         16.573145
# 3    39.180000  16.000000  112.600000    0         26.650019
# 4    28.420000   9.000000   98.800000    0         14.624474
# ..         ...        ...         ...  ...               ...
# 527  29.859179  16.056555  129.547562    1         14.332130
# 528  29.536491  12.767765  122.175057    0         16.018351
# 529  27.580821  16.000000  114.744465    1         23.887229
# 530  21.262096  12.877715  104.755431    1         41.877695
# 531  28.310714  16.000000  120.808442    1         12.657177
#
#      AB.A.delta.b.FP2  AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  \
# 0           13.113503         9.031007        14.879389        15.834830
# 1            9.737819        13.925651        12.325169        15.130696
# 2           15.586708        14.094928        12.660197        12.979617
# 3           22.823161        17.942133        17.148214        15.338128
# 4           14.277301        11.099375        16.047926        17.851932
# ..                ...              ...              ...              ...
# 527         23.574633        11.045143        18.351897        16.785585
# 528         17.909770        13.825752        14.791642        18.013545
# 529         23.936216        16.964908        23.727482        27.984030
# 530         44.607081        34.711693        28.247273        35.248240
# 531         13.350691        11.046637        11.577865        18.406045
#
#      AB.A.delta.f.F4  ...  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0          19.595759  ...              59.590594              77.310851
# 1          10.292518  ...              53.402639              60.535899
# 2          10.611797  ...              20.062716              36.041763
# 3          14.571966  ...              83.045735              85.752150
# 4          17.165379  ...              58.218838              61.211830
# ..               ...  ...                    ...                    ...
# 527        19.659401  ...              31.533846              55.828495
# 528        20.968432  ...              86.092666              53.775009
# 529        22.996285  ...              65.154648              48.855452
# 530        36.466592  ...              68.056056              70.364430
# 531        18.524563  ...              61.770018              41.084526
#
#      COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                75.280467              57.311188              48.015594
# 1                73.838548              72.298636              43.330485
# 2                36.436509              47.491240              20.875426
# 3                85.875624              86.286859              79.520327
# 4                65.038486              76.899037              49.849540
# ..                     ...                    ...                    ...
# 527              45.141456              50.233665              45.187841
# 528              92.172863              90.911438              45.939741
# 529              65.079410              69.760110              47.340168
# 530              73.989504              74.344268              53.351700
# 531              58.721209              83.692158              48.329199
#
#      COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                59.579033              68.503920              82.885151
# 1                71.298037              23.109295              62.098128
# 2                53.747615               8.009907              50.202188
# 3                84.541455              82.452224              86.950905
# 4                71.791429              39.910653              82.739819
# ..                     ...                    ...                    ...
# 527              55.899282              19.821091              39.923730
# 528              88.578716              42.796943              85.889060
# 529              68.406285              31.144459              94.580466
# 530              72.497074              48.287194              79.983862
# 531              73.856083              48.508317              76.775900
#
#      COH.F.gamma.r.O1.s.O2  main.disorder
# 0                86.986191              1
# 1                67.749204              1
# 2                33.647889              1
# 3                87.384296              1
# 4                62.285969              1
# ..                     ...            ...
# 527              47.636457              0
# 528              55.994294              0
# 529              36.281022              0
# 530              64.618663              0
# 531              64.945388              0
#
# [532 rows x 1145 columns]

# %%
sets_binaries = {}

for disorder, bin_data in binary_datasets.items():
    df_bin = bin_data['data'].copy()
    
    X_bin = df_bin.drop(columns=[target_name,'age', 'education', 'IQ', 'sex'], errors='ignore') 
    X_quantitative = df_bin.loc[:, ['age', 'education', 'IQ', 'sex']]
    y_bin = df_bin[target_name] if target_name in df_bin.columns else df_bin.iloc[:, -1]

    sets = Sets(dataframe=X_bin)

    sets_binaries[disorder] = {
        'sets': sets,
        'labels': bin_data['labels'],
        'X_quantitative': X_quantitative,
        'y': y_bin
    }

# %%
for disorder in sets_binaries:
    sets = sets_binaries[disorder]['sets']

    dfs_bands_psd = sets.create_dfs_bands(df=sets.df_ab_psd)
    dfs_bands_fc = sets.create_dfs_bands(df=sets.df_coh_fc)
    dfs_bands_psd_fc = sets.create_dfs_bands(df=sets.df_ab_psd_coh_fc)

    sets_binaries[disorder].update({
        'dfs_bands_psd': dfs_bands_psd,
        'dfs_bands_fc': dfs_bands_fc,
        'dfs_bands_psd_fc': dfs_bands_psd_fc,
    })

# %%
for disorder, data in sets_binaries.items():
    print(f"Disorder: {disorder}")
    print(f"Labels: {data['labels']}")
    print(f"Number of samples: {len(data['y'])}")
    print(f"Quantitative features shape: {data['X_quantitative'].shape}")
    print(f"PSD bands shape: {data['sets'].df_ab_psd.shape}")
    print(f"FC bands shape: {data['sets'].df_coh_fc.shape}")
    print(f"PSD + FC bands shape: {data['sets'].df_ab_psd_coh_fc.shape}\n")
# Out:
# Disorder: Addictive disorder
# Labels: ['Healthy control', 'Addictive disorder']
# Number of samples: 372
# Quantitative features shape: (372, 4)
# PSD bands shape: (372, 114)
# FC bands shape: (372, 1026)
# PSD + FC bands shape: (372, 1140)
#
# Disorder: Anxiety disorder
# Labels: ['Healthy control', 'Anxiety disorder']
# Number of samples: 214
# Quantitative features shape: (214, 4)
# PSD bands shape: (214, 114)
# FC bands shape: (214, 1026)
# PSD + FC bands shape: (214, 1140)
#
# Disorder: Mood disorder
# Labels: ['Healthy control', 'Mood disorder']
# Number of samples: 532
# Quantitative features shape: (532, 4)
# PSD bands shape: (532, 114)
# FC bands shape: (532, 1026)
# PSD + FC bands shape: (532, 1140)
#
# Disorder: Obsessive compulsive disorder
# Labels: ['Healthy control', 'Obsessive compulsive disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Schizophrenia
# Labels: ['Healthy control', 'Schizophrenia']
# Number of samples: 234
# Quantitative features shape: (234, 4)
# PSD bands shape: (234, 114)
# FC bands shape: (234, 1026)
# PSD + FC bands shape: (234, 1140)
#
# Disorder: Trauma and stress related disorder
# Labels: ['Healthy control', 'Trauma and stress related disorder']
# Number of samples: 256
# Quantitative features shape: (256, 4)
# PSD bands shape: (256, 114)
# FC bands shape: (256, 1026)
# PSD + FC bands shape: (256, 1140)

# %%
dfs_dicts_binaries = {}

for disorder, data in sets_binaries.items():
    dfs_psd = data['dfs_bands_psd']
    dfs_fc = data['dfs_bands_fc']
    dfs_psd_fc = data['dfs_bands_psd_fc']
    sets = data['sets']

    df_dict_psd_all_bands = {
        'psd_all_bands': sets.df_ab_psd,
    }

    df_dict_fc_all_bands = {
        'fc_all_bands': sets.df_coh_fc,
    }

    df_dict_psd_fc_all_bands = {
        'psd_fc_all_bands': sets.df_ab_psd_coh_fc,
    }

    df_dict_psd_band = {
        f'psd_{band}': dfs_psd[band] for band in dfs_psd
    }

    df_dict_fc_band = {
        f'fc_{band}': dfs_fc[band] for band in dfs_fc
    }

    df_dict_psd_fc_band = {
        f'psd_fc_{band}': dfs_psd_fc[band] for band in dfs_psd_fc
    }

    dfs_dicts_binaries[disorder] = {
        'df_dict_psd_all_bands': df_dict_psd_all_bands,
        'df_dict_fc_all_bands': df_dict_fc_all_bands,
        'df_dict_psd_fc_all_bands': df_dict_psd_fc_all_bands,
        'df_dict_psd_band': df_dict_psd_band,
        'df_dict_fc_band': df_dict_fc_band,
        'df_dict_psd_fc_band': df_dict_psd_fc_band,
    }

# %%
import torch.nn as nn
import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import gc

class EEGANNClassifier(nn.Module):
    def __init__(self, input_dim, neurons, dropout=0.10):
        super(EEGANNClassifier, self).__init__()

        self.layer1 = nn.Linear(input_dim, neurons[0])
        self.layer2 = nn.Linear(neurons[0], neurons[1])
        self.layer3 = nn.Linear(neurons[1], neurons[2])
        self.layer4 = nn.Linear(neurons[2], neurons[3])
        self.output_layer = nn.Linear(neurons[3], 1)

        self.bn1 = nn.BatchNorm1d(neurons[0])
        self.bn2 = nn.BatchNorm1d(neurons[1])
        self.bn3 = nn.BatchNorm1d(neurons[2])
        self.bn4 = nn.BatchNorm1d(neurons[3])

        self.gelu = nn.GELU()
        self.dropout = nn.Dropout(p=dropout)

    def forward(self, x):
        x = self.gelu(self.bn1(self.layer1(x))) 
        x = self.dropout(x)

        x = self.gelu(self.bn2(self.layer2(x)))
        x = self.dropout(x)

        x = self.gelu(self.bn3(self.layer3(x)))
        x = self.dropout(x)

        x = self.gelu(self.bn4(self.layer4(x)))
        x = self.output_layer(x)

        return x.squeeze(1)  # shape (batch,)

    def fit(self, train_loader, epochs=200, lr=1e-3, weight_decay=1e-4, device='cpu', patience=20):
        self.to(device)
        criterion = nn.BCEWithLogitsLoss()
        optimizer = optim.Adam(self.parameters(), lr=lr, weight_decay=weight_decay)
        scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True)

        best_loss = float('inf')
        patience_counter = 0
        history = {'train_loss': [], 'train_acc': []}
        
        for epoch in range(epochs):
            self.train()
            running_loss = 0.0
            correct, total = 0, 0
            
            for inputs, targets in train_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                
                assert set(targets.cpu().tolist()).issubset({0.0, 1.0}), "Targets must be binary (0 or 1)"
                
                optimizer.zero_grad()
                outputs = self(inputs)
                
                # shape
                outputs = outputs.view(-1).float()
                targets = targets.view(-1).float() 
                
                assert outputs.shape == targets.shape, "Outputs and targets must have the same shape"
                assert outputs.dtype == torch.float32 and targets.dtype == torch.float32, "Outputs and targets must be float32"
                assert outputs.dim() == 1 and targets.dim() == 1, "Outputs and targets must be 1-dimensional"
                
                loss = criterion(outputs, targets)
                loss.backward()
                optimizer.step()
                
                preds = (torch.sigmoid(outputs) > 0.5).long()
                correct += (preds == targets.long()).sum().item()
                total += targets.size(0)
                running_loss += loss.item() * inputs.size(0)
                
            train_acc = correct / total
            epoch_loss = running_loss / len(train_loader.dataset)
            history['train_acc'].append(train_acc)
            history['train_loss'].append(epoch_loss)
            
            if epoch_loss < best_loss:
                best_loss = epoch_loss
                patience_counter = 0
            else:
                patience_counter += 1

            if patience_counter >= patience:
                print("Early stopping triggered.")
                break
            
            scheduler.step(epoch_loss)
            
            print(
                f"Epoch [{epoch+1}/{epochs}] | "
                f"Train Loss: {epoch_loss:.4f}, Train Acc: {train_acc:.4f} | "
            )
        
        return history


    def test(self, test_loader, device='cpu'):
        self.to(device)
        self.eval()
        
        all_preds, all_probas, all_targets = [], [], []
        correct, total = 0, 0
        test_loss = 0.0
        criterion = nn.BCEWithLogitsLoss()
        history = {'test_loss': [], 'test_acc': [], 'test_auc': []}

        with torch.no_grad():
            for inputs, targets in test_loader:
                inputs, targets = inputs.to(device), targets.to(device)

                outputs = self(inputs)
                
                outputs = outputs.view(-1).float()
                targets = targets.view(-1).float() 
                
                loss = criterion(outputs, targets)
                
                proba = torch.sigmoid(outputs)
                pred = (proba > 0.5).long()

                all_preds.append(pred.cpu())
                all_probas.append(proba.cpu())
                all_targets.append(targets.cpu())
                
                correct += (pred == targets.long()).sum().item()
                total += targets.size(0)
                test_loss += loss.item() * inputs.size(0)
        
        test_acc = correct / total
        test_loss /= len(test_loader.dataset)
        history['test_loss'].append(test_loss)
        history['test_acc'].append(test_acc)
        
        y_true = torch.cat(all_targets).numpy().astype(int)
        y_pred = torch.cat(all_preds).numpy().astype(int)
        y_proba = torch.cat(all_probas).numpy().astype(float)

        try:
            auc = roc_auc_score(y_true, y_proba)
        except ValueError:
            auc = float('nan')

        report = classification_report(y_true, y_pred, output_dict=True)
        history['test_auc'].append(auc)

        print(
            f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}, Test AUC: {auc:.4f}"
            )
        
        return test_acc, auc, report, history

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
import gc

# %%
all_results = {}

for disorder, dicts in dfs_dicts_binaries.items():
    print(f"\n=== Disorder: {disorder} ===")
    
    y_binary = sets_binaries[disorder]['y']
    X_quantitative = sets_binaries[disorder]['X_quantitative']
    labels = sets_binaries[disorder]['labels']
    
    all_results[disorder] = {}
    
    for dict_name, df_dict in dicts.items():
        if not dict_name.startswith('df_dict_'):
            continue
        
        for df_name, df in df_dict.items():
            print(f"\n--- Processing: {df_name} ---")
            print("Shape:", df.shape)
            print("Missing values:", df.isna().sum().sum())
            
            df_full = pd.concat([X_quantitative, df], axis=1)
            assert all(df_full.index == y_binary.index), 'Misaligned indexes'
            
            X_train, X_test, y_train, y_test = train_test_split(
                df_full,
                y_binary,
                train_size=0.80,
                stratify=y_binary,
                random_state=42
            )
            
            X_cols = X_train.drop(columns=['sex']).columns
            
            scaler = RobustScaler()
            X_train_scaled = scaler.fit_transform(X_train[X_cols])
            X_test_scaled = scaler.transform(X_test[X_cols])
            
            X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_cols, index=X_train.index)
            X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_cols, index=X_test.index)

            X_train_final = pd.concat([X_train_scaled_df, X_train['sex']], axis=1)
            X_test_final = pd.concat([X_test_scaled_df, X_test['sex']], axis=1)

            X_train_array = X_train_final.to_numpy()
            X_test_array = X_test_final.to_numpy()
            y_train_array = y_train.to_numpy()
            y_test_array = y_test.to_numpy()
            
            # tensors
            X_train_tensor = torch.tensor(X_train_array, dtype=torch.float32).to(device)
            y_train_tensor = torch.tensor(y_train_array, dtype=torch.long).to(device)
            X_test_tensor = torch.tensor(X_test_array, dtype=torch.float32).to(device)
            y_test_tensor = torch.tensor(y_test_array, dtype=torch.long).to(device)
            
            train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
            test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

            train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
            test_loader = DataLoader(test_dataset, batch_size=32)
            
            model = EEGANNClassifier(
                input_dim=X_train_final.shape[1],
                neurons=[128, 64, 32, 16],
                dropout=0.10
            ).to(device)
            
            fit_history = model.fit(
                train_loader=train_loader,
                epochs=200,
                lr=1e-3,
                weight_decay=1e-5,
                device=device,
                patience=20
            )
            
            acc, auc, report, test_history = model.test(
                test_loader=test_loader,
                device=device
            )
            
            all_results.setdefault(disorder, {}).setdefault(dict_name, {})[df_name] = {
                'accuracy': acc,
                'auc': auc,
                'classification_report': report,
                'features': list(X_train_final.columns),
                'X_train_shape': X_train_tensor.shape,
                'X_test_shape': X_test_tensor.shape,
                'history': {
                    'fit': fit_history,
                    'test': test_history
                }
            }
            
            # memory cleaning
            del model
            del X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
# Out:
# === Disorder: Addictive disorder ===
#
# --- Processing: psd_all_bands ---
# Shape: (372, 114)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.7069, Train Acc: 0.5084 |
# Epoch [2/200] | Train Loss: 0.6283, Train Acc: 0.7340 |
# Epoch [3/200] | Train Loss: 0.5957, Train Acc: 0.7508 |
# Epoch [4/200] | Train Loss: 0.5630, Train Acc: 0.8215 |
# Epoch [5/200] | Train Loss: 0.5255, Train Acc: 0.7980 |
# Epoch [6/200] | Train Loss: 0.4855, Train Acc: 0.8519 |
# Epoch [7/200] | Train Loss: 0.4618, Train Acc: 0.8687 |
# Epoch [8/200] | Train Loss: 0.4335, Train Acc: 0.8923 |
# Epoch [9/200] | Train Loss: 0.3972, Train Acc: 0.8889 |
# Epoch [10/200] | Train Loss: 0.3777, Train Acc: 0.9024 |
# Epoch [11/200] | Train Loss: 0.3516, Train Acc: 0.9226 |
# Epoch [12/200] | Train Loss: 0.3357, Train Acc: 0.9125 |
# Epoch [13/200] | Train Loss: 0.3006, Train Acc: 0.9158 |
# Epoch [14/200] | Train Loss: 0.2659, Train Acc: 0.9562 |
# Epoch [15/200] | Train Loss: 0.2602, Train Acc: 0.9495 |
# Epoch [16/200] | Train Loss: 0.2555, Train Acc: 0.9495 |
# Epoch [17/200] | Train Loss: 0.2452, Train Acc: 0.9428 |
# Epoch [18/200] | Train Loss: 0.2566, Train Acc: 0.9125 |
# Epoch [19/200] | Train Loss: 0.2549, Train Acc: 0.9192 |
# Epoch [20/200] | Train Loss: 0.2059, Train Acc: 0.9495 |
# Epoch [21/200] | Train Loss: 0.1967, Train Acc: 0.9562 |
# Epoch [22/200] | Train Loss: 0.1763, Train Acc: 0.9697 |
# Epoch [23/200] | Train Loss: 0.1753, Train Acc: 0.9596 |
# Epoch [24/200] | Train Loss: 0.1683, Train Acc: 0.9596 |
# Epoch [25/200] | Train Loss: 0.1862, Train Acc: 0.9360 |
# Epoch [26/200] | Train Loss: 0.1694, Train Acc: 0.9461 |
# Epoch [27/200] | Train Loss: 0.1675, Train Acc: 0.9461 |
# Epoch [28/200] | Train Loss: 0.1464, Train Acc: 0.9461 |
# Epoch [29/200] | Train Loss: 0.1225, Train Acc: 0.9663 |
# Epoch [30/200] | Train Loss: 0.1372, Train Acc: 0.9495 |
# Epoch [31/200] | Train Loss: 0.1356, Train Acc: 0.9630 |
# Epoch [32/200] | Train Loss: 0.1527, Train Acc: 0.9461 |
# Epoch [33/200] | Train Loss: 0.1410, Train Acc: 0.9529 |
# Epoch [34/200] | Train Loss: 0.1575, Train Acc: 0.9461 |
# Epoch [35/200] | Train Loss: 0.1368, Train Acc: 0.9495 |
# Epoch [36/200] | Train Loss: 0.1503, Train Acc: 0.9495 |
# Epoch [37/200] | Train Loss: 0.1166, Train Acc: 0.9663 |
# Epoch [38/200] | Train Loss: 0.0892, Train Acc: 0.9663 |
# Epoch [39/200] | Train Loss: 0.0929, Train Acc: 0.9764 |
# Epoch [40/200] | Train Loss: 0.1455, Train Acc: 0.9428 |
# Epoch [41/200] | Train Loss: 0.1194, Train Acc: 0.9697 |
# Epoch [42/200] | Train Loss: 0.1312, Train Acc: 0.9394 |
# Epoch [43/200] | Train Loss: 0.1295, Train Acc: 0.9529 |
# Epoch [44/200] | Train Loss: 0.1359, Train Acc: 0.9697 |
# Epoch [45/200] | Train Loss: 0.1570, Train Acc: 0.9394 |
# Epoch [46/200] | Train Loss: 0.1222, Train Acc: 0.9562 |
# Epoch [47/200] | Train Loss: 0.0946, Train Acc: 0.9798 |
# Epoch [48/200] | Train Loss: 0.0750, Train Acc: 0.9731 |
# Epoch [49/200] | Train Loss: 0.0802, Train Acc: 0.9865 |
# Epoch [50/200] | Train Loss: 0.0651, Train Acc: 0.9865 |
# Epoch [51/200] | Train Loss: 0.0904, Train Acc: 0.9697 |
# Epoch [52/200] | Train Loss: 0.0786, Train Acc: 0.9798 |
# Epoch [53/200] | Train Loss: 0.0856, Train Acc: 0.9764 |
# Epoch [54/200] | Train Loss: 0.0574, Train Acc: 0.9798 |
# Epoch [55/200] | Train Loss: 0.0510, Train Acc: 0.9865 |
# Epoch [56/200] | Train Loss: 0.0630, Train Acc: 0.9731 |
# Epoch [57/200] | Train Loss: 0.0772, Train Acc: 0.9697 |
# Epoch [58/200] | Train Loss: 0.0824, Train Acc: 0.9731 |
# Epoch [59/200] | Train Loss: 0.0642, Train Acc: 0.9731 |
# Epoch [60/200] | Train Loss: 0.0457, Train Acc: 0.9899 |
# Epoch [61/200] | Train Loss: 0.0489, Train Acc: 0.9899 |
# Epoch [62/200] | Train Loss: 0.0582, Train Acc: 0.9899 |
# Epoch [63/200] | Train Loss: 0.0790, Train Acc: 0.9731 |
# Epoch [64/200] | Train Loss: 0.0746, Train Acc: 0.9697 |
# Epoch [65/200] | Train Loss: 0.0633, Train Acc: 0.9798 |
# Epoch [66/200] | Train Loss: 0.1024, Train Acc: 0.9529 |
# Epoch [67/200] | Train Loss: 0.0701, Train Acc: 0.9764 |
# Epoch [68/200] | Train Loss: 0.0872, Train Acc: 0.9697 |
# Epoch [69/200] | Train Loss: 0.0781, Train Acc: 0.9764 |
# Epoch [70/200] | Train Loss: 0.0770, Train Acc: 0.9731 |
# Epoch [71/200] | Train Loss: 0.0928, Train Acc: 0.9764 |
# Epoch [72/200] | Train Loss: 0.0888, Train Acc: 0.9630 |
# Epoch [73/200] | Train Loss: 0.0700, Train Acc: 0.9832 |
# Epoch [74/200] | Train Loss: 0.0560, Train Acc: 0.9764 |
# Epoch [75/200] | Train Loss: 0.0666, Train Acc: 0.9764 |
# Epoch [76/200] | Train Loss: 0.0894, Train Acc: 0.9562 |
# Epoch [77/200] | Train Loss: 0.0460, Train Acc: 0.9933 |
# Epoch [78/200] | Train Loss: 0.0841, Train Acc: 0.9630 |
# Epoch [79/200] | Train Loss: 0.0613, Train Acc: 0.9798 |
# Early stopping triggered.
# Test Loss: 0.3777, Test Accuracy: 0.8667, Test AUC: 0.9452
#
# --- Processing: fc_all_bands ---
# Shape: (372, 1026)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.6682, Train Acc: 0.5892 |
# Epoch [2/200] | Train Loss: 0.5683, Train Acc: 0.7811 |
# Epoch [3/200] | Train Loss: 0.5016, Train Acc: 0.8350 |
# Epoch [4/200] | Train Loss: 0.4642, Train Acc: 0.8485 |
# Epoch [5/200] | Train Loss: 0.4103, Train Acc: 0.9125 |
# Epoch [6/200] | Train Loss: 0.3653, Train Acc: 0.9293 |
# Epoch [7/200] | Train Loss: 0.3454, Train Acc: 0.9360 |
# Epoch [8/200] | Train Loss: 0.3084, Train Acc: 0.9596 |
# Epoch [9/200] | Train Loss: 0.2835, Train Acc: 0.9562 |
# Epoch [10/200] | Train Loss: 0.2494, Train Acc: 0.9697 |
# Epoch [11/200] | Train Loss: 0.2194, Train Acc: 0.9764 |
# Epoch [12/200] | Train Loss: 0.2161, Train Acc: 0.9832 |
# Epoch [13/200] | Train Loss: 0.2157, Train Acc: 0.9663 |
# Epoch [14/200] | Train Loss: 0.1902, Train Acc: 0.9697 |
# Epoch [15/200] | Train Loss: 0.1824, Train Acc: 0.9596 |
# Epoch [16/200] | Train Loss: 0.1442, Train Acc: 0.9933 |
# Epoch [17/200] | Train Loss: 0.1458, Train Acc: 0.9899 |
# Epoch [18/200] | Train Loss: 0.1534, Train Acc: 0.9798 |
# Epoch [19/200] | Train Loss: 0.1212, Train Acc: 0.9865 |
# Epoch [20/200] | Train Loss: 0.1577, Train Acc: 0.9630 |
# Epoch [21/200] | Train Loss: 0.1286, Train Acc: 0.9798 |
# Epoch [22/200] | Train Loss: 0.1488, Train Acc: 0.9562 |
# Epoch [23/200] | Train Loss: 0.1082, Train Acc: 0.9899 |
# Epoch [24/200] | Train Loss: 0.0892, Train Acc: 0.9865 |
# Epoch [25/200] | Train Loss: 0.0955, Train Acc: 0.9798 |
# Epoch [26/200] | Train Loss: 0.0883, Train Acc: 0.9832 |
# Epoch [27/200] | Train Loss: 0.0739, Train Acc: 0.9899 |
# Epoch [28/200] | Train Loss: 0.0638, Train Acc: 0.9933 |
# Epoch [29/200] | Train Loss: 0.0843, Train Acc: 0.9832 |
# Epoch [30/200] | Train Loss: 0.0668, Train Acc: 0.9933 |
# Epoch [31/200] | Train Loss: 0.0817, Train Acc: 0.9798 |
# Epoch [32/200] | Train Loss: 0.0743, Train Acc: 0.9865 |
# Epoch [33/200] | Train Loss: 0.0731, Train Acc: 0.9899 |
# Epoch [34/200] | Train Loss: 0.0902, Train Acc: 0.9764 |
# Epoch [35/200] | Train Loss: 0.0790, Train Acc: 0.9798 |
# Epoch [36/200] | Train Loss: 0.0871, Train Acc: 0.9697 |
# Epoch [37/200] | Train Loss: 0.0640, Train Acc: 0.9899 |
# Epoch [38/200] | Train Loss: 0.0532, Train Acc: 0.9899 |
# Epoch [39/200] | Train Loss: 0.0449, Train Acc: 0.9899 |
# Epoch [40/200] | Train Loss: 0.0363, Train Acc: 0.9933 |
# Epoch [41/200] | Train Loss: 0.0397, Train Acc: 0.9933 |
# Epoch [42/200] | Train Loss: 0.0327, Train Acc: 1.0000 |
# Epoch [43/200] | Train Loss: 0.0537, Train Acc: 0.9899 |
# Epoch [44/200] | Train Loss: 0.0626, Train Acc: 0.9865 |
# Epoch [45/200] | Train Loss: 0.0933, Train Acc: 0.9663 |
# Epoch [46/200] | Train Loss: 0.1245, Train Acc: 0.9495 |
# Epoch [47/200] | Train Loss: 0.1545, Train Acc: 0.9428 |
# Epoch [48/200] | Train Loss: 0.1022, Train Acc: 0.9663 |
# Epoch [49/200] | Train Loss: 0.0913, Train Acc: 0.9630 |
# Epoch [50/200] | Train Loss: 0.0837, Train Acc: 0.9731 |
# Epoch [51/200] | Train Loss: 0.0910, Train Acc: 0.9697 |
# Epoch [52/200] | Train Loss: 0.1007, Train Acc: 0.9596 |
# Epoch [53/200] | Train Loss: 0.0872, Train Acc: 0.9764 |
# Epoch [54/200] | Train Loss: 0.0708, Train Acc: 0.9832 |
# Epoch [55/200] | Train Loss: 0.0489, Train Acc: 0.9933 |
# Epoch [56/200] | Train Loss: 0.0579, Train Acc: 0.9933 |
# Epoch [57/200] | Train Loss: 0.0537, Train Acc: 0.9865 |
# Epoch [58/200] | Train Loss: 0.0535, Train Acc: 0.9798 |
# Epoch [59/200] | Train Loss: 0.0574, Train Acc: 0.9865 |
# Epoch [60/200] | Train Loss: 0.0305, Train Acc: 1.0000 |
# Epoch [61/200] | Train Loss: 0.0696, Train Acc: 0.9731 |
# Epoch [62/200] | Train Loss: 0.0472, Train Acc: 0.9933 |
# Epoch [63/200] | Train Loss: 0.0643, Train Acc: 0.9832 |
# Epoch [64/200] | Train Loss: 0.0330, Train Acc: 0.9966 |
# Epoch [65/200] | Train Loss: 0.0314, Train Acc: 0.9966 |
# Epoch [66/200] | Train Loss: 0.0302, Train Acc: 1.0000 |
# Epoch [67/200] | Train Loss: 0.0321, Train Acc: 0.9933 |
# Epoch [68/200] | Train Loss: 0.0488, Train Acc: 0.9865 |
# Epoch [69/200] | Train Loss: 0.0389, Train Acc: 0.9933 |
# Epoch [70/200] | Train Loss: 0.0533, Train Acc: 0.9899 |
# Epoch [71/200] | Train Loss: 0.0260, Train Acc: 0.9966 |
# Epoch [72/200] | Train Loss: 0.0368, Train Acc: 0.9933 |
# Epoch [73/200] | Train Loss: 0.0236, Train Acc: 1.0000 |
# Epoch [74/200] | Train Loss: 0.0351, Train Acc: 0.9966 |
# Epoch [75/200] | Train Loss: 0.0278, Train Acc: 1.0000 |
# Epoch [76/200] | Train Loss: 0.0245, Train Acc: 0.9966 |
# Epoch [77/200] | Train Loss: 0.0295, Train Acc: 0.9933 |
# Epoch [78/200] | Train Loss: 0.0253, Train Acc: 0.9966 |
# Epoch [79/200] | Train Loss: 0.0233, Train Acc: 0.9966 |
# Epoch [80/200] | Train Loss: 0.0293, Train Acc: 0.9966 |
# Epoch [81/200] | Train Loss: 0.0264, Train Acc: 1.0000 |
# Epoch [82/200] | Train Loss: 0.0258, Train Acc: 0.9966 |
# Epoch [83/200] | Train Loss: 0.0260, Train Acc: 1.0000 |
# Epoch [84/200] | Train Loss: 0.0348, Train Acc: 0.9899 |
# Epoch [85/200] | Train Loss: 0.0353, Train Acc: 0.9966 |
# Epoch [86/200] | Train Loss: 0.0247, Train Acc: 0.9966 |
# Epoch [87/200] | Train Loss: 0.0463, Train Acc: 0.9933 |
# Epoch [88/200] | Train Loss: 0.0306, Train Acc: 0.9966 |
# Epoch [89/200] | Train Loss: 0.0274, Train Acc: 0.9966 |
# Epoch [90/200] | Train Loss: 0.0230, Train Acc: 0.9966 |
# Epoch [91/200] | Train Loss: 0.0276, Train Acc: 1.0000 |
# Epoch [92/200] | Train Loss: 0.0297, Train Acc: 0.9933 |
# Epoch [93/200] | Train Loss: 0.0220, Train Acc: 1.0000 |
# Epoch [94/200] | Train Loss: 0.0215, Train Acc: 1.0000 |
# Epoch [95/200] | Train Loss: 0.0214, Train Acc: 0.9966 |
# Epoch [96/200] | Train Loss: 0.0256, Train Acc: 0.9966 |
# Epoch [97/200] | Train Loss: 0.0259, Train Acc: 0.9933 |
# Epoch [98/200] | Train Loss: 0.0194, Train Acc: 1.0000 |
# Epoch [99/200] | Train Loss: 0.0307, Train Acc: 0.9933 |
# Epoch [100/200] | Train Loss: 0.0176, Train Acc: 1.0000 |
# Epoch [101/200] | Train Loss: 0.0241, Train Acc: 1.0000 |
# Epoch [102/200] | Train Loss: 0.0299, Train Acc: 0.9966 |
# Epoch [103/200] | Train Loss: 0.0164, Train Acc: 1.0000 |
# Epoch [104/200] | Train Loss: 0.0185, Train Acc: 1.0000 |
# Epoch [105/200] | Train Loss: 0.0178, Train Acc: 1.0000 |
# Epoch [106/200] | Train Loss: 0.0447, Train Acc: 0.9865 |
# Epoch [107/200] | Train Loss: 0.0250, Train Acc: 0.9966 |
# Epoch [108/200] | Train Loss: 0.0340, Train Acc: 0.9933 |
# Epoch [109/200] | Train Loss: 0.0216, Train Acc: 0.9966 |
# Epoch [110/200] | Train Loss: 0.0414, Train Acc: 0.9899 |
# Epoch [111/200] | Train Loss: 0.0337, Train Acc: 0.9899 |
# Epoch [112/200] | Train Loss: 0.0314, Train Acc: 0.9933 |
# Epoch [113/200] | Train Loss: 0.0158, Train Acc: 1.0000 |
# Epoch [114/200] | Train Loss: 0.0208, Train Acc: 1.0000 |
# Epoch [115/200] | Train Loss: 0.0165, Train Acc: 1.0000 |
# Epoch [116/200] | Train Loss: 0.0306, Train Acc: 0.9966 |
# Epoch [117/200] | Train Loss: 0.0318, Train Acc: 1.0000 |
# Epoch [118/200] | Train Loss: 0.0248, Train Acc: 0.9966 |
# Epoch [119/200] | Train Loss: 0.0198, Train Acc: 1.0000 |
# Epoch [120/200] | Train Loss: 0.0224, Train Acc: 1.0000 |
# Epoch [121/200] | Train Loss: 0.0393, Train Acc: 0.9966 |
# Epoch [122/200] | Train Loss: 0.0170, Train Acc: 1.0000 |
# Epoch [123/200] | Train Loss: 0.0297, Train Acc: 0.9933 |
# Epoch [124/200] | Train Loss: 0.0231, Train Acc: 0.9933 |
# Epoch [125/200] | Train Loss: 0.0148, Train Acc: 1.0000 |
# Epoch [126/200] | Train Loss: 0.0154, Train Acc: 1.0000 |
# Epoch [127/200] | Train Loss: 0.0219, Train Acc: 0.9966 |
# Epoch [128/200] | Train Loss: 0.0269, Train Acc: 0.9966 |
# Epoch [129/200] | Train Loss: 0.0161, Train Acc: 1.0000 |
# Epoch [130/200] | Train Loss: 0.0145, Train Acc: 1.0000 |
# Epoch [131/200] | Train Loss: 0.0184, Train Acc: 1.0000 |
# Epoch [132/200] | Train Loss: 0.0329, Train Acc: 0.9933 |
# Epoch [133/200] | Train Loss: 0.0233, Train Acc: 0.9966 |
# Epoch [134/200] | Train Loss: 0.0243, Train Acc: 1.0000 |
# Epoch [135/200] | Train Loss: 0.0215, Train Acc: 0.9966 |
# Epoch [136/200] | Train Loss: 0.0158, Train Acc: 1.0000 |
# Epoch [137/200] | Train Loss: 0.0211, Train Acc: 1.0000 |
# Epoch [138/200] | Train Loss: 0.0225, Train Acc: 0.9966 |
# Epoch [139/200] | Train Loss: 0.0134, Train Acc: 1.0000 |
# Epoch [140/200] | Train Loss: 0.0277, Train Acc: 0.9966 |
# Epoch [141/200] | Train Loss: 0.0176, Train Acc: 1.0000 |
# Epoch [142/200] | Train Loss: 0.0203, Train Acc: 0.9966 |
# Epoch [143/200] | Train Loss: 0.0267, Train Acc: 0.9899 |
# Epoch [144/200] | Train Loss: 0.0239, Train Acc: 0.9933 |
# Epoch [145/200] | Train Loss: 0.0256, Train Acc: 0.9966 |
# Epoch [146/200] | Train Loss: 0.0257, Train Acc: 0.9966 |
# Epoch [147/200] | Train Loss: 0.0238, Train Acc: 0.9966 |
# Epoch [148/200] | Train Loss: 0.0230, Train Acc: 0.9933 |
# Epoch [149/200] | Train Loss: 0.0383, Train Acc: 0.9865 |
# Epoch [150/200] | Train Loss: 0.0171, Train Acc: 1.0000 |
# Epoch [151/200] | Train Loss: 0.0570, Train Acc: 0.9798 |
# Epoch [152/200] | Train Loss: 0.0166, Train Acc: 1.0000 |
# Epoch [153/200] | Train Loss: 0.0170, Train Acc: 1.0000 |
# Epoch [154/200] | Train Loss: 0.0172, Train Acc: 1.0000 |
# Epoch [155/200] | Train Loss: 0.0202, Train Acc: 0.9966 |
# Epoch [156/200] | Train Loss: 0.0195, Train Acc: 0.9966 |
# Epoch [157/200] | Train Loss: 0.0290, Train Acc: 0.9933 |
# Epoch [158/200] | Train Loss: 0.0164, Train Acc: 1.0000 |
# Early stopping triggered.
# Test Loss: 0.4371, Test Accuracy: 0.8533, Test AUC: 0.8947
#
# --- Processing: psd_fc_all_bands ---
# Shape: (372, 1140)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.6574, Train Acc: 0.6128 |
# Epoch [2/200] | Train Loss: 0.5621, Train Acc: 0.7980 |
# Epoch [3/200] | Train Loss: 0.5203, Train Acc: 0.8485 |
# Epoch [4/200] | Train Loss: 0.4737, Train Acc: 0.8889 |
# Epoch [5/200] | Train Loss: 0.4219, Train Acc: 0.9158 |
# Epoch [6/200] | Train Loss: 0.3892, Train Acc: 0.9360 |
# Epoch [7/200] | Train Loss: 0.3649, Train Acc: 0.9360 |
# Epoch [8/200] | Train Loss: 0.3376, Train Acc: 0.9529 |
# Epoch [9/200] | Train Loss: 0.2946, Train Acc: 0.9697 |
# Epoch [10/200] | Train Loss: 0.2611, Train Acc: 0.9933 |
# Epoch [11/200] | Train Loss: 0.2433, Train Acc: 0.9798 |
# Epoch [12/200] | Train Loss: 0.2151, Train Acc: 0.9798 |
# Epoch [13/200] | Train Loss: 0.1935, Train Acc: 0.9865 |
# Epoch [14/200] | Train Loss: 0.1876, Train Acc: 0.9899 |
# Epoch [15/200] | Train Loss: 0.1673, Train Acc: 0.9933 |
# Epoch [16/200] | Train Loss: 0.1987, Train Acc: 0.9596 |
# Epoch [17/200] | Train Loss: 0.1780, Train Acc: 0.9798 |
# Epoch [18/200] | Train Loss: 0.2270, Train Acc: 0.9428 |
# Epoch [19/200] | Train Loss: 0.1515, Train Acc: 0.9865 |
# Epoch [20/200] | Train Loss: 0.1228, Train Acc: 0.9865 |
# Epoch [21/200] | Train Loss: 0.1383, Train Acc: 0.9798 |
# Epoch [22/200] | Train Loss: 0.1169, Train Acc: 0.9798 |
# Epoch [23/200] | Train Loss: 0.1034, Train Acc: 0.9899 |
# Epoch [24/200] | Train Loss: 0.1204, Train Acc: 0.9764 |
# Epoch [25/200] | Train Loss: 0.1015, Train Acc: 0.9832 |
# Epoch [26/200] | Train Loss: 0.1006, Train Acc: 0.9832 |
# Epoch [27/200] | Train Loss: 0.0780, Train Acc: 0.9865 |
# Epoch [28/200] | Train Loss: 0.0927, Train Acc: 0.9798 |
# Epoch [29/200] | Train Loss: 0.0821, Train Acc: 0.9865 |
# Epoch [30/200] | Train Loss: 0.0698, Train Acc: 0.9899 |
# Epoch [31/200] | Train Loss: 0.0706, Train Acc: 0.9865 |
# Epoch [32/200] | Train Loss: 0.0529, Train Acc: 0.9933 |
# Epoch [33/200] | Train Loss: 0.0750, Train Acc: 0.9832 |
# Epoch [34/200] | Train Loss: 0.0654, Train Acc: 0.9933 |
# Epoch [35/200] | Train Loss: 0.0436, Train Acc: 1.0000 |
# Epoch [36/200] | Train Loss: 0.0433, Train Acc: 0.9966 |
# Epoch [37/200] | Train Loss: 0.0514, Train Acc: 0.9933 |
# Epoch [38/200] | Train Loss: 0.0660, Train Acc: 0.9764 |
# Epoch [39/200] | Train Loss: 0.0384, Train Acc: 0.9933 |
# Epoch [40/200] | Train Loss: 0.0498, Train Acc: 0.9966 |
# Epoch [41/200] | Train Loss: 0.0479, Train Acc: 0.9933 |
# Epoch [42/200] | Train Loss: 0.0573, Train Acc: 0.9731 |
# Epoch [43/200] | Train Loss: 0.0321, Train Acc: 1.0000 |
# Epoch [44/200] | Train Loss: 0.0222, Train Acc: 1.0000 |
# Epoch [45/200] | Train Loss: 0.0368, Train Acc: 0.9933 |
# Epoch [46/200] | Train Loss: 0.0221, Train Acc: 0.9966 |
# Epoch [47/200] | Train Loss: 0.0566, Train Acc: 0.9798 |
# Epoch [48/200] | Train Loss: 0.0381, Train Acc: 0.9933 |
# Epoch [49/200] | Train Loss: 0.0692, Train Acc: 0.9630 |
# Epoch [50/200] | Train Loss: 0.0461, Train Acc: 0.9899 |
# Epoch [51/200] | Train Loss: 0.0543, Train Acc: 0.9832 |
# Epoch [52/200] | Train Loss: 0.0508, Train Acc: 0.9865 |
# Epoch [53/200] | Train Loss: 0.0703, Train Acc: 0.9798 |
# Epoch [54/200] | Train Loss: 0.0353, Train Acc: 0.9865 |
# Epoch [55/200] | Train Loss: 0.0401, Train Acc: 0.9865 |
# Epoch [56/200] | Train Loss: 0.0346, Train Acc: 0.9933 |
# Epoch [57/200] | Train Loss: 0.0464, Train Acc: 0.9832 |
# Epoch [58/200] | Train Loss: 0.0300, Train Acc: 0.9933 |
# Epoch [59/200] | Train Loss: 0.0536, Train Acc: 0.9865 |
# Epoch [60/200] | Train Loss: 0.0393, Train Acc: 0.9865 |
# Epoch [61/200] | Train Loss: 0.0592, Train Acc: 0.9865 |
# Epoch [62/200] | Train Loss: 0.0409, Train Acc: 0.9899 |
# Epoch [63/200] | Train Loss: 0.0217, Train Acc: 0.9966 |
# Epoch [64/200] | Train Loss: 0.0292, Train Acc: 0.9933 |
# Epoch [65/200] | Train Loss: 0.0320, Train Acc: 0.9933 |
# Epoch [66/200] | Train Loss: 0.0165, Train Acc: 1.0000 |
# Epoch [67/200] | Train Loss: 0.0437, Train Acc: 0.9933 |
# Epoch [68/200] | Train Loss: 0.0352, Train Acc: 0.9832 |
# Epoch [69/200] | Train Loss: 0.0151, Train Acc: 1.0000 |
# Epoch [70/200] | Train Loss: 0.0165, Train Acc: 1.0000 |
# Epoch [71/200] | Train Loss: 0.0144, Train Acc: 1.0000 |
# Epoch [72/200] | Train Loss: 0.0375, Train Acc: 0.9899 |
# Epoch [73/200] | Train Loss: 0.0211, Train Acc: 0.9966 |
# Epoch [74/200] | Train Loss: 0.0143, Train Acc: 1.0000 |
# Epoch [75/200] | Train Loss: 0.0145, Train Acc: 1.0000 |
# Epoch [76/200] | Train Loss: 0.0282, Train Acc: 0.9933 |
# Epoch [77/200] | Train Loss: 0.0324, Train Acc: 0.9966 |
# Epoch [78/200] | Train Loss: 0.0159, Train Acc: 1.0000 |
# Epoch [79/200] | Train Loss: 0.0137, Train Acc: 1.0000 |
# Epoch [80/200] | Train Loss: 0.0186, Train Acc: 1.0000 |
# Epoch [81/200] | Train Loss: 0.0227, Train Acc: 0.9966 |
# Epoch [82/200] | Train Loss: 0.0134, Train Acc: 1.0000 |
# Epoch [83/200] | Train Loss: 0.0218, Train Acc: 0.9966 |
# Epoch [84/200] | Train Loss: 0.0147, Train Acc: 1.0000 |
# Epoch [85/200] | Train Loss: 0.0209, Train Acc: 1.0000 |
# Epoch [86/200] | Train Loss: 0.0168, Train Acc: 1.0000 |
# Epoch [87/200] | Train Loss: 0.0297, Train Acc: 0.9899 |
# Epoch [88/200] | Train Loss: 0.0153, Train Acc: 1.0000 |
# Epoch [89/200] | Train Loss: 0.0130, Train Acc: 1.0000 |
# Epoch [90/200] | Train Loss: 0.0147, Train Acc: 1.0000 |
# Epoch [91/200] | Train Loss: 0.0198, Train Acc: 0.9966 |
# Epoch [92/200] | Train Loss: 0.0241, Train Acc: 0.9966 |
# Epoch [93/200] | Train Loss: 0.0198, Train Acc: 1.0000 |
# Epoch [94/200] | Train Loss: 0.0140, Train Acc: 1.0000 |
# Epoch [95/200] | Train Loss: 0.0302, Train Acc: 0.9899 |
# Epoch [96/200] | Train Loss: 0.0231, Train Acc: 0.9966 |
# Epoch [97/200] | Train Loss: 0.0248, Train Acc: 0.9933 |
# Epoch [98/200] | Train Loss: 0.0115, Train Acc: 1.0000 |
# Epoch [99/200] | Train Loss: 0.0208, Train Acc: 0.9933 |
# Epoch [100/200] | Train Loss: 0.0224, Train Acc: 0.9966 |
# Epoch [101/200] | Train Loss: 0.0152, Train Acc: 1.0000 |
# Epoch [102/200] | Train Loss: 0.0236, Train Acc: 0.9933 |
# Epoch [103/200] | Train Loss: 0.0177, Train Acc: 1.0000 |
# Epoch [104/200] | Train Loss: 0.0146, Train Acc: 1.0000 |
# Epoch [105/200] | Train Loss: 0.0138, Train Acc: 1.0000 |
# Epoch [106/200] | Train Loss: 0.0107, Train Acc: 1.0000 |
# Epoch [107/200] | Train Loss: 0.0154, Train Acc: 1.0000 |
# Epoch [108/200] | Train Loss: 0.0135, Train Acc: 1.0000 |
# Epoch [109/200] | Train Loss: 0.0207, Train Acc: 0.9966 |
# Epoch [110/200] | Train Loss: 0.0109, Train Acc: 1.0000 |
# Epoch [111/200] | Train Loss: 0.0180, Train Acc: 0.9966 |
# Epoch [112/200] | Train Loss: 0.0159, Train Acc: 0.9966 |
# Epoch [113/200] | Train Loss: 0.0127, Train Acc: 1.0000 |
# Epoch [114/200] | Train Loss: 0.0134, Train Acc: 1.0000 |
# Epoch [115/200] | Train Loss: 0.0119, Train Acc: 1.0000 |
# Epoch [116/200] | Train Loss: 0.0122, Train Acc: 1.0000 |
# Epoch [117/200] | Train Loss: 0.0233, Train Acc: 0.9966 |
# Epoch [118/200] | Train Loss: 0.0112, Train Acc: 1.0000 |
# Epoch [119/200] | Train Loss: 0.0115, Train Acc: 1.0000 |
# Epoch [120/200] | Train Loss: 0.0242, Train Acc: 0.9966 |
# Epoch [121/200] | Train Loss: 0.0144, Train Acc: 1.0000 |
# Epoch [122/200] | Train Loss: 0.0759, Train Acc: 0.9865 |
# Epoch [123/200] | Train Loss: 0.0144, Train Acc: 1.0000 |
# Epoch [124/200] | Train Loss: 0.0090, Train Acc: 1.0000 |
# Epoch [125/200] | Train Loss: 0.0103, Train Acc: 1.0000 |
# Epoch [126/200] | Train Loss: 0.0360, Train Acc: 0.9899 |
# Epoch [127/200] | Train Loss: 0.0123, Train Acc: 1.0000 |
# Epoch [128/200] | Train Loss: 0.0299, Train Acc: 0.9933 |
# Epoch [129/200] | Train Loss: 0.0160, Train Acc: 0.9966 |
# Epoch [130/200] | Train Loss: 0.0122, Train Acc: 1.0000 |
# Epoch [131/200] | Train Loss: 0.0417, Train Acc: 0.9899 |
# Epoch [132/200] | Train Loss: 0.0148, Train Acc: 0.9966 |
# Epoch [133/200] | Train Loss: 0.0130, Train Acc: 1.0000 |
# Epoch [134/200] | Train Loss: 0.0132, Train Acc: 1.0000 |
# Epoch [135/200] | Train Loss: 0.0143, Train Acc: 1.0000 |
# Epoch [136/200] | Train Loss: 0.0152, Train Acc: 0.9966 |
# Epoch [137/200] | Train Loss: 0.0109, Train Acc: 1.0000 |
# Epoch [138/200] | Train Loss: 0.0114, Train Acc: 1.0000 |
# Epoch [139/200] | Train Loss: 0.0110, Train Acc: 1.0000 |
# Epoch [140/200] | Train Loss: 0.0146, Train Acc: 1.0000 |
# Epoch [141/200] | Train Loss: 0.0122, Train Acc: 1.0000 |
# Epoch [142/200] | Train Loss: 0.0309, Train Acc: 0.9933 |
# Epoch [143/200] | Train Loss: 0.0145, Train Acc: 0.9966 |
# Early stopping triggered.
# Test Loss: 0.3790, Test Accuracy: 0.8400, Test AUC: 0.9239
#
# --- Processing: psd_delta ---
# Shape: (372, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.6757, Train Acc: 0.5690 |
# Epoch [2/200] | Train Loss: 0.5885, Train Acc: 0.7508 |
# Epoch [3/200] | Train Loss: 0.5564, Train Acc: 0.7609 |
# Epoch [4/200] | Train Loss: 0.5182, Train Acc: 0.7912 |
# Epoch [5/200] | Train Loss: 0.4879, Train Acc: 0.8114 |
# Epoch [6/200] | Train Loss: 0.4703, Train Acc: 0.8081 |
# Epoch [7/200] | Train Loss: 0.4325, Train Acc: 0.8418 |
# Epoch [8/200] | Train Loss: 0.4204, Train Acc: 0.8081 |
# Epoch [9/200] | Train Loss: 0.3983, Train Acc: 0.8418 |
# Epoch [10/200] | Train Loss: 0.3893, Train Acc: 0.8653 |
# Epoch [11/200] | Train Loss: 0.3704, Train Acc: 0.8653 |
# Epoch [12/200] | Train Loss: 0.3531, Train Acc: 0.8721 |
# Epoch [13/200] | Train Loss: 0.3421, Train Acc: 0.8754 |
# Epoch [14/200] | Train Loss: 0.3285, Train Acc: 0.8990 |
# Epoch [15/200] | Train Loss: 0.3207, Train Acc: 0.8788 |
# Epoch [16/200] | Train Loss: 0.3069, Train Acc: 0.8889 |
# Epoch [17/200] | Train Loss: 0.3111, Train Acc: 0.8788 |
# Epoch [18/200] | Train Loss: 0.2920, Train Acc: 0.9024 |
# Epoch [19/200] | Train Loss: 0.2722, Train Acc: 0.8990 |
# Epoch [20/200] | Train Loss: 0.2910, Train Acc: 0.8889 |
# Epoch [21/200] | Train Loss: 0.2328, Train Acc: 0.9360 |
# Epoch [22/200] | Train Loss: 0.2324, Train Acc: 0.9192 |
# Epoch [23/200] | Train Loss: 0.2646, Train Acc: 0.8990 |
# Epoch [24/200] | Train Loss: 0.2079, Train Acc: 0.9226 |
# Epoch [25/200] | Train Loss: 0.1838, Train Acc: 0.9394 |
# Epoch [26/200] | Train Loss: 0.2239, Train Acc: 0.9226 |
# Epoch [27/200] | Train Loss: 0.2462, Train Acc: 0.8990 |
# Epoch [28/200] | Train Loss: 0.2115, Train Acc: 0.9259 |
# Epoch [29/200] | Train Loss: 0.2446, Train Acc: 0.8990 |
# Epoch [30/200] | Train Loss: 0.2127, Train Acc: 0.9125 |
# Epoch [31/200] | Train Loss: 0.1932, Train Acc: 0.9360 |
# Epoch [32/200] | Train Loss: 0.2033, Train Acc: 0.9461 |
# Epoch [33/200] | Train Loss: 0.2134, Train Acc: 0.9192 |
# Epoch [34/200] | Train Loss: 0.2435, Train Acc: 0.8956 |
# Epoch [35/200] | Train Loss: 0.1797, Train Acc: 0.9529 |
# Epoch [36/200] | Train Loss: 0.1644, Train Acc: 0.9428 |
# Epoch [37/200] | Train Loss: 0.1540, Train Acc: 0.9562 |
# Epoch [38/200] | Train Loss: 0.1571, Train Acc: 0.9596 |
# Epoch [39/200] | Train Loss: 0.1681, Train Acc: 0.9327 |
# Epoch [40/200] | Train Loss: 0.1568, Train Acc: 0.9360 |
# Epoch [41/200] | Train Loss: 0.1485, Train Acc: 0.9428 |
# Epoch [42/200] | Train Loss: 0.1139, Train Acc: 0.9731 |
# Epoch [43/200] | Train Loss: 0.1191, Train Acc: 0.9697 |
# Epoch [44/200] | Train Loss: 0.1435, Train Acc: 0.9461 |
# Epoch [45/200] | Train Loss: 0.1499, Train Acc: 0.9360 |
# Epoch [46/200] | Train Loss: 0.1303, Train Acc: 0.9529 |
# Epoch [47/200] | Train Loss: 0.1376, Train Acc: 0.9428 |
# Epoch [48/200] | Train Loss: 0.1400, Train Acc: 0.9529 |
# Epoch [49/200] | Train Loss: 0.1173, Train Acc: 0.9461 |
# Epoch [50/200] | Train Loss: 0.1317, Train Acc: 0.9495 |
# Epoch [51/200] | Train Loss: 0.1545, Train Acc: 0.9327 |
# Epoch [52/200] | Train Loss: 0.1489, Train Acc: 0.9495 |
# Epoch [53/200] | Train Loss: 0.1310, Train Acc: 0.9562 |
# Epoch [54/200] | Train Loss: 0.1156, Train Acc: 0.9663 |
# Epoch [55/200] | Train Loss: 0.1504, Train Acc: 0.9360 |
# Epoch [56/200] | Train Loss: 0.0914, Train Acc: 0.9832 |
# Epoch [57/200] | Train Loss: 0.1561, Train Acc: 0.9428 |
# Epoch [58/200] | Train Loss: 0.0827, Train Acc: 0.9764 |
# Epoch [59/200] | Train Loss: 0.1112, Train Acc: 0.9596 |
# Epoch [60/200] | Train Loss: 0.0876, Train Acc: 0.9865 |
# Epoch [61/200] | Train Loss: 0.1115, Train Acc: 0.9562 |
# Epoch [62/200] | Train Loss: 0.1223, Train Acc: 0.9428 |
# Epoch [63/200] | Train Loss: 0.1290, Train Acc: 0.9630 |
# Epoch [64/200] | Train Loss: 0.0896, Train Acc: 0.9764 |
# Epoch [65/200] | Train Loss: 0.0910, Train Acc: 0.9798 |
# Epoch [66/200] | Train Loss: 0.1085, Train Acc: 0.9663 |
# Epoch [67/200] | Train Loss: 0.0996, Train Acc: 0.9764 |
# Epoch [68/200] | Train Loss: 0.0833, Train Acc: 0.9731 |
# Epoch [69/200] | Train Loss: 0.0931, Train Acc: 0.9663 |
# Epoch [70/200] | Train Loss: 0.1244, Train Acc: 0.9630 |
# Epoch [71/200] | Train Loss: 0.0968, Train Acc: 0.9764 |
# Epoch [72/200] | Train Loss: 0.1014, Train Acc: 0.9630 |
# Epoch [73/200] | Train Loss: 0.0959, Train Acc: 0.9697 |
# Epoch [74/200] | Train Loss: 0.1038, Train Acc: 0.9663 |
# Epoch [75/200] | Train Loss: 0.1176, Train Acc: 0.9461 |
# Epoch [76/200] | Train Loss: 0.0686, Train Acc: 0.9798 |
# Epoch [77/200] | Train Loss: 0.1201, Train Acc: 0.9630 |
# Epoch [78/200] | Train Loss: 0.0870, Train Acc: 0.9731 |
# Epoch [79/200] | Train Loss: 0.1101, Train Acc: 0.9663 |
# Epoch [80/200] | Train Loss: 0.1114, Train Acc: 0.9596 |
# Epoch [81/200] | Train Loss: 0.0944, Train Acc: 0.9731 |
# Epoch [82/200] | Train Loss: 0.0920, Train Acc: 0.9663 |
# Epoch [83/200] | Train Loss: 0.1065, Train Acc: 0.9731 |
# Epoch [84/200] | Train Loss: 0.1164, Train Acc: 0.9697 |
# Epoch [85/200] | Train Loss: 0.1266, Train Acc: 0.9562 |
# Epoch [86/200] | Train Loss: 0.0757, Train Acc: 0.9865 |
# Epoch [87/200] | Train Loss: 0.0776, Train Acc: 0.9798 |
# Epoch [88/200] | Train Loss: 0.0859, Train Acc: 0.9764 |
# Epoch [89/200] | Train Loss: 0.1230, Train Acc: 0.9495 |
# Epoch [90/200] | Train Loss: 0.1393, Train Acc: 0.9596 |
# Epoch [91/200] | Train Loss: 0.1068, Train Acc: 0.9596 |
# Epoch [92/200] | Train Loss: 0.1107, Train Acc: 0.9630 |
# Epoch [93/200] | Train Loss: 0.1112, Train Acc: 0.9596 |
# Epoch [94/200] | Train Loss: 0.0932, Train Acc: 0.9697 |
# Epoch [95/200] | Train Loss: 0.1086, Train Acc: 0.9562 |
# Early stopping triggered.
# Test Loss: 0.2549, Test Accuracy: 0.9333, Test AUC: 0.9737
#
# --- Processing: psd_theta ---
# Shape: (372, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.6911, Train Acc: 0.5253 |
# Epoch [2/200] | Train Loss: 0.6035, Train Acc: 0.7138 |
# Epoch [3/200] | Train Loss: 0.5782, Train Acc: 0.7340 |
# Epoch [4/200] | Train Loss: 0.5307, Train Acc: 0.7845 |
# Epoch [5/200] | Train Loss: 0.5047, Train Acc: 0.7845 |
# Epoch [6/200] | Train Loss: 0.4933, Train Acc: 0.7845 |
# Epoch [7/200] | Train Loss: 0.4699, Train Acc: 0.7946 |
# Epoch [8/200] | Train Loss: 0.4565, Train Acc: 0.8182 |
# Epoch [9/200] | Train Loss: 0.4300, Train Acc: 0.8114 |
# Epoch [10/200] | Train Loss: 0.4553, Train Acc: 0.8013 |
# Epoch [11/200] | Train Loss: 0.3873, Train Acc: 0.8653 |
# Epoch [12/200] | Train Loss: 0.3801, Train Acc: 0.8485 |
# Epoch [13/200] | Train Loss: 0.3577, Train Acc: 0.8721 |
# Epoch [14/200] | Train Loss: 0.3519, Train Acc: 0.8687 |
# Epoch [15/200] | Train Loss: 0.3381, Train Acc: 0.8754 |
# Epoch [16/200] | Train Loss: 0.3392, Train Acc: 0.8721 |
# Epoch [17/200] | Train Loss: 0.3055, Train Acc: 0.8923 |
# Epoch [18/200] | Train Loss: 0.3167, Train Acc: 0.8788 |
# Epoch [19/200] | Train Loss: 0.2912, Train Acc: 0.8990 |
# Epoch [20/200] | Train Loss: 0.2658, Train Acc: 0.9293 |
# Epoch [21/200] | Train Loss: 0.2896, Train Acc: 0.9024 |
# Epoch [22/200] | Train Loss: 0.2801, Train Acc: 0.8889 |
# Epoch [23/200] | Train Loss: 0.2609, Train Acc: 0.8956 |
# Epoch [24/200] | Train Loss: 0.2752, Train Acc: 0.8923 |
# Epoch [25/200] | Train Loss: 0.2607, Train Acc: 0.9091 |
# Epoch [26/200] | Train Loss: 0.2545, Train Acc: 0.9091 |
# Epoch [27/200] | Train Loss: 0.2283, Train Acc: 0.9259 |
# Epoch [28/200] | Train Loss: 0.2181, Train Acc: 0.9259 |
# Epoch [29/200] | Train Loss: 0.2628, Train Acc: 0.8956 |
# Epoch [30/200] | Train Loss: 0.2238, Train Acc: 0.9360 |
# Epoch [31/200] | Train Loss: 0.2007, Train Acc: 0.9226 |
# Epoch [32/200] | Train Loss: 0.2226, Train Acc: 0.9125 |
# Epoch [33/200] | Train Loss: 0.1955, Train Acc: 0.9461 |
# Epoch [34/200] | Train Loss: 0.2629, Train Acc: 0.8923 |
# Epoch [35/200] | Train Loss: 0.2375, Train Acc: 0.9024 |
# Epoch [36/200] | Train Loss: 0.2103, Train Acc: 0.9091 |
# Epoch [37/200] | Train Loss: 0.1661, Train Acc: 0.9495 |
# Epoch [38/200] | Train Loss: 0.2003, Train Acc: 0.9125 |
# Epoch [39/200] | Train Loss: 0.1761, Train Acc: 0.9259 |
# Epoch [40/200] | Train Loss: 0.1756, Train Acc: 0.9461 |
# Epoch [41/200] | Train Loss: 0.1612, Train Acc: 0.9461 |
# Epoch [42/200] | Train Loss: 0.1641, Train Acc: 0.9461 |
# Epoch [43/200] | Train Loss: 0.1324, Train Acc: 0.9529 |
# Epoch [44/200] | Train Loss: 0.1567, Train Acc: 0.9461 |
# Epoch [45/200] | Train Loss: 0.1330, Train Acc: 0.9529 |
# Epoch [46/200] | Train Loss: 0.1530, Train Acc: 0.9529 |
# Epoch [47/200] | Train Loss: 0.1505, Train Acc: 0.9495 |
# Epoch [48/200] | Train Loss: 0.1190, Train Acc: 0.9731 |
# Epoch [49/200] | Train Loss: 0.1565, Train Acc: 0.9495 |
# Epoch [50/200] | Train Loss: 0.1959, Train Acc: 0.9327 |
# Epoch [51/200] | Train Loss: 0.1213, Train Acc: 0.9596 |
# Epoch [52/200] | Train Loss: 0.1353, Train Acc: 0.9461 |
# Epoch [53/200] | Train Loss: 0.2025, Train Acc: 0.9125 |
# Epoch [54/200] | Train Loss: 0.1520, Train Acc: 0.9394 |
# Epoch [55/200] | Train Loss: 0.1370, Train Acc: 0.9428 |
# Epoch [56/200] | Train Loss: 0.1598, Train Acc: 0.9360 |
# Epoch [57/200] | Train Loss: 0.1340, Train Acc: 0.9663 |
# Epoch [58/200] | Train Loss: 0.1787, Train Acc: 0.9327 |
# Epoch [59/200] | Train Loss: 0.1379, Train Acc: 0.9529 |
# Epoch [60/200] | Train Loss: 0.1350, Train Acc: 0.9529 |
# Epoch [61/200] | Train Loss: 0.1181, Train Acc: 0.9495 |
# Epoch [62/200] | Train Loss: 0.1652, Train Acc: 0.9394 |
# Epoch [63/200] | Train Loss: 0.1255, Train Acc: 0.9562 |
# Epoch [64/200] | Train Loss: 0.1279, Train Acc: 0.9461 |
# Epoch [65/200] | Train Loss: 0.1359, Train Acc: 0.9394 |
# Epoch [66/200] | Train Loss: 0.1147, Train Acc: 0.9663 |
# Epoch [67/200] | Train Loss: 0.0949, Train Acc: 0.9731 |
# Epoch [68/200] | Train Loss: 0.1220, Train Acc: 0.9495 |
# Epoch [69/200] | Train Loss: 0.1008, Train Acc: 0.9764 |
# Epoch [70/200] | Train Loss: 0.1373, Train Acc: 0.9529 |
# Epoch [71/200] | Train Loss: 0.0892, Train Acc: 0.9798 |
# Epoch [72/200] | Train Loss: 0.1225, Train Acc: 0.9630 |
# Epoch [73/200] | Train Loss: 0.0972, Train Acc: 0.9731 |
# Epoch [74/200] | Train Loss: 0.1032, Train Acc: 0.9697 |
# Epoch [75/200] | Train Loss: 0.1357, Train Acc: 0.9562 |
# Epoch [76/200] | Train Loss: 0.0993, Train Acc: 0.9562 |
# Epoch [77/200] | Train Loss: 0.1140, Train Acc: 0.9529 |
# Epoch [78/200] | Train Loss: 0.0934, Train Acc: 0.9764 |
# Epoch [79/200] | Train Loss: 0.1024, Train Acc: 0.9529 |
# Epoch [80/200] | Train Loss: 0.1158, Train Acc: 0.9663 |
# Epoch [81/200] | Train Loss: 0.1055, Train Acc: 0.9663 |
# Epoch [82/200] | Train Loss: 0.1406, Train Acc: 0.9428 |
# Epoch [83/200] | Train Loss: 0.0949, Train Acc: 0.9663 |
# Epoch [84/200] | Train Loss: 0.1214, Train Acc: 0.9596 |
# Epoch [85/200] | Train Loss: 0.1296, Train Acc: 0.9495 |
# Epoch [86/200] | Train Loss: 0.0979, Train Acc: 0.9731 |
# Epoch [87/200] | Train Loss: 0.1588, Train Acc: 0.9428 |
# Epoch [88/200] | Train Loss: 0.1282, Train Acc: 0.9630 |
# Epoch [89/200] | Train Loss: 0.1114, Train Acc: 0.9663 |
# Epoch [90/200] | Train Loss: 0.0946, Train Acc: 0.9764 |
# Early stopping triggered.
# Test Loss: 0.2096, Test Accuracy: 0.8933, Test AUC: 0.9787
#
# --- Processing: psd_alpha ---
# Shape: (372, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.6773, Train Acc: 0.6027 |
# Epoch [2/200] | Train Loss: 0.6158, Train Acc: 0.6801 |
# Epoch [3/200] | Train Loss: 0.5691, Train Acc: 0.7273 |
# Epoch [4/200] | Train Loss: 0.5379, Train Acc: 0.7340 |
# Epoch [5/200] | Train Loss: 0.5031, Train Acc: 0.7811 |
# Epoch [6/200] | Train Loss: 0.4808, Train Acc: 0.8047 |
# Epoch [7/200] | Train Loss: 0.4630, Train Acc: 0.8114 |
# Epoch [8/200] | Train Loss: 0.4455, Train Acc: 0.8215 |
# Epoch [9/200] | Train Loss: 0.4158, Train Acc: 0.8350 |
# Epoch [10/200] | Train Loss: 0.3999, Train Acc: 0.8519 |
# Epoch [11/200] | Train Loss: 0.3745, Train Acc: 0.8687 |
# Epoch [12/200] | Train Loss: 0.3875, Train Acc: 0.8350 |
# Epoch [13/200] | Train Loss: 0.3734, Train Acc: 0.8552 |
# Epoch [14/200] | Train Loss: 0.3495, Train Acc: 0.8485 |
# Epoch [15/200] | Train Loss: 0.3328, Train Acc: 0.8855 |
# Epoch [16/200] | Train Loss: 0.3346, Train Acc: 0.8586 |
# Epoch [17/200] | Train Loss: 0.3054, Train Acc: 0.9024 |
# Epoch [18/200] | Train Loss: 0.2819, Train Acc: 0.8990 |
# Epoch [19/200] | Train Loss: 0.3060, Train Acc: 0.8822 |
# Epoch [20/200] | Train Loss: 0.2778, Train Acc: 0.8990 |
# Epoch [21/200] | Train Loss: 0.2778, Train Acc: 0.8990 |
# Epoch [22/200] | Train Loss: 0.2981, Train Acc: 0.8788 |
# Epoch [23/200] | Train Loss: 0.2684, Train Acc: 0.8822 |
# Epoch [24/200] | Train Loss: 0.2965, Train Acc: 0.8687 |
# Epoch [25/200] | Train Loss: 0.2704, Train Acc: 0.8956 |
# Epoch [26/200] | Train Loss: 0.2682, Train Acc: 0.9024 |
# Epoch [27/200] | Train Loss: 0.2553, Train Acc: 0.9125 |
# Epoch [28/200] | Train Loss: 0.2466, Train Acc: 0.9091 |
# Epoch [29/200] | Train Loss: 0.3013, Train Acc: 0.8653 |
# Epoch [30/200] | Train Loss: 0.2822, Train Acc: 0.8620 |
# Epoch [31/200] | Train Loss: 0.2690, Train Acc: 0.8721 |
# Epoch [32/200] | Train Loss: 0.2395, Train Acc: 0.8855 |
# Epoch [33/200] | Train Loss: 0.2078, Train Acc: 0.9259 |
# Epoch [34/200] | Train Loss: 0.2655, Train Acc: 0.8788 |
# Epoch [35/200] | Train Loss: 0.2202, Train Acc: 0.9024 |
# Epoch [36/200] | Train Loss: 0.1962, Train Acc: 0.9495 |
# Epoch [37/200] | Train Loss: 0.2112, Train Acc: 0.9158 |
# Epoch [38/200] | Train Loss: 0.2011, Train Acc: 0.9125 |
# Epoch [39/200] | Train Loss: 0.2016, Train Acc: 0.9192 |
# Epoch [40/200] | Train Loss: 0.2359, Train Acc: 0.9057 |
# Epoch [41/200] | Train Loss: 0.1972, Train Acc: 0.9057 |
# Epoch [42/200] | Train Loss: 0.1879, Train Acc: 0.9394 |
# Epoch [43/200] | Train Loss: 0.1812, Train Acc: 0.9259 |
# Epoch [44/200] | Train Loss: 0.1936, Train Acc: 0.9192 |
# Epoch [45/200] | Train Loss: 0.2142, Train Acc: 0.9057 |
# Epoch [46/200] | Train Loss: 0.2018, Train Acc: 0.9226 |
# Epoch [47/200] | Train Loss: 0.2053, Train Acc: 0.9327 |
# Epoch [48/200] | Train Loss: 0.1922, Train Acc: 0.9293 |
# Epoch [49/200] | Train Loss: 0.1460, Train Acc: 0.9495 |
# Epoch [50/200] | Train Loss: 0.1636, Train Acc: 0.9259 |
# Epoch [51/200] | Train Loss: 0.1906, Train Acc: 0.9259 |
# Epoch [52/200] | Train Loss: 0.1867, Train Acc: 0.9057 |
# Epoch [53/200] | Train Loss: 0.1804, Train Acc: 0.9259 |
# Epoch [54/200] | Train Loss: 0.1897, Train Acc: 0.9091 |
# Epoch [55/200] | Train Loss: 0.1643, Train Acc: 0.9360 |
# Epoch [56/200] | Train Loss: 0.1894, Train Acc: 0.9226 |
# Epoch [57/200] | Train Loss: 0.1815, Train Acc: 0.9259 |
# Epoch [58/200] | Train Loss: 0.1783, Train Acc: 0.9259 |
# Epoch [59/200] | Train Loss: 0.1755, Train Acc: 0.9293 |
# Epoch [60/200] | Train Loss: 0.2364, Train Acc: 0.9057 |
# Epoch [61/200] | Train Loss: 0.2134, Train Acc: 0.9192 |
# Epoch [62/200] | Train Loss: 0.1931, Train Acc: 0.9192 |
# Epoch [63/200] | Train Loss: 0.1577, Train Acc: 0.9293 |
# Epoch [64/200] | Train Loss: 0.1623, Train Acc: 0.9428 |
# Epoch [65/200] | Train Loss: 0.1569, Train Acc: 0.9360 |
# Epoch [66/200] | Train Loss: 0.1635, Train Acc: 0.9428 |
# Epoch [67/200] | Train Loss: 0.1491, Train Acc: 0.9529 |
# Epoch [68/200] | Train Loss: 0.1897, Train Acc: 0.9192 |
# Early stopping triggered.
# Test Loss: 0.3944, Test Accuracy: 0.8800, Test AUC: 0.9246
#
# --- Processing: psd_beta ---
# Shape: (372, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.6668, Train Acc: 0.6128 |
# Epoch [2/200] | Train Loss: 0.6095, Train Acc: 0.7273 |
# Epoch [3/200] | Train Loss: 0.5740, Train Acc: 0.7374 |
# Epoch [4/200] | Train Loss: 0.5483, Train Acc: 0.7811 |
# Epoch [5/200] | Train Loss: 0.5236, Train Acc: 0.7811 |
# Epoch [6/200] | Train Loss: 0.4970, Train Acc: 0.8182 |
# Epoch [7/200] | Train Loss: 0.4639, Train Acc: 0.8182 |
# Epoch [8/200] | Train Loss: 0.4408, Train Acc: 0.8283 |
# Epoch [9/200] | Train Loss: 0.4197, Train Acc: 0.8316 |
# Epoch [10/200] | Train Loss: 0.4108, Train Acc: 0.8451 |
# Epoch [11/200] | Train Loss: 0.3788, Train Acc: 0.8519 |
# Epoch [12/200] | Train Loss: 0.3805, Train Acc: 0.8418 |
# Epoch [13/200] | Train Loss: 0.3520, Train Acc: 0.8620 |
# Epoch [14/200] | Train Loss: 0.3586, Train Acc: 0.8653 |
# Epoch [15/200] | Train Loss: 0.3246, Train Acc: 0.8754 |
# Epoch [16/200] | Train Loss: 0.2887, Train Acc: 0.9226 |
# Epoch [17/200] | Train Loss: 0.2852, Train Acc: 0.9125 |
# Epoch [18/200] | Train Loss: 0.2888, Train Acc: 0.8889 |
# Epoch [19/200] | Train Loss: 0.2805, Train Acc: 0.8990 |
# Epoch [20/200] | Train Loss: 0.2552, Train Acc: 0.9091 |
# Epoch [21/200] | Train Loss: 0.2412, Train Acc: 0.9125 |
# Epoch [22/200] | Train Loss: 0.2340, Train Acc: 0.9158 |
# Epoch [23/200] | Train Loss: 0.2436, Train Acc: 0.9259 |
# Epoch [24/200] | Train Loss: 0.2334, Train Acc: 0.9158 |
# Epoch [25/200] | Train Loss: 0.2417, Train Acc: 0.9192 |
# Epoch [26/200] | Train Loss: 0.2207, Train Acc: 0.9293 |
# Epoch [27/200] | Train Loss: 0.2285, Train Acc: 0.9024 |
# Epoch [28/200] | Train Loss: 0.2464, Train Acc: 0.8889 |
# Epoch [29/200] | Train Loss: 0.1926, Train Acc: 0.9259 |
# Epoch [30/200] | Train Loss: 0.2019, Train Acc: 0.9125 |
# Epoch [31/200] | Train Loss: 0.1901, Train Acc: 0.9259 |
# Epoch [32/200] | Train Loss: 0.1715, Train Acc: 0.9495 |
# Epoch [33/200] | Train Loss: 0.1781, Train Acc: 0.9394 |
# Epoch [34/200] | Train Loss: 0.1984, Train Acc: 0.9259 |
# Epoch [35/200] | Train Loss: 0.1716, Train Acc: 0.9461 |
# Epoch [36/200] | Train Loss: 0.1967, Train Acc: 0.9057 |
# Epoch [37/200] | Train Loss: 0.1723, Train Acc: 0.9327 |
# Epoch [38/200] | Train Loss: 0.1874, Train Acc: 0.9226 |
# Epoch [39/200] | Train Loss: 0.1496, Train Acc: 0.9495 |
# Epoch [40/200] | Train Loss: 0.1796, Train Acc: 0.9360 |
# Epoch [41/200] | Train Loss: 0.1427, Train Acc: 0.9529 |
# Epoch [42/200] | Train Loss: 0.1632, Train Acc: 0.9394 |
# Epoch [43/200] | Train Loss: 0.1697, Train Acc: 0.9360 |
# Epoch [44/200] | Train Loss: 0.2018, Train Acc: 0.9226 |
# Epoch [45/200] | Train Loss: 0.2258, Train Acc: 0.9091 |
# Epoch [46/200] | Train Loss: 0.1324, Train Acc: 0.9562 |
# Epoch [47/200] | Train Loss: 0.1813, Train Acc: 0.9327 |
# Epoch [48/200] | Train Loss: 0.1395, Train Acc: 0.9495 |
# Epoch [49/200] | Train Loss: 0.1523, Train Acc: 0.9461 |
# Epoch [50/200] | Train Loss: 0.1325, Train Acc: 0.9495 |
# Epoch [51/200] | Train Loss: 0.1517, Train Acc: 0.9461 |
# Epoch [52/200] | Train Loss: 0.1569, Train Acc: 0.9529 |
# Epoch [53/200] | Train Loss: 0.1089, Train Acc: 0.9663 |
# Epoch [54/200] | Train Loss: 0.1582, Train Acc: 0.9259 |
# Epoch [55/200] | Train Loss: 0.1292, Train Acc: 0.9630 |
# Epoch [56/200] | Train Loss: 0.0956, Train Acc: 0.9731 |
# Epoch [57/200] | Train Loss: 0.1563, Train Acc: 0.9461 |
# Epoch [58/200] | Train Loss: 0.1084, Train Acc: 0.9630 |
# Epoch [59/200] | Train Loss: 0.1392, Train Acc: 0.9529 |
# Epoch [60/200] | Train Loss: 0.1206, Train Acc: 0.9495 |
# Epoch [61/200] | Train Loss: 0.1383, Train Acc: 0.9495 |
# Epoch [62/200] | Train Loss: 0.1005, Train Acc: 0.9663 |
# Epoch [63/200] | Train Loss: 0.0958, Train Acc: 0.9697 |
# Epoch [64/200] | Train Loss: 0.1393, Train Acc: 0.9495 |
# Epoch [65/200] | Train Loss: 0.1755, Train Acc: 0.9327 |
# Epoch [66/200] | Train Loss: 0.1164, Train Acc: 0.9663 |
# Epoch [67/200] | Train Loss: 0.1518, Train Acc: 0.9394 |
# Epoch [68/200] | Train Loss: 0.1163, Train Acc: 0.9630 |
# Epoch [69/200] | Train Loss: 0.1371, Train Acc: 0.9495 |
# Epoch [70/200] | Train Loss: 0.0927, Train Acc: 0.9697 |
# Epoch [71/200] | Train Loss: 0.1402, Train Acc: 0.9562 |
# Epoch [72/200] | Train Loss: 0.0831, Train Acc: 0.9798 |
# Epoch [73/200] | Train Loss: 0.1018, Train Acc: 0.9764 |
# Epoch [74/200] | Train Loss: 0.1474, Train Acc: 0.9360 |
# Epoch [75/200] | Train Loss: 0.0667, Train Acc: 0.9832 |
# Epoch [76/200] | Train Loss: 0.1653, Train Acc: 0.9293 |
# Epoch [77/200] | Train Loss: 0.1390, Train Acc: 0.9327 |
# Epoch [78/200] | Train Loss: 0.1466, Train Acc: 0.9495 |
# Epoch [79/200] | Train Loss: 0.0748, Train Acc: 0.9798 |
# Epoch [80/200] | Train Loss: 0.1250, Train Acc: 0.9562 |
# Epoch [81/200] | Train Loss: 0.1016, Train Acc: 0.9731 |
# Epoch [82/200] | Train Loss: 0.0997, Train Acc: 0.9630 |
# Epoch [83/200] | Train Loss: 0.0719, Train Acc: 0.9798 |
# Epoch [84/200] | Train Loss: 0.0691, Train Acc: 0.9832 |
# Epoch [85/200] | Train Loss: 0.1523, Train Acc: 0.9428 |
# Epoch [86/200] | Train Loss: 0.1204, Train Acc: 0.9630 |
# Epoch [87/200] | Train Loss: 0.0976, Train Acc: 0.9764 |
# Epoch [88/200] | Train Loss: 0.0975, Train Acc: 0.9663 |
# Epoch [89/200] | Train Loss: 0.1595, Train Acc: 0.9360 |
# Epoch [90/200] | Train Loss: 0.0810, Train Acc: 0.9764 |
# Epoch [91/200] | Train Loss: 0.1088, Train Acc: 0.9663 |
# Epoch [92/200] | Train Loss: 0.0798, Train Acc: 0.9731 |
# Epoch [93/200] | Train Loss: 0.0916, Train Acc: 0.9663 |
# Epoch [94/200] | Train Loss: 0.0935, Train Acc: 0.9630 |
# Early stopping triggered.
# Test Loss: 0.2988, Test Accuracy: 0.8800, Test AUC: 0.9616
#
# --- Processing: psd_highbeta ---
# Shape: (372, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.7034, Train Acc: 0.5488 |
# Epoch [2/200] | Train Loss: 0.6064, Train Acc: 0.7071 |
# Epoch [3/200] | Train Loss: 0.5639, Train Acc: 0.7778 |
# Epoch [4/200] | Train Loss: 0.5275, Train Acc: 0.7912 |
# Epoch [5/200] | Train Loss: 0.4916, Train Acc: 0.7980 |
# Epoch [6/200] | Train Loss: 0.4715, Train Acc: 0.8148 |
# Epoch [7/200] | Train Loss: 0.4363, Train Acc: 0.8384 |
# Epoch [8/200] | Train Loss: 0.4339, Train Acc: 0.8316 |
# Epoch [9/200] | Train Loss: 0.4095, Train Acc: 0.8721 |
# Epoch [10/200] | Train Loss: 0.3998, Train Acc: 0.8620 |
# Epoch [11/200] | Train Loss: 0.3759, Train Acc: 0.8485 |
# Epoch [12/200] | Train Loss: 0.3675, Train Acc: 0.8653 |
# Epoch [13/200] | Train Loss: 0.3479, Train Acc: 0.8653 |
# Epoch [14/200] | Train Loss: 0.3269, Train Acc: 0.9259 |
# Epoch [15/200] | Train Loss: 0.3039, Train Acc: 0.8889 |
# Epoch [16/200] | Train Loss: 0.3097, Train Acc: 0.8788 |
# Epoch [17/200] | Train Loss: 0.2839, Train Acc: 0.8923 |
# Epoch [18/200] | Train Loss: 0.2824, Train Acc: 0.8990 |
# Epoch [19/200] | Train Loss: 0.2747, Train Acc: 0.9024 |
# Epoch [20/200] | Train Loss: 0.2469, Train Acc: 0.9293 |
# Epoch [21/200] | Train Loss: 0.2399, Train Acc: 0.9293 |
# Epoch [22/200] | Train Loss: 0.2468, Train Acc: 0.9125 |
# Epoch [23/200] | Train Loss: 0.2512, Train Acc: 0.9125 |
# Epoch [24/200] | Train Loss: 0.2111, Train Acc: 0.9394 |
# Epoch [25/200] | Train Loss: 0.2395, Train Acc: 0.9091 |
# Epoch [26/200] | Train Loss: 0.2332, Train Acc: 0.9091 |
# Epoch [27/200] | Train Loss: 0.1927, Train Acc: 0.9360 |
# Epoch [28/200] | Train Loss: 0.1947, Train Acc: 0.9293 |
# Epoch [29/200] | Train Loss: 0.2079, Train Acc: 0.9192 |
# Epoch [30/200] | Train Loss: 0.1864, Train Acc: 0.9327 |
# Epoch [31/200] | Train Loss: 0.1944, Train Acc: 0.9259 |
# Epoch [32/200] | Train Loss: 0.1913, Train Acc: 0.9226 |
# Epoch [33/200] | Train Loss: 0.2050, Train Acc: 0.9327 |
# Epoch [34/200] | Train Loss: 0.1846, Train Acc: 0.9394 |
# Epoch [35/200] | Train Loss: 0.1767, Train Acc: 0.9495 |
# Epoch [36/200] | Train Loss: 0.1642, Train Acc: 0.9461 |
# Epoch [37/200] | Train Loss: 0.1524, Train Acc: 0.9461 |
# Epoch [38/200] | Train Loss: 0.1789, Train Acc: 0.9394 |
# Epoch [39/200] | Train Loss: 0.1613, Train Acc: 0.9461 |
# Epoch [40/200] | Train Loss: 0.1726, Train Acc: 0.9360 |
# Epoch [41/200] | Train Loss: 0.1403, Train Acc: 0.9529 |
# Epoch [42/200] | Train Loss: 0.1350, Train Acc: 0.9596 |
# Epoch [43/200] | Train Loss: 0.1675, Train Acc: 0.9327 |
# Epoch [44/200] | Train Loss: 0.1442, Train Acc: 0.9562 |
# Epoch [45/200] | Train Loss: 0.1527, Train Acc: 0.9529 |
# Epoch [46/200] | Train Loss: 0.1810, Train Acc: 0.9327 |
# Epoch [47/200] | Train Loss: 0.1728, Train Acc: 0.9394 |
# Epoch [48/200] | Train Loss: 0.1239, Train Acc: 0.9630 |
# Epoch [49/200] | Train Loss: 0.1315, Train Acc: 0.9529 |
# Epoch [50/200] | Train Loss: 0.1378, Train Acc: 0.9529 |
# Epoch [51/200] | Train Loss: 0.1500, Train Acc: 0.9529 |
# Epoch [52/200] | Train Loss: 0.1269, Train Acc: 0.9495 |
# Epoch [53/200] | Train Loss: 0.1416, Train Acc: 0.9327 |
# Epoch [54/200] | Train Loss: 0.1599, Train Acc: 0.9360 |
# Epoch [55/200] | Train Loss: 0.1246, Train Acc: 0.9596 |
# Epoch [56/200] | Train Loss: 0.1341, Train Acc: 0.9630 |
# Epoch [57/200] | Train Loss: 0.0880, Train Acc: 0.9731 |
# Epoch [58/200] | Train Loss: 0.0894, Train Acc: 0.9697 |
# Epoch [59/200] | Train Loss: 0.1180, Train Acc: 0.9697 |
# Epoch [60/200] | Train Loss: 0.1300, Train Acc: 0.9596 |
# Epoch [61/200] | Train Loss: 0.1085, Train Acc: 0.9663 |
# Epoch [62/200] | Train Loss: 0.1051, Train Acc: 0.9697 |
# Epoch [63/200] | Train Loss: 0.1287, Train Acc: 0.9495 |
# Epoch [64/200] | Train Loss: 0.1128, Train Acc: 0.9663 |
# Epoch [65/200] | Train Loss: 0.0900, Train Acc: 0.9731 |
# Epoch [66/200] | Train Loss: 0.1397, Train Acc: 0.9360 |
# Epoch [67/200] | Train Loss: 0.1385, Train Acc: 0.9529 |
# Epoch [68/200] | Train Loss: 0.1040, Train Acc: 0.9630 |
# Epoch [69/200] | Train Loss: 0.1104, Train Acc: 0.9663 |
# Epoch [70/200] | Train Loss: 0.0950, Train Acc: 0.9663 |
# Epoch [71/200] | Train Loss: 0.0926, Train Acc: 0.9663 |
# Epoch [72/200] | Train Loss: 0.0783, Train Acc: 0.9697 |
# Epoch [73/200] | Train Loss: 0.0895, Train Acc: 0.9798 |
# Epoch [74/200] | Train Loss: 0.1016, Train Acc: 0.9697 |
# Epoch [75/200] | Train Loss: 0.0720, Train Acc: 0.9798 |
# Epoch [76/200] | Train Loss: 0.1020, Train Acc: 0.9731 |
# Epoch [77/200] | Train Loss: 0.0825, Train Acc: 0.9731 |
# Epoch [78/200] | Train Loss: 0.1011, Train Acc: 0.9596 |
# Epoch [79/200] | Train Loss: 0.0871, Train Acc: 0.9798 |
# ...
# Epoch [11/200] | Train Loss: 0.3241, Train Acc: 0.9608 |
# Epoch [12/200] | Train Loss: 0.2982, Train Acc: 0.9608 |
# Epoch [13/200] | Train Loss: 0.2819, Train Acc: 0.9608 |
# Epoch [14/200] | Train Loss: 0.2707, Train Acc: 0.9510 |
# Epoch [15/200] | Train Loss: 0.2347, Train Acc: 0.9804 |
# Epoch [16/200] | Train Loss: 0.2366, Train Acc: 0.9559 |
# Epoch [17/200] | Train Loss: 0.2217, Train Acc: 0.9608 |
# Epoch [18/200] | Train Loss: 0.2066, Train Acc: 0.9657 |
# Epoch [19/200] | Train Loss: 0.2031, Train Acc: 0.9608 |
# Epoch [20/200] | Train Loss: 0.2023, Train Acc: 0.9706 |
# Epoch [21/200] | Train Loss: 0.1566, Train Acc: 0.9853 |
# Epoch [22/200] | Train Loss: 0.1749, Train Acc: 0.9559 |
# Epoch [23/200] | Train Loss: 0.1542, Train Acc: 0.9853 |
# Epoch [24/200] | Train Loss: 0.1811, Train Acc: 0.9559 |
# Epoch [25/200] | Train Loss: 0.1421, Train Acc: 0.9951 |
# Epoch [26/200] | Train Loss: 0.1186, Train Acc: 0.9902 |
# Epoch [27/200] | Train Loss: 0.1071, Train Acc: 0.9951 |
# Epoch [28/200] | Train Loss: 0.1319, Train Acc: 0.9706 |
# Epoch [29/200] | Train Loss: 0.0971, Train Acc: 0.9951 |
# Epoch [30/200] | Train Loss: 0.1114, Train Acc: 0.9853 |
# Epoch [31/200] | Train Loss: 0.1049, Train Acc: 0.9706 |
# Epoch [32/200] | Train Loss: 0.1163, Train Acc: 0.9706 |
# Epoch [33/200] | Train Loss: 0.1060, Train Acc: 0.9853 |
# Epoch [34/200] | Train Loss: 0.0907, Train Acc: 0.9853 |
# Epoch [35/200] | Train Loss: 0.1132, Train Acc: 0.9706 |
# Epoch [36/200] | Train Loss: 0.1087, Train Acc: 0.9706 |
# Epoch [37/200] | Train Loss: 0.1024, Train Acc: 0.9755 |
# Epoch [38/200] | Train Loss: 0.0820, Train Acc: 0.9853 |
# Epoch [39/200] | Train Loss: 0.0820, Train Acc: 0.9853 |
# Epoch [40/200] | Train Loss: 0.0871, Train Acc: 0.9853 |
# Epoch [41/200] | Train Loss: 0.0936, Train Acc: 0.9657 |
# Epoch [42/200] | Train Loss: 0.1229, Train Acc: 0.9608 |
# Epoch [43/200] | Train Loss: 0.1035, Train Acc: 0.9657 |
# Epoch [44/200] | Train Loss: 0.0837, Train Acc: 0.9804 |
# Epoch [45/200] | Train Loss: 0.0657, Train Acc: 0.9902 |
# Epoch [46/200] | Train Loss: 0.0546, Train Acc: 0.9902 |
# Epoch [47/200] | Train Loss: 0.0703, Train Acc: 0.9804 |
# Epoch [48/200] | Train Loss: 0.1189, Train Acc: 0.9559 |
# Epoch [49/200] | Train Loss: 0.0553, Train Acc: 0.9902 |
# Epoch [50/200] | Train Loss: 0.1191, Train Acc: 0.9608 |
# Epoch [51/200] | Train Loss: 0.0759, Train Acc: 0.9804 |
# Epoch [52/200] | Train Loss: 0.0910, Train Acc: 0.9755 |
# Epoch [53/200] | Train Loss: 0.0699, Train Acc: 0.9804 |
# Epoch [54/200] | Train Loss: 0.0588, Train Acc: 0.9902 |
# Epoch [55/200] | Train Loss: 0.0684, Train Acc: 0.9853 |
# Epoch [56/200] | Train Loss: 0.0924, Train Acc: 0.9608 |
# Epoch [57/200] | Train Loss: 0.0672, Train Acc: 0.9902 |
# Epoch [58/200] | Train Loss: 0.0672, Train Acc: 0.9902 |
# Epoch [59/200] | Train Loss: 0.0469, Train Acc: 0.9951 |
# Epoch [60/200] | Train Loss: 0.0433, Train Acc: 0.9902 |
# Epoch [61/200] | Train Loss: 0.0406, Train Acc: 0.9951 |
# Epoch [62/200] | Train Loss: 0.0395, Train Acc: 0.9951 |
# Epoch [63/200] | Train Loss: 0.0510, Train Acc: 0.9853 |
# Epoch [64/200] | Train Loss: 0.0345, Train Acc: 1.0000 |
# Epoch [65/200] | Train Loss: 0.0627, Train Acc: 0.9853 |
# Epoch [66/200] | Train Loss: 0.0611, Train Acc: 0.9853 |
# Epoch [67/200] | Train Loss: 0.0425, Train Acc: 0.9951 |
# Epoch [68/200] | Train Loss: 0.0433, Train Acc: 0.9951 |
# Epoch [69/200] | Train Loss: 0.0481, Train Acc: 0.9951 |
# Epoch [70/200] | Train Loss: 0.0380, Train Acc: 0.9951 |
# Epoch [71/200] | Train Loss: 0.0268, Train Acc: 1.0000 |
# Epoch [72/200] | Train Loss: 0.0647, Train Acc: 0.9755 |
# Epoch [73/200] | Train Loss: 0.0441, Train Acc: 0.9902 |
# Epoch [74/200] | Train Loss: 0.0375, Train Acc: 0.9951 |
# Epoch [75/200] | Train Loss: 0.0328, Train Acc: 1.0000 |
# Epoch [76/200] | Train Loss: 0.0514, Train Acc: 0.9902 |
# Epoch [77/200] | Train Loss: 0.0483, Train Acc: 1.0000 |
# Epoch [78/200] | Train Loss: 0.0303, Train Acc: 1.0000 |
# Epoch [79/200] | Train Loss: 0.0511, Train Acc: 0.9902 |
# Epoch [80/200] | Train Loss: 0.0259, Train Acc: 1.0000 |
# Epoch [81/200] | Train Loss: 0.0394, Train Acc: 0.9951 |
# Epoch [82/200] | Train Loss: 0.0401, Train Acc: 0.9902 |
# Epoch [83/200] | Train Loss: 0.0312, Train Acc: 0.9951 |
# Epoch [84/200] | Train Loss: 0.0280, Train Acc: 1.0000 |
# Epoch [85/200] | Train Loss: 0.0324, Train Acc: 1.0000 |
# Epoch [86/200] | Train Loss: 0.0400, Train Acc: 0.9902 |
# Epoch [87/200] | Train Loss: 0.0284, Train Acc: 1.0000 |
# Epoch [88/200] | Train Loss: 0.0379, Train Acc: 1.0000 |
# Epoch [89/200] | Train Loss: 0.0479, Train Acc: 0.9902 |
# Epoch [90/200] | Train Loss: 0.0350, Train Acc: 0.9951 |
# Epoch [91/200] | Train Loss: 0.0454, Train Acc: 0.9853 |
# Epoch [92/200] | Train Loss: 0.0583, Train Acc: 0.9755 |
# Epoch [93/200] | Train Loss: 0.0227, Train Acc: 1.0000 |
# Epoch [94/200] | Train Loss: 0.0270, Train Acc: 1.0000 |
# Epoch [95/200] | Train Loss: 0.0228, Train Acc: 1.0000 |
# Epoch [96/200] | Train Loss: 0.0342, Train Acc: 0.9951 |
# Epoch [97/200] | Train Loss: 0.0328, Train Acc: 0.9951 |
# Epoch [98/200] | Train Loss: 0.0347, Train Acc: 0.9902 |
# Epoch [99/200] | Train Loss: 0.0247, Train Acc: 0.9951 |
# Epoch [100/200] | Train Loss: 0.0321, Train Acc: 1.0000 |
# Epoch [101/200] | Train Loss: 0.0359, Train Acc: 0.9951 |
# Epoch [102/200] | Train Loss: 0.0319, Train Acc: 1.0000 |
# Epoch [103/200] | Train Loss: 0.0269, Train Acc: 1.0000 |
# Epoch [104/200] | Train Loss: 0.0252, Train Acc: 1.0000 |
# Epoch [105/200] | Train Loss: 0.0335, Train Acc: 0.9951 |
# Epoch [106/200] | Train Loss: 0.0297, Train Acc: 1.0000 |
# Epoch [107/200] | Train Loss: 0.0363, Train Acc: 0.9951 |
# Epoch [108/200] | Train Loss: 0.0323, Train Acc: 1.0000 |
# Epoch [109/200] | Train Loss: 0.0513, Train Acc: 0.9902 |
# Epoch [110/200] | Train Loss: 0.0292, Train Acc: 0.9951 |
# Epoch [111/200] | Train Loss: 0.0246, Train Acc: 1.0000 |
# Epoch [112/200] | Train Loss: 0.0339, Train Acc: 1.0000 |
# Early stopping triggered.
# Test Loss: 0.5501, Test Accuracy: 0.7885, Test AUC: 0.8698
#
# --- Processing: psd_fc_gamma ---
# Shape: (256, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.7209, Train Acc: 0.5147 |
# Epoch [2/200] | Train Loss: 0.6271, Train Acc: 0.5686 |
# Epoch [3/200] | Train Loss: 0.5776, Train Acc: 0.6961 |
# Epoch [4/200] | Train Loss: 0.5382, Train Acc: 0.7745 |
# Epoch [5/200] | Train Loss: 0.5074, Train Acc: 0.8382 |
# Epoch [6/200] | Train Loss: 0.4673, Train Acc: 0.8676 |
# Epoch [7/200] | Train Loss: 0.4409, Train Acc: 0.9020 |
# Epoch [8/200] | Train Loss: 0.4048, Train Acc: 0.9167 |
# Epoch [9/200] | Train Loss: 0.3969, Train Acc: 0.9020 |
# Epoch [10/200] | Train Loss: 0.3579, Train Acc: 0.9167 |
# Epoch [11/200] | Train Loss: 0.3460, Train Acc: 0.9461 |
# Epoch [12/200] | Train Loss: 0.3166, Train Acc: 0.9559 |
# Epoch [13/200] | Train Loss: 0.2939, Train Acc: 0.9755 |
# Epoch [14/200] | Train Loss: 0.2848, Train Acc: 0.9804 |
# Epoch [15/200] | Train Loss: 0.2664, Train Acc: 0.9657 |
# Epoch [16/200] | Train Loss: 0.2909, Train Acc: 0.9118 |
# Epoch [17/200] | Train Loss: 0.2535, Train Acc: 0.9412 |
# Epoch [18/200] | Train Loss: 0.2291, Train Acc: 0.9657 |
# Epoch [19/200] | Train Loss: 0.2068, Train Acc: 0.9706 |
# Epoch [20/200] | Train Loss: 0.2376, Train Acc: 0.9461 |
# Epoch [21/200] | Train Loss: 0.2379, Train Acc: 0.9510 |
# Epoch [22/200] | Train Loss: 0.1971, Train Acc: 0.9706 |
# Epoch [23/200] | Train Loss: 0.2043, Train Acc: 0.9559 |
# Epoch [24/200] | Train Loss: 0.1796, Train Acc: 0.9853 |
# Epoch [25/200] | Train Loss: 0.1635, Train Acc: 0.9804 |
# Epoch [26/200] | Train Loss: 0.1490, Train Acc: 0.9902 |
# Epoch [27/200] | Train Loss: 0.1658, Train Acc: 0.9755 |
# Epoch [28/200] | Train Loss: 0.1412, Train Acc: 0.9853 |
# Epoch [29/200] | Train Loss: 0.1524, Train Acc: 0.9755 |
# Epoch [30/200] | Train Loss: 0.1374, Train Acc: 0.9853 |
# Epoch [31/200] | Train Loss: 0.1174, Train Acc: 0.9902 |
# Epoch [32/200] | Train Loss: 0.1191, Train Acc: 0.9853 |
# Epoch [33/200] | Train Loss: 0.1100, Train Acc: 0.9902 |
# Epoch [34/200] | Train Loss: 0.1329, Train Acc: 0.9706 |
# Epoch [35/200] | Train Loss: 0.1100, Train Acc: 0.9853 |
# Epoch [36/200] | Train Loss: 0.1060, Train Acc: 0.9706 |
# Epoch [37/200] | Train Loss: 0.1123, Train Acc: 0.9755 |
# Epoch [38/200] | Train Loss: 0.1216, Train Acc: 0.9706 |
# Epoch [39/200] | Train Loss: 0.0951, Train Acc: 0.9902 |
# Epoch [40/200] | Train Loss: 0.1005, Train Acc: 0.9902 |
# Epoch [41/200] | Train Loss: 0.1132, Train Acc: 0.9755 |
# Epoch [42/200] | Train Loss: 0.0904, Train Acc: 0.9804 |
# Epoch [43/200] | Train Loss: 0.1267, Train Acc: 0.9755 |
# Epoch [44/200] | Train Loss: 0.0931, Train Acc: 0.9804 |
# Epoch [45/200] | Train Loss: 0.1019, Train Acc: 0.9755 |
# Epoch [46/200] | Train Loss: 0.0709, Train Acc: 0.9902 |
# Epoch [47/200] | Train Loss: 0.0821, Train Acc: 0.9804 |
# Epoch [48/200] | Train Loss: 0.0837, Train Acc: 0.9853 |
# Epoch [49/200] | Train Loss: 0.0791, Train Acc: 0.9804 |
# Epoch [50/200] | Train Loss: 0.0763, Train Acc: 0.9902 |
# Epoch [51/200] | Train Loss: 0.0724, Train Acc: 0.9853 |
# Epoch [52/200] | Train Loss: 0.0946, Train Acc: 0.9755 |
# Epoch [53/200] | Train Loss: 0.0881, Train Acc: 0.9804 |
# Epoch [54/200] | Train Loss: 0.0566, Train Acc: 0.9902 |
# Epoch [55/200] | Train Loss: 0.0788, Train Acc: 0.9804 |
# Epoch [56/200] | Train Loss: 0.0683, Train Acc: 0.9804 |
# Epoch [57/200] | Train Loss: 0.0554, Train Acc: 0.9902 |
# Epoch [58/200] | Train Loss: 0.0538, Train Acc: 0.9951 |
# Epoch [59/200] | Train Loss: 0.0668, Train Acc: 0.9804 |
# Epoch [60/200] | Train Loss: 0.1151, Train Acc: 0.9657 |
# Epoch [61/200] | Train Loss: 0.1006, Train Acc: 0.9559 |
# Epoch [62/200] | Train Loss: 0.0756, Train Acc: 0.9853 |
# Epoch [63/200] | Train Loss: 0.1209, Train Acc: 0.9461 |
# Epoch [64/200] | Train Loss: 0.0603, Train Acc: 0.9755 |
# Epoch [65/200] | Train Loss: 0.0676, Train Acc: 0.9853 |
# Epoch [66/200] | Train Loss: 0.0781, Train Acc: 0.9657 |
# Epoch [67/200] | Train Loss: 0.0689, Train Acc: 0.9755 |
# Epoch [68/200] | Train Loss: 0.0522, Train Acc: 0.9902 |
# Epoch [69/200] | Train Loss: 0.0878, Train Acc: 0.9706 |
# Epoch [70/200] | Train Loss: 0.0530, Train Acc: 0.9951 |
# Epoch [71/200] | Train Loss: 0.0533, Train Acc: 0.9853 |
# Epoch [72/200] | Train Loss: 0.0832, Train Acc: 0.9755 |
# Epoch [73/200] | Train Loss: 0.1068, Train Acc: 0.9657 |
# Epoch [74/200] | Train Loss: 0.0628, Train Acc: 0.9902 |
# Epoch [75/200] | Train Loss: 0.0531, Train Acc: 0.9902 |
# Epoch [76/200] | Train Loss: 0.0645, Train Acc: 0.9853 |
# Epoch [77/200] | Train Loss: 0.0361, Train Acc: 0.9951 |
# Epoch [78/200] | Train Loss: 0.0706, Train Acc: 0.9755 |
# Epoch [79/200] | Train Loss: 0.0459, Train Acc: 0.9902 |
# Epoch [80/200] | Train Loss: 0.0466, Train Acc: 0.9853 |
# Epoch [81/200] | Train Loss: 0.0355, Train Acc: 0.9951 |
# Epoch [82/200] | Train Loss: 0.0296, Train Acc: 0.9951 |
# Epoch [83/200] | Train Loss: 0.0241, Train Acc: 1.0000 |
# Epoch [84/200] | Train Loss: 0.0328, Train Acc: 0.9951 |
# Epoch [85/200] | Train Loss: 0.0343, Train Acc: 0.9902 |
# Epoch [86/200] | Train Loss: 0.0315, Train Acc: 0.9951 |
# Epoch [87/200] | Train Loss: 0.0900, Train Acc: 0.9706 |
# Epoch [88/200] | Train Loss: 0.0412, Train Acc: 0.9902 |
# Epoch [89/200] | Train Loss: 0.0489, Train Acc: 0.9853 |
# Epoch [90/200] | Train Loss: 0.0228, Train Acc: 1.0000 |
# Epoch [91/200] | Train Loss: 0.0361, Train Acc: 0.9902 |
# Epoch [92/200] | Train Loss: 0.0359, Train Acc: 0.9951 |
# Epoch [93/200] | Train Loss: 0.0334, Train Acc: 0.9951 |
# Epoch [94/200] | Train Loss: 0.0337, Train Acc: 0.9902 |
# Epoch [95/200] | Train Loss: 0.0812, Train Acc: 0.9804 |
# Epoch [96/200] | Train Loss: 0.0430, Train Acc: 0.9853 |
# Epoch [97/200] | Train Loss: 0.0294, Train Acc: 1.0000 |
# Epoch [98/200] | Train Loss: 0.0335, Train Acc: 0.9951 |
# Epoch [99/200] | Train Loss: 0.0361, Train Acc: 0.9902 |
# Epoch [100/200] | Train Loss: 0.0311, Train Acc: 0.9902 |
# Epoch [101/200] | Train Loss: 0.0529, Train Acc: 0.9804 |
# Epoch [102/200] | Train Loss: 0.0495, Train Acc: 0.9853 |
# Epoch [103/200] | Train Loss: 0.0204, Train Acc: 1.0000 |
# Epoch [104/200] | Train Loss: 0.0441, Train Acc: 0.9804 |
# Epoch [105/200] | Train Loss: 0.0198, Train Acc: 1.0000 |
# Epoch [106/200] | Train Loss: 0.0267, Train Acc: 0.9902 |
# Epoch [107/200] | Train Loss: 0.0151, Train Acc: 1.0000 |
# Epoch [108/200] | Train Loss: 0.0236, Train Acc: 1.0000 |
# Epoch [109/200] | Train Loss: 0.0186, Train Acc: 1.0000 |
# Epoch [110/200] | Train Loss: 0.0443, Train Acc: 0.9804 |
# Epoch [111/200] | Train Loss: 0.0206, Train Acc: 1.0000 |
# Epoch [112/200] | Train Loss: 0.0272, Train Acc: 0.9902 |
# Epoch [113/200] | Train Loss: 0.0160, Train Acc: 1.0000 |
# Epoch [114/200] | Train Loss: 0.0253, Train Acc: 0.9902 |
# Epoch [115/200] | Train Loss: 0.0370, Train Acc: 0.9902 |
# Epoch [116/200] | Train Loss: 0.0191, Train Acc: 0.9951 |
# Epoch [117/200] | Train Loss: 0.0302, Train Acc: 0.9902 |
# Epoch [118/200] | Train Loss: 0.0141, Train Acc: 1.0000 |
# Epoch [119/200] | Train Loss: 0.0163, Train Acc: 0.9951 |
# Epoch [120/200] | Train Loss: 0.0199, Train Acc: 1.0000 |
# Epoch [121/200] | Train Loss: 0.0313, Train Acc: 0.9902 |
# Epoch [122/200] | Train Loss: 0.0403, Train Acc: 0.9853 |
# Epoch [123/200] | Train Loss: 0.0226, Train Acc: 0.9951 |
# Epoch [124/200] | Train Loss: 0.0186, Train Acc: 1.0000 |
# Epoch [125/200] | Train Loss: 0.0256, Train Acc: 1.0000 |
# Epoch [126/200] | Train Loss: 0.0231, Train Acc: 0.9951 |
# Epoch [127/200] | Train Loss: 0.0124, Train Acc: 1.0000 |
# Epoch [128/200] | Train Loss: 0.0373, Train Acc: 0.9902 |
# Epoch [129/200] | Train Loss: 0.0242, Train Acc: 0.9951 |
# Epoch [130/200] | Train Loss: 0.0118, Train Acc: 1.0000 |
# Epoch [131/200] | Train Loss: 0.0470, Train Acc: 0.9902 |
# Epoch [132/200] | Train Loss: 0.0156, Train Acc: 1.0000 |
# Epoch [133/200] | Train Loss: 0.0162, Train Acc: 1.0000 |
# Epoch [134/200] | Train Loss: 0.0210, Train Acc: 0.9951 |
# Epoch [135/200] | Train Loss: 0.0202, Train Acc: 1.0000 |
# Epoch [136/200] | Train Loss: 0.0125, Train Acc: 1.0000 |
# Epoch [137/200] | Train Loss: 0.0150, Train Acc: 1.0000 |
# Epoch [138/200] | Train Loss: 0.0147, Train Acc: 1.0000 |
# Epoch [139/200] | Train Loss: 0.0157, Train Acc: 1.0000 |
# Epoch [140/200] | Train Loss: 0.0132, Train Acc: 1.0000 |
# Epoch [141/200] | Train Loss: 0.0191, Train Acc: 1.0000 |
# Epoch [142/200] | Train Loss: 0.0115, Train Acc: 1.0000 |
# Epoch [143/200] | Train Loss: 0.0114, Train Acc: 1.0000 |
# Epoch [144/200] | Train Loss: 0.0125, Train Acc: 1.0000 |
# Epoch [145/200] | Train Loss: 0.0143, Train Acc: 1.0000 |
# Epoch [146/200] | Train Loss: 0.0215, Train Acc: 0.9951 |
# Epoch [147/200] | Train Loss: 0.0168, Train Acc: 1.0000 |
# Epoch [148/200] | Train Loss: 0.0459, Train Acc: 0.9902 |
# Epoch [149/200] | Train Loss: 0.0096, Train Acc: 1.0000 |
# Epoch [150/200] | Train Loss: 0.0144, Train Acc: 1.0000 |
# Epoch [151/200] | Train Loss: 0.0220, Train Acc: 1.0000 |
# Epoch [152/200] | Train Loss: 0.0303, Train Acc: 0.9902 |
# Epoch [153/200] | Train Loss: 0.0108, Train Acc: 1.0000 |
# Epoch [154/200] | Train Loss: 0.0155, Train Acc: 1.0000 |
# Epoch [155/200] | Train Loss: 0.0103, Train Acc: 1.0000 |
# Epoch [156/200] | Train Loss: 0.0132, Train Acc: 1.0000 |
# Epoch [157/200] | Train Loss: 0.0156, Train Acc: 1.0000 |
# Epoch [158/200] | Train Loss: 0.0152, Train Acc: 1.0000 |
# Epoch [159/200] | Train Loss: 0.0123, Train Acc: 1.0000 |
# Epoch [160/200] | Train Loss: 0.0170, Train Acc: 0.9951 |
# Epoch [161/200] | Train Loss: 0.0382, Train Acc: 0.9902 |
# Epoch [162/200] | Train Loss: 0.0122, Train Acc: 1.0000 |
# Epoch [163/200] | Train Loss: 0.0205, Train Acc: 0.9951 |
# Epoch [164/200] | Train Loss: 0.0156, Train Acc: 1.0000 |
# Epoch [165/200] | Train Loss: 0.0176, Train Acc: 1.0000 |
# Epoch [166/200] | Train Loss: 0.0107, Train Acc: 1.0000 |
# Epoch [167/200] | Train Loss: 0.0254, Train Acc: 0.9951 |
# Epoch [168/200] | Train Loss: 0.0416, Train Acc: 0.9853 |
# Early stopping triggered.
# Test Loss: 1.1068, Test Accuracy: 0.7115, Test AUC: 0.7559

# %% [markdown]
# ## | 6. Results

# %%
rows = []

for disorder, dicts in all_results.items():
    for dict_name, df_results in dicts.items():
        for df_name, metrics in df_results.items():
            row = {
                'Disorder': disorder,
                'Dict': dict_name,
                'DataFrame': df_name,
                'Accuracy': metrics['accuracy'],
                'AUC': metrics['auc'],
                'Classification Report': metrics['classification_report']
            }
            
            rows.append(row)

results_df = pd.DataFrame(rows)
results_df.to_csv(f'{experiment_name}.csv', index=False)

# best_results = df.loc[df.groupby('Disorder')['Accuracy'].idxmax()]
results_df
# Out:
#                                Disorder                      Dict  \
# 0                    Addictive disorder     df_dict_psd_all_bands
# 1                    Addictive disorder      df_dict_fc_all_bands
# 2                    Addictive disorder  df_dict_psd_fc_all_bands
# 3                    Addictive disorder          df_dict_psd_band
# 4                    Addictive disorder          df_dict_psd_band
# ..                                  ...                       ...
# 121  Trauma and stress related disorder       df_dict_psd_fc_band
# 122  Trauma and stress related disorder       df_dict_psd_fc_band
# 123  Trauma and stress related disorder       df_dict_psd_fc_band
# 124  Trauma and stress related disorder       df_dict_psd_fc_band
# 125  Trauma and stress related disorder       df_dict_psd_fc_band
#
#             DataFrame  Accuracy       AUC  \
# 0       psd_all_bands  0.866667  0.945235
# 1        fc_all_bands  0.853333  0.894737
# 2    psd_fc_all_bands  0.840000  0.923898
# 3           psd_delta  0.933333  0.973684
# 4           psd_theta  0.893333  0.978663
# ..                ...       ...       ...
# 121      psd_fc_theta  0.769231  0.869822
# 122      psd_fc_alpha  0.807692  0.924556
# 123       psd_fc_beta  0.826923  0.877219
# 124   psd_fc_highbeta  0.788462  0.869822
# 125      psd_fc_gamma  0.711538  0.755917
#
#                                  Classification Report
# 0    {'0': {'precision': 0.85, 'recall': 0.89473684...
# 1    {'0': {'precision': 0.8857142857142857, 'recal...
# 2    {'0': {'precision': 0.8421052631578947, 'recal...
# 3    {'0': {'precision': 0.9024390243902439, 'recal...
# 4    {'0': {'precision': 0.8571428571428571, 'recal...
# ..                                                 ...
# 121  {'0': {'precision': 0.75, 'recall': 0.80769230...
# 122  {'0': {'precision': 0.7666666666666667, 'recal...
# 123  {'0': {'precision': 0.84, 'recall': 0.80769230...
# 124  {'0': {'precision': 0.7777777777777778, 'recal...
# 125  {'0': {'precision': 0.6896551724137931, 'recal...
#
# [126 rows x 6 columns]

# %% [markdown]
# ## | 7. Conclusions, Problems, and Limitations

# %% [markdown]
# [need to update]
