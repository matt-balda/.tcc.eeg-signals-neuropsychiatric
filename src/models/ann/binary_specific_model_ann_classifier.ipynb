# %% [markdown]
# | Description
#
# Authors of notebook: Mateus Balda and Alessandro Bof
#
# Reference paper and dataset: https://www.frontiersin.org/journals/psychiatry/articles/10.3389/fpsyt.2021.707581/full
#
# | Notebook structure
# 0. Setup and Imports
# 1. Utility Functions
# 2. Data Loading and Preprocessing
# 3. Data Preparation for Training
# 4. Model Definition
# 5. Training and Evaluation
# 6. Results
# 7. Conclusions, Problems, and Limitations
#
# | Training
# 1. Binary classification for `y` specific.disorder (Disorder vs. Health control)
# 2. Balancing using BorderlineSMOTE for minority classes
# 3. Training across the 21 subsets

# %% [markdown]
# ## | 0. Setup and Imports

# %%
# !pip install -q imbalanced-learn==0.12.4;

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from IPython.display import FileLink, display, HTML
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.impute import KNNImputer

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau

from imblearn.over_sampling import BorderlineSMOTE

from warnings import filterwarnings
filterwarnings('ignore')

torch.__version__
# Out:
# '2.5.1+cu124'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
experiment_name = "binary_classification_specifc_disorder_ann"
device
# Out:
# device(type='cuda')

# %%
np.random.seed(123)
torch.manual_seed(123)

# %% [markdown]
# ## | 1. Utility Functions

# %% [markdown]
# ### 1. OUTLIERS

# %%
def detect_outliers_summary(df):
    outliers_summary = {}

    for col in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_limit = Q1 - 1.5 * IQR
        upper_limit = Q3 + 1.5 * IQR

        outliers = df[(df[col] < lower_limit) | (df[col] > upper_limit)][col]
        
        outliers_summary[col] = {
            'num_outliers': len(outliers),
            'percent_outliers': len(outliers) / len(df) * 100,
            'outliers': outliers.tolist(),
            'lower_limit': lower_limit,
            'upper_limit': upper_limit
        }

    return pd.DataFrame(outliers_summary).T


def treat_all_outliers_iqr(df, factor=1.5):
    df_treated = df.copy()
    
    for column in df_treated.select_dtypes(include=[np.number]).columns:
        Q1 = np.percentile(df_treated[column], 25)
        Q3 = np.percentile(df_treated[column], 75)
        IQR = Q3 - Q1

        lower_bound = Q1 - factor * IQR
        upper_bound = Q3 + factor * IQR

        df_treated[column] = np.clip(df_treated[column], lower_bound, upper_bound)

    return df_treated

# %% [markdown]
# ### 2. NANS

# %%
def remove_missing_columns(df, threshold=0.5):
    limit = int(threshold * len(df))
    df = df.dropna(thresh=limit, axis=1)
    return df
    
def find_most_null_column(df, threshold=0.5):
    null_ratios = df.isnull().mean()
    for col, ration in null_ratios.items():
        if ration > threshold:
            return col
    return None

def analyze_missing_values(df):
    missing_values = df.isnull().sum()
    missing_values = missing_values[missing_values > 0]
    total_number_nans = df.isnull().sum().sum()
    
    return missing_values, total_number_nans

def handle_nans(df):
    columns_with_nans = df.columns[df.isnull().any()].tolist()
    
    knn_imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
    
    df_imputed = pd.DataFrame(knn_imputer.fit_transform(df[columns_with_nans]),
                                columns=columns_with_nans)
    
    df[columns_with_nans] = df_imputed[columns_with_nans]
    
    return df

# %% [markdown]
# ### 3. SETS & SUBSETS

# %%
class Sets:
    # AB = PSD (Power Spectral Density) 19 * 6
    # COH = FC (Functional Connectivity) 171 * 6
    
    def __init__(self, dataframe: pd.DataFrame):
        
        if not isinstance(dataframe, pd.DataFrame):
            raise ValueError("The parameter must be a pandas DataFrame")
        
        self.df = dataframe.copy()
        self.df_ab_psd = None
        self.df_coh_fc = None
        self.df_ab_psd_coh_fc = None
        
        self.__create_df_psd()
        self.__create_df_fc()
        self.__create_union_psd_fc()

    # 19 (6 bands)
    def __create_df_psd(self):
        columns_AB = [col for col in self.df.columns if col.startswith('AB')]
        self.df_ab_psd = self.df[columns_AB]
    
    # 171 (6 bands)
    def __create_df_fc(self):
        columns_COH = [col for col in self.df.columns if col.startswith('COH')]
        self.df_coh_fc = self.df[columns_COH]
        
    def __create_union_psd_fc(self):
        if self.df_ab_psd is not None and self.df_coh_fc is not None:
            self.df_ab_psd_coh_fc = pd.concat([self.df_ab_psd, self.df_coh_fc], axis=1)
        else:
            raise ValueError("Subsets AB and COH were not created correctly")

    def create_dfs_bands(self, bands: list[str] = None, df: pd.DataFrame = None):
        dfs_bands = {}
        
        if bands is None:
            bands = ['delta', 'theta', 'alpha', 'beta', 'highbeta','gamma']
        
        for band in bands:
            columns_band = [col for col in df.columns if f'.{band}.' in col]
            if columns_band:
                dfs_bands[band] = df[columns_band]
        
        return dfs_bands

# %% [markdown]
# ## | 2. Data Loading and Preprocessing

# %%
df = pd.read_csv('../input/eeg-psychiatric-disorders-dataset/EEG.machinelearing_data_BRMH.csv')
df.shape
# Out:
# (945, 1149)

# %%
# Checking / imputing Nan

output1 = analyze_missing_values(df)
output2 = find_most_null_column(df)
df = remove_missing_columns(df)
output3 = analyze_missing_values(df)
df = handle_nans(df)

display(output1)
display(HTML('<hr>'))
display(output2)
display(HTML('<hr>'))
display(output3)
display(df.shape)
display(HTML('<hr>'))
display(df.isna().sum().sum())
display(df)
# Out:
# (education        15
#  IQ               13
#  Unnamed: 122    945
#  dtype: int64,
#  973)
# <hr>
# 'Unnamed: 122'
# <hr>
# (education    15
#  IQ           13
#  dtype: int64,
#  28)
# (945, 1148)
# <hr>
# 0
#      no. sex   age    eeg.date  education          IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30   13.43871  101.580472  Addictive disorder
# 1      2   M  37.0    2012.9.6    6.00000  120.000000  Addictive disorder
# 2      3   M  32.0   2012.9.10   16.00000  113.000000  Addictive disorder
# 3      4   M  35.0   2012.10.8   18.00000  126.000000  Addictive disorder
# 4      5   M  36.0  2012.10.18   16.00000  112.000000  Addictive disorder
# ..   ...  ..   ...         ...        ...         ...                 ...
# 940  941   M  22.0   2014.8.28   13.00000  116.000000     Healthy control
# 941  942   M  26.0   2014.9.19   13.00000  118.000000     Healthy control
# 942  943   M  26.0   2014.9.27   16.00000  113.000000     Healthy control
# 943  944   M  24.0   2014.9.20   13.00000  107.000000     Healthy control
# 944  945   M  21.0  2015.10.23   13.00000  105.000000     Healthy control
#
#         specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0    Alcohol use disorder         35.998557         21.717375  ...
# 1    Alcohol use disorder         13.425118         11.002916  ...
# 2    Alcohol use disorder         29.941780         27.544684  ...
# 3    Alcohol use disorder         21.496226         21.846832  ...
# 4    Alcohol use disorder         37.775667         33.607679  ...
# ..                    ...               ...               ...  ...
# 940       Healthy control         41.851823         36.771496  ...
# 941       Healthy control         18.986856         19.401387  ...
# 942       Healthy control         28.781317         32.369230  ...
# 943       Healthy control         19.929100         25.196375  ...
# 944       Healthy control         65.195346         69.241972  ...
#
#      COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0                55.989192              16.739679              23.452271
# 1                45.595619              17.510824              26.777368
# 2                99.475453              70.654171              39.131547
# 3                59.986561              63.822201              36.478254
# 4                61.462720              59.166097              51.465531
# ..                     ...                    ...                    ...
# 940              82.905657              34.850706              63.970519
# 941              65.917918              66.700117              44.756285
# 942              61.040959              27.632209              45.552852
# 943              99.113664              48.328934              41.248470
# 944              78.600293              68.255430              70.687410
#
#      COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                45.678820              30.167520              16.918761
# 1                28.201062              57.108861              32.375401
# 2                69.920996              71.063644              38.534505
# 3                47.117006              84.658376              24.724096
# 4                58.635415              80.685608              62.138436
# ..                     ...                    ...                    ...
# 940              63.982003              51.244725              62.203684
# 941              49.787513              98.905995              54.021304
# 942              33.638817              46.690983              19.382928
# 943              28.192238              48.665743              42.007147
# 944              74.433908              74.294750              53.254681
#
#      COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                48.850427               9.422630              34.507082
# 1                60.351749              13.900981              57.831848
# 2                69.908764              27.180532              64.803155
# 3                50.299349              35.319695              79.822944
# 4                75.888749              61.003944              87.455509
# ..                     ...                    ...                    ...
# 940              62.062237              31.013031              31.183413
# 941              93.902401              52.740396              92.807331
# 942              41.050717               7.045821              41.962451
# 943              28.735945              27.176500              27.529522
# 944              72.755265              47.810386              80.166825
#
#      COH.F.gamma.r.O1.s.O2
# 0                28.613029
# 1                43.463261
# 2                31.485799
# 3                41.141873
# 4                70.531662
# ..                     ...
# 940              98.325230
# 941              56.320868
# 942              19.092111
# 943              20.028446
# 944              64.380273
#
# [945 rows x 1148 columns]

# %%
# detecting outliers

outliers_summary = detect_outliers_summary(df)
outliers_summary.to_csv('outliers_summary.csv', index=True)
outliers_summary['num_outliers'].sum()
# Out:
# 26452

# %%
label_encoder = LabelEncoder()
target_name = 'specific.disorder'

X = df.iloc[:,8:]
target = df[target_name]

quantitative_features = df.loc[:, ['age', 'education', 'IQ']]

sex = df['sex']
sex_encoded = label_encoder.fit_transform(sex)
sex_encoded = pd.Series(sex_encoded, name='sex')

X = pd.concat([quantitative_features, sex_encoded, X], axis=1)

X.shape, target.shape, quantitative_features.shape, sex.shape
# Out:
# ((945, 1144), (945,), (945, 3), (945,))

# %%
disorders = np.unique(target).tolist()
disorders.remove('Healthy control')
disorders.remove('Obsessive compulsitve disorder')
disorders.remove('Schizophrenia')
disorders
# Out:
# ['Acute stress disorder',
#  'Adjustment disorder',
#  'Alcohol use disorder',
#  'Behavioral addiction disorder',
#  'Bipolar disorder',
#  'Depressive disorder',
#  'Panic disorder',
#  'Posttraumatic stress disorder',
#  'Social anxiety disorder']

# %%
X_concated = pd.concat([X, target], axis=1)

display(X.head())
display(X_concated.head())
display(X.isna().sum().sum())
display(X_concated.isna().sum().sum())
# Out:
#     age  education          IQ  sex  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0  57.0   13.43871  101.580472    1         35.998557         21.717375
# 1  37.0    6.00000  120.000000    1         13.425118         11.002916
# 2  32.0   16.00000  113.000000    1         29.941780         27.544684
# 3  35.0   18.00000  126.000000    1         21.496226         21.846832
# 4  36.0   16.00000  112.000000    1         37.775667         33.607679
#
#    AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  ...  \
# 0        21.518280        26.825048        26.611516        25.732649  ...
# 1        11.942516        15.272216        14.151570        12.456034  ...
# 2        17.150159        23.608960        27.087811        13.541237  ...
# 3        17.364316        13.833701        14.100954        13.100939  ...
# 4        21.865556        21.771413        22.854536        21.456377  ...
#
#    COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0              55.989192              16.739679              23.452271
# 1              45.595619              17.510824              26.777368
# 2              99.475453              70.654171              39.131547
# 3              59.986561              63.822201              36.478254
# 4              61.462720              59.166097              51.465531
#
#    COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0              45.678820              30.167520              16.918761
# 1              28.201062              57.108861              32.375401
# 2              69.920996              71.063644              38.534505
# 3              47.117006              84.658376              24.724096
# 4              58.635415              80.685608              62.138436
#
#    COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0              48.850427               9.422630              34.507082
# 1              60.351749              13.900981              57.831848
# 2              69.908764              27.180532              64.803155
# 3              50.299349              35.319695              79.822944
# 4              75.888749              61.003944              87.455509
#
#    COH.F.gamma.r.O1.s.O2
# 0              28.613029
# 1              43.463261
# 2              31.485799
# 3              41.141873
# 4              70.531662
#
# [5 rows x 1144 columns]
#     age  education          IQ  sex  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 0  57.0   13.43871  101.580472    1         35.998557         21.717375
# 1  37.0    6.00000  120.000000    1         13.425118         11.002916
# 2  32.0   16.00000  113.000000    1         29.941780         27.544684
# 3  35.0   18.00000  126.000000    1         21.496226         21.846832
# 4  36.0   16.00000  112.000000    1         37.775667         33.607679
#
#    AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  ...  \
# 0        21.518280        26.825048        26.611516        25.732649  ...
# 1        11.942516        15.272216        14.151570        12.456034  ...
# 2        17.150159        23.608960        27.087811        13.541237  ...
# 3        17.364316        13.833701        14.100954        13.100939  ...
# 4        21.865556        21.771413        22.854536        21.456377  ...
#
#    COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  COH.F.gamma.o.Pz.s.O2  \
# 0              16.739679              23.452271              45.678820
# 1              17.510824              26.777368              28.201062
# 2              70.654171              39.131547              69.920996
# 3              63.822201              36.478254              47.117006
# 4              59.166097              51.465531              58.635415
#
#    COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  COH.F.gamma.p.P4.s.O2  \
# 0              30.167520              16.918761              48.850427
# 1              57.108861              32.375401              60.351749
# 2              71.063644              38.534505              69.908764
# 3              84.658376              24.724096              50.299349
# 4              80.685608              62.138436              75.888749
#
#    COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  COH.F.gamma.r.O1.s.O2  \
# 0               9.422630              34.507082              28.613029
# 1              13.900981              57.831848              43.463261
# 2              27.180532              64.803155              31.485799
# 3              35.319695              79.822944              41.141873
# 4              61.003944              87.455509              70.531662
#
#       specific.disorder
# 0  Alcohol use disorder
# 1  Alcohol use disorder
# 2  Alcohol use disorder
# 3  Alcohol use disorder
# 4  Alcohol use disorder
#
# [5 rows x 1145 columns]
# 0
# 0

# %%
# treat outliers X_concated

X = treat_all_outliers_iqr(X, factor=1.5)
outliers_summary = detect_outliers_summary(X)
outliers_summary['num_outliers'].sum()
# Out:
# 0

# %%
binary_datasets = {}

for disorder in disorders:
    
    mask = X_concated[target_name].isin(['Healthy control', disorder])
    
    df_filtered = X_concated[mask]
    df_filtered_X = X.loc[mask]
    
    y_binary = df_filtered[target_name].apply(lambda x: 0 if x == 'Healthy control' else 1)
    
    borderline_smote = BorderlineSMOTE(kind='borderline-2', random_state=42, k_neighbors=10, m_neighbors=15)
    X_resampled, y_resampled = borderline_smote.fit_resample(df_filtered_X, y_binary)
    
    dataset = pd.concat([X_resampled, y_resampled], axis=1)
    
    binary_datasets[disorder] = {
        'data': dataset,
        'labels': ['Healthy control', disorder]
    }

# %%
binary_datasets[disorders[0]]['data']
# Out:
#            age  education          IQ  sex  AB.A.delta.a.FP1  \
# 0    19.700000  13.000000  103.000000    0         11.906893
# 1    19.940000  13.000000   81.000000    0         19.849686
# 2    19.260000  12.000000   86.600000    0         28.675766
# 3    25.610000  16.000000  108.000000    0         12.187185
# 4    24.580000  16.000000  110.000000    0          7.414042
# ..         ...        ...         ...  ...               ...
# 185  23.636111  12.460159   88.624699    0         24.991060
# 186  39.661676  12.240593  103.624002    0         14.579592
# 187  19.821461  16.000000  133.028511    0         17.654770
# 188  21.288249  12.022254   94.278175    0         16.180424
# 189  24.902333  14.389570  119.863495    0         28.722673
#
#      AB.A.delta.b.FP2  AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  \
# 0            9.707117        12.455193        14.208682        14.626761
# 1           15.705436        17.863425        25.394940        23.916326
# 2           25.368575        25.912400        29.496788        27.661687
# 3           22.798506        14.977824        13.852327        21.125052
# 4            7.173058         9.649153         9.033750         9.068607
# ..                ...              ...              ...              ...
# 185         21.790181        22.814510        27.422891        25.339652
# 186         14.081592        13.329846        10.602656        16.347242
# 187         13.746061         8.336923        10.146754        13.001747
# 188         17.626350        17.813587        12.328262        11.149706
# 189         37.327172        27.818018        23.818943        23.551339
#
#      AB.A.delta.f.F4  ...  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0          19.885365  ...              69.067513              76.479372
# 1          17.032967  ...              71.257029              74.666719
# 2          26.305027  ...              38.850170              26.148667
# 3          12.611427  ...              32.936146              48.492975
# 4          10.328719  ...              21.278355              22.090032
# ..               ...  ...                    ...                    ...
# 185        23.790325  ...              40.679754              43.349875
# 186        17.618628  ...              80.909684              80.956008
# 187        15.361196  ...              62.423946              61.543612
# 188        12.025291  ...              39.672862              46.860606
# 189        22.706705  ...              48.179674              45.615034
#
#      COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                81.723959              82.075368              65.408405
# 1                77.063648              83.056486              68.744644
# 2                47.985078              51.488546              14.825718
# 3                72.469967              45.758411              37.811075
# 4                75.129025              46.765039              12.676249
# ..                     ...                    ...                    ...
# 185              58.108614              60.001815              32.401796
# 186              87.373216              87.263718              78.826967
# 187              69.530314              80.809356              49.325702
# 188              46.651085              73.083370              42.194749
# 189              55.702417              74.844985              40.351338
#
#      COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                84.541111              58.012987              85.867872
# 1                83.468447              76.265372              90.029157
# 2                43.673794              13.046605              58.780474
# 3                70.308929               9.725031              32.678063
# 4                74.705851               9.431155              48.014229
# ..                     ...                    ...                    ...
# 185              56.697487              20.368472              52.072205
# 186              89.175762              71.807474              81.009151
# 187              75.090400              39.760503              75.953645
# 188              74.792077              29.596620              84.976867
# 189              67.946291              28.616925              69.945983
#
#      COH.F.gamma.r.O1.s.O2  specific.disorder
# 0                78.224773                  1
# 1                88.220089                  1
# 2                35.502275                  1
# 3                68.764822                  1
# 4                54.848927                  1
# ..                     ...                ...
# 185              53.363849                  1
# 186              86.173498                  1
# 187              59.867818                  1
# 188              47.631831                  1
# 189              53.747447                  1
#
# [190 rows x 1145 columns]

# %%
sets_binaries = {}

for disorder, bin_data in binary_datasets.items():
    df_bin = bin_data['data'].copy()
    
    X_bin = df_bin.drop(columns=[target_name,'age', 'education', 'IQ', 'sex'], errors='ignore') 
    X_quantitative = df_bin.loc[:, ['age', 'education', 'IQ', 'sex']]
    y_bin = df_bin[target_name] if target_name in df_bin.columns else df_bin.iloc[:, -1]

    sets = Sets(dataframe=X_bin)

    sets_binaries[disorder] = {
        'sets': sets,
        'labels': bin_data['labels'],
        'X_quantitative': X_quantitative,
        'y': y_bin
    }

# %%
for disorder in sets_binaries:
    sets = sets_binaries[disorder]['sets']

    dfs_bands_psd = sets.create_dfs_bands(df=sets.df_ab_psd)
    dfs_bands_fc = sets.create_dfs_bands(df=sets.df_coh_fc)
    dfs_bands_psd_fc = sets.create_dfs_bands(df=sets.df_ab_psd_coh_fc)

    sets_binaries[disorder].update({
        'dfs_bands_psd': dfs_bands_psd,
        'dfs_bands_fc': dfs_bands_fc,
        'dfs_bands_psd_fc': dfs_bands_psd_fc,
    })

# %%
for disorder, data in sets_binaries.items():
    print(f"Disorder: {disorder}")
    print(f"Labels: {data['labels']}")
    print(f"Number of samples: {len(data['y'])}")
    print(f"Quantitative features shape: {data['X_quantitative'].shape}")
    print(f"PSD bands shape: {data['sets'].df_ab_psd.shape}")
    print(f"FC bands shape: {data['sets'].df_coh_fc.shape}")
    print(f"PSD + FC bands shape: {data['sets'].df_ab_psd_coh_fc.shape}\n")
# Out:
# Disorder: Acute stress disorder
# Labels: ['Healthy control', 'Acute stress disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Adjustment disorder
# Labels: ['Healthy control', 'Adjustment disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Alcohol use disorder
# Labels: ['Healthy control', 'Alcohol use disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Behavioral addiction disorder
# Labels: ['Healthy control', 'Behavioral addiction disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Bipolar disorder
# Labels: ['Healthy control', 'Bipolar disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Depressive disorder
# Labels: ['Healthy control', 'Depressive disorder']
# Number of samples: 398
# Quantitative features shape: (398, 4)
# PSD bands shape: (398, 114)
# FC bands shape: (398, 1026)
# PSD + FC bands shape: (398, 1140)
#
# Disorder: Panic disorder
# Labels: ['Healthy control', 'Panic disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Posttraumatic stress disorder
# Labels: ['Healthy control', 'Posttraumatic stress disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)
#
# Disorder: Social anxiety disorder
# Labels: ['Healthy control', 'Social anxiety disorder']
# Number of samples: 190
# Quantitative features shape: (190, 4)
# PSD bands shape: (190, 114)
# FC bands shape: (190, 1026)
# PSD + FC bands shape: (190, 1140)

# %%
dfs_dicts_binaries = {}

for disorder, data in sets_binaries.items():
    dfs_psd = data['dfs_bands_psd']
    dfs_fc = data['dfs_bands_fc']
    dfs_psd_fc = data['dfs_bands_psd_fc']
    sets = data['sets']

    df_dict_psd_all_bands = {
        'psd_all_bands': sets.df_ab_psd,
    }

    df_dict_fc_all_bands = {
        'fc_all_bands': sets.df_coh_fc,
    }

    df_dict_psd_fc_all_bands = {
        'psd_fc_all_bands': sets.df_ab_psd_coh_fc,
    }

    df_dict_psd_band = {
        f'psd_{band}': dfs_psd[band] for band in dfs_psd
    }

    df_dict_fc_band = {
        f'fc_{band}': dfs_fc[band] for band in dfs_fc
    }

    df_dict_psd_fc_band = {
        f'psd_fc_{band}': dfs_psd_fc[band] for band in dfs_psd_fc
    }

    dfs_dicts_binaries[disorder] = {
        'df_dict_psd_all_bands': df_dict_psd_all_bands,
        'df_dict_fc_all_bands': df_dict_fc_all_bands,
        'df_dict_psd_fc_all_bands': df_dict_psd_fc_all_bands,
        'df_dict_psd_band': df_dict_psd_band,
        'df_dict_fc_band': df_dict_fc_band,
        'df_dict_psd_fc_band': df_dict_psd_fc_band,
    }

# %%
import torch.nn as nn
import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import gc

class EEGANNClassifier(nn.Module):
    def __init__(self, input_dim, neurons, dropout=0.10):
        super(EEGANNClassifier, self).__init__()

        self.layer1 = nn.Linear(input_dim, neurons[0])
        self.layer2 = nn.Linear(neurons[0], neurons[1])
        self.layer3 = nn.Linear(neurons[1], neurons[2])
        self.layer4 = nn.Linear(neurons[2], neurons[3])
        self.output_layer = nn.Linear(neurons[3], 1)

        self.bn1 = nn.BatchNorm1d(neurons[0])
        self.bn2 = nn.BatchNorm1d(neurons[1])
        self.bn3 = nn.BatchNorm1d(neurons[2])
        self.bn4 = nn.BatchNorm1d(neurons[3])

        self.gelu = nn.GELU()
        self.dropout = nn.Dropout(p=dropout)

    def forward(self, x):
        x = self.gelu(self.bn1(self.layer1(x))) 
        x = self.dropout(x)

        x = self.gelu(self.bn2(self.layer2(x)))
        x = self.dropout(x)

        x = self.gelu(self.bn3(self.layer3(x)))
        x = self.dropout(x)

        x = self.gelu(self.bn4(self.layer4(x)))
        x = self.output_layer(x)

        return x.squeeze(1)  # shape (batch,)

    def fit(self, train_loader, epochs=200, lr=1e-3, weight_decay=1e-4, device='cpu', patience=20):
        self.to(device)
        criterion = nn.BCEWithLogitsLoss()
        optimizer = optim.Adam(self.parameters(), lr=lr, weight_decay=weight_decay)
        scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True)

        best_loss = float('inf')
        patience_counter = 0
        history = {'train_loss': [], 'train_acc': []}
        
        for epoch in range(epochs):
            self.train()
            running_loss = 0.0
            correct, total = 0, 0
            
            for inputs, targets in train_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                
                assert set(targets.cpu().tolist()).issubset({0.0, 1.0}), "Targets must be binary (0 or 1)"
                
                optimizer.zero_grad()
                outputs = self(inputs)
                
                # shape
                outputs = outputs.view(-1).float()
                targets = targets.view(-1).float() 
                
                assert outputs.shape == targets.shape, "Outputs and targets must have the same shape"
                assert outputs.dtype == torch.float32 and targets.dtype == torch.float32, "Outputs and targets must be float32"
                assert outputs.dim() == 1 and targets.dim() == 1, "Outputs and targets must be 1-dimensional"
                
                loss = criterion(outputs, targets)
                loss.backward()
                optimizer.step()
                
                preds = (torch.sigmoid(outputs) > 0.5).long()
                correct += (preds == targets.long()).sum().item()
                total += targets.size(0)
                running_loss += loss.item() * inputs.size(0)
                
            train_acc = correct / total
            epoch_loss = running_loss / len(train_loader.dataset)
            history['train_acc'].append(train_acc)
            history['train_loss'].append(epoch_loss)
            
            min_delta = 1e-4
            if best_loss - epoch_loss > min_delta:
                best_loss = epoch_loss
                patience_counter = 0
            else:
                patience_counter += 1

            if patience_counter >= patience:
                print("Early stopping triggered.")
                break
            
            scheduler.step(epoch_loss)
            
            print(
                f"Epoch [{epoch+1}/{epochs}] | "
                f"Train Loss: {epoch_loss:.4f}, Train Acc: {train_acc:.4f} | "
            )
        
        return history


    def test(self, test_loader, device='cpu'):
        self.to(device)
        self.eval()
        
        all_preds, all_probas, all_targets = [], [], []
        correct, total = 0, 0
        test_loss = 0.0
        criterion = nn.BCEWithLogitsLoss()
        history = {'test_loss': [], 'test_acc': [], 'test_auc': []}

        with torch.no_grad():
            for inputs, targets in test_loader:
                inputs, targets = inputs.to(device), targets.to(device)

                outputs = self(inputs)
                
                outputs = outputs.view(-1).float()
                targets = targets.view(-1).float() 
                
                loss = criterion(outputs, targets)
                
                proba = torch.sigmoid(outputs)
                pred = (proba > 0.5).long()

                all_preds.append(pred.cpu())
                all_probas.append(proba.cpu())
                all_targets.append(targets.cpu())
                
                correct += (pred == targets.long()).sum().item()
                total += targets.size(0)
                test_loss += loss.item() * inputs.size(0)
        
        test_acc = correct / total
        test_loss /= len(test_loader.dataset)
        history['test_loss'].append(test_loss)
        history['test_acc'].append(test_acc)
        
        y_true = torch.cat(all_targets).numpy().astype(int)
        y_pred = torch.cat(all_preds).numpy().astype(int)
        y_proba = torch.cat(all_probas).numpy().astype(float)

        try:
            auc = roc_auc_score(y_true, y_proba)
        except ValueError:
            auc = float('nan')

        report = classification_report(y_true, y_pred, output_dict=True)
        history['test_auc'].append(auc)

        print(
            f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}, Test AUC: {auc:.4f}"
            )
        
        return test_acc, auc, report, history

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
import gc

# %%
all_results = {}

for disorder, dicts in dfs_dicts_binaries.items():
    print(f"\n=== Disorder: {disorder} ===")
    
    y_binary = sets_binaries[disorder]['y']
    X_quantitative = sets_binaries[disorder]['X_quantitative']
    labels = sets_binaries[disorder]['labels']
    
    all_results[disorder] = {}
    
    for dict_name, df_dict in dicts.items():
        if not dict_name.startswith('df_dict_'):
            continue
        
        for df_name, df in df_dict.items():
            print(f"\n--- Processing: {df_name} ---")
            print("Shape:", df.shape)
            print("Missing values:", df.isna().sum().sum())
            
            df_full = pd.concat([X_quantitative, df], axis=1)
            assert all(df_full.index == y_binary.index), 'Misaligned indexes'
            
            X_train, X_test, y_train, y_test = train_test_split(
                df_full,
                y_binary,
                train_size=0.80,
                stratify=y_binary,
                random_state=42
            )
            
            X_cols = X_train.drop(columns=['sex']).columns
            
            scaler = RobustScaler()
            X_train_scaled = scaler.fit_transform(X_train[X_cols])
            X_test_scaled = scaler.transform(X_test[X_cols])
            
            X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_cols, index=X_train.index)
            X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_cols, index=X_test.index)

            X_train_final = pd.concat([X_train_scaled_df, X_train['sex']], axis=1)
            X_test_final = pd.concat([X_test_scaled_df, X_test['sex']], axis=1)

            X_train_array = X_train_final.to_numpy()
            X_test_array = X_test_final.to_numpy()
            y_train_array = y_train.to_numpy()
            y_test_array = y_test.to_numpy()
            
            # tensors
            X_train_tensor = torch.tensor(X_train_array, dtype=torch.float32).to(device)
            y_train_tensor = torch.tensor(y_train_array, dtype=torch.long).to(device)
            X_test_tensor = torch.tensor(X_test_array, dtype=torch.float32).to(device)
            y_test_tensor = torch.tensor(y_test_array, dtype=torch.long).to(device)
            
            train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
            test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

            train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, drop_last=True)
            test_loader = DataLoader(test_dataset, batch_size=32)
            
            model = EEGANNClassifier(
                input_dim=X_train_final.shape[1],
                neurons=[128, 64, 32, 16],
                dropout=0.30
            ).to(device)
            
            fit_history = model.fit(
                train_loader=train_loader,
                epochs=200,
                lr=5e-3,
                weight_decay=1e-5,
                device=device,
                patience=5
            )
            
            acc, auc, report, test_history = model.test(
                test_loader=test_loader,
                device=device
            )
            
            all_results.setdefault(disorder, {}).setdefault(dict_name, {})[df_name] = {
                'accuracy': acc,
                'auc': auc,
                'classification_report': report,
                'features': list(X_train_final.columns),
                'X_train_shape': X_train_tensor.shape,
                'X_test_shape': X_test_tensor.shape,
                'history': {
                    'fit': fit_history,
                    'test': test_history
                }
            }
            
            # memory cleaning
            del model
            del X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
# Out:
# === Disorder: Acute stress disorder ===
#
# --- Processing: psd_all_bands ---
# Shape: (190, 114)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5676, Train Acc: 0.5625 |
# Epoch [2/200] | Train Loss: 0.5257, Train Acc: 0.6875 |
# Epoch [3/200] | Train Loss: 0.4834, Train Acc: 0.7734 |
# Epoch [4/200] | Train Loss: 0.4400, Train Acc: 0.7734 |
# Epoch [5/200] | Train Loss: 0.3791, Train Acc: 0.8516 |
# Epoch [6/200] | Train Loss: 0.3395, Train Acc: 0.8828 |
# Epoch [7/200] | Train Loss: 0.3076, Train Acc: 0.8984 |
# Epoch [8/200] | Train Loss: 0.3035, Train Acc: 0.8906 |
# Epoch [9/200] | Train Loss: 0.2714, Train Acc: 0.8750 |
# Epoch [10/200] | Train Loss: 0.2164, Train Acc: 0.9297 |
# Epoch [11/200] | Train Loss: 0.2107, Train Acc: 0.9141 |
# Epoch [12/200] | Train Loss: 0.1645, Train Acc: 0.9219 |
# Epoch [13/200] | Train Loss: 0.1473, Train Acc: 0.9609 |
# Epoch [14/200] | Train Loss: 0.1360, Train Acc: 0.9609 |
# Epoch [15/200] | Train Loss: 0.1440, Train Acc: 0.9219 |
# Epoch [16/200] | Train Loss: 0.0801, Train Acc: 0.9844 |
# Epoch [17/200] | Train Loss: 0.0988, Train Acc: 0.9531 |
# Epoch [18/200] | Train Loss: 0.0973, Train Acc: 0.9688 |
# Epoch [19/200] | Train Loss: 0.1170, Train Acc: 0.9531 |
# Epoch [20/200] | Train Loss: 0.1199, Train Acc: 0.9453 |
# Early stopping triggered.
# Test Loss: 0.1922, Test Accuracy: 0.8947, Test AUC: 0.9945
#
# --- Processing: fc_all_bands ---
# Shape: (190, 1026)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5737, Train Acc: 0.5312 |
# Epoch [2/200] | Train Loss: 0.5543, Train Acc: 0.5781 |
# Epoch [3/200] | Train Loss: 0.5007, Train Acc: 0.7656 |
# Epoch [4/200] | Train Loss: 0.4664, Train Acc: 0.7188 |
# Epoch [5/200] | Train Loss: 0.4266, Train Acc: 0.8203 |
# Epoch [6/200] | Train Loss: 0.4014, Train Acc: 0.8203 |
# Epoch [7/200] | Train Loss: 0.3589, Train Acc: 0.8438 |
# Epoch [8/200] | Train Loss: 0.3250, Train Acc: 0.8906 |
# Epoch [9/200] | Train Loss: 0.3123, Train Acc: 0.8828 |
# Epoch [10/200] | Train Loss: 0.2617, Train Acc: 0.9062 |
# Epoch [11/200] | Train Loss: 0.2466, Train Acc: 0.8984 |
# Epoch [12/200] | Train Loss: 0.1914, Train Acc: 0.9375 |
# Epoch [13/200] | Train Loss: 0.1655, Train Acc: 0.9609 |
# Epoch [14/200] | Train Loss: 0.1517, Train Acc: 0.9609 |
# Epoch [15/200] | Train Loss: 0.1338, Train Acc: 0.9531 |
# Epoch [16/200] | Train Loss: 0.1020, Train Acc: 0.9688 |
# Epoch [17/200] | Train Loss: 0.1070, Train Acc: 0.9609 |
# Epoch [18/200] | Train Loss: 0.0766, Train Acc: 0.9922 |
# Epoch [19/200] | Train Loss: 0.1092, Train Acc: 0.9453 |
# Epoch [20/200] | Train Loss: 0.1005, Train Acc: 0.9531 |
# Epoch [21/200] | Train Loss: 0.0733, Train Acc: 0.9766 |
# Epoch [22/200] | Train Loss: 0.0739, Train Acc: 0.9688 |
# Epoch [23/200] | Train Loss: 0.0520, Train Acc: 0.9844 |
# Epoch [24/200] | Train Loss: 0.1100, Train Acc: 0.9609 |
# Epoch [25/200] | Train Loss: 0.0630, Train Acc: 0.9688 |
# Epoch [26/200] | Train Loss: 0.0872, Train Acc: 0.9531 |
# Epoch [27/200] | Train Loss: 0.0853, Train Acc: 0.9766 |
# Early stopping triggered.
# Test Loss: 0.3161, Test Accuracy: 0.8684, Test AUC: 0.9806
#
# --- Processing: psd_fc_all_bands ---
# Shape: (190, 1140)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.6020, Train Acc: 0.6016 |
# Epoch [2/200] | Train Loss: 0.5381, Train Acc: 0.6328 |
# Epoch [3/200] | Train Loss: 0.4835, Train Acc: 0.7578 |
# Epoch [4/200] | Train Loss: 0.4326, Train Acc: 0.8359 |
# Epoch [5/200] | Train Loss: 0.4003, Train Acc: 0.8438 |
# Epoch [6/200] | Train Loss: 0.3679, Train Acc: 0.8672 |
# Epoch [7/200] | Train Loss: 0.3159, Train Acc: 0.8750 |
# Epoch [8/200] | Train Loss: 0.2996, Train Acc: 0.8984 |
# Epoch [9/200] | Train Loss: 0.2503, Train Acc: 0.9297 |
# Epoch [10/200] | Train Loss: 0.2028, Train Acc: 0.9375 |
# Epoch [11/200] | Train Loss: 0.1841, Train Acc: 0.9453 |
# Epoch [12/200] | Train Loss: 0.1582, Train Acc: 0.9453 |
# Epoch [13/200] | Train Loss: 0.1284, Train Acc: 0.9531 |
# Epoch [14/200] | Train Loss: 0.1498, Train Acc: 0.9531 |
# Epoch [15/200] | Train Loss: 0.1101, Train Acc: 0.9609 |
# Epoch [16/200] | Train Loss: 0.1171, Train Acc: 0.9609 |
# Epoch [17/200] | Train Loss: 0.0683, Train Acc: 0.9922 |
# Epoch [18/200] | Train Loss: 0.0693, Train Acc: 0.9844 |
# Epoch [19/200] | Train Loss: 0.0811, Train Acc: 0.9766 |
# Epoch [20/200] | Train Loss: 0.0577, Train Acc: 0.9844 |
# Epoch [21/200] | Train Loss: 0.0520, Train Acc: 0.9844 |
# Epoch [22/200] | Train Loss: 0.0280, Train Acc: 1.0000 |
# Epoch [23/200] | Train Loss: 0.0508, Train Acc: 0.9844 |
# Epoch [24/200] | Train Loss: 0.0320, Train Acc: 0.9922 |
# Epoch [25/200] | Train Loss: 0.0669, Train Acc: 0.9609 |
# Epoch [26/200] | Train Loss: 0.0371, Train Acc: 0.9844 |
# Early stopping triggered.
# Test Loss: 0.4445, Test Accuracy: 0.8421, Test AUC: 0.9391
#
# --- Processing: psd_delta ---
# Shape: (190, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5390, Train Acc: 0.6484 |
# Epoch [2/200] | Train Loss: 0.4790, Train Acc: 0.8203 |
# Epoch [3/200] | Train Loss: 0.4328, Train Acc: 0.8281 |
# Epoch [4/200] | Train Loss: 0.3740, Train Acc: 0.8672 |
# Epoch [5/200] | Train Loss: 0.3293, Train Acc: 0.8906 |
# Epoch [6/200] | Train Loss: 0.3243, Train Acc: 0.8750 |
# Epoch [7/200] | Train Loss: 0.2849, Train Acc: 0.8516 |
# Epoch [8/200] | Train Loss: 0.2289, Train Acc: 0.9219 |
# Epoch [9/200] | Train Loss: 0.2170, Train Acc: 0.9297 |
# Epoch [10/200] | Train Loss: 0.2220, Train Acc: 0.8906 |
# Epoch [11/200] | Train Loss: 0.2115, Train Acc: 0.9297 |
# Epoch [12/200] | Train Loss: 0.1917, Train Acc: 0.9141 |
# Epoch [13/200] | Train Loss: 0.1852, Train Acc: 0.9219 |
# Epoch [14/200] | Train Loss: 0.1269, Train Acc: 0.9609 |
# Epoch [15/200] | Train Loss: 0.1482, Train Acc: 0.9219 |
# Epoch [16/200] | Train Loss: 0.2315, Train Acc: 0.8906 |
# Epoch [17/200] | Train Loss: 0.1584, Train Acc: 0.9062 |
# Epoch [18/200] | Train Loss: 0.1151, Train Acc: 0.9609 |
# Epoch [19/200] | Train Loss: 0.2322, Train Acc: 0.8906 |
# Epoch [20/200] | Train Loss: 0.1589, Train Acc: 0.9453 |
# Epoch [21/200] | Train Loss: 0.1669, Train Acc: 0.9062 |
# Epoch [22/200] | Train Loss: 0.1257, Train Acc: 0.9531 |
# Epoch [23/200] | Train Loss: 0.0972, Train Acc: 0.9531 |
# Epoch [24/200] | Train Loss: 0.1186, Train Acc: 0.9453 |
# Epoch [25/200] | Train Loss: 0.1231, Train Acc: 0.9297 |
# Epoch [26/200] | Train Loss: 0.0926, Train Acc: 0.9609 |
# Epoch [27/200] | Train Loss: 0.0830, Train Acc: 0.9609 |
# Epoch [28/200] | Train Loss: 0.0919, Train Acc: 0.9609 |
# Epoch [29/200] | Train Loss: 0.0995, Train Acc: 0.9609 |
# Epoch [30/200] | Train Loss: 0.0766, Train Acc: 0.9688 |
# Epoch [31/200] | Train Loss: 0.1389, Train Acc: 0.9531 |
# Epoch [32/200] | Train Loss: 0.0635, Train Acc: 0.9609 |
# Epoch [33/200] | Train Loss: 0.1121, Train Acc: 0.9375 |
# Epoch [34/200] | Train Loss: 0.0729, Train Acc: 0.9609 |
# Epoch [35/200] | Train Loss: 0.0856, Train Acc: 0.9531 |
# Epoch [36/200] | Train Loss: 0.0719, Train Acc: 0.9609 |
# Epoch [37/200] | Train Loss: 0.0618, Train Acc: 0.9766 |
# Epoch [38/200] | Train Loss: 0.1465, Train Acc: 0.9297 |
# Epoch [39/200] | Train Loss: 0.0586, Train Acc: 0.9531 |
# Epoch [40/200] | Train Loss: 0.1133, Train Acc: 0.9375 |
# Epoch [41/200] | Train Loss: 0.0475, Train Acc: 0.9844 |
# Epoch [42/200] | Train Loss: 0.0616, Train Acc: 0.9766 |
# Epoch [43/200] | Train Loss: 0.0725, Train Acc: 0.9609 |
# Epoch [44/200] | Train Loss: 0.0377, Train Acc: 0.9922 |
# Epoch [45/200] | Train Loss: 0.0330, Train Acc: 0.9922 |
# Epoch [46/200] | Train Loss: 0.0620, Train Acc: 0.9688 |
# Epoch [47/200] | Train Loss: 0.0331, Train Acc: 0.9844 |
# Epoch [48/200] | Train Loss: 0.0211, Train Acc: 1.0000 |
# Epoch [49/200] | Train Loss: 0.0638, Train Acc: 0.9766 |
# Epoch [50/200] | Train Loss: 0.0453, Train Acc: 0.9766 |
# Epoch [51/200] | Train Loss: 0.0657, Train Acc: 0.9922 |
# Epoch [52/200] | Train Loss: 0.0723, Train Acc: 0.9688 |
# Early stopping triggered.
# Test Loss: 0.3181, Test Accuracy: 0.9211, Test AUC: 0.9557
#
# --- Processing: psd_theta ---
# Shape: (190, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5480, Train Acc: 0.5938 |
# Epoch [2/200] | Train Loss: 0.5062, Train Acc: 0.7500 |
# Epoch [3/200] | Train Loss: 0.4691, Train Acc: 0.7578 |
# Epoch [4/200] | Train Loss: 0.4041, Train Acc: 0.8672 |
# Epoch [5/200] | Train Loss: 0.3480, Train Acc: 0.8672 |
# Epoch [6/200] | Train Loss: 0.3474, Train Acc: 0.8594 |
# Epoch [7/200] | Train Loss: 0.3115, Train Acc: 0.8594 |
# Epoch [8/200] | Train Loss: 0.3375, Train Acc: 0.8281 |
# Epoch [9/200] | Train Loss: 0.2661, Train Acc: 0.8828 |
# Epoch [10/200] | Train Loss: 0.2974, Train Acc: 0.8750 |
# Epoch [11/200] | Train Loss: 0.2622, Train Acc: 0.8672 |
# Epoch [12/200] | Train Loss: 0.2631, Train Acc: 0.8672 |
# Epoch [13/200] | Train Loss: 0.2427, Train Acc: 0.8750 |
# Epoch [14/200] | Train Loss: 0.1775, Train Acc: 0.9141 |
# Epoch [15/200] | Train Loss: 0.1748, Train Acc: 0.9297 |
# Epoch [16/200] | Train Loss: 0.1628, Train Acc: 0.9219 |
# Epoch [17/200] | Train Loss: 0.1529, Train Acc: 0.9297 |
# Epoch [18/200] | Train Loss: 0.2052, Train Acc: 0.8828 |
# Epoch [19/200] | Train Loss: 0.2009, Train Acc: 0.8984 |
# Epoch [20/200] | Train Loss: 0.1519, Train Acc: 0.9297 |
# Epoch [21/200] | Train Loss: 0.1689, Train Acc: 0.9453 |
# Epoch [22/200] | Train Loss: 0.1545, Train Acc: 0.9219 |
# Epoch [23/200] | Train Loss: 0.1411, Train Acc: 0.9297 |
# Epoch [24/200] | Train Loss: 0.1832, Train Acc: 0.9062 |
# Epoch [25/200] | Train Loss: 0.1131, Train Acc: 0.9453 |
# Epoch [26/200] | Train Loss: 0.1470, Train Acc: 0.9297 |
# Epoch [27/200] | Train Loss: 0.1960, Train Acc: 0.8984 |
# Epoch [28/200] | Train Loss: 0.1409, Train Acc: 0.9062 |
# Epoch [29/200] | Train Loss: 0.1245, Train Acc: 0.9531 |
# Early stopping triggered.
# Test Loss: 0.4725, Test Accuracy: 0.8421, Test AUC: 0.9058
#
# --- Processing: psd_alpha ---
# Shape: (190, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5909, Train Acc: 0.5312 |
# Epoch [2/200] | Train Loss: 0.5255, Train Acc: 0.7031 |
# Epoch [3/200] | Train Loss: 0.4808, Train Acc: 0.7188 |
# Epoch [4/200] | Train Loss: 0.4272, Train Acc: 0.7656 |
# Epoch [5/200] | Train Loss: 0.3930, Train Acc: 0.8359 |
# Epoch [6/200] | Train Loss: 0.3563, Train Acc: 0.8594 |
# Epoch [7/200] | Train Loss: 0.3357, Train Acc: 0.8672 |
# Epoch [8/200] | Train Loss: 0.3395, Train Acc: 0.8438 |
# Epoch [9/200] | Train Loss: 0.3196, Train Acc: 0.8672 |
# Epoch [10/200] | Train Loss: 0.2793, Train Acc: 0.8516 |
# Epoch [11/200] | Train Loss: 0.2384, Train Acc: 0.8984 |
# Epoch [12/200] | Train Loss: 0.2717, Train Acc: 0.8359 |
# Epoch [13/200] | Train Loss: 0.1854, Train Acc: 0.9141 |
# Epoch [14/200] | Train Loss: 0.2049, Train Acc: 0.9297 |
# Epoch [15/200] | Train Loss: 0.2513, Train Acc: 0.8828 |
# Epoch [16/200] | Train Loss: 0.2215, Train Acc: 0.8984 |
# Epoch [17/200] | Train Loss: 0.2009, Train Acc: 0.8906 |
# Early stopping triggered.
# Test Loss: 0.5064, Test Accuracy: 0.8421, Test AUC: 0.8670
#
# --- Processing: psd_beta ---
# Shape: (190, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5767, Train Acc: 0.5625 |
# Epoch [2/200] | Train Loss: 0.5371, Train Acc: 0.6719 |
# Epoch [3/200] | Train Loss: 0.5042, Train Acc: 0.7891 |
# Epoch [4/200] | Train Loss: 0.4628, Train Acc: 0.8047 |
# Epoch [5/200] | Train Loss: 0.4317, Train Acc: 0.8281 |
# Epoch [6/200] | Train Loss: 0.4052, Train Acc: 0.7969 |
# Epoch [7/200] | Train Loss: 0.3796, Train Acc: 0.8047 |
# Epoch [8/200] | Train Loss: 0.3630, Train Acc: 0.8359 |
# Epoch [9/200] | Train Loss: 0.3077, Train Acc: 0.8828 |
# Epoch [10/200] | Train Loss: 0.2984, Train Acc: 0.8750 |
# Epoch [11/200] | Train Loss: 0.2835, Train Acc: 0.8906 |
# Epoch [12/200] | Train Loss: 0.2460, Train Acc: 0.8906 |
# Epoch [13/200] | Train Loss: 0.2366, Train Acc: 0.8906 |
# Epoch [14/200] | Train Loss: 0.2234, Train Acc: 0.9062 |
# Epoch [15/200] | Train Loss: 0.2040, Train Acc: 0.9219 |
# Epoch [16/200] | Train Loss: 0.2397, Train Acc: 0.8672 |
# Epoch [17/200] | Train Loss: 0.1829, Train Acc: 0.9375 |
# Epoch [18/200] | Train Loss: 0.1820, Train Acc: 0.9062 |
# Epoch [19/200] | Train Loss: 0.1693, Train Acc: 0.9219 |
# Epoch [20/200] | Train Loss: 0.1877, Train Acc: 0.9219 |
# Epoch [21/200] | Train Loss: 0.1781, Train Acc: 0.9141 |
# Epoch [22/200] | Train Loss: 0.2127, Train Acc: 0.8984 |
# Epoch [23/200] | Train Loss: 0.1495, Train Acc: 0.9453 |
# Epoch [24/200] | Train Loss: 0.1478, Train Acc: 0.9141 |
# Epoch [25/200] | Train Loss: 0.1475, Train Acc: 0.9219 |
# Epoch [26/200] | Train Loss: 0.1797, Train Acc: 0.9219 |
# Epoch [27/200] | Train Loss: 0.1642, Train Acc: 0.9297 |
# Epoch [28/200] | Train Loss: 0.1476, Train Acc: 0.9297 |
# Epoch [29/200] | Train Loss: 0.1245, Train Acc: 0.9688 |
# Epoch [30/200] | Train Loss: 0.1891, Train Acc: 0.9297 |
# Epoch [31/200] | Train Loss: 0.1232, Train Acc: 0.9531 |
# Epoch [32/200] | Train Loss: 0.1226, Train Acc: 0.9375 |
# Epoch [33/200] | Train Loss: 0.1356, Train Acc: 0.9375 |
# Epoch [34/200] | Train Loss: 0.0893, Train Acc: 0.9531 |
# Epoch [35/200] | Train Loss: 0.0930, Train Acc: 0.9688 |
# Epoch [36/200] | Train Loss: 0.0861, Train Acc: 0.9531 |
# Epoch [37/200] | Train Loss: 0.1596, Train Acc: 0.9375 |
# Epoch [38/200] | Train Loss: 0.1756, Train Acc: 0.9062 |
# Epoch [39/200] | Train Loss: 0.1091, Train Acc: 0.9375 |
# Epoch [40/200] | Train Loss: 0.1337, Train Acc: 0.9141 |
# Early stopping triggered.
# Test Loss: 0.5229, Test Accuracy: 0.8421, Test AUC: 0.9003
#
# --- Processing: psd_highbeta ---
# Shape: (190, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5729, Train Acc: 0.5469 |
# Epoch [2/200] | Train Loss: 0.5201, Train Acc: 0.6719 |
# Epoch [3/200] | Train Loss: 0.4550, Train Acc: 0.7969 |
# Epoch [4/200] | Train Loss: 0.4015, Train Acc: 0.8516 |
# Epoch [5/200] | Train Loss: 0.3996, Train Acc: 0.8281 |
# Epoch [6/200] | Train Loss: 0.3388, Train Acc: 0.8281 |
# Epoch [7/200] | Train Loss: 0.3076, Train Acc: 0.8828 |
# Epoch [8/200] | Train Loss: 0.3512, Train Acc: 0.8125 |
# Epoch [9/200] | Train Loss: 0.2585, Train Acc: 0.8906 |
# Epoch [10/200] | Train Loss: 0.2556, Train Acc: 0.8672 |
# Epoch [11/200] | Train Loss: 0.2634, Train Acc: 0.8828 |
# Epoch [12/200] | Train Loss: 0.2528, Train Acc: 0.8828 |
# Epoch [13/200] | Train Loss: 0.2397, Train Acc: 0.8828 |
# Epoch [14/200] | Train Loss: 0.2257, Train Acc: 0.8906 |
# Epoch [15/200] | Train Loss: 0.1987, Train Acc: 0.9141 |
# Epoch [16/200] | Train Loss: 0.1879, Train Acc: 0.9062 |
# Epoch [17/200] | Train Loss: 0.1660, Train Acc: 0.9141 |
# Epoch [18/200] | Train Loss: 0.1645, Train Acc: 0.9297 |
# Epoch [19/200] | Train Loss: 0.1928, Train Acc: 0.9141 |
# Epoch [20/200] | Train Loss: 0.2483, Train Acc: 0.8672 |
# Epoch [21/200] | Train Loss: 0.1590, Train Acc: 0.9453 |
# Epoch [22/200] | Train Loss: 0.1921, Train Acc: 0.9141 |
# Epoch [23/200] | Train Loss: 0.2277, Train Acc: 0.8828 |
# Epoch [24/200] | Train Loss: 0.1711, Train Acc: 0.9375 |
# Epoch [25/200] | Train Loss: 0.1329, Train Acc: 0.9297 |
# Epoch [26/200] | Train Loss: 0.1393, Train Acc: 0.9297 |
# Epoch [27/200] | Train Loss: 0.1498, Train Acc: 0.9453 |
# Epoch [28/200] | Train Loss: 0.1356, Train Acc: 0.9375 |
# Epoch [29/200] | Train Loss: 0.1748, Train Acc: 0.9141 |
# Early stopping triggered.
# Test Loss: 0.3499, Test Accuracy: 0.8947, Test AUC: 0.9418
#
# --- Processing: psd_gamma ---
# Shape: (190, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5935, Train Acc: 0.5391 |
# Epoch [2/200] | Train Loss: 0.5328, Train Acc: 0.6562 |
# Epoch [3/200] | Train Loss: 0.4800, Train Acc: 0.7812 |
# Epoch [4/200] | Train Loss: 0.4314, Train Acc: 0.8203 |
# Epoch [5/200] | Train Loss: 0.4052, Train Acc: 0.8125 |
# Epoch [6/200] | Train Loss: 0.3878, Train Acc: 0.8438 |
# Epoch [7/200] | Train Loss: 0.3226, Train Acc: 0.8828 |
# Epoch [8/200] | Train Loss: 0.2987, Train Acc: 0.8984 |
# Epoch [9/200] | Train Loss: 0.2730, Train Acc: 0.8984 |
# Epoch [10/200] | Train Loss: 0.3006, Train Acc: 0.8203 |
# Epoch [11/200] | Train Loss: 0.2272, Train Acc: 0.8750 |
# Epoch [12/200] | Train Loss: 0.2467, Train Acc: 0.8906 |
# Epoch [13/200] | Train Loss: 0.1957, Train Acc: 0.8906 |
# Epoch [14/200] | Train Loss: 0.1807, Train Acc: 0.9297 |
# Epoch [15/200] | Train Loss: 0.2596, Train Acc: 0.8750 |
# Epoch [16/200] | Train Loss: 0.2474, Train Acc: 0.8750 |
# Epoch [17/200] | Train Loss: 0.1933, Train Acc: 0.9141 |
# Epoch [18/200] | Train Loss: 0.1737, Train Acc: 0.9531 |
# Epoch [19/200] | Train Loss: 0.2045, Train Acc: 0.8984 |
# Epoch [20/200] | Train Loss: 0.2097, Train Acc: 0.8672 |
# Epoch [21/200] | Train Loss: 0.1871, Train Acc: 0.9062 |
# Epoch [22/200] | Train Loss: 0.1312, Train Acc: 0.9453 |
# Epoch [23/200] | Train Loss: 0.1230, Train Acc: 0.9609 |
# Epoch [24/200] | Train Loss: 0.1639, Train Acc: 0.9141 |
# Epoch [25/200] | Train Loss: 0.1355, Train Acc: 0.9141 |
# Epoch [26/200] | Train Loss: 0.1173, Train Acc: 0.9531 |
# Epoch [27/200] | Train Loss: 0.1222, Train Acc: 0.9453 |
# Epoch [28/200] | Train Loss: 0.1117, Train Acc: 0.9531 |
# Epoch [29/200] | Train Loss: 0.1386, Train Acc: 0.9219 |
# Epoch [30/200] | Train Loss: 0.1454, Train Acc: 0.9141 |
# Epoch [31/200] | Train Loss: 0.1141, Train Acc: 0.9531 |
# Epoch [32/200] | Train Loss: 0.1611, Train Acc: 0.9453 |
# Early stopping triggered.
# Test Loss: 0.3510, Test Accuracy: 0.8947, Test AUC: 0.9557
#
# --- Processing: fc_delta ---
# Shape: (190, 171)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5688, Train Acc: 0.6016 |
# Epoch [2/200] | Train Loss: 0.5078, Train Acc: 0.7578 |
# Epoch [3/200] | Train Loss: 0.4326, Train Acc: 0.8047 |
# Epoch [4/200] | Train Loss: 0.3874, Train Acc: 0.8359 |
# Epoch [5/200] | Train Loss: 0.3479, Train Acc: 0.8672 |
# Epoch [6/200] | Train Loss: 0.3478, Train Acc: 0.8672 |
# Epoch [7/200] | Train Loss: 0.3147, Train Acc: 0.9062 |
# Epoch [8/200] | Train Loss: 0.2430, Train Acc: 0.9531 |
# Epoch [9/200] | Train Loss: 0.2280, Train Acc: 0.9219 |
# Epoch [10/200] | Train Loss: 0.2012, Train Acc: 0.9453 |
# Epoch [11/200] | Train Loss: 0.1561, Train Acc: 0.9531 |
# Epoch [12/200] | Train Loss: 0.1595, Train Acc: 0.9453 |
# Epoch [13/200] | Train Loss: 0.1460, Train Acc: 0.9609 |
# Epoch [14/200] | Train Loss: 0.1255, Train Acc: 0.9609 |
# Epoch [15/200] | Train Loss: 0.1092, Train Acc: 0.9609 |
# Epoch [16/200] | Train Loss: 0.1036, Train Acc: 0.9531 |
# Epoch [17/200] | Train Loss: 0.0973, Train Acc: 0.9609 |
# Epoch [18/200] | Train Loss: 0.0807, Train Acc: 0.9688 |
# Epoch [19/200] | Train Loss: 0.1348, Train Acc: 0.9375 |
# Epoch [20/200] | Train Loss: 0.2223, Train Acc: 0.9141 |
# Epoch [21/200] | Train Loss: 0.0944, Train Acc: 0.9766 |
# Epoch [22/200] | Train Loss: 0.1621, Train Acc: 0.9297 |
# Epoch [23/200] | Train Loss: 0.0576, Train Acc: 0.9844 |
# Epoch [24/200] | Train Loss: 0.1233, Train Acc: 0.9453 |
# Epoch [25/200] | Train Loss: 0.0498, Train Acc: 0.9844 |
# Epoch [26/200] | Train Loss: 0.0647, Train Acc: 0.9844 |
# Epoch [27/200] | Train Loss: 0.1331, Train Acc: 0.9531 |
# Epoch [28/200] | Train Loss: 0.1049, Train Acc: 0.9609 |
# Epoch [29/200] | Train Loss: 0.0657, Train Acc: 0.9766 |
# Epoch [30/200] | Train Loss: 0.0390, Train Acc: 0.9922 |
# Epoch [31/200] | Train Loss: 0.0665, Train Acc: 0.9688 |
# Epoch [32/200] | Train Loss: 0.0534, Train Acc: 0.9844 |
# Epoch [33/200] | Train Loss: 0.0453, Train Acc: 0.9688 |
# Epoch [34/200] | Train Loss: 0.0545, Train Acc: 0.9766 |
# Early stopping triggered.
# Test Loss: 0.6115, Test Accuracy: 0.8421, Test AUC: 0.9058
#
# --- Processing: fc_theta ---
# Shape: (190, 171)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5702, Train Acc: 0.5391 |
# Epoch [2/200] | Train Loss: 0.5317, Train Acc: 0.6328 |
# Epoch [3/200] | Train Loss: 0.4526, Train Acc: 0.8047 |
# Epoch [4/200] | Train Loss: 0.4144, Train Acc: 0.8359 |
# Epoch [5/200] | Train Loss: 0.3680, Train Acc: 0.8672 |
# Epoch [6/200] | Train Loss: 0.3236, Train Acc: 0.9062 |
# Epoch [7/200] | Train Loss: 0.2933, Train Acc: 0.8984 |
# Epoch [8/200] | Train Loss: 0.2685, Train Acc: 0.9062 |
# Epoch [9/200] | Train Loss: 0.2583, Train Acc: 0.9297 |
# Epoch [10/200] | Train Loss: 0.2057, Train Acc: 0.9375 |
# Epoch [11/200] | Train Loss: 0.1775, Train Acc: 0.9453 |
# Epoch [12/200] | Train Loss: 0.1554, Train Acc: 0.9609 |
# Epoch [13/200] | Train Loss: 0.1536, Train Acc: 0.9375 |
# Epoch [14/200] | Train Loss: 0.1335, Train Acc: 0.9688 |
# Epoch [15/200] | Train Loss: 0.1064, Train Acc: 0.9531 |
# Epoch [16/200] | Train Loss: 0.0905, Train Acc: 0.9844 |
# Epoch [17/200] | Train Loss: 0.0922, Train Acc: 0.9531 |
# Epoch [18/200] | Train Loss: 0.1071, Train Acc: 0.9688 |
# Epoch [19/200] | Train Loss: 0.1456, Train Acc: 0.9453 |
# Epoch [20/200] | Train Loss: 0.1118, Train Acc: 0.9219 |
# Early stopping triggered.
# Test Loss: 0.3263, Test Accuracy: 0.8947, Test AUC: 0.9668
#
# --- Processing: fc_alpha ---
# Shape: (190, 171)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5947, Train Acc: 0.4844 |
# Epoch [2/200] | Train Loss: 0.5310, Train Acc: 0.6953 |
# Epoch [3/200] | Train Loss: 0.5126, Train Acc: 0.6562 |
# Epoch [4/200] | Train Loss: 0.4702, Train Acc: 0.7500 |
# Epoch [5/200] | Train Loss: 0.4605, Train Acc: 0.7344 |
# Epoch [6/200] | Train Loss: 0.4418, Train Acc: 0.7891 |
# Epoch [7/200] | Train Loss: 0.3958, Train Acc: 0.8281 |
# Epoch [8/200] | Train Loss: 0.3622, Train Acc: 0.8047 |
# Epoch [9/200] | Train Loss: 0.3109, Train Acc: 0.8672 |
# Epoch [10/200] | Train Loss: 0.2796, Train Acc: 0.8984 |
# Epoch [11/200] | Train Loss: 0.2427, Train Acc: 0.9297 |
# Epoch [12/200] | Train Loss: 0.2111, Train Acc: 0.9531 |
# Epoch [13/200] | Train Loss: 0.1985, Train Acc: 0.9531 |
# Epoch [14/200] | Train Loss: 0.1808, Train Acc: 0.9219 |
# Epoch [15/200] | Train Loss: 0.1380, Train Acc: 0.9609 |
# Epoch [16/200] | Train Loss: 0.1638, Train Acc: 0.9297 |
# Epoch [17/200] | Train Loss: 0.1248, Train Acc: 0.9453 |
# Epoch [18/200] | Train Loss: 0.1513, Train Acc: 0.9453 |
# Epoch [19/200] | Train Loss: 0.1254, Train Acc: 0.9453 |
# Epoch [20/200] | Train Loss: 0.1442, Train Acc: 0.9141 |
# Epoch [21/200] | Train Loss: 0.1338, Train Acc: 0.9297 |
# Epoch [22/200] | Train Loss: 0.0689, Train Acc: 0.9844 |
# Epoch [23/200] | Train Loss: 0.2038, Train Acc: 0.9219 |
# Epoch [24/200] | Train Loss: 0.0983, Train Acc: 0.9766 |
# Epoch [25/200] | Train Loss: 0.0971, Train Acc: 0.9609 |
# Epoch [26/200] | Train Loss: 0.0704, Train Acc: 0.9766 |
# Early stopping triggered.
# Test Loss: 0.2056, Test Accuracy: 0.8684, Test AUC: 0.9834
#
# --- Processing: fc_beta ---
# Shape: (190, 171)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5764, Train Acc: 0.5781 |
# Epoch [2/200] | Train Loss: 0.5091, Train Acc: 0.7188 |
# Epoch [3/200] | Train Loss: 0.4728, Train Acc: 0.7578 |
# Epoch [4/200] | Train Loss: 0.4377, Train Acc: 0.7969 |
# Epoch [5/200] | Train Loss: 0.4013, Train Acc: 0.8203 |
# Epoch [6/200] | Train Loss: 0.3757, Train Acc: 0.8438 |
# Epoch [7/200] | Train Loss: 0.3473, Train Acc: 0.8359 |
# Epoch [8/200] | Train Loss: 0.3055, Train Acc: 0.9141 |
# Epoch [9/200] | Train Loss: 0.2938, Train Acc: 0.8828 |
# Epoch [10/200] | Train Loss: 0.2511, Train Acc: 0.9297 |
# Epoch [11/200] | Train Loss: 0.2232, Train Acc: 0.9297 |
# Epoch [12/200] | Train Loss: 0.2323, Train Acc: 0.9141 |
# Epoch [13/200] | Train Loss: 0.1969, Train Acc: 0.9297 |
# Epoch [14/200] | Train Loss: 0.1459, Train Acc: 0.9688 |
# Epoch [15/200] | Train Loss: 0.1167, Train Acc: 0.9922 |
# Epoch [16/200] | Train Loss: 0.1244, Train Acc: 0.9609 |
# Epoch [17/200] | Train Loss: 0.1602, Train Acc: 0.9219 |
# Epoch [18/200] | Train Loss: 0.1092, Train Acc: 0.9688 |
# Epoch [19/200] | Train Loss: 0.0775, Train Acc: 0.9922 |
# Epoch [20/200] | Train Loss: 0.1100, Train Acc: 0.9531 |
# Epoch [21/200] | Train Loss: 0.1446, Train Acc: 0.9531 |
# Epoch [22/200] | Train Loss: 0.1202, Train Acc: 0.9453 |
# Epoch [23/200] | Train Loss: 0.1381, Train Acc: 0.9219 |
# Epoch [24/200] | Train Loss: 0.0713, Train Acc: 0.9688 |
# Epoch [25/200] | Train Loss: 0.0929, Train Acc: 0.9688 |
# Epoch [26/200] | Train Loss: 0.0676, Train Acc: 0.9688 |
# Epoch [27/200] | Train Loss: 0.0616, Train Acc: 0.9844 |
# Epoch [28/200] | Train Loss: 0.0681, Train Acc: 0.9688 |
# Epoch [29/200] | Train Loss: 0.0679, Train Acc: 0.9688 |
# Epoch [30/200] | Train Loss: 0.0400, Train Acc: 0.9922 |
# Epoch [31/200] | Train Loss: 0.0576, Train Acc: 0.9844 |
# Epoch [32/200] | Train Loss: 0.1523, Train Acc: 0.9453 |
# Epoch [33/200] | Train Loss: 0.0420, Train Acc: 0.9844 |
# Epoch [34/200] | Train Loss: 0.0515, Train Acc: 0.9766 |
# Early stopping triggered.
# Test Loss: 0.7750, Test Accuracy: 0.7632, Test AUC: 0.8864
#
# --- Processing: fc_highbeta ---
# Shape: (190, 171)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5669, Train Acc: 0.5703 |
# Epoch [2/200] | Train Loss: 0.5291, Train Acc: 0.6875 |
# Epoch [3/200] | Train Loss: 0.5288, Train Acc: 0.7109 |
# Epoch [4/200] | Train Loss: 0.4330, Train Acc: 0.8125 |
# Epoch [5/200] | Train Loss: 0.4357, Train Acc: 0.7422 |
# Epoch [6/200] | Train Loss: 0.3620, Train Acc: 0.8438 |
# Epoch [7/200] | Train Loss: 0.3440, Train Acc: 0.8594 |
# Epoch [8/200] | Train Loss: 0.2791, Train Acc: 0.8906 |
# Epoch [9/200] | Train Loss: 0.2726, Train Acc: 0.8984 |
# Epoch [10/200] | Train Loss: 0.2279, Train Acc: 0.9375 |
# Epoch [11/200] | Train Loss: 0.2618, Train Acc: 0.8750 |
# Epoch [12/200] | Train Loss: 0.2041, Train Acc: 0.9297 |
# Epoch [13/200] | Train Loss: 0.2183, Train Acc: 0.8828 |
# Epoch [14/200] | Train Loss: 0.1515, Train Acc: 0.9531 |
# Epoch [15/200] | Train Loss: 0.1475, Train Acc: 0.9453 |
# Epoch [16/200] | Train Loss: 0.1234, Train Acc: 0.9453 |
# Epoch [17/200] | Train Loss: 0.1345, Train Acc: 0.9531 |
# Epoch [18/200] | Train Loss: 0.1035, Train Acc: 0.9531 |
# Epoch [19/200] | Train Loss: 0.1292, Train Acc: 0.9453 |
# Epoch [20/200] | Train Loss: 0.1652, Train Acc: 0.9219 |
# Epoch [21/200] | Train Loss: 0.1173, Train Acc: 0.9609 |
# Epoch [22/200] | Train Loss: 0.1286, Train Acc: 0.9297 |
# Early stopping triggered.
# Test Loss: 0.2945, Test Accuracy: 0.9211, Test AUC: 0.9668
#
# --- Processing: fc_gamma ---
# Shape: (190, 171)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5914, Train Acc: 0.4766 |
# Epoch [2/200] | Train Loss: 0.5476, Train Acc: 0.6797 |
# Epoch [3/200] | Train Loss: 0.5247, Train Acc: 0.7031 |
# Epoch [4/200] | Train Loss: 0.4652, Train Acc: 0.8203 |
# Epoch [5/200] | Train Loss: 0.4257, Train Acc: 0.8438 |
# Epoch [6/200] | Train Loss: 0.3919, Train Acc: 0.8203 |
# Epoch [7/200] | Train Loss: 0.3570, Train Acc: 0.8359 |
# Epoch [8/200] | Train Loss: 0.3260, Train Acc: 0.8516 |
# Epoch [9/200] | Train Loss: 0.3182, Train Acc: 0.8125 |
# Epoch [10/200] | Train Loss: 0.2629, Train Acc: 0.8984 |
# Epoch [11/200] | Train Loss: 0.2379, Train Acc: 0.9141 |
# Epoch [12/200] | Train Loss: 0.2632, Train Acc: 0.8750 |
# Epoch [13/200] | Train Loss: 0.1772, Train Acc: 0.9375 |
# Epoch [14/200] | Train Loss: 0.2053, Train Acc: 0.9141 |
# Epoch [15/200] | Train Loss: 0.1575, Train Acc: 0.9375 |
# Epoch [16/200] | Train Loss: 0.1405, Train Acc: 0.9375 |
# Epoch [17/200] | Train Loss: 0.1698, Train Acc: 0.9375 |
# Epoch [18/200] | Train Loss: 0.1001, Train Acc: 0.9609 |
# Epoch [19/200] | Train Loss: 0.1470, Train Acc: 0.9297 |
# Epoch [20/200] | Train Loss: 0.1668, Train Acc: 0.9141 |
# Epoch [21/200] | Train Loss: 0.1151, Train Acc: 0.9375 |
# Epoch [22/200] | Train Loss: 0.1173, Train Acc: 0.9375 |
# Early stopping triggered.
# Test Loss: 0.4373, Test Accuracy: 0.8158, Test AUC: 0.8947
#
# --- Processing: psd_fc_delta ---
# Shape: (190, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5798, Train Acc: 0.5312 |
# Epoch [2/200] | Train Loss: 0.4999, Train Acc: 0.7188 |
# Epoch [3/200] | Train Loss: 0.4818, Train Acc: 0.7500 |
# Epoch [4/200] | Train Loss: 0.4112, Train Acc: 0.8281 |
# Epoch [5/200] | Train Loss: 0.3581, Train Acc: 0.8750 |
# Epoch [6/200] | Train Loss: 0.3116, Train Acc: 0.8906 |
# Epoch [7/200] | Train Loss: 0.2656, Train Acc: 0.8750 |
# Epoch [8/200] | Train Loss: 0.2681, Train Acc: 0.9219 |
# Epoch [9/200] | Train Loss: 0.2171, Train Acc: 0.9375 |
# Epoch [10/200] | Train Loss: 0.1942, Train Acc: 0.9297 |
# Epoch [11/200] | Train Loss: 0.1417, Train Acc: 0.9609 |
# Epoch [12/200] | Train Loss: 0.1465, Train Acc: 0.9531 |
# Epoch [13/200] | Train Loss: 0.1050, Train Acc: 0.9688 |
# Epoch [14/200] | Train Loss: 0.1032, Train Acc: 0.9609 |
# Epoch [15/200] | Train Loss: 0.1166, Train Acc: 0.9531 |
# Epoch [16/200] | Train Loss: 0.0756, Train Acc: 0.9766 |
# Epoch [17/200] | Train Loss: 0.0795, Train Acc: 0.9688 |
# Epoch [18/200] | Train Loss: 0.0796, Train Acc: 0.9688 |
# Epoch [19/200] | Train Loss: 0.0880, Train Acc: 0.9609 |
# Epoch [20/200] | Train Loss: 0.1057, Train Acc: 0.9609 |
# Early stopping triggered.
# Test Loss: 0.3828, Test Accuracy: 0.8684, Test AUC: 0.9474
#
# --- Processing: psd_fc_theta ---
# Shape: (190, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5632, Train Acc: 0.5938 |
# Epoch [2/200] | Train Loss: 0.5214, Train Acc: 0.7109 |
# Epoch [3/200] | Train Loss: 0.4640, Train Acc: 0.7734 |
# Epoch [4/200] | Train Loss: 0.4216, Train Acc: 0.8359 |
# Epoch [5/200] | Train Loss: 0.4128, Train Acc: 0.7656 |
# Epoch [6/200] | Train Loss: 0.3403, Train Acc: 0.8516 |
# Epoch [7/200] | Train Loss: 0.2951, Train Acc: 0.9219 |
# Epoch [8/200] | Train Loss: 0.2733, Train Acc: 0.9141 |
# Epoch [9/200] | Train Loss: 0.2504, Train Acc: 0.9062 |
# Epoch [10/200] | Train Loss: 0.2135, Train Acc: 0.9375 |
# Epoch [11/200] | Train Loss: 0.1525, Train Acc: 0.9844 |
# Epoch [12/200] | Train Loss: 0.1550, Train Acc: 0.9453 |
# Epoch [13/200] | Train Loss: 0.1348, Train Acc: 0.9531 |
# Epoch [14/200] | Train Loss: 0.1360, Train Acc: 0.9531 |
# Epoch [15/200] | Train Loss: 0.1099, Train Acc: 0.9766 |
# Epoch [16/200] | Train Loss: 0.0639, Train Acc: 1.0000 |
# Epoch [17/200] | Train Loss: 0.1018, Train Acc: 0.9531 |
# Epoch [18/200] | Train Loss: 0.0861, Train Acc: 0.9688 |
# Epoch [19/200] | Train Loss: 0.1075, Train Acc: 0.9531 |
# Epoch [20/200] | Train Loss: 0.0934, Train Acc: 0.9688 |
# Early stopping triggered.
# Test Loss: 0.2562, Test Accuracy: 0.8947, Test AUC: 0.9695
#
# --- Processing: psd_fc_alpha ---
# Shape: (190, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5910, Train Acc: 0.5469 |
# Epoch [2/200] | Train Loss: 0.5297, Train Acc: 0.6562 |
# Epoch [3/200] | Train Loss: 0.4957, Train Acc: 0.7500 |
# Epoch [4/200] | Train Loss: 0.4294, Train Acc: 0.8125 |
# Epoch [5/200] | Train Loss: 0.3813, Train Acc: 0.8125 |
# Epoch [6/200] | Train Loss: 0.3207, Train Acc: 0.9141 |
# Epoch [7/200] | Train Loss: 0.2889, Train Acc: 0.9062 |
# Epoch [8/200] | Train Loss: 0.2493, Train Acc: 0.9453 |
# Epoch [9/200] | Train Loss: 0.2121, Train Acc: 0.9375 |
# Epoch [10/200] | Train Loss: 0.2268, Train Acc: 0.8906 |
# Epoch [11/200] | Train Loss: 0.1865, Train Acc: 0.9219 |
# Epoch [12/200] | Train Loss: 0.1663, Train Acc: 0.9375 |
# Epoch [13/200] | Train Loss: 0.1689, Train Acc: 0.9219 |
# Epoch [14/200] | Train Loss: 0.1116, Train Acc: 0.9531 |
# Epoch [15/200] | Train Loss: 0.1481, Train Acc: 0.9375 |
# Epoch [16/200] | Train Loss: 0.0899, Train Acc: 0.9766 |
# Epoch [17/200] | Train Loss: 0.1278, Train Acc: 0.9375 |
# Epoch [18/200] | Train Loss: 0.0912, Train Acc: 0.9688 |
# Epoch [19/200] | Train Loss: 0.0809, Train Acc: 0.9766 |
# Epoch [20/200] | Train Loss: 0.0792, Train Acc: 0.9609 |
# Epoch [21/200] | Train Loss: 0.0811, Train Acc: 0.9688 |
# Epoch [22/200] | Train Loss: 0.1166, Train Acc: 0.9609 |
# Epoch [23/200] | Train Loss: 0.0761, Train Acc: 0.9531 |
# Epoch [24/200] | Train Loss: 0.0840, Train Acc: 0.9688 |
# Epoch [25/200] | Train Loss: 0.1488, Train Acc: 0.9375 |
# Epoch [26/200] | Train Loss: 0.0579, Train Acc: 0.9688 |
# Epoch [27/200] | Train Loss: 0.0777, Train Acc: 0.9844 |
# Epoch [28/200] | Train Loss: 0.0820, Train Acc: 0.9375 |
# Epoch [29/200] | Train Loss: 0.0984, Train Acc: 0.9531 |
# Epoch [30/200] | Train Loss: 0.0330, Train Acc: 0.9922 |
# Epoch [31/200] | Train Loss: 0.1254, Train Acc: 0.9375 |
# Epoch [32/200] | Train Loss: 0.0557, Train Acc: 0.9844 |
# Epoch [33/200] | Train Loss: 0.0530, Train Acc: 0.9766 |
# Epoch [34/200] | Train Loss: 0.0885, Train Acc: 0.9688 |
# Epoch [35/200] | Train Loss: 0.0295, Train Acc: 0.9922 |
# Epoch [36/200] | Train Loss: 0.1086, Train Acc: 0.9453 |
# Epoch [37/200] | Train Loss: 0.0540, Train Acc: 0.9766 |
# Epoch [38/200] | Train Loss: 0.0682, Train Acc: 0.9766 |
# Epoch [39/200] | Train Loss: 0.0450, Train Acc: 0.9844 |
# Early stopping triggered.
# Test Loss: 0.4238, Test Accuracy: 0.8421, Test AUC: 0.9557
#
# --- Processing: psd_fc_beta ---
# Shape: (190, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5845, Train Acc: 0.5312 |
# Epoch [2/200] | Train Loss: 0.5739, Train Acc: 0.5234 |
# Epoch [3/200] | Train Loss: 0.5309, Train Acc: 0.6328 |
# Epoch [4/200] | Train Loss: 0.4948, Train Acc: 0.7891 |
# Epoch [5/200] | Train Loss: 0.4421, Train Acc: 0.8516 |
# Epoch [6/200] | Train Loss: 0.4070, Train Acc: 0.8594 |
# Epoch [7/200] | Train Loss: 0.3840, Train Acc: 0.8203 |
# Epoch [8/200] | Train Loss: 0.3434, Train Acc: 0.8828 |
# Epoch [9/200] | Train Loss: 0.3343, Train Acc: 0.8203 |
# Epoch [10/200] | Train Loss: 0.2790, Train Acc: 0.8672 |
# Epoch [11/200] | Train Loss: 0.2600, Train Acc: 0.9141 |
# Epoch [12/200] | Train Loss: 0.2138, Train Acc: 0.9219 |
# Epoch [13/200] | Train Loss: 0.1945, Train Acc: 0.9297 |
# Epoch [14/200] | Train Loss: 0.1913, Train Acc: 0.9141 |
# Epoch [15/200] | Train Loss: 0.1471, Train Acc: 0.9531 |
# Epoch [16/200] | Train Loss: 0.1317, Train Acc: 0.9531 |
# Epoch [17/200] | Train Loss: 0.1065, Train Acc: 0.9688 |
# Epoch [18/200] | Train Loss: 0.1230, Train Acc: 0.9531 |
# Epoch [19/200] | Train Loss: 0.1014, Train Acc: 0.9609 |
# Epoch [20/200] | Train Loss: 0.1029, Train Acc: 0.9453 |
# Epoch [21/200] | Train Loss: 0.0969, Train Acc: 0.9609 |
# Epoch [22/200] | Train Loss: 0.0707, Train Acc: 0.9688 |
# Epoch [23/200] | Train Loss: 0.0926, Train Acc: 0.9609 |
# Epoch [24/200] | Train Loss: 0.1309, Train Acc: 0.9531 |
# Epoch [25/200] | Train Loss: 0.1308, Train Acc: 0.9219 |
# Epoch [26/200] | Train Loss: 0.0599, Train Acc: 0.9766 |
# Epoch [27/200] | Train Loss: 0.1083, Train Acc: 0.9453 |
# Epoch [28/200] | Train Loss: 0.0603, Train Acc: 0.9766 |
# Epoch [29/200] | Train Loss: 0.1062, Train Acc: 0.9609 |
# Epoch [30/200] | Train Loss: 0.1836, Train Acc: 0.9219 |
# Early stopping triggered.
# Test Loss: 0.8464, Test Accuracy: 0.7895, Test AUC: 0.8476
#
# --- Processing: psd_fc_highbeta ---
# Shape: (190, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5783, Train Acc: 0.6562 |
# Epoch [2/200] | Train Loss: 0.5028, Train Acc: 0.7500 |
# Epoch [3/200] | Train Loss: 0.4667, Train Acc: 0.7891 |
# Epoch [4/200] | Train Loss: 0.4446, Train Acc: 0.7500 |
# Epoch [5/200] | Train Loss: 0.3903, Train Acc: 0.8438 |
# Epoch [6/200] | Train Loss: 0.3716, Train Acc: 0.8438 |
# Epoch [7/200] | Train Loss: 0.3319, Train Acc: 0.8828 |
# Epoch [8/200] | Train Loss: 0.3014, Train Acc: 0.8906 |
# Epoch [9/200] | Train Loss: 0.2560, Train Acc: 0.8984 |
# Epoch [10/200] | Train Loss: 0.2284, Train Acc: 0.9141 |
# Epoch [11/200] | Train Loss: 0.2586, Train Acc: 0.8828 |
# Epoch [12/200] | Train Loss: 0.1739, Train Acc: 0.9375 |
# Epoch [13/200] | Train Loss: 0.2160, Train Acc: 0.9141 |
# Epoch [14/200] | Train Loss: 0.1801, Train Acc: 0.9062 |
# Epoch [15/200] | Train Loss: 0.1659, Train Acc: 0.9375 |
# Epoch [16/200] | Train Loss: 0.1710, Train Acc: 0.9141 |
# Epoch [17/200] | Train Loss: 0.1651, Train Acc: 0.9141 |
# Epoch [18/200] | Train Loss: 0.1349, Train Acc: 0.9375 |
# Epoch [19/200] | Train Loss: 0.1562, Train Acc: 0.9141 |
# Epoch [20/200] | Train Loss: 0.1237, Train Acc: 0.9453 |
# Epoch [21/200] | Train Loss: 0.1072, Train Acc: 0.9766 |
# Epoch [22/200] | Train Loss: 0.0962, Train Acc: 0.9609 |
# Epoch [23/200] | Train Loss: 0.0874, Train Acc: 0.9766 |
# Epoch [24/200] | Train Loss: 0.0858, Train Acc: 0.9688 |
# Epoch [25/200] | Train Loss: 0.0966, Train Acc: 0.9688 |
# Epoch [26/200] | Train Loss: 0.1040, Train Acc: 0.9688 |
# Epoch [27/200] | Train Loss: 0.0879, Train Acc: 0.9844 |
# Epoch [28/200] | Train Loss: 0.0585, Train Acc: 0.9766 |
# Epoch [29/200] | Train Loss: 0.0595, Train Acc: 0.9766 |
# Epoch [30/200] | Train Loss: 0.0569, Train Acc: 0.9766 |
# Epoch [31/200] | Train Loss: 0.1081, Train Acc: 0.9531 |
# Epoch [32/200] | Train Loss: 0.1356, Train Acc: 0.9297 |
# Epoch [33/200] | Train Loss: 0.0804, Train Acc: 0.9609 |
# Epoch [34/200] | Train Loss: 0.1144, Train Acc: 0.9453 |
# Early stopping triggered.
# Test Loss: 0.2900, Test Accuracy: 0.8684, Test AUC: 0.9695
#
# --- Processing: psd_fc_gamma ---
# Shape: (190, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5851, Train Acc: 0.5391 |
# Epoch [2/200] | Train Loss: 0.5459, Train Acc: 0.6484 |
# Epoch [3/200] | Train Loss: 0.5229, Train Acc: 0.6875 |
# Epoch [4/200] | Train Loss: 0.4940, Train Acc: 0.7500 |
# Epoch [5/200] | Train Loss: 0.4647, Train Acc: 0.7266 |
# Epoch [6/200] | Train Loss: 0.4096, Train Acc: 0.7969 |
# Epoch [7/200] | Train Loss: 0.3818, Train Acc: 0.8125 |
# Epoch [8/200] | Train Loss: 0.3493, Train Acc: 0.8516 |
# Epoch [9/200] | Train Loss: 0.3192, Train Acc: 0.8203 |
# Epoch [10/200] | Train Loss: 0.2741, Train Acc: 0.8906 |
# Epoch [11/200] | Train Loss: 0.2606, Train Acc: 0.8906 |
# Epoch [12/200] | Train Loss: 0.2229, Train Acc: 0.9062 |
# Epoch [13/200] | Train Loss: 0.2141, Train Acc: 0.9062 |
# Epoch [14/200] | Train Loss: 0.2104, Train Acc: 0.8828 |
# Epoch [15/200] | Train Loss: 0.2138, Train Acc: 0.9141 |
# Epoch [16/200] | Train Loss: 0.1737, Train Acc: 0.9297 |
# Epoch [17/200] | Train Loss: 0.1715, Train Acc: 0.9062 |
# Epoch [18/200] | Train Loss: 0.2034, Train Acc: 0.8906 |
# Epoch [19/200] | Train Loss: 0.1979, Train Acc: 0.8984 |
# Epoch [20/200] | Train Loss: 0.1336, Train Acc: 0.9375 |
# Epoch [21/200] | Train Loss: 0.1302, Train Acc: 0.9453 |
# Epoch [22/200] | Train Loss: 0.1608, Train Acc: 0.9375 |
# Epoch [23/200] | Train Loss: 0.1177, Train Acc: 0.9531 |
# Epoch [24/200] | Train Loss: 0.0928, Train Acc: 0.9609 |
# Epoch [25/200] | Train Loss: 0.1494, Train Acc: 0.9297 |
# Epoch [26/200] | Train Loss: 0.0978, Train Acc: 0.9453 |
# Epoch [27/200] | Train Loss: 0.0930, Train Acc: 0.9766 |
# Epoch [28/200] | Train Loss: 0.0885, Train Acc: 0.9688 |
# Epoch [29/200] | Train Loss: 0.0690, Train Acc: 0.9688 |
# Epoch [30/200] | Train Loss: 0.1290, Train Acc: 0.9453 |
# Epoch [31/200] | Train Loss: 0.1332, Train Acc: 0.9375 |
# Epoch [32/200] | Train Loss: 0.1092, Train Acc: 0.9531 |
# Epoch [33/200] | Train Loss: 0.1067, Train Acc: 0.9531 |
# Early stopping triggered.
# Test Loss: 0.3420, Test Accuracy: 0.8684, Test AUC: 0.9557
#
# === Disorder: Adjustment disorder ===
#
# --- Processing: psd_all_bands ---
# Shape: (190, 114)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5617, Train Acc: 0.6250 |
# Epoch [2/200] | Train Loss: 0.5178, Train Acc: 0.6484 |
# Epoch [3/200] | Train Loss: 0.4766, Train Acc: 0.7266 |
# Epoch [4/200] | Train Loss: 0.4336, Train Acc: 0.8281 |
# Epoch [5/200] | Train Loss: 0.4407, Train Acc: 0.7969 |
# Epoch [6/200] | Train Loss: 0.3905, Train Acc: 0.8281 |
# Epoch [7/200] | Train Loss: 0.3442, Train Acc: 0.8750 |
# Epoch [8/200] | Train Loss: 0.3140, Train Acc: 0.8672 |
# Epoch [9/200] | Train Loss: 0.2593, Train Acc: 0.8984 |
# Epoch [10/200] | Train Loss: 0.2387, Train Acc: 0.9219 |
# Epoch [11/200] | Train Loss: 0.2336, Train Acc: 0.8984 |
# Epoch [12/200] | Train Loss: 0.1600, Train Acc: 0.9609 |
# Epoch [13/200] | Train Loss: 0.1542, Train Acc: 0.9453 |
# Epoch [14/200] | Train Loss: 0.1670, Train Acc: 0.9375 |
# Epoch [15/200] | Train Loss: 0.1291, Train Acc: 0.9688 |
# Epoch [16/200] | Train Loss: 0.1000, Train Acc: 0.9922 |
# Epoch [17/200] | Train Loss: 0.0962, Train Acc: 0.9531 |
# Epoch [18/200] | Train Loss: 0.1065, Train Acc: 0.9609 |
# Epoch [19/200] | Train Loss: 0.0582, Train Acc: 0.9922 |
# Epoch [20/200] | Train Loss: 0.0840, Train Acc: 0.9766 |
# Epoch [21/200] | Train Loss: 0.0750, Train Acc: 0.9766 |
# Epoch [22/200] | Train Loss: 0.0867, Train Acc: 0.9609 |
# Epoch [23/200] | Train Loss: 0.0713, Train Acc: 0.9766 |
# Early stopping triggered.
# Test Loss: 0.3947, Test Accuracy: 0.8684, Test AUC: 0.9584
#
# --- Processing: fc_all_bands ---
# Shape: (190, 1026)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5922, Train Acc: 0.5234 |
# Epoch [2/200] | Train Loss: 0.5257, Train Acc: 0.7109 |
# Epoch [3/200] | Train Loss: 0.5201, Train Acc: 0.6953 |
# Epoch [4/200] | Train Loss: 0.4546, Train Acc: 0.7812 |
# Epoch [5/200] | Train Loss: 0.4292, Train Acc: 0.8125 |
# Epoch [6/200] | Train Loss: 0.3788, Train Acc: 0.8594 |
# Epoch [7/200] | Train Loss: 0.3315, Train Acc: 0.8750 |
# Epoch [8/200] | Train Loss: 0.3014, Train Acc: 0.9062 |
# Epoch [9/200] | Train Loss: 0.2445, Train Acc: 0.9453 |
# Epoch [10/200] | Train Loss: 0.2318, Train Acc: 0.8984 |
# Epoch [11/200] | Train Loss: 0.2095, Train Acc: 0.8984 |
# Epoch [12/200] | Train Loss: 0.1458, Train Acc: 0.9609 |
# Epoch [13/200] | Train Loss: 0.1619, Train Acc: 0.9453 |
# Epoch [14/200] | Train Loss: 0.1411, Train Acc: 0.9609 |
# Epoch [15/200] | Train Loss: 0.0946, Train Acc: 0.9922 |
# Epoch [16/200] | Train Loss: 0.1254, Train Acc: 0.9609 |
# Epoch [17/200] | Train Loss: 0.0920, Train Acc: 0.9688 |
# Epoch [18/200] | Train Loss: 0.0816, Train Acc: 0.9844 |
# Epoch [19/200] | Train Loss: 0.0495, Train Acc: 0.9922 |
# Epoch [20/200] | Train Loss: 0.0700, Train Acc: 0.9844 |
# Epoch [21/200] | Train Loss: 0.0368, Train Acc: 1.0000 |
# Epoch [22/200] | Train Loss: 0.0823, Train Acc: 0.9453 |
# Epoch [23/200] | Train Loss: 0.0285, Train Acc: 0.9922 |
# Epoch [24/200] | Train Loss: 0.0286, Train Acc: 0.9922 |
# Epoch [25/200] | Train Loss: 0.0489, Train Acc: 0.9844 |
# Epoch [26/200] | Train Loss: 0.0456, Train Acc: 0.9688 |
# Epoch [27/200] | Train Loss: 0.0354, Train Acc: 0.9766 |
# Epoch [28/200] | Train Loss: 0.0263, Train Acc: 0.9922 |
# Epoch [29/200] | Train Loss: 0.0593, Train Acc: 0.9844 |
# Epoch [30/200] | Train Loss: 0.0309, Train Acc: 0.9922 |
# Epoch [31/200] | Train Loss: 0.0636, Train Acc: 0.9766 |
# Epoch [32/200] | Train Loss: 0.0300, Train Acc: 0.9844 |
# Early stopping triggered.
# Test Loss: 0.5497, Test Accuracy: 0.8158, Test AUC: 0.9529
#
# --- Processing: psd_fc_all_bands ---
# Shape: (190, 1140)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.6000, Train Acc: 0.5156 |
# Epoch [2/200] | Train Loss: 0.5522, Train Acc: 0.6484 |
# Epoch [3/200] | Train Loss: 0.5297, Train Acc: 0.6797 |
# Epoch [4/200] | Train Loss: 0.4866, Train Acc: 0.7578 |
# Epoch [5/200] | Train Loss: 0.4618, Train Acc: 0.8203 |
# Epoch [6/200] | Train Loss: 0.4326, Train Acc: 0.8047 |
# Epoch [7/200] | Train Loss: 0.3782, Train Acc: 0.8516 |
# Epoch [8/200] | Train Loss: 0.2937, Train Acc: 0.9141 |
# Epoch [9/200] | Train Loss: 0.3013, Train Acc: 0.8750 |
# Epoch [10/200] | Train Loss: 0.2422, Train Acc: 0.9062 |
# Epoch [11/200] | Train Loss: 0.2049, Train Acc: 0.9453 |
# Epoch [12/200] | Train Loss: 0.1947, Train Acc: 0.9453 |
# Epoch [13/200] | Train Loss: 0.1483, Train Acc: 0.9609 |
# Epoch [14/200] | Train Loss: 0.1208, Train Acc: 0.9844 |
# Epoch [15/200] | Train Loss: 0.1097, Train Acc: 0.9766 |
# Epoch [16/200] | Train Loss: 0.0769, Train Acc: 0.9922 |
# Epoch [17/200] | Train Loss: 0.1274, Train Acc: 0.9531 |
# Epoch [18/200] | Train Loss: 0.0472, Train Acc: 1.0000 |
# Epoch [19/200] | Train Loss: 0.0955, Train Acc: 0.9609 |
# Epoch [20/200] | Train Loss: 0.1309, Train Acc: 0.9375 |
# Epoch [21/200] | Train Loss: 0.0938, Train Acc: 0.9453 |
# Epoch [22/200] | Train Loss: 0.0362, Train Acc: 1.0000 |
# Epoch [23/200] | Train Loss: 0.0927, Train Acc: 0.9453 |
# Epoch [24/200] | Train Loss: 0.0316, Train Acc: 0.9922 |
# Epoch [25/200] | Train Loss: 0.1093, Train Acc: 0.9609 |
# Epoch [26/200] | Train Loss: 0.0556, Train Acc: 0.9766 |
# Epoch [27/200] | Train Loss: 0.0374, Train Acc: 0.9844 |
# Epoch [28/200] | Train Loss: 0.0212, Train Acc: 1.0000 |
# Epoch [29/200] | Train Loss: 0.0499, Train Acc: 0.9844 |
# Epoch [30/200] | Train Loss: 0.0407, Train Acc: 0.9922 |
# Epoch [31/200] | Train Loss: 0.0365, Train Acc: 0.9844 |
# Epoch [32/200] | Train Loss: 0.0229, Train Acc: 0.9922 |
# Early stopping triggered.
# Test Loss: 0.2020, Test Accuracy: 0.8684, Test AUC: 0.9806
#
# --- Processing: psd_delta ---
# Shape: (190, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5656, Train Acc: 0.5078 |
# Epoch [2/200] | Train Loss: 0.4625, Train Acc: 0.8281 |
# Epoch [3/200] | Train Loss: 0.4327, Train Acc: 0.8359 |
# Epoch [4/200] | Train Loss: 0.3623, Train Acc: 0.9297 |
# Epoch [5/200] | Train Loss: 0.3323, Train Acc: 0.9062 |
# Epoch [6/200] | Train Loss: 0.2790, Train Acc: 0.9375 |
# Epoch [7/200] | Train Loss: 0.2760, Train Acc: 0.8984 |
# Epoch [8/200] | Train Loss: 0.2181, Train Acc: 0.9688 |
# Epoch [9/200] | Train Loss: 0.2535, Train Acc: 0.8828 |
# Epoch [10/200] | Train Loss: 0.1996, Train Acc: 0.9141 |
# Epoch [11/200] | Train Loss: 0.1431, Train Acc: 0.9609 |
# Epoch [12/200] | Train Loss: 0.1468, Train Acc: 0.9609 |
# Epoch [13/200] | Train Loss: 0.1577, Train Acc: 0.9453 |
# Epoch [14/200] | Train Loss: 0.1306, Train Acc: 0.9609 |
# Epoch [15/200] | Train Loss: 0.1069, Train Acc: 0.9688 |
# Epoch [16/200] | Train Loss: 0.0851, Train Acc: 0.9609 |
# Epoch [17/200] | Train Loss: 0.0840, Train Acc: 0.9766 |
# Epoch [18/200] | Train Loss: 0.0937, Train Acc: 0.9766 |
# Epoch [19/200] | Train Loss: 0.1154, Train Acc: 0.9609 |
# Epoch [20/200] | Train Loss: 0.0652, Train Acc: 0.9922 |
# Epoch [21/200] | Train Loss: 0.0552, Train Acc: 0.9844 |
# Epoch [22/200] | Train Loss: 0.0716, Train Acc: 0.9766 |
# Epoch [23/200] | Train Loss: 0.0526, Train Acc: 0.9766 |
# Epoch [24/200] | Train Loss: 0.0843, Train Acc: 0.9766 |
# Epoch [25/200] | Train Loss: 0.0424, Train Acc: 0.9844 |
# Epoch [26/200] | Train Loss: 0.0342, Train Acc: 0.9922 |
# Epoch [27/200] | Train Loss: 0.0259, Train Acc: 1.0000 |
# Epoch [28/200] | Train Loss: 0.0452, Train Acc: 0.9688 |
# Epoch [29/200] | Train Loss: 0.0524, Train Acc: 0.9688 |
# Epoch [30/200] | Train Loss: 0.0228, Train Acc: 1.0000 |
# Epoch [31/200] | Train Loss: 0.1125, Train Acc: 0.9297 |
# Epoch [32/200] | Train Loss: 0.0622, Train Acc: 0.9688 |
# Epoch [33/200] | Train Loss: 0.0200, Train Acc: 1.0000 |
# Epoch [34/200] | Train Loss: 0.0961, Train Acc: 0.9609 |
# Epoch [35/200] | Train Loss: 0.0583, Train Acc: 0.9766 |
# Epoch [36/200] | Train Loss: 0.0518, Train Acc: 0.9766 |
# Epoch [37/200] | Train Loss: 0.0482, Train Acc: 0.9844 |
# Early stopping triggered.
# Test Loss: 0.5901, Test Accuracy: 0.8684, Test AUC: 0.9307
#
# --- Processing: psd_theta ---
# Shape: (190, 19)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5633, Train Acc: 0.5625 |
# Epoch [2/200] | Train Loss: 0.5194, Train Acc: 0.7422 |
# Epoch [3/200] | Train Loss: 0.4565, Train Acc: 0.7891 |
# Epoch [4/200] | Train Loss: 0.4000, Train Acc: 0.8672 |
# Epoch [5/200] | Train Loss: 0.4011, Train Acc: 0.8438 |
# Epoch [6/200] | Train Loss: 0.3357, Train Acc: 0.8906 |
# Epoch [7/200] | Train Loss: 0.3152, Train Acc: 0.8906 |
# Epoch [8/200] | Train Loss: 0.2648, Train Acc: 0.9062 |
# Epoch [9/200] | Train Loss: 0.2261, Train Acc: 0.9453 |
# Epoch [10/200] | Train Loss: 0.2384, Train Acc: 0.9062 |
# Epoch [11/200] | Train Loss: 0.1802, Train Acc: 0.9609 |
# Epoch [12/200] | Train Loss: 0.1693, Train Acc: 0.9375 |
# Epoch [13/200] | Train Loss: 0.1661, Train Acc: 0.8984 |
# Epoch [14/200] | Train Loss: 0.1418, Train Acc: 0.9531 |
# Epoch [15/200] | Train Loss: 0.1349, Train Acc: 0.9766 |
# Epoch [16/200] | Train Loss: 0.1638, Train Acc: 0.9219 |
# Epoch [17/200] | Train Loss: 0.1091, Train Acc: 0.9531 |
# Epoch [18/200] | Train Loss: 0.1182, Train Acc: 0.9531 |
# Epoch [19/200] | Train Loss: 0.1375, Train Acc: 0.9375 |
# Epoch [20/200] | Train Loss: 0.1425, Train Acc: 0.9453 |
# Epoch [21/200] | Train Loss: 0.1041, Train Acc: 0.9609 |
# Epoch [22/200] | Train Loss: 0.0986, Train Acc: 0.9375 |
# Epoch [23/200] | Train Loss: 0.0792, Train Acc: 0.9766 |
# Epoch [24/200] | Train Loss: 0.0819, Train Acc: 0.9688 |
# Epoch [25/200] | Train Loss: 0.0699, Train Acc: 0.9844 |
# Epoch [26/200] | Train Loss: 0.1365, Train Acc: 0.9141 |
# Epoch [27/200] | Train Loss: 0.0870, Train Acc: 0.9609 |
# Epoch [28/200] | Train Loss: 0.2008, Train Acc: 0.9219 |
# Epoch [29/200] | Train Loss: 0.0648, Train Acc: 0.9609 |
# Epoch [30/200] | Train Loss: 0.0593, Train Acc: 0.9766 |
# Epoch [31/200] | Train Loss: 0.0769, Train Acc: 0.9766 |
# Epoch [32/200] | Train Loss: 0.0837, Train Acc: 0.9688 |
# ...
# Epoch [18/200] | Train Loss: 0.1168, Train Acc: 0.9609 |
# Epoch [19/200] | Train Loss: 0.0779, Train Acc: 0.9844 |
# Epoch [20/200] | Train Loss: 0.1378, Train Acc: 0.9219 |
# Epoch [21/200] | Train Loss: 0.0866, Train Acc: 0.9688 |
# Epoch [22/200] | Train Loss: 0.0795, Train Acc: 0.9688 |
# Epoch [23/200] | Train Loss: 0.1295, Train Acc: 0.9453 |
# Early stopping triggered.
# Test Loss: 0.4429, Test Accuracy: 0.8421, Test AUC: 0.9252
#
# --- Processing: fc_highbeta ---
# Shape: (190, 171)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5983, Train Acc: 0.5078 |
# Epoch [2/200] | Train Loss: 0.5424, Train Acc: 0.6406 |
# Epoch [3/200] | Train Loss: 0.5384, Train Acc: 0.6250 |
# Epoch [4/200] | Train Loss: 0.4706, Train Acc: 0.7891 |
# Epoch [5/200] | Train Loss: 0.4449, Train Acc: 0.7891 |
# Epoch [6/200] | Train Loss: 0.4003, Train Acc: 0.8672 |
# Epoch [7/200] | Train Loss: 0.3740, Train Acc: 0.8516 |
# Epoch [8/200] | Train Loss: 0.3611, Train Acc: 0.8359 |
# Epoch [9/200] | Train Loss: 0.3854, Train Acc: 0.7812 |
# Epoch [10/200] | Train Loss: 0.2597, Train Acc: 0.9219 |
# Epoch [11/200] | Train Loss: 0.2639, Train Acc: 0.8672 |
# Epoch [12/200] | Train Loss: 0.2381, Train Acc: 0.9219 |
# Epoch [13/200] | Train Loss: 0.1895, Train Acc: 0.9453 |
# Epoch [14/200] | Train Loss: 0.1996, Train Acc: 0.9062 |
# Epoch [15/200] | Train Loss: 0.2091, Train Acc: 0.9141 |
# Epoch [16/200] | Train Loss: 0.1655, Train Acc: 0.9141 |
# Epoch [17/200] | Train Loss: 0.1678, Train Acc: 0.9297 |
# Epoch [18/200] | Train Loss: 0.1691, Train Acc: 0.8984 |
# Epoch [19/200] | Train Loss: 0.1633, Train Acc: 0.9141 |
# Epoch [20/200] | Train Loss: 0.1317, Train Acc: 0.9375 |
# Epoch [21/200] | Train Loss: 0.0937, Train Acc: 0.9531 |
# Epoch [22/200] | Train Loss: 0.1588, Train Acc: 0.9219 |
# Epoch [23/200] | Train Loss: 0.1066, Train Acc: 0.9375 |
# Epoch [24/200] | Train Loss: 0.1014, Train Acc: 0.9531 |
# Epoch [25/200] | Train Loss: 0.1252, Train Acc: 0.9297 |
# Early stopping triggered.
# Test Loss: 0.4952, Test Accuracy: 0.7895, Test AUC: 0.8947
#
# --- Processing: fc_gamma ---
# Shape: (190, 171)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5840, Train Acc: 0.5859 |
# Epoch [2/200] | Train Loss: 0.5483, Train Acc: 0.6641 |
# Epoch [3/200] | Train Loss: 0.5392, Train Acc: 0.6719 |
# Epoch [4/200] | Train Loss: 0.5143, Train Acc: 0.6484 |
# Epoch [5/200] | Train Loss: 0.4910, Train Acc: 0.6719 |
# Epoch [6/200] | Train Loss: 0.4339, Train Acc: 0.7969 |
# Epoch [7/200] | Train Loss: 0.4418, Train Acc: 0.7969 |
# Epoch [8/200] | Train Loss: 0.3610, Train Acc: 0.8672 |
# Epoch [9/200] | Train Loss: 0.3328, Train Acc: 0.8516 |
# Epoch [10/200] | Train Loss: 0.2953, Train Acc: 0.8906 |
# Epoch [11/200] | Train Loss: 0.2708, Train Acc: 0.9375 |
# Epoch [12/200] | Train Loss: 0.2578, Train Acc: 0.9141 |
# Epoch [13/200] | Train Loss: 0.2128, Train Acc: 0.9375 |
# Epoch [14/200] | Train Loss: 0.1974, Train Acc: 0.9375 |
# Epoch [15/200] | Train Loss: 0.1692, Train Acc: 0.9219 |
# Epoch [16/200] | Train Loss: 0.1629, Train Acc: 0.9297 |
# Epoch [17/200] | Train Loss: 0.2051, Train Acc: 0.9062 |
# Epoch [18/200] | Train Loss: 0.1648, Train Acc: 0.8984 |
# Epoch [19/200] | Train Loss: 0.2411, Train Acc: 0.9141 |
# Epoch [20/200] | Train Loss: 0.1937, Train Acc: 0.9219 |
# Epoch [21/200] | Train Loss: 0.1527, Train Acc: 0.9375 |
# Epoch [22/200] | Train Loss: 0.1189, Train Acc: 0.9609 |
# Epoch [23/200] | Train Loss: 0.1307, Train Acc: 0.9297 |
# Epoch [24/200] | Train Loss: 0.2072, Train Acc: 0.8906 |
# Epoch [25/200] | Train Loss: 0.1582, Train Acc: 0.9297 |
# Epoch [26/200] | Train Loss: 0.1003, Train Acc: 0.9688 |
# Epoch [27/200] | Train Loss: 0.1275, Train Acc: 0.9531 |
# Epoch [28/200] | Train Loss: 0.1247, Train Acc: 0.9375 |
# Epoch [29/200] | Train Loss: 0.1026, Train Acc: 0.9688 |
# Epoch [30/200] | Train Loss: 0.1122, Train Acc: 0.9531 |
# Epoch [31/200] | Train Loss: 0.0815, Train Acc: 0.9609 |
# Epoch [32/200] | Train Loss: 0.1041, Train Acc: 0.9453 |
# Epoch [33/200] | Train Loss: 0.0726, Train Acc: 0.9922 |
# Epoch [34/200] | Train Loss: 0.0934, Train Acc: 0.9609 |
# Epoch [35/200] | Train Loss: 0.0682, Train Acc: 0.9766 |
# Epoch [36/200] | Train Loss: 0.0588, Train Acc: 0.9766 |
# Epoch [37/200] | Train Loss: 0.0661, Train Acc: 0.9766 |
# Epoch [38/200] | Train Loss: 0.0561, Train Acc: 0.9688 |
# Epoch [39/200] | Train Loss: 0.0577, Train Acc: 0.9688 |
# Epoch [40/200] | Train Loss: 0.1056, Train Acc: 0.9531 |
# Epoch [41/200] | Train Loss: 0.1123, Train Acc: 0.9688 |
# Epoch [42/200] | Train Loss: 0.0900, Train Acc: 0.9766 |
# Early stopping triggered.
# Test Loss: 0.4899, Test Accuracy: 0.7895, Test AUC: 0.9169
#
# --- Processing: psd_fc_delta ---
# Shape: (190, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5521, Train Acc: 0.5859 |
# Epoch [2/200] | Train Loss: 0.4893, Train Acc: 0.7109 |
# Epoch [3/200] | Train Loss: 0.4458, Train Acc: 0.7578 |
# Epoch [4/200] | Train Loss: 0.4105, Train Acc: 0.8125 |
# Epoch [5/200] | Train Loss: 0.3562, Train Acc: 0.8594 |
# Epoch [6/200] | Train Loss: 0.3280, Train Acc: 0.8594 |
# Epoch [7/200] | Train Loss: 0.2803, Train Acc: 0.9062 |
# Epoch [8/200] | Train Loss: 0.2522, Train Acc: 0.9219 |
# Epoch [9/200] | Train Loss: 0.2170, Train Acc: 0.9219 |
# Epoch [10/200] | Train Loss: 0.1713, Train Acc: 0.9688 |
# Epoch [11/200] | Train Loss: 0.1887, Train Acc: 0.9297 |
# Epoch [12/200] | Train Loss: 0.1309, Train Acc: 0.9766 |
# Epoch [13/200] | Train Loss: 0.1368, Train Acc: 0.9453 |
# Epoch [14/200] | Train Loss: 0.0813, Train Acc: 0.9844 |
# Epoch [15/200] | Train Loss: 0.1209, Train Acc: 0.9531 |
# Epoch [16/200] | Train Loss: 0.0790, Train Acc: 0.9766 |
# Epoch [17/200] | Train Loss: 0.2110, Train Acc: 0.9219 |
# Epoch [18/200] | Train Loss: 0.1163, Train Acc: 0.9688 |
# Epoch [19/200] | Train Loss: 0.1251, Train Acc: 0.9531 |
# Epoch [20/200] | Train Loss: 0.0514, Train Acc: 0.9922 |
# Epoch [21/200] | Train Loss: 0.0656, Train Acc: 0.9766 |
# Epoch [22/200] | Train Loss: 0.1060, Train Acc: 0.9453 |
# Epoch [23/200] | Train Loss: 0.0716, Train Acc: 0.9688 |
# Epoch [24/200] | Train Loss: 0.0421, Train Acc: 0.9844 |
# Epoch [25/200] | Train Loss: 0.0780, Train Acc: 0.9766 |
# Epoch [26/200] | Train Loss: 0.0531, Train Acc: 0.9766 |
# Epoch [27/200] | Train Loss: 0.0510, Train Acc: 0.9844 |
# Epoch [28/200] | Train Loss: 0.0396, Train Acc: 0.9844 |
# Epoch [29/200] | Train Loss: 0.0408, Train Acc: 0.9844 |
# Epoch [30/200] | Train Loss: 0.0457, Train Acc: 0.9766 |
# Epoch [31/200] | Train Loss: 0.0233, Train Acc: 0.9922 |
# Epoch [32/200] | Train Loss: 0.0454, Train Acc: 0.9766 |
# Epoch [33/200] | Train Loss: 0.0552, Train Acc: 0.9609 |
# Epoch [34/200] | Train Loss: 0.0235, Train Acc: 0.9922 |
# Epoch [35/200] | Train Loss: 0.0303, Train Acc: 0.9922 |
# Early stopping triggered.
# Test Loss: 0.7711, Test Accuracy: 0.7895, Test AUC: 0.8615
#
# --- Processing: psd_fc_theta ---
# Shape: (190, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5796, Train Acc: 0.5938 |
# Epoch [2/200] | Train Loss: 0.5206, Train Acc: 0.7500 |
# Epoch [3/200] | Train Loss: 0.4977, Train Acc: 0.7578 |
# Epoch [4/200] | Train Loss: 0.4531, Train Acc: 0.8125 |
# Epoch [5/200] | Train Loss: 0.4103, Train Acc: 0.8281 |
# Epoch [6/200] | Train Loss: 0.3640, Train Acc: 0.8672 |
# Epoch [7/200] | Train Loss: 0.3611, Train Acc: 0.8594 |
# Epoch [8/200] | Train Loss: 0.2945, Train Acc: 0.9141 |
# Epoch [9/200] | Train Loss: 0.2637, Train Acc: 0.9375 |
# Epoch [10/200] | Train Loss: 0.2138, Train Acc: 0.9766 |
# Epoch [11/200] | Train Loss: 0.2174, Train Acc: 0.9297 |
# Epoch [12/200] | Train Loss: 0.1628, Train Acc: 0.9297 |
# Epoch [13/200] | Train Loss: 0.1794, Train Acc: 0.9219 |
# Epoch [14/200] | Train Loss: 0.1293, Train Acc: 0.9609 |
# Epoch [15/200] | Train Loss: 0.1306, Train Acc: 0.9609 |
# Epoch [16/200] | Train Loss: 0.0902, Train Acc: 0.9766 |
# Epoch [17/200] | Train Loss: 0.0856, Train Acc: 0.9766 |
# Epoch [18/200] | Train Loss: 0.0788, Train Acc: 0.9844 |
# Epoch [19/200] | Train Loss: 0.0867, Train Acc: 0.9688 |
# Epoch [20/200] | Train Loss: 0.0840, Train Acc: 0.9609 |
# Epoch [21/200] | Train Loss: 0.0803, Train Acc: 0.9609 |
# Epoch [22/200] | Train Loss: 0.0807, Train Acc: 0.9688 |
# Epoch [23/200] | Train Loss: 0.0663, Train Acc: 0.9766 |
# Epoch [24/200] | Train Loss: 0.0533, Train Acc: 0.9766 |
# Epoch [25/200] | Train Loss: 0.0769, Train Acc: 0.9766 |
# Epoch [26/200] | Train Loss: 0.0312, Train Acc: 0.9922 |
# Epoch [27/200] | Train Loss: 0.0318, Train Acc: 0.9844 |
# Epoch [28/200] | Train Loss: 0.0226, Train Acc: 1.0000 |
# Epoch [29/200] | Train Loss: 0.0746, Train Acc: 0.9688 |
# Epoch [30/200] | Train Loss: 0.1553, Train Acc: 0.9375 |
# Epoch [31/200] | Train Loss: 0.0493, Train Acc: 0.9766 |
# Epoch [32/200] | Train Loss: 0.0387, Train Acc: 0.9766 |
# Early stopping triggered.
# Test Loss: 0.5482, Test Accuracy: 0.8158, Test AUC: 0.9058
#
# --- Processing: psd_fc_alpha ---
# Shape: (190, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5894, Train Acc: 0.5156 |
# Epoch [2/200] | Train Loss: 0.5596, Train Acc: 0.6484 |
# Epoch [3/200] | Train Loss: 0.4979, Train Acc: 0.7031 |
# Epoch [4/200] | Train Loss: 0.4740, Train Acc: 0.7422 |
# Epoch [5/200] | Train Loss: 0.4285, Train Acc: 0.8438 |
# Epoch [6/200] | Train Loss: 0.3977, Train Acc: 0.8516 |
# Epoch [7/200] | Train Loss: 0.3303, Train Acc: 0.8906 |
# Epoch [8/200] | Train Loss: 0.3144, Train Acc: 0.9062 |
# Epoch [9/200] | Train Loss: 0.2793, Train Acc: 0.9297 |
# Epoch [10/200] | Train Loss: 0.2343, Train Acc: 0.9141 |
# Epoch [11/200] | Train Loss: 0.1904, Train Acc: 0.9531 |
# Epoch [12/200] | Train Loss: 0.1602, Train Acc: 0.9609 |
# Epoch [13/200] | Train Loss: 0.1424, Train Acc: 0.9766 |
# Epoch [14/200] | Train Loss: 0.1500, Train Acc: 0.9688 |
# Epoch [15/200] | Train Loss: 0.0990, Train Acc: 0.9766 |
# Epoch [16/200] | Train Loss: 0.1375, Train Acc: 0.9453 |
# Epoch [17/200] | Train Loss: 0.0917, Train Acc: 0.9844 |
# Epoch [18/200] | Train Loss: 0.1230, Train Acc: 0.9453 |
# Epoch [19/200] | Train Loss: 0.0952, Train Acc: 0.9531 |
# Epoch [20/200] | Train Loss: 0.1447, Train Acc: 0.9141 |
# Epoch [21/200] | Train Loss: 0.0661, Train Acc: 0.9844 |
# Epoch [22/200] | Train Loss: 0.0712, Train Acc: 0.9844 |
# Epoch [23/200] | Train Loss: 0.0952, Train Acc: 0.9766 |
# Epoch [24/200] | Train Loss: 0.0672, Train Acc: 0.9844 |
# Epoch [25/200] | Train Loss: 0.0517, Train Acc: 0.9844 |
# Epoch [26/200] | Train Loss: 0.0377, Train Acc: 0.9922 |
# Epoch [27/200] | Train Loss: 0.0503, Train Acc: 0.9766 |
# Epoch [28/200] | Train Loss: 0.0616, Train Acc: 0.9531 |
# Epoch [29/200] | Train Loss: 0.0482, Train Acc: 0.9766 |
# Epoch [30/200] | Train Loss: 0.0288, Train Acc: 0.9922 |
# Epoch [31/200] | Train Loss: 0.0701, Train Acc: 0.9609 |
# Epoch [32/200] | Train Loss: 0.0934, Train Acc: 0.9609 |
# Epoch [33/200] | Train Loss: 0.0470, Train Acc: 0.9766 |
# Epoch [34/200] | Train Loss: 0.0531, Train Acc: 0.9766 |
# Epoch [35/200] | Train Loss: 0.0231, Train Acc: 0.9922 |
# Epoch [36/200] | Train Loss: 0.0251, Train Acc: 0.9844 |
# Epoch [37/200] | Train Loss: 0.0298, Train Acc: 0.9922 |
# Epoch [38/200] | Train Loss: 0.0365, Train Acc: 0.9922 |
# Epoch [39/200] | Train Loss: 0.0444, Train Acc: 0.9688 |
# Early stopping triggered.
# Test Loss: 0.7896, Test Accuracy: 0.7632, Test AUC: 0.8532
#
# --- Processing: psd_fc_beta ---
# Shape: (190, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5817, Train Acc: 0.5312 |
# Epoch [2/200] | Train Loss: 0.5479, Train Acc: 0.5703 |
# Epoch [3/200] | Train Loss: 0.5016, Train Acc: 0.7500 |
# Epoch [4/200] | Train Loss: 0.4831, Train Acc: 0.7422 |
# Epoch [5/200] | Train Loss: 0.4148, Train Acc: 0.8281 |
# Epoch [6/200] | Train Loss: 0.3767, Train Acc: 0.8750 |
# Epoch [7/200] | Train Loss: 0.3524, Train Acc: 0.8516 |
# Epoch [8/200] | Train Loss: 0.2945, Train Acc: 0.9062 |
# Epoch [9/200] | Train Loss: 0.2633, Train Acc: 0.9141 |
# Epoch [10/200] | Train Loss: 0.2393, Train Acc: 0.9375 |
# Epoch [11/200] | Train Loss: 0.1908, Train Acc: 0.9297 |
# Epoch [12/200] | Train Loss: 0.1891, Train Acc: 0.9453 |
# Epoch [13/200] | Train Loss: 0.1337, Train Acc: 0.9688 |
# Epoch [14/200] | Train Loss: 0.1316, Train Acc: 0.9688 |
# Epoch [15/200] | Train Loss: 0.1150, Train Acc: 0.9766 |
# Epoch [16/200] | Train Loss: 0.1781, Train Acc: 0.9141 |
# Epoch [17/200] | Train Loss: 0.1074, Train Acc: 0.9766 |
# Epoch [18/200] | Train Loss: 0.0947, Train Acc: 0.9531 |
# Epoch [19/200] | Train Loss: 0.0720, Train Acc: 0.9766 |
# Epoch [20/200] | Train Loss: 0.0755, Train Acc: 0.9766 |
# Epoch [21/200] | Train Loss: 0.0570, Train Acc: 0.9844 |
# Epoch [22/200] | Train Loss: 0.0806, Train Acc: 0.9609 |
# Epoch [23/200] | Train Loss: 0.1135, Train Acc: 0.9531 |
# Epoch [24/200] | Train Loss: 0.0770, Train Acc: 0.9766 |
# Epoch [25/200] | Train Loss: 0.0920, Train Acc: 0.9375 |
# Epoch [26/200] | Train Loss: 0.0402, Train Acc: 0.9844 |
# Epoch [27/200] | Train Loss: 0.0903, Train Acc: 0.9766 |
# Epoch [28/200] | Train Loss: 0.0405, Train Acc: 0.9844 |
# Epoch [29/200] | Train Loss: 0.0453, Train Acc: 0.9844 |
# Epoch [30/200] | Train Loss: 0.0513, Train Acc: 0.9844 |
# Early stopping triggered.
# Test Loss: 0.6473, Test Accuracy: 0.7632, Test AUC: 0.8781
#
# --- Processing: psd_fc_highbeta ---
# Shape: (190, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5918, Train Acc: 0.4922 |
# Epoch [2/200] | Train Loss: 0.5594, Train Acc: 0.6406 |
# Epoch [3/200] | Train Loss: 0.5193, Train Acc: 0.6953 |
# Epoch [4/200] | Train Loss: 0.4744, Train Acc: 0.7812 |
# Epoch [5/200] | Train Loss: 0.4632, Train Acc: 0.7500 |
# Epoch [6/200] | Train Loss: 0.4537, Train Acc: 0.7578 |
# Epoch [7/200] | Train Loss: 0.3750, Train Acc: 0.8438 |
# Epoch [8/200] | Train Loss: 0.3362, Train Acc: 0.8750 |
# Epoch [9/200] | Train Loss: 0.3509, Train Acc: 0.8594 |
# Epoch [10/200] | Train Loss: 0.2942, Train Acc: 0.8984 |
# Epoch [11/200] | Train Loss: 0.2567, Train Acc: 0.8984 |
# Epoch [12/200] | Train Loss: 0.2355, Train Acc: 0.8984 |
# Epoch [13/200] | Train Loss: 0.2082, Train Acc: 0.9297 |
# Epoch [14/200] | Train Loss: 0.1967, Train Acc: 0.9297 |
# Epoch [15/200] | Train Loss: 0.1856, Train Acc: 0.9141 |
# Epoch [16/200] | Train Loss: 0.1867, Train Acc: 0.9062 |
# Epoch [17/200] | Train Loss: 0.1595, Train Acc: 0.9375 |
# Epoch [18/200] | Train Loss: 0.1202, Train Acc: 0.9609 |
# Epoch [19/200] | Train Loss: 0.1664, Train Acc: 0.9141 |
# Epoch [20/200] | Train Loss: 0.1379, Train Acc: 0.9375 |
# Epoch [21/200] | Train Loss: 0.1418, Train Acc: 0.9531 |
# Epoch [22/200] | Train Loss: 0.1397, Train Acc: 0.9141 |
# Early stopping triggered.
# Test Loss: 0.6473, Test Accuracy: 0.7632, Test AUC: 0.7950
#
# --- Processing: psd_fc_gamma ---
# Shape: (190, 190)
# Missing values: 0
# Epoch [1/200] | Train Loss: 0.5898, Train Acc: 0.5547 |
# Epoch [2/200] | Train Loss: 0.5583, Train Acc: 0.6406 |
# Epoch [3/200] | Train Loss: 0.5586, Train Acc: 0.6719 |
# Epoch [4/200] | Train Loss: 0.4883, Train Acc: 0.7812 |
# Epoch [5/200] | Train Loss: 0.4557, Train Acc: 0.7969 |
# Epoch [6/200] | Train Loss: 0.4234, Train Acc: 0.7891 |
# Epoch [7/200] | Train Loss: 0.3822, Train Acc: 0.7891 |
# Epoch [8/200] | Train Loss: 0.3534, Train Acc: 0.8359 |
# Epoch [9/200] | Train Loss: 0.3085, Train Acc: 0.8984 |
# Epoch [10/200] | Train Loss: 0.2943, Train Acc: 0.8906 |
# Epoch [11/200] | Train Loss: 0.2606, Train Acc: 0.9062 |
# Epoch [12/200] | Train Loss: 0.2533, Train Acc: 0.8828 |
# Epoch [13/200] | Train Loss: 0.2299, Train Acc: 0.9062 |
# Epoch [14/200] | Train Loss: 0.1870, Train Acc: 0.9453 |
# Epoch [15/200] | Train Loss: 0.1527, Train Acc: 0.9609 |
# Epoch [16/200] | Train Loss: 0.1382, Train Acc: 0.9766 |
# Epoch [17/200] | Train Loss: 0.1229, Train Acc: 0.9766 |
# Epoch [18/200] | Train Loss: 0.1334, Train Acc: 0.9609 |
# Epoch [19/200] | Train Loss: 0.0934, Train Acc: 0.9844 |
# Epoch [20/200] | Train Loss: 0.1225, Train Acc: 0.9531 |
# Epoch [21/200] | Train Loss: 0.0953, Train Acc: 0.9453 |
# Epoch [22/200] | Train Loss: 0.1018, Train Acc: 0.9609 |
# Epoch [23/200] | Train Loss: 0.0996, Train Acc: 0.9531 |
# Early stopping triggered.
# Test Loss: 0.8672, Test Accuracy: 0.7632, Test AUC: 0.8393

# %% [markdown]
# ## | 6. Results

# %%
rows = []

for disorder, dicts in all_results.items():
    for dict_name, df_results in dicts.items():
        for df_name, metrics in df_results.items():
            row = {
                'Disorder': disorder,
                'Dict': dict_name,
                'DataFrame': df_name,
                'Accuracy': metrics['accuracy'],
                'AUC': metrics['auc'],
                'Classification Report': metrics['classification_report']
            }
            
            rows.append(row)

results_df = pd.DataFrame(rows)
results_df.to_csv(f'{experiment_name}.csv', index=False)

# best_results = df.loc[df.groupby('Disorder')['Accuracy'].idxmax()]

# %% [markdown]
# ## | 7. Conclusions, Problems, and Limitations

# %% [markdown]
# [need to update]
